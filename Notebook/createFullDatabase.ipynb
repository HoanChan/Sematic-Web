# %% [markdown]
# ### Cài đặt thư viện:
#
# Cài đặt các thư viện vào môi trường anaconda:
#
# ```bash
# conda install -c conda-forge owlready2
# ```

# %% [markdown]
# ### Tạo ontology

# %%
from owlready2 import *

# Tạo ontology
onto = get_ontology("http://hc.com/school")
with onto:
    class ChucVu(Thing): pass
    class ToChuc(Thing): pass
    class Nguoi(Thing): pass
    class NhanVien(Nguoi): pass
    class PhuHuynh(Nguoi): pass
    class LopHoc(ToChuc):
        def __str__(self):
            return ' - '.join([self.ten, getattr(self.giaoVienChuNhiem,'hoTen',''), getattr(self.phongHoc,'ten','')])
    class HocSinh(Nguoi): 
        def __str__(self):
            return ' - '.join([self.hoTen, self.ngaySinh, self.gioiTinh, getattr(self.hocLop,'ten','')])
    class GiaoVien(NhanVien): 
        def __str__(self):
            return ' - '.join([self.hoTen, self.ngaySinh, self.gioiTinh, self.trinhDo, [mon.ten for mon in self.dayMon], getattr(self.lopChuNhiem,'ten','')])
    class MonHoc(Thing): pass
    class DiemSo(Thing): pass
    class TheDocGia(Thing): pass
    class TacGia(Thing): pass
    class NhaXuatBan(Thing): pass
    class Sach(Thing): pass
    class TheLoai(Thing): pass
    class PhieuMuon(Thing): pass
    class Phong(Thing): pass
    class HoatDong(Thing): pass
    class DiemDanh(Thing): pass
    
    # -------- Các thuộc tính của Đối tượng -------- #
    # InverseFunctionalProperty: Giống khoá chính trong SQL, không được trùng
    # FunctionalProperty: chỉ nhận 1 giá trị duy nhất (Không thể có tên)
    class ten(DatatypeProperty, FunctionalProperty):
        domain = [ChucVu, ToChuc, LopHoc, MonHoc, NhaXuatBan, Sach, TheLoai, Phong, HoatDong]
        range = [str]
    class moTa(ObjectProperty, FunctionalProperty): 
        domain = [ChucVu, MonHoc, Phong, TheLoai, HoatDong]
        range = [str]
    # -------- Các thuộc tính của Chức vụ -------- #
    class phuCap(ChucVu >> int, FunctionalProperty): pass
    class toChuc(ChucVu >> ToChuc): pass
    # -------- Các thuộc tính của Tổ chức -------- #
    class thanhVien(ToChuc >> Nguoi): pass
    class phong(ToChuc >> Phong): pass
    # -------- Các thuộc tính của Người -------- #
    class hoTen(Nguoi >> str, FunctionalProperty): pass
    class ngaySinh(Nguoi >> datetime.date, FunctionalProperty): pass
    class gioiTinh(Nguoi >> str, FunctionalProperty): pass
    class thuocToChuc(Nguoi >> ToChuc): 
        inverse_property = thanhVien # Đảo ngược thuộc tính, nếu có 1 người thuộc 1 tổ chức thì tổ chức đó có 1 thành viên là người đó
    # -------- Các thuộc tính của Nhân viên -------- #
    class chucVu(NhanVien >> ChucVu): pass
    class luong(NhanVien >> int, FunctionalProperty): pass
    # -------- Các thuộc tính của Phụ huynh -------- #
    class ngheNghiep(Nguoi >> str, FunctionalProperty): pass
    class con(PhuHuynh >> HocSinh): pass
    # -------- Các thuộc tính của Lớp học -------- #
    class giaoVienChuNhiem(LopHoc >> GiaoVien, FunctionalProperty): pass
    class phongHoc(LopHoc >> Phong, FunctionalProperty): pass
    class dsHocSinh(LopHoc >> HocSinh): pass
    # -------- Các thuộc tính của Học sinh -------- #
    class hocLop(HocSinh >> LopHoc, FunctionalProperty): 
        inverse_property = dsHocSinh
    class phuHuynh(HocSinh >> PhuHuynh): 
        inverse_property = con
    class diemSo(HocSinh >> DiemSo): pass
    # -------- Các thuộc tính của Giáo viên -------- #
    class dayMon(GiaoVien >> MonHoc):pass
    class trinhDo(GiaoVien >> str, FunctionalProperty): pass
    class lopChuNhiem(GiaoVien >> LopHoc, FunctionalProperty): 
        inverse_property = giaoVienChuNhiem
    # -------- Các thuộc tính của Môn học -------- #
    class giaoVienDay(MonHoc >> GiaoVien):
        inverse_property = dayMon
    class soTiet(MonHoc >> int, FunctionalProperty): pass
    # -------- Các thuộc tính của Điểm -------- #
    class hocSinh(DiemSo >> HocSinh, FunctionalProperty): 
        inverse_property = diemSo
    class monHoc(DiemSo >> MonHoc, FunctionalProperty): pass
    class heSo1(DiemSo >> float): pass
    class heSo2(DiemSo >> float): pass
    class heSo3(DiemSo >> float): pass
    # -------- Các thuộc tính của Thẻ Đọc giả -------- #
    class docGia(TheDocGia >> Nguoi, FunctionalProperty): pass
    class ngayCap(TheDocGia >> datetime.date, FunctionalProperty): pass
    class ngayHetHan(TheDocGia >> datetime.date, FunctionalProperty): pass
    class sachDaDoc(TheDocGia >> Sach): pass
    # -------- Các thuộc tính của Tác giả + Nhà xuất bản -------- #
    class dsSach(ObjectProperty): 
        domain = [TacGia, NhaXuatBan, TheLoai]
        range = [Sach]    
    # -------- Các thuộc tính của Sách -------- #
    class tacGia(Sach >> TacGia, FunctionalProperty): pass
    class nhaXuatBan(Sach >> NhaXuatBan, FunctionalProperty): pass
    class theLoai(Sach >> TheLoai): pass
    class giaTien(Sach >> int, FunctionalProperty): pass
    class soLuong(Sach >> int, FunctionalProperty): pass
    # -------- Các thuộc tính của Thể loại -------- #
    
    # -------- Các thuộc tính của Phiếu mượn -------- #
    class theDocGia(PhieuMuon >> TheDocGia, FunctionalProperty): pass
    class ngayMuon(PhieuMuon >> datetime.date, FunctionalProperty): pass
    class ngayTra(PhieuMuon >> datetime.date, FunctionalProperty): pass
    class sachMuon(PhieuMuon >> Sach): pass
    # -------- Các thuộc tính của Phòng -------- #
    class suDungBoi(Phong >> ToChuc): pass
    # -------- Các thuộc tính của Hoạt động -------- #
    class ngayBatDau(HoatDong >> datetime.date, FunctionalProperty): pass
    class ngayKetThuc(HoatDong >> datetime.date, FunctionalProperty): pass
    class quanLy(HoatDong >> Nguoi): pass
    class thamGia(HoatDong >> Nguoi): pass
    # -------- Các thuộc tính của Điểm danh -------- #
    class nguoiDiemDanh(DiemDanh >> Nguoi, FunctionalProperty): pass
    class hoatDong(DiemDanh >> HoatDong, FunctionalProperty): pass
    class ngayGio(DiemDanh >> datetime.datetime, FunctionalProperty): pass
    class trangThai(DiemDanh >> str, FunctionalProperty): pass
# Out:
# * Owlready2 * Warning: optimized Cython parser module 'owlready2_optimized' is not available, defaulting to slower Python implementation

# %%
# Lưu CSDL ra file
onto.save(file="../app/data/education.owl")
with open("../app/data/education.owl", "r") as f:
    print(f.read())
# Out:
# <?xml version="1.0"?>
# <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#"
#          xmlns:xsd="http://www.w3.org/2001/XMLSchema#"
#          xmlns:rdfs="http://www.w3.org/2000/01/rdf-schema#"
#          xmlns:owl="http://www.w3.org/2002/07/owl#"
#          xml:base="http://hc.com/school"
#          xmlns="http://hc.com/school#">
#
# <owl:Ontology rdf:about="http://hc.com/school"/>
#
# <owl:ObjectProperty rdf:about="#moTa">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Phong"/>
#   <rdfs:domain rdf:resource="#ChucVu"/>
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:domain rdf:resource="#MonHoc"/>
#   <rdfs:domain rdf:resource="#TheLoai"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#toChuc">
#   <rdfs:domain rdf:resource="#ChucVu"/>
#   <rdfs:range rdf:resource="#ToChuc"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#thanhVien">
#   <rdfs:domain rdf:resource="#ToChuc"/>
#   <rdfs:range rdf:resource="#Nguoi"/>
#   <owl:inverseOf rdf:resource="#thuocToChuc"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#phong">
#   <rdfs:domain rdf:resource="#ToChuc"/>
#   <rdfs:range rdf:resource="#Phong"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#thuocToChuc">
#   <rdfs:domain rdf:resource="#Nguoi"/>
#   <rdfs:range rdf:resource="#ToChuc"/>
#   <owl:inverseOf rdf:resource="#thanhVien"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#chucVu">
#   <rdfs:domain rdf:resource="#NhanVien"/>
#   <rdfs:range rdf:resource="#ChucVu"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#con">
#   <rdfs:domain rdf:resource="#PhuHuynh"/>
#   <rdfs:range rdf:resource="#HocSinh"/>
#   <owl:inverseOf rdf:resource="#phuHuynh"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#giaoVienChuNhiem">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#LopHoc"/>
#   <rdfs:range rdf:resource="#GiaoVien"/>
#   <owl:inverseOf rdf:resource="#lopChuNhiem"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#phongHoc">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#LopHoc"/>
#   <rdfs:range rdf:resource="#Phong"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#dsHocSinh">
#   <rdfs:domain rdf:resource="#LopHoc"/>
#   <rdfs:range rdf:resource="#HocSinh"/>
#   <owl:inverseOf rdf:resource="#hocLop"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#hocLop">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#LopHoc"/>
#   <owl:inverseOf rdf:resource="#dsHocSinh"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#phuHuynh">
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#PhuHuynh"/>
#   <owl:inverseOf rdf:resource="#con"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#diemSo">
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#DiemSo"/>
#   <owl:inverseOf rdf:resource="#hocSinh"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#dayMon">
#   <rdfs:domain rdf:resource="#GiaoVien"/>
#   <rdfs:range rdf:resource="#MonHoc"/>
#   <owl:inverseOf rdf:resource="#giaoVienDay"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#lopChuNhiem">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#GiaoVien"/>
#   <rdfs:range rdf:resource="#LopHoc"/>
#   <owl:inverseOf rdf:resource="#giaoVienChuNhiem"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#giaoVienDay">
#   <rdfs:domain rdf:resource="#MonHoc"/>
#   <rdfs:range rdf:resource="#GiaoVien"/>
#   <owl:inverseOf rdf:resource="#dayMon"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#hocSinh">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="#HocSinh"/>
#   <owl:inverseOf rdf:resource="#diemSo"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#monHoc">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="#MonHoc"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#docGia">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#TheDocGia"/>
#   <rdfs:range rdf:resource="#Nguoi"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#sachDaDoc">
#   <rdfs:domain rdf:resource="#TheDocGia"/>
#   <rdfs:range rdf:resource="#Sach"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#dsSach">
#   <rdfs:domain rdf:resource="#TacGia"/>
#   <rdfs:domain rdf:resource="#NhaXuatBan"/>
#   <rdfs:domain rdf:resource="#TheLoai"/>
#   <rdfs:range rdf:resource="#Sach"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#tacGia">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Sach"/>
#   <rdfs:range rdf:resource="#TacGia"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#nhaXuatBan">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Sach"/>
#   <rdfs:range rdf:resource="#NhaXuatBan"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#theLoai">
#   <rdfs:domain rdf:resource="#Sach"/>
#   <rdfs:range rdf:resource="#TheLoai"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#theDocGia">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#PhieuMuon"/>
#   <rdfs:range rdf:resource="#TheDocGia"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#sachMuon">
#   <rdfs:domain rdf:resource="#PhieuMuon"/>
#   <rdfs:range rdf:resource="#Sach"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#suDungBoi">
#   <rdfs:domain rdf:resource="#Phong"/>
#   <rdfs:range rdf:resource="#ToChuc"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#quanLy">
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:range rdf:resource="#Nguoi"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#thamGia">
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:range rdf:resource="#Nguoi"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#nguoiDiemDanh">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemDanh"/>
#   <rdfs:range rdf:resource="#Nguoi"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#hoatDong">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemDanh"/>
#   <rdfs:range rdf:resource="#HoatDong"/>
# </owl:ObjectProperty>
#
# <owl:DatatypeProperty rdf:about="#ten">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#ChucVu"/>
#   <rdfs:domain rdf:resource="#MonHoc"/>
#   <rdfs:domain rdf:resource="#ToChuc"/>
#   <rdfs:domain rdf:resource="#LopHoc"/>
#   <rdfs:domain rdf:resource="#TheLoai"/>
#   <rdfs:domain rdf:resource="#Phong"/>
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:domain rdf:resource="#NhaXuatBan"/>
#   <rdfs:domain rdf:resource="#Sach"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#phuCap">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#ChucVu"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#integer"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#hoTen">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Nguoi"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngaySinh">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Nguoi"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#gioiTinh">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Nguoi"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#luong">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#NhanVien"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#integer"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngheNghiep">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Nguoi"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#trinhDo">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#GiaoVien"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#soTiet">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#MonHoc"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#integer"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#heSo1">
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#heSo2">
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#heSo3">
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayCap">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#TheDocGia"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayHetHan">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#TheDocGia"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#giaTien">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Sach"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#integer"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#soLuong">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Sach"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#integer"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayMuon">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#PhieuMuon"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayTra">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#PhieuMuon"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayBatDau">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayKetThuc">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayGio">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemDanh"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#dateTime"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#trangThai">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemDanh"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:Class rdf:about="#ChucVu">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#ToChuc">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#Nguoi">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#NhanVien">
#   <rdfs:subClassOf rdf:resource="#Nguoi"/>
# </owl:Class>
#
# <owl:Class rdf:about="#PhuHuynh">
#   <rdfs:subClassOf rdf:resource="#Nguoi"/>
# </owl:Class>
#
# <owl:Class rdf:about="#LopHoc">
#   <rdfs:subClassOf rdf:resource="#ToChuc"/>
# </owl:Class>
#
# <owl:Class rdf:about="#HocSinh">
#   <rdfs:subClassOf rdf:resource="#Nguoi"/>
# </owl:Class>
#
# <owl:Class rdf:about="#GiaoVien">
#   <rdfs:subClassOf rdf:resource="#NhanVien"/>
# </owl:Class>
#
# <owl:Class rdf:about="#MonHoc">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#DiemSo">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#TheDocGia">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#TacGia">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#NhaXuatBan">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#Sach">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#TheLoai">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#PhieuMuon">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#Phong">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#HoatDong">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#DiemDanh">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
#
# </rdf:RDF>

# %% [markdown]
# ### Thêm dữ liệu

# %%
import random
from datetime import datetime, timedelta

def createRandomDate(start_year, end_year):
    # Tính toán số ngày trong năm bắt đầu và kết thúc
    start_date = datetime(year=start_year, month=1, day=1)
    end_date = datetime(year=end_year, month=12, day=31)
    days_in_range = (end_date - start_date).days + 1

    # Tạo ngẫu nhiên số ngày trong khoảng thời gian bắt đầu và kết thúc
    random_days = random.randint(0, days_in_range - 1)

    # Tính toán ngày sinh từ số ngày được chọn
    birth_date = start_date + timedelta(days=random_days)

    # Trả về chuỗi ngày sinh dạng dd/mm/yyyy
    return birth_date.strftime('%d/%m/%Y')

def createRandomInfo():
    ho = random.choice(["Nguyễn", "Trần", "Lê", "Phạm", "Hoàng", "Huỳnh", "Phan", "Vũ", "Võ", "Đặng", "Bùi", "Đỗ", "Hồ", "Ngô", "Dương", "Lý", "Lương", "Mai", "Trương", "Tạ", "Đào", 
                            "Đoàn", "Đinh", "Lâm", "Phùng", "Đoàn", "Bành", "Quách", "Thái", "Tô", "Tôn", "Tăng"])
    lot = random.choice(['Văn', 'Thị', 'Hồng', 'Anh', 'Quý', 'Bảo', "Thanh", "Thu", "Hữu", "Mai", "Đình", "Hoài", "Ngọc", "Minh", "Kim"])
    ten = random.choice(["An", "Bình", "Cường", "Dũng", "Hải", "Hiền", "Hoàng", "Hùng", "Khánh", "Linh", "Long", "Minh", "Nam", "Ngọc", "Nhật", "Phương", "Quân", "Quang", "Quỳnh", 
                            "Sơn", "Thảo", "Thiên", "Thiện", "Thúy", "Thuận", "Tùng", "Tú", "Tường", "Việt", "Vân", "Vinh", "Xuân"])
    gioiTinh = random.choice(["Nam", "Nữ", "Khác"])
    return f"{ho} {lot} {ten}", gioiTinh
def randScore():
    score = random.randint(0, 10)
    if score != 10:
        score += random.choice([0.3, 0.5, 0.8])
    return score
def getClassName(i):
    if i < 9:
        return "10A0" + str(i+1)
    else:
        return "10A" + str(i+1)
# Đọc CSDL từ file
onto = get_ontology("../app/data/education.owl").load()

# Thêm dữ liệu cho từng đối tượng
with onto: 
    # Tạo ngẫu nhiên 10 lớp học
    for i in range(10):
        lop = LopHoc(ten = getClassName(i))
        # Tạo ngẫu nhiên 10 HS cho mỗi lớp
        for j in range(10):
            ten, gt = createRandomInfo()
            hs = HocSinh(hoTen = ten, ngaySinh = createRandomDate(2000, 2000), gioiTinh = gt, hocLop = lop)

    # Tạo môn học
    id_mon_hoc = ['Toan', 'NguVan', 'HoaHoc', 'LichSu', 'DiaLy', 'SinhHoc', 'TiengAnh', 'GDCD', 'CongNghe', 'TheDuc']
    ds_mon_hoc = ['Toán học', 'Ngữ văn', 'Hóa học', 'Lịch sử', 'Địa lý', 'Sinh học', 'Tiếng Anh', 'GDCD', 'Công nghệ', 'Thể dục']
    so_tiet = [5, 3, 3, 3, 5, 2, 2, 3, 2]
    for id, mon, st, i in zip(id_mon_hoc, ds_mon_hoc, so_tiet, range(len(id_mon_hoc))):
        mon_hoc = MonHoc(id, ten = mon, soTiet = st)
        # Tạo ngẫu nhiên 10 GV cho mỗi môn
        for j in range(10):
            ten, gt = createRandomInfo()
            td = str(random.choices(['Đại học', 'Thạc sĩ']))
            gv = GiaoVien(hoTen = ten, ngaySinh = createRandomDate(1970, 1990), gioiTinh = gt, trinhDo = td, dayMon = [mon_hoc])
            if j == 0:
                gv.lopChuNhiem = onto.search_one(ten = getClassName(i))
        # Tạo điểm số cho từng HS
        for hs in onto.HocSinh.instances():
            diem = DiemSo(hocSinh = hs, monHoc = mon_hoc, 
                          heSo1 = [randScore(),randScore(),randScore()], 
                          heSo2 = [randScore(),randScore()], 
                          heSo3 = [randScore()])

# Lưu CSDL ra file
onto.save(file="../app/data/education.owl", format="rdfxml")
with open("../app/data/education.owl", "r") as f:
    print(f.read())
# Out:
# <?xml version="1.0"?>
# <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#"
#          xmlns:xsd="http://www.w3.org/2001/XMLSchema#"
#          xmlns:rdfs="http://www.w3.org/2000/01/rdf-schema#"
#          xmlns:owl="http://www.w3.org/2002/07/owl#"
#          xml:base="http://hc.com/school"
#          xmlns="http://hc.com/school#">
#
# <owl:Ontology rdf:about="http://hc.com/school"/>
#
# <owl:ObjectProperty rdf:about="#moTa">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Phong"/>
#   <rdfs:domain rdf:resource="#ChucVu"/>
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:domain rdf:resource="#MonHoc"/>
#   <rdfs:domain rdf:resource="#TheLoai"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#toChuc">
#   <rdfs:domain rdf:resource="#ChucVu"/>
#   <rdfs:range rdf:resource="#ToChuc"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#thanhVien">
#   <rdfs:domain rdf:resource="#ToChuc"/>
#   <rdfs:range rdf:resource="#Nguoi"/>
#   <owl:inverseOf rdf:resource="#thuocToChuc"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#phong">
#   <rdfs:domain rdf:resource="#ToChuc"/>
#   <rdfs:range rdf:resource="#Phong"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#thuocToChuc">
#   <rdfs:domain rdf:resource="#Nguoi"/>
#   <rdfs:range rdf:resource="#ToChuc"/>
#   <owl:inverseOf rdf:resource="#thanhVien"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#chucVu">
#   <rdfs:domain rdf:resource="#NhanVien"/>
#   <rdfs:range rdf:resource="#ChucVu"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#con">
#   <rdfs:domain rdf:resource="#PhuHuynh"/>
#   <rdfs:range rdf:resource="#HocSinh"/>
#   <owl:inverseOf rdf:resource="#phuHuynh"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#giaoVienChuNhiem">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#LopHoc"/>
#   <rdfs:range rdf:resource="#GiaoVien"/>
#   <owl:inverseOf rdf:resource="#lopChuNhiem"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#phongHoc">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#LopHoc"/>
#   <rdfs:range rdf:resource="#Phong"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#dsHocSinh">
#   <rdfs:domain rdf:resource="#LopHoc"/>
#   <rdfs:range rdf:resource="#HocSinh"/>
#   <owl:inverseOf rdf:resource="#hocLop"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#hocLop">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#LopHoc"/>
#   <owl:inverseOf rdf:resource="#dsHocSinh"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#phuHuynh">
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#PhuHuynh"/>
#   <owl:inverseOf rdf:resource="#con"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#diemSo">
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#DiemSo"/>
#   <owl:inverseOf rdf:resource="#hocSinh"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#dayMon">
#   <rdfs:domain rdf:resource="#GiaoVien"/>
#   <rdfs:range rdf:resource="#MonHoc"/>
#   <owl:inverseOf rdf:resource="#giaoVienDay"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#lopChuNhiem">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#GiaoVien"/>
#   <rdfs:range rdf:resource="#LopHoc"/>
#   <owl:inverseOf rdf:resource="#giaoVienChuNhiem"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#giaoVienDay">
#   <rdfs:domain rdf:resource="#MonHoc"/>
#   <rdfs:range rdf:resource="#GiaoVien"/>
#   <owl:inverseOf rdf:resource="#dayMon"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#hocSinh">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="#HocSinh"/>
#   <owl:inverseOf rdf:resource="#diemSo"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#monHoc">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="#MonHoc"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#docGia">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#TheDocGia"/>
#   <rdfs:range rdf:resource="#Nguoi"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#sachDaDoc">
#   <rdfs:domain rdf:resource="#TheDocGia"/>
#   <rdfs:range rdf:resource="#Sach"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#dsSach">
#   <rdfs:domain rdf:resource="#TacGia"/>
#   <rdfs:domain rdf:resource="#NhaXuatBan"/>
#   <rdfs:domain rdf:resource="#TheLoai"/>
#   <rdfs:range rdf:resource="#Sach"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#tacGia">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Sach"/>
#   <rdfs:range rdf:resource="#TacGia"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#nhaXuatBan">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Sach"/>
#   <rdfs:range rdf:resource="#NhaXuatBan"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#theLoai">
#   <rdfs:domain rdf:resource="#Sach"/>
#   <rdfs:range rdf:resource="#TheLoai"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#theDocGia">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#PhieuMuon"/>
#   <rdfs:range rdf:resource="#TheDocGia"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#sachMuon">
#   <rdfs:domain rdf:resource="#PhieuMuon"/>
#   <rdfs:range rdf:resource="#Sach"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#suDungBoi">
#   <rdfs:domain rdf:resource="#Phong"/>
#   <rdfs:range rdf:resource="#ToChuc"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#quanLy">
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:range rdf:resource="#Nguoi"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#thamGia">
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:range rdf:resource="#Nguoi"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#nguoiDiemDanh">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemDanh"/>
#   <rdfs:range rdf:resource="#Nguoi"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#hoatDong">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemDanh"/>
#   <rdfs:range rdf:resource="#HoatDong"/>
# </owl:ObjectProperty>
#
# <owl:DatatypeProperty rdf:about="#ten">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#ChucVu"/>
#   <rdfs:domain rdf:resource="#MonHoc"/>
#   <rdfs:domain rdf:resource="#ToChuc"/>
#   <rdfs:domain rdf:resource="#LopHoc"/>
#   <rdfs:domain rdf:resource="#TheLoai"/>
#   <rdfs:domain rdf:resource="#Phong"/>
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:domain rdf:resource="#NhaXuatBan"/>
#   <rdfs:domain rdf:resource="#Sach"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#phuCap">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#ChucVu"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#integer"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#hoTen">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Nguoi"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngaySinh">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Nguoi"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#gioiTinh">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Nguoi"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#luong">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#NhanVien"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#integer"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngheNghiep">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Nguoi"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#trinhDo">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#GiaoVien"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#soTiet">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#MonHoc"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#integer"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#heSo1">
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#heSo2">
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#heSo3">
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayCap">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#TheDocGia"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayHetHan">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#TheDocGia"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#giaTien">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Sach"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#integer"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#soLuong">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Sach"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#integer"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayMuon">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#PhieuMuon"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayTra">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#PhieuMuon"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayBatDau">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayKetThuc">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayGio">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemDanh"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#dateTime"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#trangThai">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemDanh"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:Class rdf:about="#ChucVu">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#ToChuc">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#Nguoi">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#NhanVien">
#   <rdfs:subClassOf rdf:resource="#Nguoi"/>
# </owl:Class>
#
# <owl:Class rdf:about="#PhuHuynh">
#   <rdfs:subClassOf rdf:resource="#Nguoi"/>
# </owl:Class>
#
# <owl:Class rdf:about="#LopHoc">
#   <rdfs:subClassOf rdf:resource="#ToChuc"/>
# </owl:Class>
#
# <owl:Class rdf:about="#HocSinh">
#   <rdfs:subClassOf rdf:resource="#Nguoi"/>
# </owl:Class>
#
# <owl:Class rdf:about="#GiaoVien">
#   <rdfs:subClassOf rdf:resource="#NhanVien"/>
# </owl:Class>
#
# <owl:Class rdf:about="#MonHoc">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#DiemSo">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#TheDocGia">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#TacGia">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#NhaXuatBan">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#Sach">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#TheLoai">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#PhieuMuon">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#Phong">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#HoatDong">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#DiemDanh">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <LopHoc rdf:about="#lophoc1">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <ten rdf:datatype="http://www.w3.org/2001/XMLSchema#string">10A01</ten>
# </LopHoc>
#
# <HocSinh rdf:about="#hocsinh1">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc1"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Ngô Quý Thuận</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">13/01/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh2">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc1"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nguyễn Thu Thảo</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">12/11/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh3">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc1"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Võ Ngọc Tùng</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">07/07/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh4">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc1"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Lâm Ngọc Vân</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">16/07/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh5">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc1"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Bành Mai Hoàng</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">28/08/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh6">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc1"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Lê Hồng Vân</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">13/08/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh7">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc1"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Hồ Hữu Xuân</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">27/03/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh8">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc1"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Thái Minh Long</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">11/01/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh9">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc1"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tạ Thanh Tú</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">18/08/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh10">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc1"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đỗ Văn Sơn</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">19/11/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
# </HocSinh>
#
# <LopHoc rdf:about="#lophoc2">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <ten rdf:datatype="http://www.w3.org/2001/XMLSchema#string">10A02</ten>
# </LopHoc>
#
# <HocSinh rdf:about="#hocsinh11">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc2"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Phạm Kim Thảo</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">28/04/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh12">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc2"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Huỳnh Ngọc Vân</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">16/05/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh13">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc2"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Trần Đình Hải</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">30/04/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh14">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc2"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tôn Thanh Hoàng</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">25/07/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh15">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc2"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Thái Anh Bình</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">27/06/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh16">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc2"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đoàn Hồng Minh</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">12/09/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh17">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc2"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tô Quý Hiền</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">20/12/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh18">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc2"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Dương Hữu Thúy</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">03/09/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh19">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc2"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tăng Văn Thuận</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">13/10/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh20">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc2"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Trần Bảo Bình</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">15/09/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
# </HocSinh>
#
# <LopHoc rdf:about="#lophoc3">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <ten rdf:datatype="http://www.w3.org/2001/XMLSchema#string">10A03</ten>
# </LopHoc>
#
# <HocSinh rdf:about="#hocsinh21">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc3"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Phùng Ngọc Quân</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">10/03/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh22">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc3"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tô Thị Thảo</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">11/03/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh23">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc3"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đào Ngọc Nam</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">26/11/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh24">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc3"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Dương Thu Thuận</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">10/11/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh25">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc3"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tô Quý Nam</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">26/11/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh26">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc3"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Trần Hồng Xuân</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">27/02/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh27">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc3"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Dương Hữu Tường</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">05/12/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh28">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc3"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Hoàng Minh Hải</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">29/02/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh29">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc3"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Vũ Ngọc Sơn</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">12/03/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh30">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc3"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Lê Đình Thuận</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">02/10/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
# </HocSinh>
#
# <LopHoc rdf:about="#lophoc4">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <ten rdf:datatype="http://www.w3.org/2001/XMLSchema#string">10A04</ten>
# </LopHoc>
#
# <HocSinh rdf:about="#hocsinh31">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc4"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tôn Thị Vinh</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">01/06/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh32">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc4"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Lê Thị Hiền</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">01/10/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh33">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc4"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Bành Mai Thảo</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">20/02/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh34">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc4"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Lâm Minh Hùng</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">26/12/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh35">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc4"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tạ Văn Quỳnh</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">26/07/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh36">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc4"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tô Văn Bình</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">30/05/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh37">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc4"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tôn Thị Thiện</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">19/06/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh38">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc4"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tạ Bảo Hùng</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">22/03/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh39">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc4"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đinh Bảo Linh</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">13/08/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh40">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc4"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đoàn Thanh Vân</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">24/11/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
# </HocSinh>
#
# <LopHoc rdf:about="#lophoc5">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <ten rdf:datatype="http://www.w3.org/2001/XMLSchema#string">10A05</ten>
# </LopHoc>
#
# <HocSinh rdf:about="#hocsinh41">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc5"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Phạm Ngọc Thiện</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">11/07/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh42">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc5"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Hồ Minh Xuân</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">11/02/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh43">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc5"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Phùng Hoài Hải</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">29/08/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh44">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc5"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Mai Hồng Long</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">15/03/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh45">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc5"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đinh Thị Quỳnh</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">04/11/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh46">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc5"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Quách Thanh Ngọc</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">11/06/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh47">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc5"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Lương Hữu Linh</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">20/04/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh48">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc5"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Lý Hồng Quỳnh</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">07/03/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh49">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc5"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Lương Hồng Linh</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">20/09/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh50">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc5"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Trần Hữu Quân</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">09/03/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
# </HocSinh>
#
# <LopHoc rdf:about="#lophoc6">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <ten rdf:datatype="http://www.w3.org/2001/XMLSchema#string">10A06</ten>
# </LopHoc>
#
# <HocSinh rdf:about="#hocsinh51">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc6"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đoàn Kim Long</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">11/06/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh52">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc6"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Hoàng Hữu Thiên</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">13/03/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh53">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc6"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Mai Ngọc Xuân</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">26/12/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh54">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc6"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tôn Mai Hùng</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">29/07/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh55">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc6"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Võ Hoài Vân</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">03/01/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh56">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc6"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tô Hoài Hoàng</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">23/04/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh57">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc6"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Hoàng Bảo An</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">25/07/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh58">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc6"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đoàn Mai Quang</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">24/03/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh59">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc6"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Dương Thị Vân</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">25/11/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh60">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc6"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Mai Mai Ngọc</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">12/04/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
# </HocSinh>
#
# <LopHoc rdf:about="#lophoc7">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <ten rdf:datatype="http://www.w3.org/2001/XMLSchema#string">10A07</ten>
# </LopHoc>
#
# <HocSinh rdf:about="#hocsinh61">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc7"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Lương Kim Minh</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">22/12/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh62">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc7"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Thái Đình Minh</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">02/12/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh63">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc7"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Lê Mai Khánh</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">15/02/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh64">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc7"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Lương Mai Hải</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">22/07/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh65">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc7"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Lâm Hữu Thuận</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">13/09/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh66">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc7"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Bùi Anh Quỳnh</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">03/05/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh67">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc7"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Mai Ngọc Việt</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">20/04/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh68">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc7"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Bùi Thu Quang</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">18/02/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh69">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc7"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Bành Quý Tường</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">09/04/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh70">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc7"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Thái Anh Sơn</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">23/01/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
# </HocSinh>
#
# <LopHoc rdf:about="#lophoc8">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <ten rdf:datatype="http://www.w3.org/2001/XMLSchema#string">10A08</ten>
# </LopHoc>
#
# <HocSinh rdf:about="#hocsinh71">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc8"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đoàn Bảo Vân</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">29/10/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh72">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc8"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Lâm Minh Nhật</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">20/08/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh73">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc8"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đặng Văn Thiên</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">28/07/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh74">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc8"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Quách Đình Hùng</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">24/03/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh75">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc8"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tôn Bảo Ngọc</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">27/11/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh76">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc8"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Huỳnh Kim Việt</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">29/11/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh77">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc8"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Dương Hoài Quân</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">27/10/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh78">
# ...
#   <hocSinh rdf:resource="#hocsinh76"/>
#   <monHoc rdf:resource="#CongNghe"/>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">2.5</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">9.5</heSo1>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">1.3</heSo2>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">0.5</heSo2>
#   <heSo3 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">5.5</heSo3>
# </DiemSo>
#
# <DiemSo rdf:about="#diemso877">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocSinh rdf:resource="#hocsinh77"/>
#   <monHoc rdf:resource="#CongNghe"/>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">6.3</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">5.3</heSo1>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">1.5</heSo2>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">0.8</heSo2>
#   <heSo3 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">2.8</heSo3>
# </DiemSo>
#
# <DiemSo rdf:about="#diemso878">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocSinh rdf:resource="#hocsinh78"/>
#   <monHoc rdf:resource="#CongNghe"/>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">3.8</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">2.5</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">9.8</heSo1>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">10</heSo2>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">0.8</heSo2>
#   <heSo3 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">7.3</heSo3>
# </DiemSo>
#
# <DiemSo rdf:about="#diemso879">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocSinh rdf:resource="#hocsinh79"/>
#   <monHoc rdf:resource="#CongNghe"/>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">3.5</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">4.8</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">0.8</heSo1>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">0.3</heSo2>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">1.5</heSo2>
#   <heSo3 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">8.3</heSo3>
# </DiemSo>
#
# <DiemSo rdf:about="#diemso880">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocSinh rdf:resource="#hocsinh80"/>
#   <monHoc rdf:resource="#CongNghe"/>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">5.8</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">5.5</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">5.3</heSo1>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">0.3</heSo2>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">4.3</heSo2>
#   <heSo3 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">2.5</heSo3>
# </DiemSo>
#
# <DiemSo rdf:about="#diemso881">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocSinh rdf:resource="#hocsinh81"/>
#   <monHoc rdf:resource="#CongNghe"/>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">7.5</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">0.8</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">6.3</heSo1>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">9.8</heSo2>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">6.3</heSo2>
#   <heSo3 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">8.5</heSo3>
# </DiemSo>
#
# <DiemSo rdf:about="#diemso882">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocSinh rdf:resource="#hocsinh82"/>
#   <monHoc rdf:resource="#CongNghe"/>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">7.8</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">8.3</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">8.8</heSo1>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">0.5</heSo2>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">3.5</heSo2>
#   <heSo3 rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">10</heSo3>
# </DiemSo>
#
# <DiemSo rdf:about="#diemso883">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocSinh rdf:resource="#hocsinh83"/>
#   <monHoc rdf:resource="#CongNghe"/>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">3.3</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">7.8</heSo1>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">9.3</heSo2>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">1.8</heSo2>
#   <heSo3 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">5.3</heSo3>
# </DiemSo>
#
# <DiemSo rdf:about="#diemso884">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocSinh rdf:resource="#hocsinh84"/>
#   <monHoc rdf:resource="#CongNghe"/>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">8.8</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">3.3</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">1.3</heSo1>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">2.8</heSo2>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">1.3</heSo2>
#   <heSo3 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">5.3</heSo3>
# </DiemSo>
#
# <DiemSo rdf:about="#diemso885">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocSinh rdf:resource="#hocsinh85"/>
#   <monHoc rdf:resource="#CongNghe"/>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">2.3</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">5.3</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">4.8</heSo1>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">8.5</heSo2>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">5.5</heSo2>
#   <heSo3 rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">10</heSo3>
# </DiemSo>
#
# <DiemSo rdf:about="#diemso886">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocSinh rdf:resource="#hocsinh86"/>
#   <monHoc rdf:resource="#CongNghe"/>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">4.3</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">10</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">8.3</heSo1>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">6.3</heSo2>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">1.5</heSo2>
#   <heSo3 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">6.5</heSo3>
# </DiemSo>
#
# <DiemSo rdf:about="#diemso887">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocSinh rdf:resource="#hocsinh87"/>
#   <monHoc rdf:resource="#CongNghe"/>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">9.8</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">4.3</heSo1>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">4.8</heSo2>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">3.5</heSo2>
#   <heSo3 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">3.3</heSo3>
# </DiemSo>
#
# <DiemSo rdf:about="#diemso888">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocSinh rdf:resource="#hocsinh88"/>
#   <monHoc rdf:resource="#CongNghe"/>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">10</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">8.8</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">7.5</heSo1>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">4.8</heSo2>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">5.5</heSo2>
#   <heSo3 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">5.3</heSo3>
# </DiemSo>
#
# <DiemSo rdf:about="#diemso889">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocSinh rdf:resource="#hocsinh89"/>
#   <monHoc rdf:resource="#CongNghe"/>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">9.3</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">6.5</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">4.5</heSo1>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">8.8</heSo2>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">0.8</heSo2>
#   <heSo3 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">6.5</heSo3>
# </DiemSo>
#
# <DiemSo rdf:about="#diemso890">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocSinh rdf:resource="#hocsinh90"/>
#   <monHoc rdf:resource="#CongNghe"/>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">6.3</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">2.5</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">5.8</heSo1>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">1.5</heSo2>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">1.8</heSo2>
#   <heSo3 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">1.3</heSo3>
# </DiemSo>
#
# <DiemSo rdf:about="#diemso891">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocSinh rdf:resource="#hocsinh91"/>
#   <monHoc rdf:resource="#CongNghe"/>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">5.8</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">5.5</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">5.3</heSo1>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">5.8</heSo2>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">5.5</heSo2>
#   <heSo3 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">7.8</heSo3>
# </DiemSo>
#
# <DiemSo rdf:about="#diemso892">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocSinh rdf:resource="#hocsinh92"/>
#   <monHoc rdf:resource="#CongNghe"/>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">6.5</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">10</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">6.3</heSo1>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">1.3</heSo2>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">10</heSo2>
#   <heSo3 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">0.3</heSo3>
# </DiemSo>
#
# <DiemSo rdf:about="#diemso893">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocSinh rdf:resource="#hocsinh93"/>
#   <monHoc rdf:resource="#CongNghe"/>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">0.8</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">2.5</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">7.8</heSo1>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">7.8</heSo2>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">10</heSo2>
#   <heSo3 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">6.5</heSo3>
# </DiemSo>
#
# <DiemSo rdf:about="#diemso894">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocSinh rdf:resource="#hocsinh94"/>
#   <monHoc rdf:resource="#CongNghe"/>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">3.5</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">8.5</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">7.3</heSo1>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">3.3</heSo2>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">6.5</heSo2>
#   <heSo3 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">7.8</heSo3>
# </DiemSo>
#
# <DiemSo rdf:about="#diemso895">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocSinh rdf:resource="#hocsinh95"/>
#   <monHoc rdf:resource="#CongNghe"/>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">1.8</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">8.3</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">4.5</heSo1>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">1.8</heSo2>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">4.3</heSo2>
#   <heSo3 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">2.3</heSo3>
# </DiemSo>
#
# <DiemSo rdf:about="#diemso896">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocSinh rdf:resource="#hocsinh96"/>
#   <monHoc rdf:resource="#CongNghe"/>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">3.3</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">0.8</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">1.3</heSo1>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">9.8</heSo2>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">0.5</heSo2>
#   <heSo3 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">5.5</heSo3>
# </DiemSo>
#
# <DiemSo rdf:about="#diemso897">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocSinh rdf:resource="#hocsinh97"/>
#   <monHoc rdf:resource="#CongNghe"/>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">6.5</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">7.3</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">2.8</heSo1>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">10</heSo2>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">5.5</heSo2>
#   <heSo3 rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">10</heSo3>
# </DiemSo>
#
# <DiemSo rdf:about="#diemso898">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocSinh rdf:resource="#hocsinh98"/>
#   <monHoc rdf:resource="#CongNghe"/>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">3.5</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">9.5</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">2.3</heSo1>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">1.8</heSo2>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">9.5</heSo2>
#   <heSo3 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">1.8</heSo3>
# </DiemSo>
#
# <DiemSo rdf:about="#diemso899">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocSinh rdf:resource="#hocsinh99"/>
#   <monHoc rdf:resource="#CongNghe"/>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">0.3</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">1.5</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">10</heSo1>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">9.5</heSo2>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">2.5</heSo2>
#   <heSo3 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">0.5</heSo3>
# </DiemSo>
#
# <DiemSo rdf:about="#diemso900">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocSinh rdf:resource="#hocsinh100"/>
#   <monHoc rdf:resource="#CongNghe"/>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">4.8</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">7.5</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">0.3</heSo1>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">8.8</heSo2>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">8.5</heSo2>
#   <heSo3 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">8.5</heSo3>
# </DiemSo>
#
#
# </rdf:RDF>

# %%
# Đọc CSDL từ file
onto = get_ontology("../app/data/education.owl").load()

# In DS học sinh ra màn hình
print("Danh sách học sinh:")
stt = 1
for hs in onto.HocSinh.instances():
    print(stt, hs)
    stt += 1
# Out:
# Danh sách học sinh:
# 1 Ngô Quý Thuận - 13/01/2000 - Khác - 10A01
# 2 Nguyễn Thu Thảo - 12/11/2000 - Nam - 10A01
# 3 Võ Ngọc Tùng - 07/07/2000 - Nữ - 10A01
# 4 Lâm Ngọc Vân - 16/07/2000 - Nữ - 10A01
# 5 Bành Mai Hoàng - 28/08/2000 - Khác - 10A01
# 6 Lê Hồng Vân - 13/08/2000 - Nữ - 10A01
# 7 Hồ Hữu Xuân - 27/03/2000 - Nam - 10A01
# 8 Thái Minh Long - 11/01/2000 - Nữ - 10A01
# 9 Tạ Thanh Tú - 18/08/2000 - Nữ - 10A01
# 10 Đỗ Văn Sơn - 19/11/2000 - Nam - 10A01
# 11 Phạm Kim Thảo - 28/04/2000 - Nữ - 10A02
# 12 Huỳnh Ngọc Vân - 16/05/2000 - Nam - 10A02
# 13 Trần Đình Hải - 30/04/2000 - Nữ - 10A02
# 14 Tôn Thanh Hoàng - 25/07/2000 - Nam - 10A02
# 15 Thái Anh Bình - 27/06/2000 - Nam - 10A02
# 16 Đoàn Hồng Minh - 12/09/2000 - Nam - 10A02
# 17 Tô Quý Hiền - 20/12/2000 - Nữ - 10A02
# 18 Dương Hữu Thúy - 03/09/2000 - Nam - 10A02
# 19 Tăng Văn Thuận - 13/10/2000 - Khác - 10A02
# 20 Trần Bảo Bình - 15/09/2000 - Nữ - 10A02
# 21 Phùng Ngọc Quân - 10/03/2000 - Nam - 10A03
# 22 Tô Thị Thảo - 11/03/2000 - Nam - 10A03
# 23 Đào Ngọc Nam - 26/11/2000 - Khác - 10A03
# 24 Dương Thu Thuận - 10/11/2000 - Khác - 10A03
# 25 Tô Quý Nam - 26/11/2000 - Nữ - 10A03
# 26 Trần Hồng Xuân - 27/02/2000 - Khác - 10A03
# 27 Dương Hữu Tường - 05/12/2000 - Nam - 10A03
# 28 Hoàng Minh Hải - 29/02/2000 - Nam - 10A03
# 29 Vũ Ngọc Sơn - 12/03/2000 - Nữ - 10A03
# 30 Lê Đình Thuận - 02/10/2000 - Khác - 10A03
# 31 Tôn Thị Vinh - 01/06/2000 - Nam - 10A04
# 32 Lê Thị Hiền - 01/10/2000 - Khác - 10A04
# 33 Bành Mai Thảo - 20/02/2000 - Nam - 10A04
# 34 Lâm Minh Hùng - 26/12/2000 - Nữ - 10A04
# 35 Tạ Văn Quỳnh - 26/07/2000 - Nam - 10A04
# 36 Tô Văn Bình - 30/05/2000 - Khác - 10A04
# 37 Tôn Thị Thiện - 19/06/2000 - Nữ - 10A04
# 38 Tạ Bảo Hùng - 22/03/2000 - Khác - 10A04
# 39 Đinh Bảo Linh - 13/08/2000 - Khác - 10A04
# 40 Đoàn Thanh Vân - 24/11/2000 - Nữ - 10A04
# 41 Phạm Ngọc Thiện - 11/07/2000 - Khác - 10A05
# 42 Hồ Minh Xuân - 11/02/2000 - Nam - 10A05
# 43 Phùng Hoài Hải - 29/08/2000 - Nam - 10A05
# 44 Mai Hồng Long - 15/03/2000 - Khác - 10A05
# 45 Đinh Thị Quỳnh - 04/11/2000 - Nữ - 10A05
# 46 Quách Thanh Ngọc - 11/06/2000 - Khác - 10A05
# 47 Lương Hữu Linh - 20/04/2000 - Nam - 10A05
# 48 Lý Hồng Quỳnh - 07/03/2000 - Nữ - 10A05
# 49 Lương Hồng Linh - 20/09/2000 - Khác - 10A05
# 50 Trần Hữu Quân - 09/03/2000 - Nam - 10A05
# 51 Đoàn Kim Long - 11/06/2000 - Nam - 10A06
# 52 Hoàng Hữu Thiên - 13/03/2000 - Nam - 10A06
# 53 Mai Ngọc Xuân - 26/12/2000 - Nam - 10A06
# 54 Tôn Mai Hùng - 29/07/2000 - Khác - 10A06
# 55 Võ Hoài Vân - 03/01/2000 - Khác - 10A06
# 56 Tô Hoài Hoàng - 23/04/2000 - Nữ - 10A06
# 57 Hoàng Bảo An - 25/07/2000 - Khác - 10A06
# 58 Đoàn Mai Quang - 24/03/2000 - Nữ - 10A06
# 59 Dương Thị Vân - 25/11/2000 - Nam - 10A06
# 60 Mai Mai Ngọc - 12/04/2000 - Khác - 10A06
# 61 Lương Kim Minh - 22/12/2000 - Nữ - 10A07
# 62 Thái Đình Minh - 02/12/2000 - Khác - 10A07
# 63 Lê Mai Khánh - 15/02/2000 - Khác - 10A07
# 64 Lương Mai Hải - 22/07/2000 - Nữ - 10A07
# 65 Lâm Hữu Thuận - 13/09/2000 - Khác - 10A07
# 66 Bùi Anh Quỳnh - 03/05/2000 - Nam - 10A07
# 67 Mai Ngọc Việt - 20/04/2000 - Khác - 10A07
# 68 Bùi Thu Quang - 18/02/2000 - Khác - 10A07
# 69 Bành Quý Tường - 09/04/2000 - Khác - 10A07
# 70 Thái Anh Sơn - 23/01/2000 - Nữ - 10A07
# 71 Đoàn Bảo Vân - 29/10/2000 - Nam - 10A08
# 72 Lâm Minh Nhật - 20/08/2000 - Nữ - 10A08
# 73 Đặng Văn Thiên - 28/07/2000 - Khác - 10A08
# 74 Quách Đình Hùng - 24/03/2000 - Nam - 10A08
# 75 Tôn Bảo Ngọc - 27/11/2000 - Nữ - 10A08
# 76 Huỳnh Kim Việt - 29/11/2000 - Nam - 10A08
# 77 Dương Hoài Quân - 27/10/2000 - Khác - 10A08
# 78 Huỳnh Thị Thiên - 15/09/2000 - Nam - 10A08
# 79 Đặng Thanh Thúy - 15/08/2000 - Khác - 10A08
# 80 Dương Mai Hoàng - 13/10/2000 - Nam - 10A08
# 81 Huỳnh Văn Phương - 28/05/2000 - Nam - 10A09
# 82 Đặng Thị An - 27/03/2000 - Nữ - 10A09
# 83 Lý Văn An - 23/01/2000 - Nữ - 10A09
# 84 Lê Kim Hiền - 01/11/2000 - Nữ - 10A09
# 85 Nguyễn Thị An - 22/06/2000 - Nữ - 10A09
# 86 Thái Hoài Nhật - 24/08/2000 - Khác - 10A09
# 87 Đinh Hữu Bình - 25/10/2000 - Nữ - 10A09
# 88 Hoàng Hoài Ngọc - 22/02/2000 - Nữ - 10A09
# 89 Trương Văn Dũng - 15/10/2000 - Nam - 10A09
# 90 Trần Hoài Long - 11/05/2000 - Khác - 10A09
# 91 Vũ Thu An - 17/03/2000 - Nam - 10A10
# 92 Đoàn Thị Phương - 01/11/2000 - Nữ - 10A10
# 93 Đỗ Ngọc Xuân - 10/06/2000 - Nam - 10A10
# 94 Lâm Thị Khánh - 21/05/2000 - Nữ - 10A10
# 95 Bùi Bảo Vân - 28/02/2000 - Nam - 10A10
# 96 Nguyễn Văn Việt - 05/10/2000 - Nữ - 10A10
# 97 Đào Ngọc Long - 04/07/2000 - Nữ - 10A10
# 98 Tôn Thanh Quân - 22/01/2000 - Nam - 10A10
# 99 Đỗ Hoài Vân - 20/03/2000 - Khác - 10A10
# 100 Quách Văn Hoàng - 12/11/2000 - Nam - 10A10

# %%
# In DS giáo viên
print("Danh sách giáo viên:")
for gv in onto.GiaoVien.instances():
    print(gv.hoTen, gv.ngaySinh, gv.gioiTinh, gv.trinhDo, getattr(gv.lopChuNhiem,'ten',''), *[mon.ten for mon in gv.dayMon])
# Out:
# Danh sách giáo viên:
# Tôn Ngọc Việt 23/05/1989 Nữ ['Thạc sĩ'] 10A01 Toán học
# Tăng Kim Việt 31/03/1973 Khác ['Đại học']  Toán học
# Tạ Văn Phương 02/01/1990 Nam ['Đại học']  Toán học
# Nguyễn Anh Thúy 30/09/1985 Nam ['Thạc sĩ']  Toán học
# Vũ Bảo Hải 12/10/1984 Nữ ['Thạc sĩ']  Toán học
# Lương Văn Vân 27/11/1980 Khác ['Đại học']  Toán học
# Trần Bảo Bình 30/01/1984 Khác ['Thạc sĩ']  Toán học
# Lê Quý Long 08/03/1988 Nữ ['Đại học']  Toán học
# Tô Hồng Bình 13/06/1976 Khác ['Đại học']  Toán học
# Bành Ngọc Hùng 11/09/1986 Nữ ['Đại học']  Toán học
# Võ Quý Nhật 26/09/1986 Nữ ['Đại học'] 10A02 Ngữ văn
# Lý Thu Thảo 18/12/1984 Nữ ['Thạc sĩ']  Ngữ văn
# Trương Quý Cường 23/01/1971 Nam ['Đại học']  Ngữ văn
# Lương Thu Hoàng 12/11/1978 Nam ['Thạc sĩ']  Ngữ văn
# Đặng Anh Linh 24/11/1974 Khác ['Thạc sĩ']  Ngữ văn
# Tô Thị Khánh 14/03/1988 Khác ['Thạc sĩ']  Ngữ văn
# Bùi Thanh Vân 10/09/1983 Nữ ['Đại học']  Ngữ văn
# Bành Mai Việt 27/05/1986 Nữ ['Đại học']  Ngữ văn
# Vũ Quý Linh 30/03/1984 Nữ ['Thạc sĩ']  Ngữ văn
# Đỗ Mai Thiên 02/09/1981 Nữ ['Đại học']  Ngữ văn
# Đào Bảo Tú 13/12/1974 Khác ['Thạc sĩ'] 10A03 Hóa học
# Hoàng Hữu Cường 04/08/1981 Khác ['Đại học']  Hóa học
# Đinh Mai Thiên 10/12/1976 Nam ['Thạc sĩ']  Hóa học
# Lâm Văn Vinh 01/11/1977 Nam ['Đại học']  Hóa học
# Ngô Bảo Thúy 07/08/1977 Khác ['Đại học']  Hóa học
# Lý Đình Hải 23/12/1973 Nam ['Đại học']  Hóa học
# Lương Bảo Việt 14/09/1979 Nam ['Đại học']  Hóa học
# Tôn Quý Sơn 11/05/1983 Nữ ['Đại học']  Hóa học
# Đoàn Hoài An 18/09/1985 Nam ['Đại học']  Hóa học
# Đào Thị Sơn 11/05/1979 Nam ['Đại học']  Hóa học
# Trần Ngọc Quang 03/12/1977 Nam ['Đại học'] 10A04 Lịch sử
# Lê Kim Phương 02/04/1972 Khác ['Thạc sĩ']  Lịch sử
# Bùi Mai Quang 28/09/1971 Nam ['Đại học']  Lịch sử
# Lê Thu Nam 24/09/1981 Nam ['Thạc sĩ']  Lịch sử
# Trần Bảo Sơn 23/11/1970 Nam ['Đại học']  Lịch sử
# Võ Đình Xuân 14/05/1972 Khác ['Đại học']  Lịch sử
# Lý Mai Nhật 29/11/1976 Nữ ['Đại học']  Lịch sử
# Võ Ngọc Hùng 19/02/1987 Nam ['Đại học']  Lịch sử
# Trần Thanh Minh 17/04/1977 Nữ ['Thạc sĩ']  Lịch sử
# Hồ Văn Phương 11/08/1989 Nam ['Thạc sĩ']  Lịch sử
# Võ Ngọc Vinh 23/07/1980 Nam ['Đại học'] 10A05 Địa lý
# Trần Văn Hùng 14/01/1977 Nam ['Đại học']  Địa lý
# Hồ Mai An 13/09/1976 Nữ ['Thạc sĩ']  Địa lý
# Quách Ngọc Hải 22/08/1982 Nữ ['Thạc sĩ']  Địa lý
# Dương Minh Hải 14/09/1971 Nữ ['Thạc sĩ']  Địa lý
# Thái Kim Xuân 04/04/1970 Khác ['Thạc sĩ']  Địa lý
# Hoàng Hồng Cường 26/09/1971 Nam ['Đại học']  Địa lý
# Đỗ Anh Quân 31/07/1984 Nữ ['Đại học']  Địa lý
# Đào Quý Nam 10/04/1987 Nam ['Thạc sĩ']  Địa lý
# Thái Mai Dũng 03/05/1970 Khác ['Thạc sĩ']  Địa lý
# Bành Kim Thúy 19/02/1980 Nam ['Thạc sĩ'] 10A06 Sinh học
# Lâm Mai Hiền 22/12/1987 Nam ['Đại học']  Sinh học
# Đỗ Thị Cường 28/08/1989 Nữ ['Đại học']  Sinh học
# Đặng Hoài Nhật 18/03/1981 Khác ['Đại học']  Sinh học
# Huỳnh Thanh Long 02/08/1982 Khác ['Thạc sĩ']  Sinh học
# Phạm Thị Hoàng 02/11/1979 Khác ['Thạc sĩ']  Sinh học
# Võ Hồng Ngọc 13/01/1973 Khác ['Đại học']  Sinh học
# Trương Mai An 15/02/1983 Nữ ['Đại học']  Sinh học
# Tôn Kim Việt 14/04/1981 Nam ['Đại học']  Sinh học
# Bành Văn Thúy 04/06/1988 Khác ['Đại học']  Sinh học
# Đoàn Đình Cường 24/02/1971 Khác ['Đại học'] 10A07 Tiếng Anh
# Thái Hữu Thiên 05/06/1974 Khác ['Thạc sĩ']  Tiếng Anh
# Lý Thanh Vinh 28/07/1981 Khác ['Đại học']  Tiếng Anh
# Đào Hoài Vân 13/06/1984 Nam ['Thạc sĩ']  Tiếng Anh
# Phùng Mai Thiện 26/11/1985 Nữ ['Đại học']  Tiếng Anh
# Huỳnh Anh Quang 15/10/1980 Nam ['Đại học']  Tiếng Anh
# Lý Bảo An 19/01/1971 Nữ ['Đại học']  Tiếng Anh
# Tô Văn Xuân 16/11/1971 Khác ['Đại học']  Tiếng Anh
# Tôn Minh Tùng 17/02/1970 Nam ['Thạc sĩ']  Tiếng Anh
# Tạ Đình Thúy 19/01/1981 Nam ['Thạc sĩ']  Tiếng Anh
# Tôn Hữu Khánh 15/04/1976 Khác ['Đại học'] 10A08 GDCD
# Lâm Mai Khánh 03/09/1985 Nam ['Thạc sĩ']  GDCD
# Tăng Thị Thúy 24/07/1976 Nữ ['Đại học']  GDCD
# Lương Hồng Hoàng 06/02/1976 Nam ['Thạc sĩ']  GDCD
# Dương Mai Quang 06/04/1977 Nam ['Đại học']  GDCD
# Dương Ngọc Thuận 22/06/1970 Nam ['Đại học']  GDCD
# Bùi Hữu Cường 05/04/1987 Nữ ['Thạc sĩ']  GDCD
# Ngô Quý Vinh 15/07/1983 Nam ['Đại học']  GDCD
# Ngô Kim Xuân 08/01/1976 Khác ['Đại học']  GDCD
# Đỗ Thị Hoàng 24/11/1990 Nữ ['Thạc sĩ']  GDCD
# Thái Đình Quỳnh 30/12/1982 Nam ['Đại học'] 10A09 Công nghệ
# Huỳnh Mai Hoàng 09/05/1987 Nữ ['Đại học']  Công nghệ
# Thái Bảo Quang 14/05/1987 Khác ['Thạc sĩ']  Công nghệ
# Quách Đình Thảo 16/11/1977 Nữ ['Đại học']  Công nghệ
# Đinh Thanh Linh 24/01/1984 Nữ ['Thạc sĩ']  Công nghệ
# Ngô Ngọc Quân 01/08/1975 Khác ['Thạc sĩ']  Công nghệ
# Đào Ngọc Vinh 12/01/1986 Nam ['Đại học']  Công nghệ
# Lê Ngọc Quân 27/07/1987 Khác ['Thạc sĩ']  Công nghệ
# Nguyễn Hồng Tú 27/08/1973 Nữ ['Đại học']  Công nghệ
# Hoàng Hoài Hùng 11/03/1990 Khác ['Thạc sĩ']  Công nghệ

# %%
# In DS HS trong lớp 10A01
print("Danh sách học sinh lớp 10A01:")
for hs in onto.HocSinh.instances():
    if hs.hocLop.ten == "10A01":
        print(hs)
# Out:
# Danh sách học sinh lớp 10A01:
# Ngô Quý Thuận - 13/01/2000 - Khác - 10A01
# Nguyễn Thu Thảo - 12/11/2000 - Nam - 10A01
# Võ Ngọc Tùng - 07/07/2000 - Nữ - 10A01
# Lâm Ngọc Vân - 16/07/2000 - Nữ - 10A01
# Bành Mai Hoàng - 28/08/2000 - Khác - 10A01
# Lê Hồng Vân - 13/08/2000 - Nữ - 10A01
# Hồ Hữu Xuân - 27/03/2000 - Nam - 10A01
# Thái Minh Long - 11/01/2000 - Nữ - 10A01
# Tạ Thanh Tú - 18/08/2000 - Nữ - 10A01
# Đỗ Văn Sơn - 19/11/2000 - Nam - 10A01

# %%
# in ds GV chủ nhiệm của từng lớp
print("Danh sách giáo viên chủ nhiệm:")
for lop in onto.LopHoc.instances():
    gv = lop.giaoVienChuNhiem
    if gv:
        print(gv.hoTen, gv.ngaySinh, gv.gioiTinh, gv.trinhDo, getattr(gv.lopChuNhiem,'ten',''))
# Out:
# Danh sách giáo viên chủ nhiệm:
# Tôn Ngọc Việt 23/05/1989 Nữ ['Thạc sĩ'] 10A01
# Võ Quý Nhật 26/09/1986 Nữ ['Đại học'] 10A02
# Đào Bảo Tú 13/12/1974 Khác ['Thạc sĩ'] 10A03
# Trần Ngọc Quang 03/12/1977 Nam ['Đại học'] 10A04
# Võ Ngọc Vinh 23/07/1980 Nam ['Đại học'] 10A05
# Bành Kim Thúy 19/02/1980 Nam ['Thạc sĩ'] 10A06
# Đoàn Đình Cường 24/02/1971 Khác ['Đại học'] 10A07
# Tôn Hữu Khánh 15/04/1976 Khác ['Đại học'] 10A08
# Thái Đình Quỳnh 30/12/1982 Nam ['Đại học'] 10A09

# %%
# Sửa tên của giáo viên chủ nhiệm Nguyễn Văn X thành Nguyễn Văn Tèo
print("Sửa tên của giáo viên chủ nhiệm Nguyễn Văn X thành Nguyễn Văn Tèo")
for gv in onto.GiaoVien.instances():
    if gv.hoTen == "Nguyễn Văn X":
        gv.hoTen = "Nguyễn Văn Tèo"
        print(gv.hoTen, gv.ngaySinh, gv.gioiTinh, gv.trinhDo, getattr(gv.lopChuNhiem,'ten',''))
# Out:
# Sửa tên của giáo viên chủ nhiệm Nguyễn Văn X thành Nguyễn Văn Tèo

# %%
# Tạo mới một học sinh và thêm vào lớp 10A01
print("Tạo mới một học sinh và thêm vào lớp 10A01")
lop = onto.search_one(ten = "10A01", type = onto.LopHoc)
hs1 = HocSinh(hoTen = "Nguyễn Văn XXX", ngaySinh = "01/01/2011", gioiTinh = "Nam", lopHoc = lop)
# In DS HS trong lớp 10A01
print("Danh sách học sinh lớp 10A01:")
print('\n'.join(str(hs) for hs in lop.dsHocSinh))
# Out:
# Tạo mới một học sinh và thêm vào lớp 10A01
# Danh sách học sinh lớp 10A01:
# Ngô Quý Thuận - 13/01/2000 - Khác - 10A01
# Nguyễn Thu Thảo - 12/11/2000 - Nam - 10A01
# Võ Ngọc Tùng - 07/07/2000 - Nữ - 10A01
# Lâm Ngọc Vân - 16/07/2000 - Nữ - 10A01
# Bành Mai Hoàng - 28/08/2000 - Khác - 10A01
# Lê Hồng Vân - 13/08/2000 - Nữ - 10A01
# Hồ Hữu Xuân - 27/03/2000 - Nam - 10A01
# Thái Minh Long - 11/01/2000 - Nữ - 10A01
# Tạ Thanh Tú - 18/08/2000 - Nữ - 10A01
# Đỗ Văn Sơn - 19/11/2000 - Nam - 10A01

# %%
# Xoá học sinh có ngày sinh là 01/01/2011
print("Xoá học sinh có ngày sinh là 01/01/2011")
hs_ind = onto.search_one(ngaySinh="01/01/2011", type=onto.HocSinh)
# Nếu individual được tìm thấy, xoá individual đó
if hs_ind is not None:
    destroy_entity(hs_ind)
# Out:
# Xoá học sinh có ngày sinh là 01/01/2011

# %%
# In tất cả điểm số của một học sinh
print("In tất cả điểm số của một học sinh")
hs_ind = onto.search_one(type=onto.HocSinh)
if hs_ind is not None:
    for diem in hs_ind.diemSo:
        print(diem.monHoc.ten, *diem.heSo1, *diem.heSo2, *diem.heSo3)
# Out:
# In tất cả điểm số của một học sinh
# Toán học 4.5 4.3 7.3 0.8 3.3 5.8
# Ngữ văn 6.5 9.5 9.8 10 8.3 7.8
# Hóa học 2.8 2.5 0.3 8.8 7.8 4.5
# Lịch sử 8.8 9.8 2.3 5.5 2.5 8.8
# Địa lý 10 0.8 7.3 4.5 7.3 5.8
# Sinh học 7.3 9.8 2.3 8.3 7.8
# Tiếng Anh 8.5 7.8 3.3 8.5 1.5 6.3
# GDCD 9.3 1.5 8.5 1.3 5.5 3.8
# Công nghệ 4.5 10 9.3 9.5 4.3 10

# %%
print(hoTen.iri)
print(HocSinh.iri)
# Out:
# http://hc.com/school#hoTen
# http://hc.com/school#HocSinh

# %%
# sử dụng SPARQL để tìm tất cả các học sinh có họ Lê
print("sử dụng SPARQL để tìm tất cả các học sinh có họ Lê")
result = default_world.sparql("""
PREFIX school: <http://hc.com/school#>
SELECT ?hoTen 
WHERE {
    # ?hs a school:HocSinh.
    # ?hs school:hoTen ?hoTen.
    FILTER (STRSTARTS(?hoTen, "Lê")).
}

""")
# in kết quả
print(list(result))
# Out:
# sử dụng SPARQL để tìm tất cả các học sinh có họ Lê
# [['Lê Hồng Vân'], ['Lê Đình Thuận'], ['Lê Thị Hiền'], ['Lê Mai Khánh'], ['Lê Kim Hiền']]
