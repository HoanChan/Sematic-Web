# %% [markdown]
# ### Cài đặt thư viện:
#
# Cài đặt các thư viện vào môi trường anaconda:
#
# ```bash
# conda install -c conda-forge owlready2
# ```

# %% [markdown]
# ### Tạo ontology

# %%
# %run ../app/models/model.py
# Out:
# * Owlready2 * Warning: optimized Cython parser module 'owlready2_optimized' is not available, defaulting to slower Python implementation

# %%
lsPro = list(onto.properties())
def get_properties(obj):
    return [p for p in lsPro if obj.is_a[0] in p.domain] + [p for p in lsPro if obj in p.domain]
print('STT\tTên lớp\tKế thừa từ\tThuộc tính')
lsClass= list(onto.classes())
for i, class_ in zip(range(len(lsClass)), lsClass):
    print(f"{str(i+1)}\t{class_.name}\t{str(class_.is_a).split('.')[1][:-1]}\t{', '.join([x.name for x in get_properties(class_)])}")
    # print(str(i+1)+'.', class_.name, 'kế thừa từ', class_.is_a)
    # for x in get_properties(class_) :
    #     print('-', x.name, ':', x.range[0])
# Out:
# STT	Tên lớp	Kế thừa từ	Thuộc tính
# 1	ChucVu	Thing	ten, phuCap
# 2	ToChuc	Thing	ten, thanhVien, phong
# 3	Nguoi	Thing	hoTen, ngaySinh, gioiTinh, toChuc
# 4	NhanVien	Nguoi	hoTen, ngaySinh, gioiTinh, toChuc, heSoLuong, chucVu, phongLamViec
# 5	PhuHuynh	Nguoi	hoTen, ngaySinh, gioiTinh, toChuc, ngheNghiep, con
# 6	Cha	PhuHuynh	ngheNghiep, con, vo
# 7	Me	PhuHuynh	ngheNghiep, con, chong
# 8	LopHoc	ToChuc	ten, thanhVien, phong, giaoVienChuNhiem, dsHocSinh
# 9	HocSinh	Nguoi	hoTen, ngaySinh, gioiTinh, toChuc, diemTB, hanhKiem, hocLuc, danhHieu, hocLop, phuHuynh, me, cha, diemSo, anhChiEm, anh, chi, em
# 10	Anh	HocSinh	diemTB, hanhKiem, hocLuc, danhHieu, hocLop, phuHuynh, me, cha, diemSo, anhChiEm, anh, chi, em
# 11	Chi	HocSinh	diemTB, hanhKiem, hocLuc, danhHieu, hocLop, phuHuynh, me, cha, diemSo, anhChiEm, anh, chi, em
# 12	Em	HocSinh	diemTB, hanhKiem, hocLuc, danhHieu, hocLop, phuHuynh, me, cha, diemSo, anhChiEm, anh, chi, em
# 13	GiaoVien	NhanVien	heSoLuong, chucVu, phongLamViec, trinhDo, dayMon, giangDay, lopChuNhiem
# 14	MonHoc	Thing	ten, soTiet, giaoVienDay
# 15	DiemSo	Thing	diemTB, heSo1, heSo2, heSo3, hocSinh, monHoc
# 16	GiangDay	Thing	monHoc, giaoVien, lopHoc
# 17	Phong	Thing	ten, suDungBoi
# 18	HoatDong	Thing	ten, ngayBatDau, ngayKetThuc, quanLy, thamGia
# 19	DiemDanh	Thing	ngayGio, trangThai, nguoi, hoatDong

# %%
print('\nSTT\tTên thuộc tính\tDomain\tRange\tLoại')
import re
i=1
for p in lsPro:
    if p.is_a[0].name == 'ObjectProperty': continue
    domains = set([str(d).split('.')[1] for d in p.domain])
    ranges = []
    for r in p.range:
        data = re.findall(r"[\w']+", str(r))
        ranges.append(data[1].replace("'", ''))
    stype = [a.name for a in p.is_a][1:]
    print(f"{i}\t{p.name}\t{', '.join(domains)}\t{', '.join(set(ranges))}\t{', '.join(stype)}")
    i+=1
# Out:
# STT	Tên thuộc tính	Domain	Range	Loại
# 1	ten	MonHoc, ChucVu, HoatDong, ToChuc, Phong	str	FunctionalProperty
# 2	phuCap	ChucVu	float	FunctionalProperty
# 3	hoTen	Nguoi	str	FunctionalProperty
# 4	ngaySinh	Nguoi	datetime	FunctionalProperty
# 5	gioiTinh	Nguoi	str	FunctionalProperty
# 6	heSoLuong	NhanVien	float	FunctionalProperty
# 7	ngheNghiep	PhuHuynh	str	FunctionalProperty
# 8	diemTB	DiemSo, HocSinh	float	FunctionalProperty
# 9	hanhKiem	HocSinh	str	FunctionalProperty
# 10	trinhDo	GiaoVien	str	FunctionalProperty
# 11	soTiet	MonHoc	int	FunctionalProperty
# 12	heSo1	DiemSo	float
# 13	heSo2	DiemSo	float
# 14	heSo3	DiemSo	float
# 15	ngayBatDau	HoatDong	datetime	FunctionalProperty
# 16	ngayKetThuc	HoatDong	datetime	FunctionalProperty
# 17	ngayGio	DiemDanh	datetime	FunctionalProperty
# 18	trangThai	DiemDanh	str	FunctionalProperty
# 19	hocLuc	HocSinh	str	FunctionalProperty
# 20	danhHieu	HocSinh	str	FunctionalProperty

# %%
print('\nSTT\tTên thuộc tính\tDomain\tRange\tLoại')
import re
i=1
for p in lsPro:
    if p.is_a[0].name != 'ObjectProperty': continue
    domains = set([str(d).split('.')[1] for d in p.domain])
    ranges = []
    for r in p.range:
        data = re.findall(r"[\w']+", str(r))
        ranges.append(data[1].replace("'", ''))
    stype = [a.name for a in p.is_a][1:]
    print(f"{i}\t{p.name}\t{', '.join(domains)}\t{', '.join(set(ranges))}\t{', '.join(stype)}")
    i+=1
# Out:
# STT	Tên thuộc tính	Domain	Range	Loại
# 1	thanhVien	ToChuc	Nguoi
# 2	phong	ToChuc	Phong
# 3	toChuc	Nguoi	ToChuc
# 4	chucVu	NhanVien	ChucVu
# 5	con	PhuHuynh	HocSinh
# 6	giaoVienChuNhiem	LopHoc	GiaoVien	FunctionalProperty
# 7	dsHocSinh	LopHoc	HocSinh
# 8	hocLop	HocSinh	LopHoc	FunctionalProperty
# 9	phuHuynh	HocSinh	PhuHuynh
# 10	me	HocSinh	Me	FunctionalProperty, phuHuynh
# 11	cha	HocSinh	Cha	FunctionalProperty, phuHuynh
# 12	diemSo	HocSinh	DiemSo
# 13	dayMon	GiaoVien	MonHoc
# 14	giangDay	GiaoVien	GiangDay
# 15	lopChuNhiem	GiaoVien	LopHoc	FunctionalProperty
# 16	giaoVienDay	MonHoc	GiaoVien
# 17	hocSinh	DiemSo	HocSinh	FunctionalProperty
# 18	monHoc	GiangDay, DiemSo	MonHoc	FunctionalProperty
# 19	giaoVien	GiangDay	GiaoVien	FunctionalProperty
# 20	lopHoc	GiangDay	LopHoc	FunctionalProperty
# 21	suDungBoi	Phong	ToChuc
# 22	quanLy	HoatDong	Nguoi
# 23	thamGia	HoatDong	Nguoi
# 24	nguoi	DiemDanh	Nguoi	FunctionalProperty
# 25	hoatDong	DiemDanh	HoatDong	FunctionalProperty
# 26	anhChiEm	HocSinh	HocSinh
# 27	anh	HocSinh	Anh	anhChiEm
# 28	chi	HocSinh	Chi	anhChiEm
# 29	em	HocSinh	Em	anhChiEm
# 30	vo	Cha	Me	FunctionalProperty
# 31	chong	Me	Cha	FunctionalProperty
# 32	phongLamViec	NhanVien	Phong

# %%
# Lưu CSDL ra file
onto.save(file="../app/data/education.owl")
with open("../app/data/education.owl", "r") as f:
    print(f.read())
# Out:
# <?xml version="1.0"?>
# <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#"
#          xmlns:xsd="http://www.w3.org/2001/XMLSchema#"
#          xmlns:rdfs="http://www.w3.org/2000/01/rdf-schema#"
#          xmlns:owl="http://www.w3.org/2002/07/owl#"
#          xml:base="http://hc.com/school"
#          xmlns="http://hc.com/school#"
#          xmlns:swrl="http://www.w3.org/2003/11/swrl#">
#
# <owl:Ontology rdf:about="http://hc.com/school"/>
#
# <owl:ObjectProperty rdf:about="#thanhVien">
#   <rdfs:domain rdf:resource="#ToChuc"/>
#   <rdfs:range rdf:resource="#Nguoi"/>
#   <owl:inverseOf rdf:resource="#toChuc"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#phong">
#   <rdfs:domain rdf:resource="#ToChuc"/>
#   <rdfs:range rdf:resource="#Phong"/>
#   <owl:inverseOf rdf:resource="#suDungBoi"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#toChuc">
#   <rdfs:domain rdf:resource="#Nguoi"/>
#   <rdfs:range rdf:resource="#ToChuc"/>
#   <owl:inverseOf rdf:resource="#thanhVien"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#chucVu">
#   <rdfs:domain rdf:resource="#NhanVien"/>
#   <rdfs:range rdf:resource="#ChucVu"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#con">
#   <rdfs:domain rdf:resource="#PhuHuynh"/>
#   <rdfs:range rdf:resource="#HocSinh"/>
#   <owl:inverseOf rdf:resource="#phuHuynh"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#giaoVienChuNhiem">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#LopHoc"/>
#   <rdfs:range rdf:resource="#GiaoVien"/>
#   <owl:inverseOf rdf:resource="#lopChuNhiem"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#dsHocSinh">
#   <rdfs:domain rdf:resource="#LopHoc"/>
#   <rdfs:range rdf:resource="#HocSinh"/>
#   <owl:inverseOf rdf:resource="#hocLop"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#hocLop">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#LopHoc"/>
#   <owl:inverseOf rdf:resource="#dsHocSinh"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#phuHuynh">
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#PhuHuynh"/>
#   <owl:inverseOf rdf:resource="#con"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#me">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:subPropertyOf rdf:resource="#phuHuynh"/>
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#Me"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#cha">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:subPropertyOf rdf:resource="#phuHuynh"/>
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#Cha"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#diemSo">
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#DiemSo"/>
#   <owl:inverseOf rdf:resource="#hocSinh"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#dayMon">
#   <rdfs:domain rdf:resource="#GiaoVien"/>
#   <rdfs:range rdf:resource="#MonHoc"/>
#   <owl:inverseOf rdf:resource="#giaoVienDay"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#giangDay">
#   <rdfs:domain rdf:resource="#GiaoVien"/>
#   <rdfs:range rdf:resource="#GiangDay"/>
#   <owl:inverseOf rdf:resource="#giaoVien"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#lopChuNhiem">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#GiaoVien"/>
#   <rdfs:range rdf:resource="#LopHoc"/>
#   <owl:inverseOf rdf:resource="#giaoVienChuNhiem"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#giaoVienDay">
#   <rdfs:domain rdf:resource="#MonHoc"/>
#   <rdfs:range rdf:resource="#GiaoVien"/>
#   <owl:inverseOf rdf:resource="#dayMon"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#hocSinh">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="#HocSinh"/>
#   <owl:inverseOf rdf:resource="#diemSo"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#monHoc">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="#MonHoc"/>
#   <rdfs:domain rdf:resource="#GiangDay"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#giaoVien">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#GiangDay"/>
#   <rdfs:range rdf:resource="#GiaoVien"/>
#   <owl:inverseOf rdf:resource="#giangDay"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#lopHoc">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#GiangDay"/>
#   <rdfs:range rdf:resource="#LopHoc"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#suDungBoi">
#   <rdfs:domain rdf:resource="#Phong"/>
#   <rdfs:range rdf:resource="#ToChuc"/>
#   <owl:inverseOf rdf:resource="#phong"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#quanLy">
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:range rdf:resource="#Nguoi"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#thamGia">
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:range rdf:resource="#Nguoi"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#nguoi">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemDanh"/>
#   <rdfs:range rdf:resource="#Nguoi"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#hoatDong">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemDanh"/>
#   <rdfs:range rdf:resource="#HoatDong"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#anhChiEm">
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#HocSinh"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#anh">
#   <rdfs:subPropertyOf rdf:resource="#anhChiEm"/>
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#Anh"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#chi">
#   <rdfs:subPropertyOf rdf:resource="#anhChiEm"/>
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#Chi"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#em">
#   <rdfs:subPropertyOf rdf:resource="#anhChiEm"/>
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#Em"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#vo">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Cha"/>
#   <rdfs:range rdf:resource="#Me"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#chong">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Me"/>
#   <rdfs:range rdf:resource="#Cha"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#phongLamViec">
#   <rdfs:domain rdf:resource="#NhanVien"/>
#   <rdfs:range rdf:resource="#Phong"/>
# </owl:ObjectProperty>
#
# <owl:DatatypeProperty rdf:about="#ten">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#ChucVu"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
#   <rdfs:domain rdf:resource="#ToChuc"/>
#   <rdfs:domain rdf:resource="#MonHoc"/>
#   <rdfs:domain rdf:resource="#Phong"/>
#   <rdfs:domain rdf:resource="#HoatDong"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#phuCap">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#ChucVu"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#hoTen">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Nguoi"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngaySinh">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Nguoi"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#gioiTinh">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Nguoi"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#heSoLuong">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#NhanVien"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngheNghiep">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#PhuHuynh"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#diemTB">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
#   <rdfs:domain rdf:resource="#DiemSo"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#hanhKiem">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#trinhDo">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#GiaoVien"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#soTiet">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#MonHoc"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#integer"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#heSo1">
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#heSo2">
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#heSo3">
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayBatDau">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayKetThuc">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayGio">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemDanh"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#dateTime"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#trangThai">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemDanh"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#hocLuc">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#danhHieu">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:Class rdf:about="#ChucVu">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#ToChuc">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#Nguoi">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#NhanVien">
#   <rdfs:subClassOf rdf:resource="#Nguoi"/>
# </owl:Class>
#
# <owl:Class rdf:about="#PhuHuynh">
#   <rdfs:subClassOf rdf:resource="#Nguoi"/>
# </owl:Class>
#
# <owl:Class rdf:about="#Cha">
#   <rdfs:subClassOf rdf:resource="#PhuHuynh"/>
# </owl:Class>
#
# <owl:Class rdf:about="#Me">
#   <rdfs:subClassOf rdf:resource="#PhuHuynh"/>
# </owl:Class>
#
# <owl:Class rdf:about="#LopHoc">
#   <rdfs:subClassOf rdf:resource="#ToChuc"/>
# </owl:Class>
#
# <owl:Class rdf:about="#HocSinh">
#   <rdfs:subClassOf rdf:resource="#Nguoi"/>
# </owl:Class>
#
# <owl:Class rdf:about="#Anh">
#   <rdfs:subClassOf rdf:resource="#HocSinh"/>
# </owl:Class>
#
# <owl:Class rdf:about="#Chi">
#   <rdfs:subClassOf rdf:resource="#HocSinh"/>
# </owl:Class>
#
# <owl:Class rdf:about="#Em">
#   <rdfs:subClassOf rdf:resource="#HocSinh"/>
# </owl:Class>
#
# <owl:Class rdf:about="#GiaoVien">
#   <rdfs:subClassOf rdf:resource="#NhanVien"/>
# </owl:Class>
#
# <owl:Class rdf:about="#MonHoc">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#DiemSo">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#GiangDay">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#Phong">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#HoatDong">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#DiemDanh">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <swrl:Variable rdf:about="urn:swrl#hs"/>
#
# <swrl:Variable rdf:about="urn:swrl#c"/>
#
# <swrl:Variable rdf:about="urn:swrl#m"/>
#
# <swrl:Variable rdf:about="urn:swrl#ph1"/>
#
# <swrl:Variable rdf:about="urn:swrl#ph2"/>
#
# <swrl:Variable rdf:about="urn:swrl#hs1"/>
#
# <swrl:Variable rdf:about="urn:swrl#hs2"/>
#
# <swrl:Variable rdf:about="urn:swrl#ns1"/>
#
# <swrl:Variable rdf:about="urn:swrl#ns2"/>
#
# <swrl:Variable rdf:about="urn:swrl#dtb"/>
#
# <swrl:Variable rdf:about="urn:swrl#hl"/>
#
# <swrl:Variable rdf:about="urn:swrl#hk"/>
#
# <swrl:Variable rdf:about="urn:swrl#gv"/>
#
# <swrl:Variable rdf:about="urn:swrl#dscv"/>
#
# <swrl:Variable rdf:about="urn:swrl#cv"/>
#
# <swrl:Variable rdf:about="urn:swrl#tc"/>
#
# <swrl:Variable rdf:about="urn:swrl#p"/>
#
# <swrl:Variable rdf:about="urn:swrl#lh"/>
#
# <swrl:Imp>
#   <swrl:body>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:ClassAtom>
#           <swrl:classPredicate rdf:resource="#LopHoc"/>
#           <swrl:argument1 rdf:resource="urn:swrl#lh"/>
#         </swrl:ClassAtom>
#       </rdf:first>
#       <rdf:rest>
#         <rdf:Description>
#           <rdf:first>
#             <swrl:IndividualPropertyAtom>
#               <swrl:propertyPredicate rdf:resource="#giaoVienChuNhiem"/>
#               <swrl:argument1 rdf:resource="urn:swrl#lh"/>
#               <swrl:argument2 rdf:resource="urn:swrl#gv"/>
#             </swrl:IndividualPropertyAtom>
#           </rdf:first>
#           <rdf:rest>
#             <rdf:Description>
#               <rdf:first>
#                 <swrl:IndividualPropertyAtom>
#                   <swrl:propertyPredicate rdf:resource="#phong"/>
#                   <swrl:argument1 rdf:resource="urn:swrl#lh"/>
#                   <swrl:argument2 rdf:resource="urn:swrl#p"/>
#                 </swrl:IndividualPropertyAtom>
#               </rdf:first>
#               <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#             </rdf:Description>
#           </rdf:rest>
#         </rdf:Description>
#       </rdf:rest>
#     </rdf:Description>
#   </swrl:body>
#   <swrl:head>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:IndividualPropertyAtom>
#           <swrl:propertyPredicate rdf:resource="#phongLamViec"/>
#           <swrl:argument1 rdf:resource="urn:swrl#gv"/>
#           <swrl:argument2 rdf:resource="urn:swrl#p"/>
#         </swrl:IndividualPropertyAtom>
#       </rdf:first>
#       <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#     </rdf:Description>
#   </swrl:head>
# </swrl:Imp>
#
# <swrl:Imp>
#   <swrl:body>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:ClassAtom>
#           <swrl:classPredicate rdf:resource="#GiaoVien"/>
#           <swrl:argument1 rdf:resource="urn:swrl#gv"/>
#         </swrl:ClassAtom>
#       </rdf:first>
#       <rdf:rest>
#         <rdf:Description>
#           <rdf:first>
#             <swrl:IndividualPropertyAtom>
#               <swrl:propertyPredicate rdf:resource="#chucVu"/>
#               <swrl:argument1 rdf:resource="urn:swrl#gv"/>
#               <swrl:argument2 rdf:resource="urn:swrl#dscv"/>
#             </swrl:IndividualPropertyAtom>
#           </rdf:first>
#           <rdf:rest>
#             <rdf:Description>
#               <rdf:first>
#                 <swrl:ClassAtom>
#                   <swrl:classPredicate rdf:resource="#ChucVu"/>
#                   <swrl:argument1 rdf:resource="urn:swrl#cv"/>
#                 </swrl:ClassAtom>
#               </rdf:first>
#               <rdf:rest>
#                 <rdf:Description>
#                   <rdf:first>
#                     <swrl:BuiltinAtom>
#                       <swrl:builtin rdf:resource="http://www.w3.org/2003/11/swrlb#endsWith"/>
#                       <swrl:arguments>
#                         <rdf:Description>
#                           <rdf:first rdf:resource="urn:swrl#cv"/>
#                           <rdf:rest>
#                             <rdf:Description>
#                               <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                               <rdf:first rdf:datatype="http://www.w3.org/2001/XMLSchema#string">cvToTruong</rdf:first>
#                             </rdf:Description>
#                           </rdf:rest>
#                         </rdf:Description>
#                       </swrl:arguments>
#                     </swrl:BuiltinAtom>
#                   </rdf:first>
#                   <rdf:rest>
#                     <rdf:Description>
#                       <rdf:first>
#                         <swrl:BuiltinAtom>
#                           <swrl:builtin rdf:resource="http://www.w3.org/2003/11/swrlb#member"/>
#                           <swrl:arguments>
#                             <rdf:Description>
#                               <rdf:first rdf:resource="urn:swrl#cv"/>
#                               <rdf:rest>
#                                 <rdf:Description>
#                                   <rdf:first rdf:resource="urn:swrl#dscv"/>
#                                   <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                                 </rdf:Description>
#                               </rdf:rest>
#                             </rdf:Description>
#                           </swrl:arguments>
#                         </swrl:BuiltinAtom>
#                       </rdf:first>
#                       <rdf:rest>
#                         <rdf:Description>
#                           <rdf:first>
#                             <swrl:IndividualPropertyAtom>
#                               <swrl:propertyPredicate rdf:resource="#toChuc"/>
#                               <swrl:argument1 rdf:resource="urn:swrl#gv"/>
#                               <swrl:argument2 rdf:resource="urn:swrl#tc"/>
#                             </swrl:IndividualPropertyAtom>
#                           </rdf:first>
#                           <rdf:rest>
#                             <rdf:Description>
#                               <rdf:first>
#                                 <swrl:IndividualPropertyAtom>
#                                   <swrl:propertyPredicate rdf:resource="#phong"/>
#                                   <swrl:argument1 rdf:resource="urn:swrl#tc"/>
#                                   <swrl:argument2 rdf:resource="urn:swrl#p"/>
#                                 </swrl:IndividualPropertyAtom>
#                               </rdf:first>
#                               <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                             </rdf:Description>
#                           </rdf:rest>
#                         </rdf:Description>
#                       </rdf:rest>
#                     </rdf:Description>
#                   </rdf:rest>
#                 </rdf:Description>
#               </rdf:rest>
#             </rdf:Description>
#           </rdf:rest>
#         </rdf:Description>
#       </rdf:rest>
#     </rdf:Description>
#   </swrl:body>
#   <swrl:head>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:IndividualPropertyAtom>
#           <swrl:propertyPredicate rdf:resource="#phongLamViec"/>
#           <swrl:argument1 rdf:resource="urn:swrl#gv"/>
#           <swrl:argument2 rdf:resource="urn:swrl#p"/>
#         </swrl:IndividualPropertyAtom>
#       </rdf:first>
#       <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#     </rdf:Description>
#   </swrl:head>
# </swrl:Imp>
#
# <swrl:Imp>
#   <swrl:body>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:ClassAtom>
#           <swrl:classPredicate rdf:resource="#HocSinh"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#         </swrl:ClassAtom>
#       </rdf:first>
#       <rdf:rest>
#         <rdf:Description>
#           <rdf:first>
#             <swrl:DatavaluedPropertyAtom>
#               <swrl:propertyPredicate rdf:resource="#hocLuc"/>
#               <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#               <swrl:argument2 rdf:resource="urn:swrl#hl"/>
#             </swrl:DatavaluedPropertyAtom>
#           </rdf:first>
#           <rdf:rest>
#             <rdf:Description>
#               <rdf:first>
#                 <swrl:DatavaluedPropertyAtom>
#                   <swrl:propertyPredicate rdf:resource="#hanhKiem"/>
#                   <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#                   <swrl:argument2 rdf:resource="urn:swrl#hk"/>
#                 </swrl:DatavaluedPropertyAtom>
#               </rdf:first>
#               <rdf:rest>
#                 <rdf:Description>
#                   <rdf:first>
#                     <swrl:BuiltinAtom>
#                       <swrl:builtin rdf:resource="http://www.w3.org/2003/11/swrlb#startsWith"/>
#                       <swrl:arguments>
#                         <rdf:Description>
#                           <rdf:first rdf:resource="urn:swrl#hl"/>
#                           <rdf:rest>
#                             <rdf:Description>
#                               <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                               <rdf:first rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Kh</rdf:first>
#                             </rdf:Description>
#                           </rdf:rest>
#                         </rdf:Description>
#                       </swrl:arguments>
#                     </swrl:BuiltinAtom>
#                   </rdf:first>
#                   <rdf:rest>
#                     <rdf:Description>
#                       <rdf:first>
#                         <swrl:BuiltinAtom>
#                           <swrl:builtin rdf:resource="http://www.w3.org/2003/11/swrlb#startsWith"/>
#                           <swrl:arguments>
#                             <rdf:Description>
#                               <rdf:first rdf:resource="urn:swrl#hk"/>
#                               <rdf:rest>
#                                 <rdf:Description>
#                                   <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                                   <rdf:first rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Kh</rdf:first>
#                                 </rdf:Description>
#                               </rdf:rest>
#                             </rdf:Description>
#                           </swrl:arguments>
#                         </swrl:BuiltinAtom>
#                       </rdf:first>
#                       <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                     </rdf:Description>
#                   </rdf:rest>
#                 </rdf:Description>
#               </rdf:rest>
#             </rdf:Description>
#           </rdf:rest>
#         </rdf:Description>
#       </rdf:rest>
#     </rdf:Description>
#   </swrl:body>
#   <swrl:head>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:DatavaluedPropertyAtom>
#           <swrl:propertyPredicate rdf:resource="#danhHieu"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#           <swrl:argument2 rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Học sinh tiên tiến</swrl:argument2>
#         </swrl:DatavaluedPropertyAtom>
#       </rdf:first>
#       <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#     </rdf:Description>
#   </swrl:head>
# </swrl:Imp>
#
# <swrl:Imp>
#   <swrl:body>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:ClassAtom>
#           <swrl:classPredicate rdf:resource="#HocSinh"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#         </swrl:ClassAtom>
#       </rdf:first>
#       <rdf:rest>
#         <rdf:Description>
#           <rdf:first>
#             <swrl:DatavaluedPropertyAtom>
#               <swrl:propertyPredicate rdf:resource="#hocLuc"/>
#               <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#               <swrl:argument2 rdf:resource="urn:swrl#hl"/>
#             </swrl:DatavaluedPropertyAtom>
#           </rdf:first>
#           <rdf:rest>
#             <rdf:Description>
#               <rdf:first>
#                 <swrl:DatavaluedPropertyAtom>
#                   <swrl:propertyPredicate rdf:resource="#hanhKiem"/>
#                   <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#                   <swrl:argument2 rdf:resource="urn:swrl#hk"/>
#                 </swrl:DatavaluedPropertyAtom>
#               </rdf:first>
#               <rdf:rest>
#                 <rdf:Description>
#                   <rdf:first>
#                     <swrl:BuiltinAtom>
#                       <swrl:builtin rdf:resource="http://www.w3.org/2003/11/swrlb#startsWith"/>
#                       <swrl:arguments>
#                         <rdf:Description>
#                           <rdf:first rdf:resource="urn:swrl#hl"/>
#                           <rdf:rest>
#                             <rdf:Description>
#                               <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                               <rdf:first rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Kh</rdf:first>
#                             </rdf:Description>
#                           </rdf:rest>
#                         </rdf:Description>
#                       </swrl:arguments>
#                     </swrl:BuiltinAtom>
#                   </rdf:first>
#                   <rdf:rest>
#                     <rdf:Description>
#                       <rdf:first>
#                         <swrl:BuiltinAtom>
#                           <swrl:builtin rdf:resource="http://www.w3.org/2003/11/swrlb#endsWith"/>
#                           <swrl:arguments>
#                             <rdf:Description>
#                               <rdf:first rdf:resource="urn:swrl#hk"/>
#                               <rdf:rest>
#                                 <rdf:Description>
#                                   <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                                   <rdf:first rdf:datatype="http://www.w3.org/2001/XMLSchema#string">t</rdf:first>
#                                 </rdf:Description>
#                               </rdf:rest>
#                             </rdf:Description>
#                           </swrl:arguments>
#                         </swrl:BuiltinAtom>
#                       </rdf:first>
#                       <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                     </rdf:Description>
#                   </rdf:rest>
#                 </rdf:Description>
#               </rdf:rest>
#             </rdf:Description>
#           </rdf:rest>
#         </rdf:Description>
#       </rdf:rest>
#     </rdf:Description>
#   </swrl:body>
#   <swrl:head>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:DatavaluedPropertyAtom>
#           <swrl:propertyPredicate rdf:resource="#danhHieu"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#           <swrl:argument2 rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Học sinh tiên tiến</swrl:argument2>
#         </swrl:DatavaluedPropertyAtom>
#       </rdf:first>
#       <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#     </rdf:Description>
#   </swrl:head>
# </swrl:Imp>
#
# <swrl:Imp>
#   <swrl:body>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:ClassAtom>
#           <swrl:classPredicate rdf:resource="#HocSinh"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#         </swrl:ClassAtom>
#       </rdf:first>
#       <rdf:rest>
#         <rdf:Description>
#           <rdf:first>
#             <swrl:DatavaluedPropertyAtom>
#               <swrl:propertyPredicate rdf:resource="#hocLuc"/>
#               <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#               <swrl:argument2 rdf:resource="urn:swrl#hl"/>
#             </swrl:DatavaluedPropertyAtom>
#           </rdf:first>
#           <rdf:rest>
#             <rdf:Description>
#               <rdf:first>
#                 <swrl:DatavaluedPropertyAtom>
#                   <swrl:propertyPredicate rdf:resource="#hanhKiem"/>
#                   <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#                   <swrl:argument2 rdf:resource="urn:swrl#hk"/>
#                 </swrl:DatavaluedPropertyAtom>
#               </rdf:first>
#               <rdf:rest>
#                 <rdf:Description>
#                   <rdf:first>
#                     <swrl:BuiltinAtom>
#                       <swrl:builtin rdf:resource="http://www.w3.org/2003/11/swrlb#startsWith"/>
#                       <swrl:arguments>
#                         <rdf:Description>
#                           <rdf:first rdf:resource="urn:swrl#hl"/>
#                           <rdf:rest>
#                             <rdf:Description>
#                               <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                               <rdf:first rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Gi</rdf:first>
#                             </rdf:Description>
#                           </rdf:rest>
#                         </rdf:Description>
#                       </swrl:arguments>
#                     </swrl:BuiltinAtom>
#                   </rdf:first>
#                   <rdf:rest>
#                     <rdf:Description>
#                       <rdf:first>
#                         <swrl:BuiltinAtom>
#                           <swrl:builtin rdf:resource="http://www.w3.org/2003/11/swrlb#startsWith"/>
#                           <swrl:arguments>
#                             <rdf:Description>
#                               <rdf:first rdf:resource="urn:swrl#hk"/>
#                               <rdf:rest>
#                                 <rdf:Description>
#                                   <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                                   <rdf:first rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Kh</rdf:first>
#                                 </rdf:Description>
#                               </rdf:rest>
#                             </rdf:Description>
#                           </swrl:arguments>
#                         </swrl:BuiltinAtom>
#                       </rdf:first>
#                       <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                     </rdf:Description>
#                   </rdf:rest>
#                 </rdf:Description>
#               </rdf:rest>
#             </rdf:Description>
#           </rdf:rest>
#         </rdf:Description>
#       </rdf:rest>
#     </rdf:Description>
#   </swrl:body>
#   <swrl:head>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:DatavaluedPropertyAtom>
#           <swrl:propertyPredicate rdf:resource="#danhHieu"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#           <swrl:argument2 rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Học sinh giỏi</swrl:argument2>
#         </swrl:DatavaluedPropertyAtom>
#       </rdf:first>
#       <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#     </rdf:Description>
#   </swrl:head>
# </swrl:Imp>
#
# <swrl:Imp>
#   <swrl:body>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:ClassAtom>
#           <swrl:classPredicate rdf:resource="#HocSinh"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#         </swrl:ClassAtom>
#       </rdf:first>
#       <rdf:rest>
#         <rdf:Description>
#           <rdf:first>
#             <swrl:DatavaluedPropertyAtom>
#               <swrl:propertyPredicate rdf:resource="#hocLuc"/>
#               <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#               <swrl:argument2 rdf:resource="urn:swrl#hl"/>
#             </swrl:DatavaluedPropertyAtom>
#           </rdf:first>
#           <rdf:rest>
#             <rdf:Description>
#               <rdf:first>
#                 <swrl:DatavaluedPropertyAtom>
#                   <swrl:propertyPredicate rdf:resource="#hanhKiem"/>
#                   <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#                   <swrl:argument2 rdf:resource="urn:swrl#hk"/>
#                 </swrl:DatavaluedPropertyAtom>
#               </rdf:first>
#               <rdf:rest>
#                 <rdf:Description>
#                   <rdf:first>
#                     <swrl:BuiltinAtom>
#                       <swrl:builtin rdf:resource="http://www.w3.org/2003/11/swrlb#startsWith"/>
#                       <swrl:arguments>
#                         <rdf:Description>
#                           <rdf:first rdf:resource="urn:swrl#hl"/>
#                           <rdf:rest>
#                             <rdf:Description>
#                               <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                               <rdf:first rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Gi</rdf:first>
#                             </rdf:Description>
#                           </rdf:rest>
#                         </rdf:Description>
#                       </swrl:arguments>
#                     </swrl:BuiltinAtom>
#                   </rdf:first>
#                   <rdf:rest>
#                     <rdf:Description>
#                       <rdf:first>
#                         <swrl:BuiltinAtom>
#                           <swrl:builtin rdf:resource="http://www.w3.org/2003/11/swrlb#endsWith"/>
#                           <swrl:arguments>
#                             <rdf:Description>
#                               <rdf:first rdf:resource="urn:swrl#hk"/>
#                               <rdf:rest>
#                                 <rdf:Description>
#                                   <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                                   <rdf:first rdf:datatype="http://www.w3.org/2001/XMLSchema#string">t</rdf:first>
#                                 </rdf:Description>
#                               </rdf:rest>
#                             </rdf:Description>
#                           </swrl:arguments>
#                         </swrl:BuiltinAtom>
#                       </rdf:first>
#                       <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                     </rdf:Description>
#                   </rdf:rest>
#                 </rdf:Description>
#               </rdf:rest>
#             </rdf:Description>
#           </rdf:rest>
#         </rdf:Description>
#       </rdf:rest>
#     </rdf:Description>
#   </swrl:body>
#   <swrl:head>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:DatavaluedPropertyAtom>
#           <swrl:propertyPredicate rdf:resource="#danhHieu"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#           <swrl:argument2 rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Học sinh giỏi</swrl:argument2>
#         </swrl:DatavaluedPropertyAtom>
#       </rdf:first>
#       <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#     </rdf:Description>
#   </swrl:head>
# </swrl:Imp>
#
# <swrl:Imp>
#   <swrl:body>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:ClassAtom>
#           <swrl:classPredicate rdf:resource="#HocSinh"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#         </swrl:ClassAtom>
#       </rdf:first>
#       <rdf:rest>
#         <rdf:Description>
#           <rdf:first>
#             <swrl:DatavaluedPropertyAtom>
#               <swrl:propertyPredicate rdf:resource="#diemTB"/>
#               <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#               <swrl:argument2 rdf:resource="urn:swrl#dtb"/>
#             </swrl:DatavaluedPropertyAtom>
#           </rdf:first>
#           <rdf:rest>
#             <rdf:Description>
#               <rdf:first>
#                 <swrl:BuiltinAtom>
#                   <swrl:builtin rdf:resource="http://www.w3.org/2003/11/swrlb#lessThan"/>
#                   <swrl:arguments>
#                     <rdf:Description>
#                       <rdf:first rdf:resource="urn:swrl#dtb"/>
#                       <rdf:rest>
#                         <rdf:Description>
#                           <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                           <rdf:first rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">5.0</rdf:first>
#                         </rdf:Description>
#                       </rdf:rest>
#                     </rdf:Description>
#                   </swrl:arguments>
#                 </swrl:BuiltinAtom>
#               </rdf:first>
#               <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#             </rdf:Description>
#           </rdf:rest>
#         </rdf:Description>
#       </rdf:rest>
#     </rdf:Description>
#   </swrl:body>
#   <swrl:head>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:DatavaluedPropertyAtom>
#           <swrl:propertyPredicate rdf:resource="#hocLuc"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#           <swrl:argument2 rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Yếu</swrl:argument2>
#         </swrl:DatavaluedPropertyAtom>
#       </rdf:first>
#       <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#     </rdf:Description>
#   </swrl:head>
# </swrl:Imp>
#
# <swrl:Imp>
#   <swrl:body>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:ClassAtom>
#           <swrl:classPredicate rdf:resource="#HocSinh"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#         </swrl:ClassAtom>
#       </rdf:first>
#       <rdf:rest>
#         <rdf:Description>
#           <rdf:first>
#             <swrl:DatavaluedPropertyAtom>
#               <swrl:propertyPredicate rdf:resource="#diemTB"/>
#               <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#               <swrl:argument2 rdf:resource="urn:swrl#dtb"/>
#             </swrl:DatavaluedPropertyAtom>
#           </rdf:first>
#           <rdf:rest>
#             <rdf:Description>
#               <rdf:first>
#                 <swrl:BuiltinAtom>
#                   <swrl:builtin rdf:resource="http://www.w3.org/2003/11/swrlb#greaterThanOrEqual"/>
#                   <swrl:arguments>
#                     <rdf:Description>
#                       <rdf:first rdf:resource="urn:swrl#dtb"/>
#                       <rdf:rest>
#                         <rdf:Description>
#                           <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                           <rdf:first rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">5.0</rdf:first>
#                         </rdf:Description>
#                       </rdf:rest>
#                     </rdf:Description>
#                   </swrl:arguments>
#                 </swrl:BuiltinAtom>
#               </rdf:first>
#               <rdf:rest>
#                 <rdf:Description>
#                   <rdf:first>
#                     <swrl:BuiltinAtom>
#                       <swrl:builtin rdf:resource="http://www.w3.org/2003/11/swrlb#lessThan"/>
#                       <swrl:arguments>
#                         <rdf:Description>
#                           <rdf:first rdf:resource="urn:swrl#dtb"/>
#                           <rdf:rest>
#                             <rdf:Description>
#                               <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                               <rdf:first rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">6.5</rdf:first>
#                             </rdf:Description>
#                           </rdf:rest>
#                         </rdf:Description>
#                       </swrl:arguments>
#                     </swrl:BuiltinAtom>
#                   </rdf:first>
#                   <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                 </rdf:Description>
#               </rdf:rest>
#             </rdf:Description>
#           </rdf:rest>
#         </rdf:Description>
#       </rdf:rest>
#     </rdf:Description>
#   </swrl:body>
#   <swrl:head>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:DatavaluedPropertyAtom>
#           <swrl:propertyPredicate rdf:resource="#hocLuc"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#           <swrl:argument2 rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Trung bình</swrl:argument2>
#         </swrl:DatavaluedPropertyAtom>
#       </rdf:first>
#       <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#     </rdf:Description>
#   </swrl:head>
# </swrl:Imp>
#
# <swrl:Imp>
#   <swrl:body>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:ClassAtom>
#           <swrl:classPredicate rdf:resource="#HocSinh"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#         </swrl:ClassAtom>
#       </rdf:first>
#       <rdf:rest>
#         <rdf:Description>
#           <rdf:first>
#             <swrl:DatavaluedPropertyAtom>
#               <swrl:propertyPredicate rdf:resource="#diemTB"/>
#               <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#               <swrl:argument2 rdf:resource="urn:swrl#dtb"/>
#             </swrl:DatavaluedPropertyAtom>
#           </rdf:first>
#           <rdf:rest>
#             <rdf:Description>
#               <rdf:first>
#                 <swrl:BuiltinAtom>
#                   <swrl:builtin rdf:resource="http://www.w3.org/2003/11/swrlb#greaterThanOrEqual"/>
#                   <swrl:arguments>
#                     <rdf:Description>
#                       <rdf:first rdf:resource="urn:swrl#dtb"/>
#                       <rdf:rest>
#                         <rdf:Description>
#                           <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                           <rdf:first rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">6.5</rdf:first>
#                         </rdf:Description>
#                       </rdf:rest>
#                     </rdf:Description>
#                   </swrl:arguments>
#                 </swrl:BuiltinAtom>
#               </rdf:first>
#               <rdf:rest>
#                 <rdf:Description>
#                   <rdf:first>
#                     <swrl:BuiltinAtom>
#                       <swrl:builtin rdf:resource="http://www.w3.org/2003/11/swrlb#lessThan"/>
#                       <swrl:arguments>
#                         <rdf:Description>
#                           <rdf:first rdf:resource="urn:swrl#dtb"/>
#                           <rdf:rest>
#                             <rdf:Description>
#                               <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                               <rdf:first rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">8.0</rdf:first>
#                             </rdf:Description>
#                           </rdf:rest>
#                         </rdf:Description>
#                       </swrl:arguments>
#                     </swrl:BuiltinAtom>
#                   </rdf:first>
#                   <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                 </rdf:Description>
#               </rdf:rest>
#             </rdf:Description>
#           </rdf:rest>
#         </rdf:Description>
#       </rdf:rest>
#     </rdf:Description>
#   </swrl:body>
#   <swrl:head>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:DatavaluedPropertyAtom>
#           <swrl:propertyPredicate rdf:resource="#hocLuc"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#           <swrl:argument2 rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khá</swrl:argument2>
#         </swrl:DatavaluedPropertyAtom>
#       </rdf:first>
#       <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#     </rdf:Description>
#   </swrl:head>
# </swrl:Imp>
#
# <swrl:Imp>
#   <swrl:body>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:ClassAtom>
#           <swrl:classPredicate rdf:resource="#HocSinh"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#         </swrl:ClassAtom>
#       </rdf:first>
#       <rdf:rest>
#         <rdf:Description>
#           <rdf:first>
#             <swrl:DatavaluedPropertyAtom>
#               <swrl:propertyPredicate rdf:resource="#diemTB"/>
#               <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#               <swrl:argument2 rdf:resource="urn:swrl#dtb"/>
#             </swrl:DatavaluedPropertyAtom>
#           </rdf:first>
#           <rdf:rest>
#             <rdf:Description>
#               <rdf:first>
#                 <swrl:BuiltinAtom>
#                   <swrl:builtin rdf:resource="http://www.w3.org/2003/11/swrlb#greaterThanOrEqual"/>
#                   <swrl:arguments>
#                     <rdf:Description>
#                       <rdf:first rdf:resource="urn:swrl#dtb"/>
#                       <rdf:rest>
#                         <rdf:Description>
#                           <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                           <rdf:first rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">8.0</rdf:first>
#                         </rdf:Description>
#                       </rdf:rest>
#                     </rdf:Description>
#                   </swrl:arguments>
#                 </swrl:BuiltinAtom>
#               </rdf:first>
#               <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#             </rdf:Description>
#           </rdf:rest>
#         </rdf:Description>
#       </rdf:rest>
#     </rdf:Description>
#   </swrl:body>
#   <swrl:head>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:DatavaluedPropertyAtom>
#           <swrl:propertyPredicate rdf:resource="#hocLuc"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#           <swrl:argument2 rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Giỏi</swrl:argument2>
#         </swrl:DatavaluedPropertyAtom>
#       </rdf:first>
#       <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#     </rdf:Description>
#   </swrl:head>
# </swrl:Imp>
#
# <swrl:Imp>
#   <swrl:body>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:ClassAtom>
#           <swrl:classPredicate rdf:resource="#HocSinh"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs1"/>
#         </swrl:ClassAtom>
#       </rdf:first>
#       <rdf:rest>
#         <rdf:Description>
#           <rdf:first>
#             <swrl:ClassAtom>
#               <swrl:classPredicate rdf:resource="#HocSinh"/>
#               <swrl:argument1 rdf:resource="urn:swrl#hs2"/>
#             </swrl:ClassAtom>
#           </rdf:first>
#           <rdf:rest>
#             <rdf:Description>
#               <rdf:first>
#                 <swrl:IndividualPropertyAtom>
#                   <swrl:propertyPredicate rdf:resource="#me"/>
#                   <swrl:argument1 rdf:resource="urn:swrl#hs1"/>
#                   <swrl:argument2 rdf:resource="urn:swrl#ph1"/>
#                 </swrl:IndividualPropertyAtom>
#               </rdf:first>
#               <rdf:rest>
#                 <rdf:Description>
#                   <rdf:first>
# ...
#                                 <swrl:DatavaluedPropertyAtom>
#                                   <swrl:propertyPredicate rdf:resource="#ngaySinh"/>
#                                   <swrl:argument1 rdf:resource="urn:swrl#hs1"/>
#                                   <swrl:argument2 rdf:resource="urn:swrl#ns1"/>
#                                 </swrl:DatavaluedPropertyAtom>
#                               </rdf:first>
#                               <rdf:rest>
#                                 <rdf:Description>
#                                   <rdf:first>
#                                     <swrl:DatavaluedPropertyAtom>
#                                       <swrl:propertyPredicate rdf:resource="#ngaySinh"/>
#                                       <swrl:argument1 rdf:resource="urn:swrl#hs2"/>
#                                       <swrl:argument2 rdf:resource="urn:swrl#ns2"/>
#                                     </swrl:DatavaluedPropertyAtom>
#                                   </rdf:first>
#                                   <rdf:rest>
#                                     <rdf:Description>
#                                       <rdf:first>
#                                         <swrl:BuiltinAtom>
#                                           <swrl:builtin rdf:resource="http://www.w3.org/2003/11/swrlb#greaterThanOrEqual"/>
#                                           <swrl:arguments>
#                                             <rdf:Description>
#                                               <rdf:first rdf:resource="urn:swrl#ns1"/>
#                                               <rdf:rest>
#                                                 <rdf:Description>
#                                                   <rdf:first rdf:resource="urn:swrl#ns2"/>
#                                                   <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                                                 </rdf:Description>
#                                               </rdf:rest>
#                                             </rdf:Description>
#                                           </swrl:arguments>
#                                         </swrl:BuiltinAtom>
#                                       </rdf:first>
#                                       <rdf:rest>
#                                         <rdf:Description>
#                                           <rdf:first>
#                                             <swrl:DatavaluedPropertyAtom>
#                                               <swrl:propertyPredicate rdf:resource="#gioiTinh"/>
#                                               <swrl:argument1 rdf:resource="urn:swrl#hs1"/>
#                                               <swrl:argument2 rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</swrl:argument2>
#                                             </swrl:DatavaluedPropertyAtom>
#                                           </rdf:first>
#                                           <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                                         </rdf:Description>
#                                       </rdf:rest>
#                                     </rdf:Description>
#                                   </rdf:rest>
#                                 </rdf:Description>
#                               </rdf:rest>
#                             </rdf:Description>
#                           </rdf:rest>
#                         </rdf:Description>
#                       </rdf:rest>
#                     </rdf:Description>
#                   </rdf:rest>
#                 </rdf:Description>
#               </rdf:rest>
#             </rdf:Description>
#           </rdf:rest>
#         </rdf:Description>
#       </rdf:rest>
#     </rdf:Description>
#   </swrl:body>
#   <swrl:head>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:IndividualPropertyAtom>
#           <swrl:propertyPredicate rdf:resource="#chi"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs1"/>
#           <swrl:argument2 rdf:resource="urn:swrl#hs2"/>
#         </swrl:IndividualPropertyAtom>
#       </rdf:first>
#       <rdf:rest>
#         <rdf:Description>
#           <rdf:first>
#             <swrl:IndividualPropertyAtom>
#               <swrl:propertyPredicate rdf:resource="#em"/>
#               <swrl:argument1 rdf:resource="urn:swrl#hs2"/>
#               <swrl:argument2 rdf:resource="urn:swrl#hs1"/>
#             </swrl:IndividualPropertyAtom>
#           </rdf:first>
#           <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#         </rdf:Description>
#       </rdf:rest>
#     </rdf:Description>
#   </swrl:head>
# </swrl:Imp>
#
# <swrl:Imp>
#   <swrl:body>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:ClassAtom>
#           <swrl:classPredicate rdf:resource="#HocSinh"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs1"/>
#         </swrl:ClassAtom>
#       </rdf:first>
#       <rdf:rest>
#         <rdf:Description>
#           <rdf:first>
#             <swrl:ClassAtom>
#               <swrl:classPredicate rdf:resource="#HocSinh"/>
#               <swrl:argument1 rdf:resource="urn:swrl#hs2"/>
#             </swrl:ClassAtom>
#           </rdf:first>
#           <rdf:rest>
#             <rdf:Description>
#               <rdf:first>
#                 <swrl:IndividualPropertyAtom>
#                   <swrl:propertyPredicate rdf:resource="#me"/>
#                   <swrl:argument1 rdf:resource="urn:swrl#hs1"/>
#                   <swrl:argument2 rdf:resource="urn:swrl#ph1"/>
#                 </swrl:IndividualPropertyAtom>
#               </rdf:first>
#               <rdf:rest>
#                 <rdf:Description>
#                   <rdf:first>
#                     <swrl:IndividualPropertyAtom>
#                       <swrl:propertyPredicate rdf:resource="#me"/>
#                       <swrl:argument1 rdf:resource="urn:swrl#hs2"/>
#                       <swrl:argument2 rdf:resource="urn:swrl#ph2"/>
#                     </swrl:IndividualPropertyAtom>
#                   </rdf:first>
#                   <rdf:rest>
#                     <rdf:Description>
#                       <rdf:first>
#                         <swrl:DifferentIndividualsAtom>
#                           <swrl:argument1 rdf:resource="urn:swrl#hs1"/>
#                           <swrl:argument2 rdf:resource="urn:swrl#hs2"/>
#                         </swrl:DifferentIndividualsAtom>
#                       </rdf:first>
#                       <rdf:rest>
#                         <rdf:Description>
#                           <rdf:first>
#                             <swrl:SameIndividualAtom>
#                               <swrl:argument1 rdf:resource="urn:swrl#ph1"/>
#                               <swrl:argument2 rdf:resource="urn:swrl#ph2"/>
#                             </swrl:SameIndividualAtom>
#                           </rdf:first>
#                           <rdf:rest>
#                             <rdf:Description>
#                               <rdf:first>
#                                 <swrl:DatavaluedPropertyAtom>
#                                   <swrl:propertyPredicate rdf:resource="#ngaySinh"/>
#                                   <swrl:argument1 rdf:resource="urn:swrl#hs1"/>
#                                   <swrl:argument2 rdf:resource="urn:swrl#ns1"/>
#                                 </swrl:DatavaluedPropertyAtom>
#                               </rdf:first>
#                               <rdf:rest>
#                                 <rdf:Description>
#                                   <rdf:first>
#                                     <swrl:DatavaluedPropertyAtom>
#                                       <swrl:propertyPredicate rdf:resource="#ngaySinh"/>
#                                       <swrl:argument1 rdf:resource="urn:swrl#hs2"/>
#                                       <swrl:argument2 rdf:resource="urn:swrl#ns2"/>
#                                     </swrl:DatavaluedPropertyAtom>
#                                   </rdf:first>
#                                   <rdf:rest>
#                                     <rdf:Description>
#                                       <rdf:first>
#                                         <swrl:BuiltinAtom>
#                                           <swrl:builtin rdf:resource="http://www.w3.org/2003/11/swrlb#greaterThanOrEqual"/>
#                                           <swrl:arguments>
#                                             <rdf:Description>
#                                               <rdf:first rdf:resource="urn:swrl#ns1"/>
#                                               <rdf:rest>
#                                                 <rdf:Description>
#                                                   <rdf:first rdf:resource="urn:swrl#ns2"/>
#                                                   <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                                                 </rdf:Description>
#                                               </rdf:rest>
#                                             </rdf:Description>
#                                           </swrl:arguments>
#                                         </swrl:BuiltinAtom>
#                                       </rdf:first>
#                                       <rdf:rest>
#                                         <rdf:Description>
#                                           <rdf:first>
#                                             <swrl:DatavaluedPropertyAtom>
#                                               <swrl:propertyPredicate rdf:resource="#gioiTinh"/>
#                                               <swrl:argument1 rdf:resource="urn:swrl#hs1"/>
#                                               <swrl:argument2 rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</swrl:argument2>
#                                             </swrl:DatavaluedPropertyAtom>
#                                           </rdf:first>
#                                           <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                                         </rdf:Description>
#                                       </rdf:rest>
#                                     </rdf:Description>
#                                   </rdf:rest>
#                                 </rdf:Description>
#                               </rdf:rest>
#                             </rdf:Description>
#                           </rdf:rest>
#                         </rdf:Description>
#                       </rdf:rest>
#                     </rdf:Description>
#                   </rdf:rest>
#                 </rdf:Description>
#               </rdf:rest>
#             </rdf:Description>
#           </rdf:rest>
#         </rdf:Description>
#       </rdf:rest>
#     </rdf:Description>
#   </swrl:body>
#   <swrl:head>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:IndividualPropertyAtom>
#           <swrl:propertyPredicate rdf:resource="#anh"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs1"/>
#           <swrl:argument2 rdf:resource="urn:swrl#hs2"/>
#         </swrl:IndividualPropertyAtom>
#       </rdf:first>
#       <rdf:rest>
#         <rdf:Description>
#           <rdf:first>
#             <swrl:IndividualPropertyAtom>
#               <swrl:propertyPredicate rdf:resource="#em"/>
#               <swrl:argument1 rdf:resource="urn:swrl#hs2"/>
#               <swrl:argument2 rdf:resource="urn:swrl#hs1"/>
#             </swrl:IndividualPropertyAtom>
#           </rdf:first>
#           <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#         </rdf:Description>
#       </rdf:rest>
#     </rdf:Description>
#   </swrl:head>
# </swrl:Imp>
#
# <swrl:Imp>
#   <swrl:body>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:ClassAtom>
#           <swrl:classPredicate rdf:resource="#HocSinh"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#         </swrl:ClassAtom>
#       </rdf:first>
#       <rdf:rest>
#         <rdf:Description>
#           <rdf:first>
#             <swrl:IndividualPropertyAtom>
#               <swrl:propertyPredicate rdf:resource="#cha"/>
#               <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#               <swrl:argument2 rdf:resource="urn:swrl#ph1"/>
#             </swrl:IndividualPropertyAtom>
#           </rdf:first>
#           <rdf:rest>
#             <rdf:Description>
#               <rdf:first>
#                 <swrl:IndividualPropertyAtom>
#                   <swrl:propertyPredicate rdf:resource="#me"/>
#                   <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#                   <swrl:argument2 rdf:resource="urn:swrl#ph2"/>
#                 </swrl:IndividualPropertyAtom>
#               </rdf:first>
#               <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#             </rdf:Description>
#           </rdf:rest>
#         </rdf:Description>
#       </rdf:rest>
#     </rdf:Description>
#   </swrl:body>
#   <swrl:head>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:IndividualPropertyAtom>
#           <swrl:propertyPredicate rdf:resource="#vo"/>
#           <swrl:argument1 rdf:resource="urn:swrl#ph1"/>
#           <swrl:argument2 rdf:resource="urn:swrl#ph2"/>
#         </swrl:IndividualPropertyAtom>
#       </rdf:first>
#       <rdf:rest>
#         <rdf:Description>
#           <rdf:first>
#             <swrl:IndividualPropertyAtom>
#               <swrl:propertyPredicate rdf:resource="#chong"/>
#               <swrl:argument1 rdf:resource="urn:swrl#ph2"/>
#               <swrl:argument2 rdf:resource="urn:swrl#ph1"/>
#             </swrl:IndividualPropertyAtom>
#           </rdf:first>
#           <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#         </rdf:Description>
#       </rdf:rest>
#     </rdf:Description>
#   </swrl:head>
# </swrl:Imp>
#
# <swrl:Imp>
#   <swrl:body>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:ClassAtom>
#           <swrl:classPredicate rdf:resource="#HocSinh"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#         </swrl:ClassAtom>
#       </rdf:first>
#       <rdf:rest>
#         <rdf:Description>
#           <rdf:first>
#             <swrl:IndividualPropertyAtom>
#               <swrl:propertyPredicate rdf:resource="#me"/>
#               <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#               <swrl:argument2 rdf:resource="urn:swrl#m"/>
#             </swrl:IndividualPropertyAtom>
#           </rdf:first>
#           <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#         </rdf:Description>
#       </rdf:rest>
#     </rdf:Description>
#   </swrl:body>
#   <swrl:head>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:IndividualPropertyAtom>
#           <swrl:propertyPredicate rdf:resource="#phuHuynh"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#           <swrl:argument2 rdf:resource="urn:swrl#m"/>
#         </swrl:IndividualPropertyAtom>
#       </rdf:first>
#       <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#     </rdf:Description>
#   </swrl:head>
# </swrl:Imp>
#
# <swrl:Imp>
#   <swrl:body>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:ClassAtom>
#           <swrl:classPredicate rdf:resource="#HocSinh"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#         </swrl:ClassAtom>
#       </rdf:first>
#       <rdf:rest>
#         <rdf:Description>
#           <rdf:first>
#             <swrl:IndividualPropertyAtom>
#               <swrl:propertyPredicate rdf:resource="#cha"/>
#               <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#               <swrl:argument2 rdf:resource="urn:swrl#c"/>
#             </swrl:IndividualPropertyAtom>
#           </rdf:first>
#           <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#         </rdf:Description>
#       </rdf:rest>
#     </rdf:Description>
#   </swrl:body>
#   <swrl:head>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:IndividualPropertyAtom>
#           <swrl:propertyPredicate rdf:resource="#phuHuynh"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#           <swrl:argument2 rdf:resource="urn:swrl#c"/>
#         </swrl:IndividualPropertyAtom>
#       </rdf:first>
#       <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#     </rdf:Description>
#   </swrl:head>
# </swrl:Imp>
#
#
# </rdf:RDF>

# %% [markdown]
# ### Thêm dữ liệu

# %%
# # Đọc CSDL từ file
# onto = get_ontology("../app/data/education.owl").load()

# %%
# %run ../app/models/data.py
create_Data(soLopMoiKhoi = 3, soHSMoiLop = 5, soHSCoAnhEm = 20, soGVMoiMon = 3, soGVDay2Mon = 5)
# Lưu CSDL ra file
onto.save(file="../app/data/education.owl", format='rdfxml') # 'ntriples' / "rdfxml"
with open("../app/data/education.owl", "r") as f:
    print(f.read())
# Out:
# <?xml version="1.0"?>
# <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#"
#          xmlns:xsd="http://www.w3.org/2001/XMLSchema#"
#          xmlns:rdfs="http://www.w3.org/2000/01/rdf-schema#"
#          xmlns:owl="http://www.w3.org/2002/07/owl#"
#          xml:base="http://hc.com/school"
#          xmlns="http://hc.com/school#"
#          xmlns:swrl="http://www.w3.org/2003/11/swrl#">
#
# <owl:Ontology rdf:about="http://hc.com/school"/>
#
# <owl:ObjectProperty rdf:about="#thanhVien">
#   <rdfs:domain rdf:resource="#ToChuc"/>
#   <rdfs:range rdf:resource="#Nguoi"/>
#   <owl:inverseOf rdf:resource="#toChuc"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#phong">
#   <rdfs:domain rdf:resource="#ToChuc"/>
#   <rdfs:range rdf:resource="#Phong"/>
#   <owl:inverseOf rdf:resource="#suDungBoi"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#toChuc">
#   <rdfs:domain rdf:resource="#Nguoi"/>
#   <rdfs:range rdf:resource="#ToChuc"/>
#   <owl:inverseOf rdf:resource="#thanhVien"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#chucVu">
#   <rdfs:domain rdf:resource="#NhanVien"/>
#   <rdfs:range rdf:resource="#ChucVu"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#con">
#   <rdfs:domain rdf:resource="#PhuHuynh"/>
#   <rdfs:range rdf:resource="#HocSinh"/>
#   <owl:inverseOf rdf:resource="#phuHuynh"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#giaoVienChuNhiem">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#LopHoc"/>
#   <rdfs:range rdf:resource="#GiaoVien"/>
#   <owl:inverseOf rdf:resource="#lopChuNhiem"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#dsHocSinh">
#   <rdfs:domain rdf:resource="#LopHoc"/>
#   <rdfs:range rdf:resource="#HocSinh"/>
#   <owl:inverseOf rdf:resource="#hocLop"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#hocLop">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#LopHoc"/>
#   <owl:inverseOf rdf:resource="#dsHocSinh"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#phuHuynh">
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#PhuHuynh"/>
#   <owl:inverseOf rdf:resource="#con"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#me">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:subPropertyOf rdf:resource="#phuHuynh"/>
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#Me"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#cha">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:subPropertyOf rdf:resource="#phuHuynh"/>
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#Cha"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#diemSo">
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#DiemSo"/>
#   <owl:inverseOf rdf:resource="#hocSinh"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#dayMon">
#   <rdfs:domain rdf:resource="#GiaoVien"/>
#   <rdfs:range rdf:resource="#MonHoc"/>
#   <owl:inverseOf rdf:resource="#giaoVienDay"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#giangDay">
#   <rdfs:domain rdf:resource="#GiaoVien"/>
#   <rdfs:range rdf:resource="#GiangDay"/>
#   <owl:inverseOf rdf:resource="#giaoVien"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#lopChuNhiem">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#GiaoVien"/>
#   <rdfs:range rdf:resource="#LopHoc"/>
#   <owl:inverseOf rdf:resource="#giaoVienChuNhiem"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#giaoVienDay">
#   <rdfs:domain rdf:resource="#MonHoc"/>
#   <rdfs:range rdf:resource="#GiaoVien"/>
#   <owl:inverseOf rdf:resource="#dayMon"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#hocSinh">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="#HocSinh"/>
#   <owl:inverseOf rdf:resource="#diemSo"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#monHoc">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="#MonHoc"/>
#   <rdfs:domain rdf:resource="#GiangDay"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#giaoVien">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#GiangDay"/>
#   <rdfs:range rdf:resource="#GiaoVien"/>
#   <owl:inverseOf rdf:resource="#giangDay"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#lopHoc">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#GiangDay"/>
#   <rdfs:range rdf:resource="#LopHoc"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#suDungBoi">
#   <rdfs:domain rdf:resource="#Phong"/>
#   <rdfs:range rdf:resource="#ToChuc"/>
#   <owl:inverseOf rdf:resource="#phong"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#quanLy">
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:range rdf:resource="#Nguoi"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#thamGia">
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:range rdf:resource="#Nguoi"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#nguoi">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemDanh"/>
#   <rdfs:range rdf:resource="#Nguoi"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#hoatDong">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemDanh"/>
#   <rdfs:range rdf:resource="#HoatDong"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#anhChiEm">
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#HocSinh"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#anh">
#   <rdfs:subPropertyOf rdf:resource="#anhChiEm"/>
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#Anh"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#chi">
#   <rdfs:subPropertyOf rdf:resource="#anhChiEm"/>
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#Chi"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#em">
#   <rdfs:subPropertyOf rdf:resource="#anhChiEm"/>
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#Em"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#vo">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Cha"/>
#   <rdfs:range rdf:resource="#Me"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#chong">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Me"/>
#   <rdfs:range rdf:resource="#Cha"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#phongLamViec">
#   <rdfs:domain rdf:resource="#NhanVien"/>
#   <rdfs:range rdf:resource="#Phong"/>
# </owl:ObjectProperty>
#
# <owl:DatatypeProperty rdf:about="#ten">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#ChucVu"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
#   <rdfs:domain rdf:resource="#ToChuc"/>
#   <rdfs:domain rdf:resource="#MonHoc"/>
#   <rdfs:domain rdf:resource="#Phong"/>
#   <rdfs:domain rdf:resource="#HoatDong"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#phuCap">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#ChucVu"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#hoTen">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Nguoi"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngaySinh">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Nguoi"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#gioiTinh">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Nguoi"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#heSoLuong">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#NhanVien"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngheNghiep">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#PhuHuynh"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#diemTB">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
#   <rdfs:domain rdf:resource="#DiemSo"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#hanhKiem">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#trinhDo">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#GiaoVien"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#soTiet">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#MonHoc"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#integer"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#heSo1">
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#heSo2">
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#heSo3">
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayBatDau">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayKetThuc">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayGio">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemDanh"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#dateTime"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#trangThai">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemDanh"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#hocLuc">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#danhHieu">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:Class rdf:about="#ChucVu">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#ToChuc">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#Nguoi">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#NhanVien">
#   <rdfs:subClassOf rdf:resource="#Nguoi"/>
# </owl:Class>
#
# <owl:Class rdf:about="#PhuHuynh">
#   <rdfs:subClassOf rdf:resource="#Nguoi"/>
# </owl:Class>
#
# <owl:Class rdf:about="#Cha">
#   <rdfs:subClassOf rdf:resource="#PhuHuynh"/>
# </owl:Class>
#
# <owl:Class rdf:about="#Me">
#   <rdfs:subClassOf rdf:resource="#PhuHuynh"/>
# </owl:Class>
#
# <owl:Class rdf:about="#LopHoc">
#   <rdfs:subClassOf rdf:resource="#ToChuc"/>
# </owl:Class>
#
# <owl:Class rdf:about="#HocSinh">
#   <rdfs:subClassOf rdf:resource="#Nguoi"/>
# </owl:Class>
#
# <owl:Class rdf:about="#Anh">
#   <rdfs:subClassOf rdf:resource="#HocSinh"/>
# </owl:Class>
#
# <owl:Class rdf:about="#Chi">
#   <rdfs:subClassOf rdf:resource="#HocSinh"/>
# </owl:Class>
#
# <owl:Class rdf:about="#Em">
#   <rdfs:subClassOf rdf:resource="#HocSinh"/>
# </owl:Class>
#
# <owl:Class rdf:about="#GiaoVien">
#   <rdfs:subClassOf rdf:resource="#NhanVien"/>
# </owl:Class>
#
# <owl:Class rdf:about="#MonHoc">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#DiemSo">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#GiangDay">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#Phong">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#HoatDong">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#DiemDanh">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <swrl:Variable rdf:about="urn:swrl#hs"/>
#
# <swrl:Variable rdf:about="urn:swrl#c"/>
#
# <swrl:Variable rdf:about="urn:swrl#m"/>
#
# <swrl:Variable rdf:about="urn:swrl#ph1"/>
#
# <swrl:Variable rdf:about="urn:swrl#ph2"/>
#
# <swrl:Variable rdf:about="urn:swrl#hs1"/>
#
# <swrl:Variable rdf:about="urn:swrl#hs2"/>
#
# <swrl:Variable rdf:about="urn:swrl#ns1"/>
#
# <swrl:Variable rdf:about="urn:swrl#ns2"/>
#
# <swrl:Variable rdf:about="urn:swrl#dtb"/>
#
# <swrl:Variable rdf:about="urn:swrl#hl"/>
#
# <swrl:Variable rdf:about="urn:swrl#hk"/>
#
# <swrl:Variable rdf:about="urn:swrl#gv"/>
#
# <swrl:Variable rdf:about="urn:swrl#dscv"/>
#
# <swrl:Variable rdf:about="urn:swrl#cv"/>
#
# <swrl:Variable rdf:about="urn:swrl#tc"/>
#
# <swrl:Variable rdf:about="urn:swrl#p"/>
#
# <swrl:Variable rdf:about="urn:swrl#lh"/>
#
# <Phong rdf:about="#Phong10C01">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <ten rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Phòng 10C01</ten>
# </Phong>
#
# <LopHoc rdf:about="#10C01">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <phong rdf:resource="#Phong10C01"/>
#   <ten rdf:datatype="http://www.w3.org/2001/XMLSchema#string">10C01</ten>
# </LopHoc>
#
# <HocSinh rdf:about="#hocsinh1">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#10C01"/>
#   <cha rdf:resource="#cha26"/>
#   <me rdf:resource="#me26"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Lâm Hoài Quỳnh</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-12-21</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <diemTB rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">7.36</diemTB>
#   <hanhKiem rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khá</hanhKiem>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh2">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#10C01"/>
#   <cha rdf:resource="#cha15"/>
#   <me rdf:resource="#me15"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Vũ Ngọc Hiền</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-11-04</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <diemTB rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">7.16</diemTB>
#   <hanhKiem rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tốt</hanhKiem>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh3">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#10C01"/>
#   <cha rdf:resource="#cha3"/>
#   <me rdf:resource="#me3"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nguyễn Hoài Khánh</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-03-27</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <diemTB rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">7.28</diemTB>
#   <hanhKiem rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tốt</hanhKiem>
# </HocSinh>
#
# <Cha rdf:about="#cha3">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tăng Văn Nam</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1973-07-14</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Giáo viên</ngheNghiep>
# </Cha>
#
# <Me rdf:about="#me3">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Vũ Ngọc Minh</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1973-01-17</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nông dân</ngheNghiep>
# </Me>
#
# <HocSinh rdf:about="#hocsinh4">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#10C01"/>
#   <cha rdf:resource="#cha32"/>
#   <me rdf:resource="#me32"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nguyễn Hồng Hiền</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-01-10</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <diemTB rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">7.42</diemTB>
#   <hanhKiem rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khá</hanhKiem>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh5">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#10C01"/>
#   <cha rdf:resource="#cha3"/>
#   <me rdf:resource="#me3"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Bùi Anh Linh</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-03-05</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <diemTB rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">7.52</diemTB>
#   <hanhKiem rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khá</hanhKiem>
# </HocSinh>
#
# <Phong rdf:about="#Phong10C02">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <ten rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Phòng 10C02</ten>
# </Phong>
#
# <LopHoc rdf:about="#10C02">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <phong rdf:resource="#Phong10C02"/>
#   <ten rdf:datatype="http://www.w3.org/2001/XMLSchema#string">10C02</ten>
# </LopHoc>
#
# <HocSinh rdf:about="#hocsinh6">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#10C02"/>
#   <cha rdf:resource="#cha6"/>
#   <me rdf:resource="#me6"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Trương Minh Cường</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-01-06</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <diemTB rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">7.51</diemTB>
#   <hanhKiem rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khá</hanhKiem>
# </HocSinh>
#
# <Cha rdf:about="#cha6">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tôn Văn Sơn</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1980-05-29</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Bác sĩ</ngheNghiep>
# </Cha>
#
# <Me rdf:about="#me6">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Huỳnh Hữu Hiền</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1976-09-21</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Công nhân</ngheNghiep>
# </Me>
#
# <HocSinh rdf:about="#hocsinh7">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#10C02"/>
#   <cha rdf:resource="#cha22"/>
#   <me rdf:resource="#me22"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đặng Kim Hiền</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-11-22</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <diemTB rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">6.97</diemTB>
#   <hanhKiem rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khá</hanhKiem>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh8">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#10C02"/>
#   <cha rdf:resource="#cha8"/>
#   <me rdf:resource="#me8"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tăng Thị Tú</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-01-06</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <diemTB rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">7.32</diemTB>
#   <hanhKiem rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tốt</hanhKiem>
# </HocSinh>
#
# <Cha rdf:about="#cha8">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Lương Hữu Long</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1972-03-26</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nông dân</ngheNghiep>
# </Cha>
#
# <Me rdf:about="#me8">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Vũ Thị Tú</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1979-11-25</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Kỹ sư</ngheNghiep>
# </Me>
#
# <HocSinh rdf:about="#hocsinh9">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#10C02"/>
#   <cha rdf:resource="#cha35"/>
#   <me rdf:resource="#me35"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đinh Thị Khánh</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-07-07</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <diemTB rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">6.91</diemTB>
#   <hanhKiem rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khá</hanhKiem>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh10">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#10C02"/>
#   <cha rdf:resource="#cha10"/>
#   <me rdf:resource="#me10"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Huỳnh Hồng Long</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-07-15</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <diemTB rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">7.28</diemTB>
#   <hanhKiem rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khá</hanhKiem>
# </HocSinh>
#
# <Cha rdf:about="#cha10">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Ngô Hồng Việt</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1972-12-29</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nông dân</ngheNghiep>
# </Cha>
#
# <Me rdf:about="#me10">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đoàn Hoài Linh</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1974-03-11</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nhân viên văn phòng</ngheNghiep>
# </Me>
#
# <Phong rdf:about="#Phong10C03">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <ten rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Phòng 10C03</ten>
# </Phong>
#
# <LopHoc rdf:about="#10C03">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <phong rdf:resource="#Phong10C03"/>
#   <ten rdf:datatype="http://www.w3.org/2001/XMLSchema#string">10C03</ten>
# </LopHoc>
#
# <HocSinh rdf:about="#hocsinh11">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#10C03"/>
#   <cha rdf:resource="#cha18"/>
#   <me rdf:resource="#me18"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đinh Thu Hải</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-12-09</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <diemTB rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">7.6</diemTB>
#   <hanhKiem rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khá</hanhKiem>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh12">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#10C03"/>
#   <cha rdf:resource="#cha12"/>
#   <me rdf:resource="#me12"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đặng Mai Thuận</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-10-02</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <diemTB rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">7.18</diemTB>
#   <hanhKiem rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tốt</hanhKiem>
# </HocSinh>
#
# <Cha rdf:about="#cha12">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Võ Quý Phương</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1972-08-17</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nông dân</ngheNghiep>
# </Cha>
#
# <Me rdf:about="#me12">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Trương Ngọc An</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1977-02-22</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Bác sĩ</ngheNghiep>
# </Me>
#
# <HocSinh rdf:about="#hocsinh13">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#10C03"/>
#   <cha rdf:resource="#cha13"/>
#   <me rdf:resource="#me13"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đoàn Kim Minh</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-04-02</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <diemTB rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">7.23</diemTB>
#   <hanhKiem rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khá</hanhKiem>
# </HocSinh>
#
# <Cha rdf:about="#cha13">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nguyễn Thanh Thúy</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1971-12-15</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Chủ doanh nghiệp</ngheNghiep>
# </Cha>
#
# <Me rdf:about="#me13">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Lê Văn Tùng</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1979-02-02</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Chủ doanh nghiệp</ngheNghiep>
# </Me>
#
# <HocSinh rdf:about="#hocsinh14">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#10C03"/>
#   <cha rdf:resource="#cha8"/>
#   <me rdf:resource="#me8"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Trần Bảo Long</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-10-09</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <diemTB rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">7.75</diemTB>
#   <hanhKiem rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khá</hanhKiem>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh15">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#10C03"/>
#   <cha rdf:resource="#cha15"/>
#   <me rdf:resource="#me15"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tạ Ngọc Thiện</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-04-13</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <diemTB rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">7.23</diemTB>
#   <hanhKiem rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khá</hanhKiem>
# </HocSinh>
#
# <Cha rdf:about="#cha15">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Lương Anh Nam</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1970-08-31</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nông dân</ngheNghiep>
# </Cha>
#
# <Me rdf:about="#me15">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Phạm Kim Hiền</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1974-03-18</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Kỹ sư</ngheNghiep>
# </Me>
#
# <Phong rdf:about="#Phong11B01">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <ten rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Phòng 11B01</ten>
# </Phong>
#
# <LopHoc rdf:about="#11B01">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <phong rdf:resource="#Phong11B01"/>
#   <ten rdf:datatype="http://www.w3.org/2001/XMLSchema#string">11B01</ten>
# </LopHoc>
#
# <HocSinh rdf:about="#hocsinh16">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#11B01"/>
#   <cha rdf:resource="#cha41"/>
#   <me rdf:resource="#me41"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Hoàng Mai Thúy</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-10-07</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <diemTB rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">7.18</diemTB>
#   <hanhKiem rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tốt</hanhKiem>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh17">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#11B01"/>
#   <cha rdf:resource="#cha20"/>
#   <me rdf:resource="#me20"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Lý Quốc Ngọc</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-04-22</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <diemTB rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">7.09</diemTB>
#   <hanhKiem rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khá</hanhKiem>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh18">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#11B01"/>
#   <cha rdf:resource="#cha18"/>
#   <me rdf:resource="#me18"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Mai Thị Linh</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-05-01</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <diemTB rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">7.2</diemTB>
#   <hanhKiem rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khá</hanhKiem>
# </HocSinh>
#
# <Cha rdf:about="#cha18">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Lê Văn Thảo</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1973-12-08</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Công nhân</ngheNghiep>
# </Cha>
#
# <Me rdf:about="#me18">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Trương Bảo Linh</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1975-02-01</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Công nhân</ngheNghiep>
# </Me>
#
# <HocSinh rdf:about="#hocsinh19">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#11B01"/>
#   <cha rdf:resource="#cha42"/>
#   <me rdf:resource="#me42"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tạ Thị Hùng</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-08-08</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <diemTB rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">7.32</diemTB>
#   <hanhKiem rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tốt</hanhKiem>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh20">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#11B01"/>
#   <cha rdf:resource="#cha20"/>
#   <me rdf:resource="#me20"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Dương Quốc Tường</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-10-08</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <diemTB rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">6.8</diemTB>
#   <hanhKiem rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khá</hanhKiem>
# </HocSinh>
#
# <Cha rdf:about="#cha20">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đoàn Anh Nhật</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1972-03-12</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nông dân</ngheNghiep>
# </Cha>
#
# <Me rdf:about="#me20">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tô Quý Vinh</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1970-08-07</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Bác sĩ</ngheNghiep>
# </Me>
#
# <Phong rdf:about="#Phong11B02">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <ten rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Phòng 11B02</ten>
# </Phong>
#
# <LopHoc rdf:about="#11B02">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <phong rdf:resource="#Phong11B02"/>
#   <ten rdf:datatype="http://www.w3.org/2001/XMLSchema#string">11B02</ten>
# </LopHoc>
#
# <HocSinh rdf:about="#hocsinh21">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#11B02"/>
#   <cha rdf:resource="#cha21"/>
#   <me rdf:resource="#me21"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tô Văn Phương</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-05-16</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <diemTB rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">7.49</diemTB>
#   <hanhKiem rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tốt</hanhKiem>
# </HocSinh>
#
# <Cha rdf:about="#cha21">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Vũ Văn Thuận</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1976-12-29</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Công nhân</ngheNghiep>
# </Cha>
#
# <Me rdf:about="#me21">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Trương Đình Linh</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1973-07-05</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nông dân</ngheNghiep>
# </Me>
#
# <HocSinh rdf:about="#hocsinh22">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#11B02"/>
#   <cha rdf:resource="#cha22"/>
#   <me rdf:resource="#me22"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nguyễn Hồng Tùng</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-12-17</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <diemTB rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">7.41</diemTB>
#   <hanhKiem rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khá</hanhKiem>
# </HocSinh>
#
# <Cha rdf:about="#cha22">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Hồ Ngọc Xuân</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1977-06-05</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Kỹ sư</ngheNghiep>
# </Cha>
#
# <Me rdf:about="#me22">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đặng Hữu Hùng</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1976-05-16</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Giáo viên</ngheNghiep>
# </Me>
#
# <HocSinh rdf:about="#hocsinh23">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#11B02"/>
#   <cha rdf:resource="#cha10"/>
#   <me rdf:resource="#me10"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Phan Mai Tú</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-09-30</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <diemTB rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">6.97</diemTB>
#   <hanhKiem rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tốt</hanhKiem>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh24">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#11B02"/>
#   <cha rdf:resource="#cha24"/>
#   <me rdf:resource="#me24"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Ngô Văn Tường</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-01-29</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <diemTB rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">7.25</diemTB>
#   <hanhKiem rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khá</hanhKiem>
# </HocSinh>
#
# <Cha rdf:about="#cha24">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đoàn Thu Thuận</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1976-03-25</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Giáo viên</ngheNghiep>
# </Cha>
#
# <Me rdf:about="#me24">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Thái Ngọc Hải</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1980-10-20</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Bác sĩ</ngheNghiep>
# </Me>
#
# <HocSinh rdf:about="#hocsinh25">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#11B02"/>
#   <cha rdf:resource="#cha25"/>
#   <me rdf:resource="#me25"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Phùng Thanh Quân</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-05-15</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <diemTB rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">7.75</diemTB>
#   <hanhKiem rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khá</hanhKiem>
# </HocSinh>
#
# <Cha rdf:about="#cha25">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đoàn Hồng Tùng</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1970-02-16</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Bác sĩ</ngheNghiep>
# </Cha>
#
# <Me rdf:about="#me25">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tô Hồng Quân</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1974-08-29</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nông dân</ngheNghiep>
# </Me>
#
# <Phong rdf:about="#Phong11B03">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <ten rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Phòng 11B03</ten>
# </Phong>
#
# <LopHoc rdf:about="#11B03">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <phong rdf:resource="#Phong11B03"/>
#   <ten rdf:datatype="http://www.w3.org/2001/XMLSchema#string">11B03</ten>
# </LopHoc>
#
# <HocSinh rdf:about="#hocsinh26">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#11B03"/>
#   <cha rdf:resource="#cha26"/>
#   <me rdf:resource="#me26"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đinh Thanh Vinh</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-06-20</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <diemTB rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">7.68</diemTB>
#   <hanhKiem rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khá</hanhKiem>
# </HocSinh>
#
# <Cha rdf:about="#cha26">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đinh Quốc Phương</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1972-03-21</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Giáo viên</ngheNghiep>
# </Cha>
#
# <Me rdf:about="#me26">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Bành Ngọc Thiên</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1974-12-01</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Bác sĩ</ngheNghiep>
# </Me>
#
# <HocSinh rdf:about="#hocsinh27">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#11B03"/>
#   <cha rdf:resource="#cha21"/>
#   <me rdf:resource="#me21"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đặng Anh Khánh</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-01-02</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <diemTB rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">7.38</diemTB>
#   <hanhKiem rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tốt</hanhKiem>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh28">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#11B03"/>
#   <cha rdf:resource="#cha13"/>
#   <me rdf:resource="#me13"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tăng Quý An</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-11-06</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <diemTB rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">7.31</diemTB>
#   <hanhKiem rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tốt</hanhKiem>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh29">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#11B03"/>
#   <cha rdf:resource="#cha29"/>
#   <me rdf:resource="#me29"/>
# ...
#                                 <swrl:DatavaluedPropertyAtom>
#                                   <swrl:propertyPredicate rdf:resource="#ngaySinh"/>
#                                   <swrl:argument1 rdf:resource="urn:swrl#hs1"/>
#                                   <swrl:argument2 rdf:resource="urn:swrl#ns1"/>
#                                 </swrl:DatavaluedPropertyAtom>
#                               </rdf:first>
#                               <rdf:rest>
#                                 <rdf:Description>
#                                   <rdf:first>
#                                     <swrl:DatavaluedPropertyAtom>
#                                       <swrl:propertyPredicate rdf:resource="#ngaySinh"/>
#                                       <swrl:argument1 rdf:resource="urn:swrl#hs2"/>
#                                       <swrl:argument2 rdf:resource="urn:swrl#ns2"/>
#                                     </swrl:DatavaluedPropertyAtom>
#                                   </rdf:first>
#                                   <rdf:rest>
#                                     <rdf:Description>
#                                       <rdf:first>
#                                         <swrl:BuiltinAtom>
#                                           <swrl:builtin rdf:resource="http://www.w3.org/2003/11/swrlb#greaterThanOrEqual"/>
#                                           <swrl:arguments>
#                                             <rdf:Description>
#                                               <rdf:first rdf:resource="urn:swrl#ns1"/>
#                                               <rdf:rest>
#                                                 <rdf:Description>
#                                                   <rdf:first rdf:resource="urn:swrl#ns2"/>
#                                                   <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                                                 </rdf:Description>
#                                               </rdf:rest>
#                                             </rdf:Description>
#                                           </swrl:arguments>
#                                         </swrl:BuiltinAtom>
#                                       </rdf:first>
#                                       <rdf:rest>
#                                         <rdf:Description>
#                                           <rdf:first>
#                                             <swrl:DatavaluedPropertyAtom>
#                                               <swrl:propertyPredicate rdf:resource="#gioiTinh"/>
#                                               <swrl:argument1 rdf:resource="urn:swrl#hs1"/>
#                                               <swrl:argument2 rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</swrl:argument2>
#                                             </swrl:DatavaluedPropertyAtom>
#                                           </rdf:first>
#                                           <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                                         </rdf:Description>
#                                       </rdf:rest>
#                                     </rdf:Description>
#                                   </rdf:rest>
#                                 </rdf:Description>
#                               </rdf:rest>
#                             </rdf:Description>
#                           </rdf:rest>
#                         </rdf:Description>
#                       </rdf:rest>
#                     </rdf:Description>
#                   </rdf:rest>
#                 </rdf:Description>
#               </rdf:rest>
#             </rdf:Description>
#           </rdf:rest>
#         </rdf:Description>
#       </rdf:rest>
#     </rdf:Description>
#   </swrl:body>
#   <swrl:head>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:IndividualPropertyAtom>
#           <swrl:propertyPredicate rdf:resource="#chi"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs1"/>
#           <swrl:argument2 rdf:resource="urn:swrl#hs2"/>
#         </swrl:IndividualPropertyAtom>
#       </rdf:first>
#       <rdf:rest>
#         <rdf:Description>
#           <rdf:first>
#             <swrl:IndividualPropertyAtom>
#               <swrl:propertyPredicate rdf:resource="#em"/>
#               <swrl:argument1 rdf:resource="urn:swrl#hs2"/>
#               <swrl:argument2 rdf:resource="urn:swrl#hs1"/>
#             </swrl:IndividualPropertyAtom>
#           </rdf:first>
#           <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#         </rdf:Description>
#       </rdf:rest>
#     </rdf:Description>
#   </swrl:head>
# </swrl:Imp>
#
# <swrl:Imp>
#   <swrl:body>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:ClassAtom>
#           <swrl:classPredicate rdf:resource="#HocSinh"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs1"/>
#         </swrl:ClassAtom>
#       </rdf:first>
#       <rdf:rest>
#         <rdf:Description>
#           <rdf:first>
#             <swrl:ClassAtom>
#               <swrl:classPredicate rdf:resource="#HocSinh"/>
#               <swrl:argument1 rdf:resource="urn:swrl#hs2"/>
#             </swrl:ClassAtom>
#           </rdf:first>
#           <rdf:rest>
#             <rdf:Description>
#               <rdf:first>
#                 <swrl:IndividualPropertyAtom>
#                   <swrl:propertyPredicate rdf:resource="#me"/>
#                   <swrl:argument1 rdf:resource="urn:swrl#hs1"/>
#                   <swrl:argument2 rdf:resource="urn:swrl#ph1"/>
#                 </swrl:IndividualPropertyAtom>
#               </rdf:first>
#               <rdf:rest>
#                 <rdf:Description>
#                   <rdf:first>
#                     <swrl:IndividualPropertyAtom>
#                       <swrl:propertyPredicate rdf:resource="#me"/>
#                       <swrl:argument1 rdf:resource="urn:swrl#hs2"/>
#                       <swrl:argument2 rdf:resource="urn:swrl#ph2"/>
#                     </swrl:IndividualPropertyAtom>
#                   </rdf:first>
#                   <rdf:rest>
#                     <rdf:Description>
#                       <rdf:first>
#                         <swrl:DifferentIndividualsAtom>
#                           <swrl:argument1 rdf:resource="urn:swrl#hs1"/>
#                           <swrl:argument2 rdf:resource="urn:swrl#hs2"/>
#                         </swrl:DifferentIndividualsAtom>
#                       </rdf:first>
#                       <rdf:rest>
#                         <rdf:Description>
#                           <rdf:first>
#                             <swrl:SameIndividualAtom>
#                               <swrl:argument1 rdf:resource="urn:swrl#ph1"/>
#                               <swrl:argument2 rdf:resource="urn:swrl#ph2"/>
#                             </swrl:SameIndividualAtom>
#                           </rdf:first>
#                           <rdf:rest>
#                             <rdf:Description>
#                               <rdf:first>
#                                 <swrl:DatavaluedPropertyAtom>
#                                   <swrl:propertyPredicate rdf:resource="#ngaySinh"/>
#                                   <swrl:argument1 rdf:resource="urn:swrl#hs1"/>
#                                   <swrl:argument2 rdf:resource="urn:swrl#ns1"/>
#                                 </swrl:DatavaluedPropertyAtom>
#                               </rdf:first>
#                               <rdf:rest>
#                                 <rdf:Description>
#                                   <rdf:first>
#                                     <swrl:DatavaluedPropertyAtom>
#                                       <swrl:propertyPredicate rdf:resource="#ngaySinh"/>
#                                       <swrl:argument1 rdf:resource="urn:swrl#hs2"/>
#                                       <swrl:argument2 rdf:resource="urn:swrl#ns2"/>
#                                     </swrl:DatavaluedPropertyAtom>
#                                   </rdf:first>
#                                   <rdf:rest>
#                                     <rdf:Description>
#                                       <rdf:first>
#                                         <swrl:BuiltinAtom>
#                                           <swrl:builtin rdf:resource="http://www.w3.org/2003/11/swrlb#greaterThanOrEqual"/>
#                                           <swrl:arguments>
#                                             <rdf:Description>
#                                               <rdf:first rdf:resource="urn:swrl#ns1"/>
#                                               <rdf:rest>
#                                                 <rdf:Description>
#                                                   <rdf:first rdf:resource="urn:swrl#ns2"/>
#                                                   <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                                                 </rdf:Description>
#                                               </rdf:rest>
#                                             </rdf:Description>
#                                           </swrl:arguments>
#                                         </swrl:BuiltinAtom>
#                                       </rdf:first>
#                                       <rdf:rest>
#                                         <rdf:Description>
#                                           <rdf:first>
#                                             <swrl:DatavaluedPropertyAtom>
#                                               <swrl:propertyPredicate rdf:resource="#gioiTinh"/>
#                                               <swrl:argument1 rdf:resource="urn:swrl#hs1"/>
#                                               <swrl:argument2 rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</swrl:argument2>
#                                             </swrl:DatavaluedPropertyAtom>
#                                           </rdf:first>
#                                           <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                                         </rdf:Description>
#                                       </rdf:rest>
#                                     </rdf:Description>
#                                   </rdf:rest>
#                                 </rdf:Description>
#                               </rdf:rest>
#                             </rdf:Description>
#                           </rdf:rest>
#                         </rdf:Description>
#                       </rdf:rest>
#                     </rdf:Description>
#                   </rdf:rest>
#                 </rdf:Description>
#               </rdf:rest>
#             </rdf:Description>
#           </rdf:rest>
#         </rdf:Description>
#       </rdf:rest>
#     </rdf:Description>
#   </swrl:body>
#   <swrl:head>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:IndividualPropertyAtom>
#           <swrl:propertyPredicate rdf:resource="#anh"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs1"/>
#           <swrl:argument2 rdf:resource="urn:swrl#hs2"/>
#         </swrl:IndividualPropertyAtom>
#       </rdf:first>
#       <rdf:rest>
#         <rdf:Description>
#           <rdf:first>
#             <swrl:IndividualPropertyAtom>
#               <swrl:propertyPredicate rdf:resource="#em"/>
#               <swrl:argument1 rdf:resource="urn:swrl#hs2"/>
#               <swrl:argument2 rdf:resource="urn:swrl#hs1"/>
#             </swrl:IndividualPropertyAtom>
#           </rdf:first>
#           <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#         </rdf:Description>
#       </rdf:rest>
#     </rdf:Description>
#   </swrl:head>
# </swrl:Imp>
#
# <swrl:Imp>
#   <swrl:body>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:ClassAtom>
#           <swrl:classPredicate rdf:resource="#HocSinh"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#         </swrl:ClassAtom>
#       </rdf:first>
#       <rdf:rest>
#         <rdf:Description>
#           <rdf:first>
#             <swrl:IndividualPropertyAtom>
#               <swrl:propertyPredicate rdf:resource="#cha"/>
#               <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#               <swrl:argument2 rdf:resource="urn:swrl#ph1"/>
#             </swrl:IndividualPropertyAtom>
#           </rdf:first>
#           <rdf:rest>
#             <rdf:Description>
#               <rdf:first>
#                 <swrl:IndividualPropertyAtom>
#                   <swrl:propertyPredicate rdf:resource="#me"/>
#                   <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#                   <swrl:argument2 rdf:resource="urn:swrl#ph2"/>
#                 </swrl:IndividualPropertyAtom>
#               </rdf:first>
#               <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#             </rdf:Description>
#           </rdf:rest>
#         </rdf:Description>
#       </rdf:rest>
#     </rdf:Description>
#   </swrl:body>
#   <swrl:head>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:IndividualPropertyAtom>
#           <swrl:propertyPredicate rdf:resource="#vo"/>
#           <swrl:argument1 rdf:resource="urn:swrl#ph1"/>
#           <swrl:argument2 rdf:resource="urn:swrl#ph2"/>
#         </swrl:IndividualPropertyAtom>
#       </rdf:first>
#       <rdf:rest>
#         <rdf:Description>
#           <rdf:first>
#             <swrl:IndividualPropertyAtom>
#               <swrl:propertyPredicate rdf:resource="#chong"/>
#               <swrl:argument1 rdf:resource="urn:swrl#ph2"/>
#               <swrl:argument2 rdf:resource="urn:swrl#ph1"/>
#             </swrl:IndividualPropertyAtom>
#           </rdf:first>
#           <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#         </rdf:Description>
#       </rdf:rest>
#     </rdf:Description>
#   </swrl:head>
# </swrl:Imp>
#
# <swrl:Imp>
#   <swrl:body>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:ClassAtom>
#           <swrl:classPredicate rdf:resource="#HocSinh"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#         </swrl:ClassAtom>
#       </rdf:first>
#       <rdf:rest>
#         <rdf:Description>
#           <rdf:first>
#             <swrl:IndividualPropertyAtom>
#               <swrl:propertyPredicate rdf:resource="#me"/>
#               <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#               <swrl:argument2 rdf:resource="urn:swrl#m"/>
#             </swrl:IndividualPropertyAtom>
#           </rdf:first>
#           <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#         </rdf:Description>
#       </rdf:rest>
#     </rdf:Description>
#   </swrl:body>
#   <swrl:head>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:IndividualPropertyAtom>
#           <swrl:propertyPredicate rdf:resource="#phuHuynh"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#           <swrl:argument2 rdf:resource="urn:swrl#m"/>
#         </swrl:IndividualPropertyAtom>
#       </rdf:first>
#       <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#     </rdf:Description>
#   </swrl:head>
# </swrl:Imp>
#
# <swrl:Imp>
#   <swrl:body>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:ClassAtom>
#           <swrl:classPredicate rdf:resource="#HocSinh"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#         </swrl:ClassAtom>
#       </rdf:first>
#       <rdf:rest>
#         <rdf:Description>
#           <rdf:first>
#             <swrl:IndividualPropertyAtom>
#               <swrl:propertyPredicate rdf:resource="#cha"/>
#               <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#               <swrl:argument2 rdf:resource="urn:swrl#c"/>
#             </swrl:IndividualPropertyAtom>
#           </rdf:first>
#           <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#         </rdf:Description>
#       </rdf:rest>
#     </rdf:Description>
#   </swrl:body>
#   <swrl:head>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:IndividualPropertyAtom>
#           <swrl:propertyPredicate rdf:resource="#phuHuynh"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#           <swrl:argument2 rdf:resource="urn:swrl#c"/>
#         </swrl:IndividualPropertyAtom>
#       </rdf:first>
#       <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#     </rdf:Description>
#   </swrl:head>
# </swrl:Imp>
#
#
# </rdf:RDF>

# %%
# Đọc CSDL từ file
onto = get_ontology("../app/data/education.owl").load()

# In DS học sinh ra màn hình
print("Danh sách học sinh:")
stt = 1
for hs in onto.HocSinh.instances():
    print(stt, hs.hoTen)
    stt += 1
# Out:
# Danh sách học sinh:
# 1 Lâm Hoài Quỳnh
# 2 Vũ Ngọc Hiền
# 3 Nguyễn Hoài Khánh
# 4 Nguyễn Hồng Hiền
# 5 Bùi Anh Linh
# 6 Trương Minh Cường
# 7 Đặng Kim Hiền
# 8 Tăng Thị Tú
# 9 Đinh Thị Khánh
# 10 Huỳnh Hồng Long
# 11 Đinh Thu Hải
# 12 Đặng Mai Thuận
# 13 Đoàn Kim Minh
# 14 Trần Bảo Long
# 15 Tạ Ngọc Thiện
# 16 Hoàng Mai Thúy
# 17 Lý Quốc Ngọc
# 18 Mai Thị Linh
# 19 Tạ Thị Hùng
# 20 Dương Quốc Tường
# 21 Tô Văn Phương
# 22 Nguyễn Hồng Tùng
# 23 Phan Mai Tú
# 24 Ngô Văn Tường
# 25 Phùng Thanh Quân
# 26 Đinh Thanh Vinh
# 27 Đặng Anh Khánh
# 28 Tăng Quý An
# 29 Bùi Hoài Phương
# 30 Võ Mai Thiên
# 31 Trần Quốc Quang
# 32 Quách Kim Tường
# 33 Hồ Quốc Quỳnh
# 34 Đặng Hồng Long
# 35 Đoàn Quý Hùng
# 36 Tô Kim Thuận
# 37 Dương Anh Thảo
# 38 Trương Quý Bình
# 39 Tô Ngọc Xuân
# 40 Mai Hoài Thảo
# 41 Vũ Hoài Việt
# 42 Bùi Hồng Thúy
# 43 Vũ Thu Quỳnh
# 44 Lương Thu Thúy
# 45 Bùi Kim Vân

# %%
# In DS giáo viên
print("Danh sách giáo viên:")
for gv in onto.GiaoVien.instances():
    print(gv.hoTen, gv.ngaySinh, gv.gioiTinh, gv.trinhDo, getattr(gv.lopChuNhiem,'ten',''), *[mon.ten for mon in gv.dayMon])
# Out:
# Danh sách giáo viên:
# Ngô Quý Vân 1983-06-16 Nam Thạc sĩ  Toán học
# Đoàn Thanh Nhật 1989-07-21 Nữ Thạc sĩ 11B02 Toán học
# Quách Kim Linh 1984-12-09 Nữ Thạc sĩ 10C02 Toán học Hóa học
# Lương Mai Nam 1987-05-29 Nữ Đại học  Ngữ văn
# Thái Quốc Quang 1970-01-11 Nam Đại học  Ngữ văn
# Lương Hồng Cường 1984-05-28 Nữ Thạc sĩ  Ngữ văn
# Quách Hồng Minh 1982-02-24 Nữ Thạc sĩ  Hóa học
# Phùng Quý Hiền 1973-06-02 Nam Thạc sĩ  Hóa học
# Trần Thanh Vân 1984-02-29 Nữ Đại học  Hóa học Địa lý
# Tạ Thu Minh 1984-01-18 Nữ Đại học  Lịch sử
# Trương Thanh Linh 1978-11-05 Nữ Đại học 12A03 Lịch sử
# Lương Mai Khánh 1974-12-26 Nữ Thạc sĩ  Lịch sử
# Phùng Thị Quang 1980-03-11 Nữ Thạc sĩ  Địa lý
# Đoàn Minh Khánh 1989-01-06 Nam Thạc sĩ  Địa lý
# Đoàn Quý Vinh 1979-01-18 Nam Thạc sĩ 10C03 Địa lý
# Thái Quốc Quang 1976-10-25 Nam Thạc sĩ  Sinh học
# Dương Kim Quang 1973-04-01 Nữ Thạc sĩ 10C01 Sinh học
# Lâm Đình Quỳnh 1989-09-07 Nam Đại học  Sinh học Toán học
# Ngô Bảo Tường 1989-01-22 Nam Thạc sĩ  Tiếng Anh
# Ngô Thu Xuân 1990-12-24 Nữ Đại học  Tiếng Anh
# Đặng Hoài Hiền 1973-11-18 Nữ Đại học  Tiếng Anh GDCD
# Lý Minh Linh 1970-06-05 Nam Thạc sĩ  GDCD
# Thái Văn Quân 1981-12-03 Nam Thạc sĩ 12A01 GDCD
# Tôn Quốc Nhật 1985-02-22 Nam Đại học 12A02 GDCD Thể dục
# Lê Đình Sơn 1983-09-08 Nam Thạc sĩ  Công nghệ
# Ngô Ngọc Tùng 1988-02-05 Nữ Đại học  Công nghệ
# Đoàn Mai Bình 1979-02-26 Nữ Đại học  Công nghệ
# Võ Hữu Việt 1983-11-11 Nam Đại học 11B01 Thể dục
# Lý Thanh Việt 1970-04-28 Nữ Đại học 11B03 Thể dục
# Tăng Thu Sơn 1984-08-16 Nữ Đại học  Thể dục

# %%
# In DS HS trong lớp 10C01
print("Danh sách học sinh lớp 10C01:")
for hs in onto.HocSinh.instances():
    if hs.hocLop.ten == "10C01":
        print(hs.hoTen, hs.ngaySinh, hs.gioiTinh, hs.hocLop.ten)
# Out:
# Danh sách học sinh lớp 10C01:
# Lâm Hoài Quỳnh 2000-12-21 Nữ 10C01
# Vũ Ngọc Hiền 2000-11-04 Nữ 10C01
# Nguyễn Hoài Khánh 2000-03-27 Nữ 10C01
# Nguyễn Hồng Hiền 2000-01-10 Nữ 10C01
# Bùi Anh Linh 2000-03-05 Nam 10C01

# %%
# in ds GV chủ nhiệm của từng lớp
print("Danh sách giáo viên chủ nhiệm:")
for lop in onto.LopHoc.instances():
    gv = lop.giaoVienChuNhiem
    if gv:
        print(gv.hoTen, gv.ngaySinh, gv.gioiTinh, gv.trinhDo, getattr(gv.lopChuNhiem,'ten',''))
# Out:
# Danh sách giáo viên chủ nhiệm:
# Dương Kim Quang 1973-04-01 Nữ Thạc sĩ 10C01
# Quách Kim Linh 1984-12-09 Nữ Thạc sĩ 10C02
# Đoàn Quý Vinh 1979-01-18 Nam Thạc sĩ 10C03
# Võ Hữu Việt 1983-11-11 Nam Đại học 11B01
# Đoàn Thanh Nhật 1989-07-21 Nữ Thạc sĩ 11B02
# Lý Thanh Việt 1970-04-28 Nữ Đại học 11B03
# Thái Văn Quân 1981-12-03 Nam Thạc sĩ 12A01
# Tôn Quốc Nhật 1985-02-22 Nam Đại học 12A02
# Trương Thanh Linh 1978-11-05 Nữ Đại học 12A03

# %%
# Sửa tên của giáo viên chủ nhiệm Nguyễn Văn X thành Nguyễn Văn Tèo
print("Sửa tên của giáo viên chủ nhiệm Nguyễn Văn X thành Nguyễn Văn Tèo")
for gv in onto.GiaoVien.instances():
    if gv.hoTen == "Nguyễn Văn X":
        gv.hoTen = "Nguyễn Văn Tèo"
        print(gv.hoTen, gv.ngaySinh, gv.gioiTinh, gv.trinhDo, getattr(gv.lopChuNhiem,'ten',''))
# Out:
# Sửa tên của giáo viên chủ nhiệm Nguyễn Văn X thành Nguyễn Văn Tèo

# %%
# Tạo mới một học sinh và thêm vào lớp 10A01
print("Tạo mới một học sinh và thêm vào lớp 10C01")
lop = onto.search_one(ten = "10C01", type = onto.LopHoc)
hs1 = HocSinh(hoTen = "Nguyễn Văn XXX", ngaySinh = "01/01/2011", gioiTinh = "Nam", hocLop = lop)
# In DS HS trong lớp 10A01
print("Danh sách học sinh lớp 10A01:")
print('\n'.join(str(hs.hoTen) for hs in lop.dsHocSinh))
# Out:
# Tạo mới một học sinh và thêm vào lớp 10C01
# Danh sách học sinh lớp 10A01:
# Lâm Hoài Quỳnh
# Vũ Ngọc Hiền
# Nguyễn Hoài Khánh
# Nguyễn Hồng Hiền
# Bùi Anh Linh
# Nguyễn Văn XXX

# %%
# Xoá học sinh có ngày sinh là 01/01/2011
print("Xoá học sinh có ngày sinh là 01/01/2011")
hs_ind = onto.search_one(ngaySinh="01/01/2011", type=onto.HocSinh)
# Nếu individual được tìm thấy, xoá individual đó
if hs_ind is not None:
    destroy_entity(hs_ind)
# Out:
# Xoá học sinh có ngày sinh là 01/01/2011

# %%
# In tất cả điểm số của một học sinh
print("In tất cả điểm số của một học sinh")
hs_ind = onto.search_one(type=onto.HocSinh)
if hs_ind is not None:
    for diem in hs_ind.diemSo:
        print(diem.monHoc.ten, *diem.heSo1, *diem.heSo2, *diem.heSo3)
# Out:
# In tất cả điểm số của một học sinh
# Toán học 10.0 10 9.8 10.0 10 9.8 10 10 6.3 6.3
# Ngữ văn 9.3 10 9.3 10 7.8 7.8 8.3 8.3
# Hóa học 6.3 5.5 5.8 6.3 5.5 5.8 10 10 6.8 6.8
# Lịch sử 5.8 7.5 5.8 7.5 6.5 6.5 8.3 8.3
# Địa lý 6.5 3.5 3.8 6.5 3.5 3.8 3.8 3.8 9.3 9.3
# Sinh học 8.5 7.5 6.3 8.5 7.5 6.3 4.8 4.8 5.5 5.5
# Tiếng Anh 9.8 7.8 9.3 9.8 7.8 9.3 9.5 9.5 10 10
# GDCD 10 7.8 7.5 10 7.8 7.5 7.8 7.8 5.8 5.8
# Công nghệ 5.8 6.8 7.3 5.8 6.8 7.3 8.8 8.8 7.3 7.3
# Thể dục 4.8 5.3 1.8 4.8 5.3 1.8 6.3 6.3 6.8 6.8

# %%
print(hoTen.iri)
print(HocSinh.iri)
# Out:
# http://hc.com/school#hoTen
# http://hc.com/school#HocSinh

# %%
print('In ra các lớp mà GV dạy')
gv = onto.search_one(type = onto.GiaoVien)
for gd in gv.giangDay:
    print(gd.lopHoc.ten, gd.monHoc.ten)
# Out:
# In ra các lớp mà GV dạy
# 10C01 Toán học
# 10C02 Toán học

# %%
print('In các GV dạy lớp 10C03')
lop = onto.search_one(type = onto.LopHoc, ten = '10C03')
gd = onto.search(type = onto.GiangDay, lopHoc = lop)
for g in gd:
    print(g.giaoVien.hoTen, g.monHoc.ten, g.lopHoc.ten)
# Out:
# In các GV dạy lớp 10C03
# Đoàn Thanh Nhật Toán học 10C03
# Lương Mai Nam Ngữ văn 10C03
# Quách Hồng Minh Hóa học 10C03
# Tạ Thu Minh Lịch sử 10C03
# Phùng Thị Quang Địa lý 10C03
# Thái Quốc Quang Sinh học 10C03
# Ngô Bảo Tường Tiếng Anh 10C03
# Lý Minh Linh GDCD 10C03
# Lê Đình Sơn Công nghệ 10C03
# Võ Hữu Việt Thể dục 10C03

# %%
print('- Liệt kê ban giám hiệu')
BGH = onto.search_one(type = onto.ToChuc, ten = 'Ban giám hiệu')
for nv in BGH.thanhVien:
    print(nv.hoTen, nv.chucVu[0].ten, nv.chucVu[0].phuCap)
print('- Liệt kê tổ Văn phòng')
VP = onto.search_one(type = onto.ToChuc, ten = 'Văn phòng')
for nv in VP.thanhVien:
    print(nv.hoTen, nv.chucVu[0].ten, nv.chucVu[0].phuCap)
# Out:
# - Liệt kê ban giám hiệu
# Hoàng Minh Tường Hiệu trưởng 0.7
# Tô Mai Bình Phó hiệu Trưởng 0.5
# Đỗ Thu Minh Phó hiệu Trưởng 0.5
# - Liệt kê tổ Văn phòng
# Tôn Quốc Linh Bảo vệ 0
# Phùng Đình Cường Bảo vệ 0
# Đinh Đình An Bảo vệ 0
# Quách Quốc Bình Phục vụ 0
# Đào Minh Thuận Phục vụ 0
# Huỳnh Quý Quang Văn thư 0.3
# Tô Văn Cường Thủ quỹ 0.3
# Phạm Mai Việt Kế toán 0.5
# Đặng Anh Nam Thư viện 0
# Tô Văn Quỳnh Thiết bị 0.25
# Lý Minh Quang Thiết bị 0.25

# %%
print('Liệt kê các tổ trưởng và tổ phó của các tổ chuyên môn')
toChuyenMon = [x for x in onto.search(type = onto.ToChuc) if x.name.startswith('To')]
for tc in toChuyenMon:
    print(tc.ten)
    for nv in tc.thanhVien:
        print('   -', nv.hoTen, nv.chucVu[0].ten, nv.chucVu[0].phuCap, nv.dayMon)
# Out:
# Liệt kê các tổ trưởng và tổ phó của các tổ chuyên môn
# Tổ Toán học
#    - Ngô Quý Vân Tổ trưởng 0.2 [school.Toan]
#    - Đoàn Thanh Nhật Tổ phó 0.15 [school.Toan]
#    - Quách Kim Linh Giáo viên 0 [school.Toan, school.HoaHoc]
#    - Lâm Đình Quỳnh Giáo viên 0 [school.SinhHoc, school.Toan]
# Tổ Ngữ văn
#    - Lương Mai Nam Tổ trưởng 0.2 [school.NguVan]
#    - Thái Quốc Quang Tổ phó 0.15 [school.NguVan]
#    - Lương Hồng Cường Giáo viên 0 [school.NguVan]
# Tổ Hóa học
#    - Quách Kim Linh Giáo viên 0 [school.Toan, school.HoaHoc]
#    - Quách Hồng Minh Tổ trưởng 0.2 [school.HoaHoc]
#    - Phùng Quý Hiền Tổ phó 0.15 [school.HoaHoc]
#    - Trần Thanh Vân Giáo viên 0 [school.HoaHoc, school.DiaLy]
# Tổ Lịch sử
#    - Tạ Thu Minh Tổ trưởng 0.2 [school.LichSu]
#    - Trương Thanh Linh Tổ phó 0.15 [school.LichSu]
#    - Lương Mai Khánh Giáo viên 0 [school.LichSu]
# Tổ Địa lý
#    - Trần Thanh Vân Giáo viên 0 [school.HoaHoc, school.DiaLy]
#    - Phùng Thị Quang Tổ trưởng 0.2 [school.DiaLy]
#    - Đoàn Minh Khánh Tổ phó 0.15 [school.DiaLy]
#    - Đoàn Quý Vinh Giáo viên 0 [school.DiaLy]
# Tổ Sinh học
#    - Thái Quốc Quang Tổ trưởng 0.2 [school.SinhHoc]
#    - Dương Kim Quang Tổ phó 0.15 [school.SinhHoc]
#    - Lâm Đình Quỳnh Giáo viên 0 [school.SinhHoc, school.Toan]
# Tổ Tiếng Anh
#    - Ngô Bảo Tường Tổ trưởng 0.2 [school.TiengAnh]
#    - Ngô Thu Xuân Tổ phó 0.15 [school.TiengAnh]
#    - Đặng Hoài Hiền Giáo viên 0 [school.TiengAnh, school.GDCD]
# Tổ GDCD
#    - Đặng Hoài Hiền Giáo viên 0 [school.TiengAnh, school.GDCD]
#    - Lý Minh Linh Tổ trưởng 0.2 [school.GDCD]
#    - Thái Văn Quân Tổ phó 0.15 [school.GDCD]
#    - Tôn Quốc Nhật Giáo viên 0 [school.GDCD, school.TheDuc]
# Tổ Công nghệ
#    - Lê Đình Sơn Tổ trưởng 0.2 [school.CongNghe]
#    - Ngô Ngọc Tùng Tổ phó 0.15 [school.CongNghe]
#    - Đoàn Mai Bình Giáo viên 0 [school.CongNghe]
# Tổ Thể dục
#    - Tôn Quốc Nhật Giáo viên 0 [school.GDCD, school.TheDuc]
#    - Võ Hữu Việt Tổ trưởng 0.2 [school.TheDuc]
#    - Lý Thanh Việt Tổ phó 0.15 [school.TheDuc]
#    - Tăng Thu Sơn Giáo viên 0 [school.TheDuc]

# %%
print('Liệt kê các phòng kèm tổ chức sử dụng')
for p in onto.Phong.instances():
    print(p.ten, end = ' ')
    for tc in p.suDungBoi:
        print('-', tc.ten, end = ' ')
    print()
# Out:
# Liệt kê các phòng kèm tổ chức sử dụng
# Phòng 10C01 - 10C01
# Phòng 10C02 - 10C02
# Phòng 10C03 - 10C03
# Phòng 11B01 - 11B01
# Phòng 11B02 - 11B02
# Phòng 11B03 - 11B03
# Phòng 12A01 - 12A01
# Phòng 12A02 - 12A02
# Phòng 12A03 - 12A03
# Phòng Toán học - Tổ Toán học
# Phòng Ngữ văn - Tổ Ngữ văn
# Phòng Hóa học - Tổ Hóa học
# Phòng Lịch sử - Tổ Lịch sử
# Phòng Địa lý - Tổ Địa lý
# Phòng Sinh học - Tổ Sinh học
# Phòng Tiếng Anh - Tổ Tiếng Anh
# Phòng GDCD - Tổ GDCD
# Phòng Công nghệ - Tổ Công nghệ
# Phòng Thể dục - Tổ Thể dục
# Phòng Hiệu trưởng - Ban giám hiệu
# Phòng Phó hiệu Trưởng 1 - Ban giám hiệu
# Phòng Phó hiệu Trưởng 2 - Ban giám hiệu
# Phòng Bảo vệ 1 - Văn phòng
# Phòng Bảo vệ 2 - Văn phòng
# Phòng Bảo vệ 3 - Văn phòng
# Phòng Phục vụ 1 - Văn phòng
# Phòng Phục vụ 2 - Văn phòng
# Phòng Văn thư - Văn phòng
# Phòng Thủ quỹ - Văn phòng
# Phòng Kế toán - Văn phòng
# Phòng Thư viện - Văn phòng
# Phòng Thiết bị 1 - Văn phòng
# Phòng Thiết bị 2 - Văn phòng

# %%
print('Liệt kê các hoạt động')
for hd in onto.HoatDong.instances():
    print(hd.ten, hd.ngayBatDau, hd.ngayKetThuc,[gv.hoTen for gv in hd.quanLy], [ng.hoTen for ng in hd.thamGia])
# Out:
# Liệt kê các hoạt động
# Học tập 2021-10-31 2022-01-08 ['Lê Đình Sơn', 'Trần Thanh Vân', 'Lê Đình Sơn', 'Trần Thanh Vân'] ['Phùng Thanh Quân', 'Lâm Hoài Quỳnh', 'Trương Quý Bình', 'Đoàn Quý Hùng', 'Nguyễn Hồng Tùng', 'Dương Anh Thảo', 'Mai Hoài Thảo']
# Thể thao 2021-09-21 2022-01-15 ['Ngô Bảo Tường', 'Ngô Bảo Tường'] ['Dương Anh Thảo', 'Bùi Anh Linh', 'Đinh Thu Hải', 'Bùi Kim Vân', 'Lý Quốc Ngọc', 'Vũ Ngọc Hiền', 'Đinh Thị Khánh', 'Hoàng Mai Thúy', 'Tô Kim Thuận', 'Lương Thu Thúy']
# Văn hóa 2021-10-02 2022-01-12 ['Lương Mai Nam', 'Lương Mai Nam'] ['Đặng Hồng Long', 'Võ Mai Thiên', 'Dương Anh Thảo', 'Trần Quốc Quang', 'Đặng Kim Hiền', 'Đặng Mai Thuận', 'Đoàn Kim Minh']
# Nghệ thuật 2021-10-21 2022-03-19 ['Dương Kim Quang', 'Trần Thanh Vân', 'Dương Kim Quang', 'Trần Thanh Vân'] ['Đinh Thu Hải', 'Phùng Thanh Quân', 'Đoàn Kim Minh', 'Vũ Hoài Việt', 'Đặng Anh Khánh', 'Mai Thị Linh', 'Bùi Kim Vân']
# Tình nguyện 2021-10-19 2022-05-03 ['Đoàn Mai Bình', 'Đoàn Mai Bình'] ['Đặng Kim Hiền', 'Đặng Hồng Long', 'Võ Mai Thiên', 'Tô Văn Phương', 'Vũ Hoài Việt', 'Trương Quý Bình', 'Đinh Thu Hải', 'Nguyễn Hồng Hiền', 'Đoàn Kim Minh']
# Khoa học 2021-12-07 2022-01-03 ['Thái Văn Quân', 'Thái Văn Quân'] ['Nguyễn Hoài Khánh', 'Phùng Thanh Quân', 'Lương Thu Thúy']
# Kỹ năng sống 2021-09-16 2022-01-13 ['Tạ Thu Minh', 'Thái Quốc Quang', 'Tạ Thu Minh', 'Thái Quốc Quang'] ['Nguyễn Hồng Hiền', 'Võ Mai Thiên', 'Đoàn Kim Minh', 'Tăng Thị Tú', 'Lương Thu Thúy', 'Mai Thị Linh']
# Ngoại khóa 2021-09-10 2022-04-21 ['Trần Thanh Vân', 'Thái Quốc Quang', 'Đoàn Thanh Nhật', 'Trần Thanh Vân', 'Thái Quốc Quang', 'Đoàn Thanh Nhật'] ['Tô Ngọc Xuân', 'Đặng Hồng Long', 'Ngô Văn Tường', 'Trương Quý Bình']

# %%
print('Liệt kê các HS điểm danh ở 1 hoạt động')
hd = onto.search(type = onto.HoatDong)[4]
dd = onto.search(type = onto.DiemDanh, hoatDong = hd)
for d in dd:
    print(d.nguoi.hoTen, d.ngayGio, d.trangThai)
# Out:
# Liệt kê các HS điểm danh ở 1 hoạt động
# Đặng Kim Hiền 2021-10-19 08:00:00 Vắng
# Đặng Hồng Long 2021-10-19 08:00:00 Vắng
# Võ Mai Thiên 2021-10-19 08:00:00 Vắng
# Tô Văn Phương 2021-10-19 09:00:00 Có mặt
# Vũ Hoài Việt 2021-10-19 09:00:00 Vắng
# Trương Quý Bình 2021-10-19 07:00:00 Vắng
# Đinh Thu Hải 2021-10-19 08:00:00 Có mặt
# Nguyễn Hồng Hiền 2021-10-19 08:00:00 Có mặt
# Đoàn Kim Minh 2021-10-19 07:00:00 Vắng

# %%
print('Liệt kê các đối tượng chưa có dữ liệu trong CSDL')
for x in onto.classes():
    if len(x.instances()) == 0:
        print(x.name)
# Out:
# Liệt kê các đối tượng chưa có dữ liệu trong CSDL
# Anh
# Chi
# Em
