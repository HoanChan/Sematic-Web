# %% [markdown]
# ### Cài đặt thư viện:
#
# Cài đặt các thư viện vào môi trường anaconda:
#
# ```bash
# conda install -c conda-forge owlready2
# ```

# %% [markdown]
# ### Tạo ontology

# %%
# %run ../app/models/model.py
# Out:
# * Owlready2 * Warning: optimized Cython parser module 'owlready2_optimized' is not available, defaulting to slower Python implementation

# %%
# Lưu CSDL ra file
onto.save(file="../app/data/education.owl")
with open("../app/data/education.owl", "r") as f:
    print(f.read())
# Out:
# <?xml version="1.0"?>
# <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#"
#          xmlns:xsd="http://www.w3.org/2001/XMLSchema#"
#          xmlns:rdfs="http://www.w3.org/2000/01/rdf-schema#"
#          xmlns:owl="http://www.w3.org/2002/07/owl#"
#          xml:base="http://hc.com/school"
#          xmlns="http://hc.com/school#">
#
# <owl:Ontology rdf:about="http://hc.com/school"/>
#
# <owl:ObjectProperty rdf:about="#thanhVien">
#   <rdfs:domain rdf:resource="#ToChuc"/>
#   <rdfs:range rdf:resource="#Nguoi"/>
#   <owl:inverseOf rdf:resource="#toChuc"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#phong">
#   <rdfs:domain rdf:resource="#ToChuc"/>
#   <rdfs:range rdf:resource="#Phong"/>
#   <owl:inverseOf rdf:resource="#suDungBoi"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#toChuc">
#   <rdfs:domain rdf:resource="#Nguoi"/>
#   <rdfs:range rdf:resource="#ToChuc"/>
#   <owl:inverseOf rdf:resource="#thanhVien"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#chucVu">
#   <rdfs:domain rdf:resource="#NhanVien"/>
#   <rdfs:range rdf:resource="#ChucVu"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#con">
#   <rdfs:domain rdf:resource="#PhuHuynh"/>
#   <rdfs:range rdf:resource="#HocSinh"/>
#   <owl:inverseOf rdf:resource="#phuHuynh"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#giaoVienChuNhiem">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#LopHoc"/>
#   <rdfs:range rdf:resource="#GiaoVien"/>
#   <owl:inverseOf rdf:resource="#lopChuNhiem"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#phongHoc">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#LopHoc"/>
#   <rdfs:range rdf:resource="#Phong"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#dsHocSinh">
#   <rdfs:domain rdf:resource="#LopHoc"/>
#   <rdfs:range rdf:resource="#HocSinh"/>
#   <owl:inverseOf rdf:resource="#hocLop"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#hocLop">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#LopHoc"/>
#   <owl:inverseOf rdf:resource="#dsHocSinh"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#phuHuynh">
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#PhuHuynh"/>
#   <owl:inverseOf rdf:resource="#con"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#diemSo">
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#DiemSo"/>
#   <owl:inverseOf rdf:resource="#hocSinh"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#dayMon">
#   <rdfs:domain rdf:resource="#GiaoVien"/>
#   <rdfs:range rdf:resource="#MonHoc"/>
#   <owl:inverseOf rdf:resource="#giaoVienDay"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#giangDay">
#   <rdfs:domain rdf:resource="#GiaoVien"/>
#   <rdfs:range rdf:resource="#GiangDay"/>
#   <owl:inverseOf rdf:resource="#giaoVien"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#lopChuNhiem">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#GiaoVien"/>
#   <rdfs:range rdf:resource="#LopHoc"/>
#   <owl:inverseOf rdf:resource="#giaoVienChuNhiem"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#giaoVienDay">
#   <rdfs:domain rdf:resource="#MonHoc"/>
#   <rdfs:range rdf:resource="#GiaoVien"/>
#   <owl:inverseOf rdf:resource="#dayMon"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#hocSinh">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="#HocSinh"/>
#   <owl:inverseOf rdf:resource="#diemSo"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#monHoc">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="#MonHoc"/>
#   <rdfs:domain rdf:resource="#GiangDay"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#giaoVien">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#GiangDay"/>
#   <rdfs:range rdf:resource="#GiaoVien"/>
#   <owl:inverseOf rdf:resource="#giangDay"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#lopHoc">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#GiangDay"/>
#   <rdfs:range rdf:resource="#LopHoc"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#docGia">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DocGia"/>
#   <rdfs:range rdf:resource="#Nguoi"/>
#   <rdfs:domain rdf:resource="#PhieuMuon"/>
#   <rdfs:range rdf:resource="#DocGia"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#sachDaDoc">
#   <rdfs:domain rdf:resource="#DocGia"/>
#   <rdfs:range rdf:resource="#Sach"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#dsSach">
#   <rdfs:domain rdf:resource="#TacGia"/>
#   <rdfs:range rdf:resource="#Sach"/>
#   <rdfs:domain rdf:resource="#NhaXuatBan"/>
#   <rdfs:domain rdf:resource="#TheLoai"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#tacGia">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Sach"/>
#   <rdfs:range rdf:resource="#TacGia"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#nhaXuatBan">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Sach"/>
#   <rdfs:range rdf:resource="#NhaXuatBan"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#theLoai">
#   <rdfs:domain rdf:resource="#Sach"/>
#   <rdfs:range rdf:resource="#TheLoai"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#sachMuon">
#   <rdfs:domain rdf:resource="#PhieuMuon"/>
#   <rdfs:range rdf:resource="#Sach"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#suDungBoi">
#   <rdfs:domain rdf:resource="#Phong"/>
#   <rdfs:range rdf:resource="#ToChuc"/>
#   <owl:inverseOf rdf:resource="#phong"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#quanLy">
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:range rdf:resource="#Nguoi"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#thamGia">
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:range rdf:resource="#Nguoi"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#nguoi">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemDanh"/>
#   <rdfs:range rdf:resource="#Nguoi"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#hoatDong">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemDanh"/>
#   <rdfs:range rdf:resource="#HoatDong"/>
# </owl:ObjectProperty>
#
# <owl:DatatypeProperty rdf:about="#ten">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#ChucVu"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
#   <rdfs:domain rdf:resource="#ToChuc"/>
#   <rdfs:domain rdf:resource="#MonHoc"/>
#   <rdfs:domain rdf:resource="#TacGia"/>
#   <rdfs:domain rdf:resource="#NhaXuatBan"/>
#   <rdfs:domain rdf:resource="#Sach"/>
#   <rdfs:domain rdf:resource="#TheLoai"/>
#   <rdfs:domain rdf:resource="#Phong"/>
#   <rdfs:domain rdf:resource="#HoatDong"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#phuCap">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#ChucVu"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#hoTen">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Nguoi"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngaySinh">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Nguoi"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#gioiTinh">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Nguoi"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#heSoLuong">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#NhanVien"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngheNghiep">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#PhuHuynh"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#trinhDo">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#GiaoVien"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#soTiet">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#MonHoc"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#integer"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#heSo1">
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#heSo2">
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#heSo3">
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayCap">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DocGia"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayHetHan">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DocGia"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#giaTien">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Sach"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#integer"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#soLuong">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Sach"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#integer"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayMuon">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#PhieuMuon"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayTra">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#PhieuMuon"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayBatDau">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayKetThuc">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayGio">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemDanh"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#dateTime"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#trangThai">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemDanh"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:Class rdf:about="#ChucVu">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#ToChuc">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#Nguoi">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#NhanVien">
#   <rdfs:subClassOf rdf:resource="#Nguoi"/>
# </owl:Class>
#
# <owl:Class rdf:about="#PhuHuynh">
#   <rdfs:subClassOf rdf:resource="#Nguoi"/>
# </owl:Class>
#
# <owl:Class rdf:about="#LopHoc">
#   <rdfs:subClassOf rdf:resource="#ToChuc"/>
# </owl:Class>
#
# <owl:Class rdf:about="#HocSinh">
#   <rdfs:subClassOf rdf:resource="#Nguoi"/>
# </owl:Class>
#
# <owl:Class rdf:about="#GiaoVien">
#   <rdfs:subClassOf rdf:resource="#NhanVien"/>
# </owl:Class>
#
# <owl:Class rdf:about="#MonHoc">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#DiemSo">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#GiangDay">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#DocGia">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#TacGia">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#NhaXuatBan">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#Sach">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#TheLoai">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#PhieuMuon">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#Phong">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#HoatDong">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#DiemDanh">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
#
# </rdf:RDF>

# %%
lsPro = list(onto.properties())
def get_properties(obj):
    return [p for p in lsPro if obj.is_a[0] in p.domain] + [p for p in lsPro if obj in p.domain]
print('Liệt kê toàn bộ các đối tượng trong ontology')
lsClass= list(onto.classes())
for i, class_ in zip(range(len(lsClass)), lsClass):
    # print(class_.name, '[', ', '.join([x.name for x in get_properties(class_)]), ']')
    print(str(i+1)+'.', class_.name, 'kế thừa từ', class_.is_a)
    for x in get_properties(class_) :
        print('-', x.name, ':', x.range)
# Out:
# Liệt kê toàn bộ các đối tượng trong ontology
# 1. ChucVu kế thừa từ [owl.Thing]
# - ten : [<class 'str'>, <class 'str'>]
# - phuCap : [<class 'float'>]
# 2. ToChuc kế thừa từ [owl.Thing]
# - ten : [<class 'str'>, <class 'str'>]
# - thanhVien : [school.Nguoi]
# - phong : [school.Phong]
# 3. Nguoi kế thừa từ [owl.Thing]
# - hoTen : [<class 'str'>]
# - ngaySinh : [<class 'datetime.date'>]
# - gioiTinh : [<class 'str'>]
# - toChuc : [school.ToChuc]
# 4. NhanVien kế thừa từ [school.Nguoi]
# - hoTen : [<class 'str'>]
# - ngaySinh : [<class 'datetime.date'>]
# - gioiTinh : [<class 'str'>]
# - toChuc : [school.ToChuc]
# - heSoLuong : [<class 'float'>]
# - chucVu : [school.ChucVu]
# 5. PhuHuynh kế thừa từ [school.Nguoi]
# - hoTen : [<class 'str'>]
# - ngaySinh : [<class 'datetime.date'>]
# - gioiTinh : [<class 'str'>]
# - toChuc : [school.ToChuc]
# - ngheNghiep : [<class 'str'>]
# - con : [school.HocSinh]
# 6. LopHoc kế thừa từ [school.ToChuc]
# - ten : [<class 'str'>, <class 'str'>]
# - thanhVien : [school.Nguoi]
# - phong : [school.Phong]
# - giaoVienChuNhiem : [school.GiaoVien]
# - phongHoc : [school.Phong]
# - dsHocSinh : [school.HocSinh]
# 7. HocSinh kế thừa từ [school.Nguoi]
# - hoTen : [<class 'str'>]
# - ngaySinh : [<class 'datetime.date'>]
# - gioiTinh : [<class 'str'>]
# - toChuc : [school.ToChuc]
# - hocLop : [school.LopHoc]
# - phuHuynh : [school.PhuHuynh]
# - diemSo : [school.DiemSo]
# 8. GiaoVien kế thừa từ [school.NhanVien]
# - heSoLuong : [<class 'float'>]
# - chucVu : [school.ChucVu]
# - trinhDo : [<class 'str'>]
# - dayMon : [school.MonHoc]
# - giangDay : [school.GiangDay]
# - lopChuNhiem : [school.LopHoc]
# 9. MonHoc kế thừa từ [owl.Thing]
# - ten : [<class 'str'>, <class 'str'>]
# - soTiet : [<class 'int'>]
# - giaoVienDay : [school.GiaoVien]
# 10. DiemSo kế thừa từ [owl.Thing]
# - heSo1 : [<class 'float'>]
# - heSo2 : [<class 'float'>]
# - heSo3 : [<class 'float'>]
# - hocSinh : [school.HocSinh]
# - monHoc : [school.MonHoc, school.MonHoc]
# 11. GiangDay kế thừa từ [owl.Thing]
# - monHoc : [school.MonHoc, school.MonHoc]
# - giaoVien : [school.GiaoVien]
# - lopHoc : [school.LopHoc]
# 12. DocGia kế thừa từ [owl.Thing]
# - ngayCap : [<class 'datetime.date'>]
# - ngayHetHan : [<class 'datetime.date'>]
# - docGia : [school.Nguoi, school.DocGia]
# - sachDaDoc : [school.Sach]
# 13. TacGia kế thừa từ [owl.Thing]
# - ten : [<class 'str'>, <class 'str'>]
# - dsSach : [school.Sach, school.Sach]
# 14. NhaXuatBan kế thừa từ [owl.Thing]
# - ten : [<class 'str'>, <class 'str'>]
# - dsSach : [school.Sach, school.Sach]
# 15. Sach kế thừa từ [owl.Thing]
# - ten : [<class 'str'>, <class 'str'>]
# - giaTien : [<class 'int'>]
# - soLuong : [<class 'int'>]
# - tacGia : [school.TacGia]
# - nhaXuatBan : [school.NhaXuatBan]
# - theLoai : [school.TheLoai]
# 16. TheLoai kế thừa từ [owl.Thing]
# - ten : [<class 'str'>, <class 'str'>]
# - dsSach : [school.Sach, school.Sach]
# 17. PhieuMuon kế thừa từ [owl.Thing]
# - ngayMuon : [<class 'datetime.date'>]
# - ngayTra : [<class 'datetime.date'>]
# - docGia : [school.Nguoi, school.DocGia]
# - sachMuon : [school.Sach]
# 18. Phong kế thừa từ [owl.Thing]
# - ten : [<class 'str'>, <class 'str'>]
# - suDungBoi : [school.ToChuc]
# 19. HoatDong kế thừa từ [owl.Thing]
# - ten : [<class 'str'>, <class 'str'>]
# - ngayBatDau : [<class 'datetime.date'>]
# - ngayKetThuc : [<class 'datetime.date'>]
# - quanLy : [school.Nguoi]
# - thamGia : [school.Nguoi]
# 20. DiemDanh kế thừa từ [owl.Thing]
# - ngayGio : [<class 'datetime.datetime'>]
# - trangThai : [<class 'str'>]
# - nguoi : [school.Nguoi]
# - hoatDong : [school.HoatDong]

# %% [markdown]
# ### Thêm dữ liệu

# %%
import random
from datetime import datetime, timedelta

def createRandomDate(start_year, end_year):
    # Tính toán số ngày trong năm bắt đầu và kết thúc
    start_date = datetime(year=start_year, month=1, day=1)
    end_date = datetime(year=end_year, month=12, day=31)
    days_in_range = (end_date - start_date).days + 1

    # Tạo ngẫu nhiên số ngày trong khoảng thời gian bắt đầu và kết thúc
    random_days = random.randint(0, days_in_range - 1)

    # Tính toán ngày sinh từ số ngày được chọn
    birth_date = start_date + timedelta(days=random_days)

    # Trả về chuỗi ngày sinh dạng dd/mm/yyyy
    return birth_date.strftime('%d/%m/%Y')

def createRandomInfo():
    ho = random.choice(["Nguyễn", "Trần", "Lê", "Phạm", "Hoàng", "Huỳnh", "Phan", "Vũ", "Võ", "Đặng", "Bùi", "Đỗ", "Hồ", "Ngô", "Dương", "Lý", "Lương", "Mai", "Trương", "Tạ", "Đào", 
                            "Đoàn", "Đinh", "Lâm", "Phùng", "Đoàn", "Bành", "Quách", "Thái", "Tô", "Tôn", "Tăng"])
    lot = random.choice(['Văn', 'Thị', 'Hồng', 'Anh', 'Quý', 'Bảo', "Thanh", "Thu", "Hữu", "Mai", "Đình", "Hoài", "Ngọc", "Minh", "Kim"])
    ten = random.choice(["An", "Bình", "Cường", "Dũng", "Hải", "Hiền", "Hoàng", "Hùng", "Khánh", "Linh", "Long", "Minh", "Nam", "Ngọc", "Nhật", "Phương", "Quân", "Quang", "Quỳnh", 
                            "Sơn", "Thảo", "Thiên", "Thiện", "Thúy", "Thuận", "Tùng", "Tú", "Tường", "Việt", "Vân", "Vinh", "Xuân"])
    gioiTinh = random.choice(["Nam", "Nữ", "Khác"])
    return f"{ho} {lot} {ten}", gioiTinh
def randScore():
    score = random.randint(0, 10)
    if score != 10:
        score += random.choice([0.3, 0.5, 0.8])
    return score

def getClassName(soLopMoiKhoi, index):
    khoi = index // soLopMoiKhoi
    lop = index % soLopMoiKhoi + 1
    tenLop = f'{khoi+10}{"CBA"[khoi]}'
    if lop < 10:
        return f'{tenLop}0{lop}'
    else:
        return f'{tenLop}{lop}'
# Đọc CSDL từ file
onto = get_ontology("../app/data/education.owl").load()

# Thêm dữ liệu cho từng đối tượng
with onto: 
    # Tạo ngẫu nhiên 10 lớp học mỗi khối lớp
    soLopMoiKhoi = 3
    tongSoLop = soLopMoiKhoi * 3
    soHSMoiLop = 5
    soHSCoAnhEm = 20
    soGVMoiMon = 3
    soGVDay2Mon = 5
    soDocGia = 10
    soSach = 15
    soTacGia = 5
    soNXB = 3
    dsLop, dsHS, dsGV, dsMonHoc, dsToChuc, dsChucVu, dsNV, dsPhong  = [], [], [], [], [], [], [], []

    for i in range(tongSoLop):
        lop = LopHoc(ten = getClassName(soLopMoiKhoi, i))
        dsLop.append(lop)
        # Tạo ngẫu nhiên HS cho mỗi lớp
        for j in range(soHSMoiLop):
            ten, gt = createRandomInfo()
            hs = HocSinh(hoTen = ten, ngaySinh = createRandomDate(2000, 2000), gioiTinh = gt, hocLop = lop)
            dsHS.append(hs)
            # Tạo ngẫu nhiên 2 PH cho mỗi HS
            for k in range(2):
                ten, gt = createRandomInfo()
                nghe = random.choice(["Nông dân", "Công nhân", "Giáo viên", "Bác sĩ", "Kỹ sư", "Nhân viên văn phòng", "Chủ doanh nghiệp"])
                ph = PhuHuynh(hoTen = ten, ngaySinh = createRandomDate(1970, 1980), gioiTinh = gt, con = [hs], ngheNghiep = nghe)
    
    # Cho một số học sinh có chung phụ huynh
    random_items = random.sample(dsHS, soHSCoAnhEm)
    remaining_items = list(set(dsHS) - set(random_items))
    new_random_items = random.sample(remaining_items, soHSCoAnhEm)
    for hs, i in zip(random_items, range(soHSCoAnhEm)):
        for ph in hs.phuHuynh: destroy_entity(ph)
        hs.phuHuynh = []
        for ph in new_random_items[i].phuHuynh: 
            ph.con.append(hs)
            hs.phuHuynh.append(ph)

    # Tạo chức vụ tổ trưởng, tổ phó
    toTruong = ChucVu('cvToTruong', ten = 'Tổ trưởng', phuCap = 0.2)
    dsChucVu.append(toTruong)
    toPho = ChucVu('cvToPho', ten = 'Tổ phó', phuCap = 0.15)
    dsChucVu.append(toPho)
    giaoVien = ChucVu('cvGiaoVien', ten = 'Giáo viên', phuCap = 0)
    dsChucVu.append(giaoVien)
    # Tạo môn học
    dataMonHoc = [('Toan', 'Toán học', 5), ('NguVan', 'Ngữ văn', 3), ('HoaHoc', 'Hóa học', 3), ('LichSu', 'Lịch sử', 3), ('DiaLy', 'Địa lý', 5), 
                  ('SinhHoc', 'Sinh học', 2), ('TiengAnh', 'Tiếng Anh', 2), ('GDCD', 'GDCD', 3), ('CongNghe', 'Công nghệ', 2), ('TheDuc', 'Thể dục', 2)]
    for id, mon, st in dataMonHoc:
        mon_hoc = MonHoc(id, ten = mon, soTiet = st)
        dsMonHoc.append(mon_hoc)
        phong = Phong('Phong' + id, ten = 'Phòng ' + mon)
        dsPhong.append(phong)
        toChuyenMon = ToChuc('To' + id, ten = 'Tổ '+ mon, phong = [phong]) 
        dsToChuc.append(toChuyenMon)
        # Tạo ngẫu nhiên GV cho mỗi môn
        for j in range(soGVMoiMon):
            ten, gt = createRandomInfo()
            td = ['Đại học', 'Thạc sĩ'][random.randint(0,1)]
            gv = GiaoVien(hoTen = ten, ngaySinh = createRandomDate(1970, 1990), gioiTinh = gt, trinhDo = td, dayMon = [mon_hoc], toChuc = [toChuyenMon], heSoLuong = random.uniform(1, 9))
            if j == 0: gv.chucVu = [toTruong, giaoVien]
            elif j == 1: gv.chucVu = [toPho, giaoVien]   
            else: gv.chucVu = [giaoVien]         
            dsGV.append(gv)
        # Tạo điểm số cho từng HS
        for hs in dsHS:
            diem = DiemSo(hocSinh = hs, monHoc = mon_hoc, 
                          heSo1 = [randScore(),randScore(),randScore()], 
                          heSo2 = [randScore(),randScore()], 
                          heSo3 = [randScore()])
    # Chọn ngẫu nhiên các giáo viên làm tổ trưởng, tổ phó
    # Cho một số GV dạy 2 môn
    gvKhongChucVu = [gv for gv in dsGV if len(gv.chucVu) == 1]
    for gv in random.sample(gvKhongChucVu, soGVDay2Mon):
        monChuaDay = [mon for mon in dsMonHoc if mon not in gv.dayMon]
        mon = random.choice(monChuaDay)
        gv.dayMon.append(mon)
        to = [to for to in dsToChuc if mon.ten in to.ten][0]
        gv.toChuc.append(to)

    # Gán GVCN cho từng lớp
    dsGVCN = random.sample(dsGV, tongSoLop)
    for i in range(tongSoLop):
        dsGVCN[i].lopChuNhiem = dsLop[i]

    # Phân công giáo viên dạy môn học
    for mon in dsMonHoc:
        dsGVDayMon = [gv for gv in dsGV if mon in gv.dayMon]
        soLopMoiGV = len(dsLop) // len(dsGVDayMon)
        index = 0
        for gv in dsGVDayMon:
            for i in range(soLopMoiGV):
                tenLop = getClassName(soLopMoiKhoi, index)
                lop = [l for l in dsLop if l.ten == tenLop][0]
                gd = GiangDay(giaoVien = gv, monHoc = mon, lopHoc = lop)
                index += 1
        # Phân công giáo viên dạy môn học cho lớp còn lại
        for i in range(index, tongSoLop):
            tenLop = getClassName(soLopMoiKhoi, i)
            lop = [l for l in dsLop if l.ten == tenLop][0]
            gv = random.choice(dsGVDayMon)
            gd = GiangDay(giaoVien = gv, monHoc = mon, lopHoc = lop)

    dataNhanVien = [('BGH', 'Ban giám hiệu', 'Hiệu trưởng', 0.7, 1), ('BGH', 'Ban giám hiệu', 'Phó hiệu Trưởng', 0.5, 2), 
                    ('VP', 'Văn phòng', 'Bảo vệ', 0, 3), ('VP', 'Văn phòng', 'Phục vụ', 0, 2), ('VP', 'Văn phòng', 'Văn thư', 0.3, 1), ('VP', 'Văn phòng', 'Thủ quỹ', 0.3, 1), 
                    ('VP', 'Văn phòng', 'Kế toán', 0.5, 1), ('VP', 'Văn phòng', 'Thư viện', 0, 1), ('VP', 'Văn phòng', 'Thiết bị', 0.25, 2)]
    for id, toChuc, chucVu, phuCap, soNV in dataNhanVien:
        if id not in [tc.name for tc in dsToChuc]:
            tc = ToChuc(id, ten = toChuc)
            dsToChuc.append(tc)
        else:
            tc = [tc for tc in dsToChuc if tc.name == id][0]
        if chucVu not in [cv.ten for cv in dsChucVu]:
            cv = ChucVu(ten = chucVu, phuCap = phuCap)
            dsChucVu.append(cv)
        else:
            cv = [cv for cv in dsChucVu if cv.toChuc == tc and cv.ten == chucVu][0]
        for i in range(soNV):
            ten, gt = createRandomInfo()
            nv = NhanVien(hoTen = ten, ngaySinh = createRandomDate(1960, 1995), gioiTinh = gt, toChuc = [tc], chucVu = [cv], heSoLuong = random.uniform(1, 9))
            dsNV.append(nv)
    # Cho kế toán làm tổ trưởng và văn thư làm tổ phó
    nv = [nv for nv in dsNV if nv.chucVu[0].ten == 'Kế toán'][0]
    nv.chucVu.append(toTruong)
    nv = [nv for nv in dsNV if nv.chucVu[0].ten == 'Văn thư'][0]
    nv.chucVu.append(toPho)

    # Tạo ngẫu nhiên tác giả
    dsTacGia = []
    for i in range(soTacGia):
        tg = TacGia(ten = f'Tác giả {i+1}')
        dsTacGia.append(tg)
    
    # Tạo ngẫu nhiên NXB
    dsNXB = []
    for i in range(soNXB):
        nxb = NhaXuatBan(ten = f'NXB {i+1}')
        dsNXB.append(nxb)
    # Tạo ngẫu nhiên thể loại sách
    dsTheLoai = []
    dsTenTheLoai = ["SGK", "Sách bài tập", "Tài liệu tham khảo", "Truyện tranh"]
    for theLoai in dsTenTheLoai:
        tl = TheLoai(ten = theLoai)
        dsTheLoai.append(tl)
    # Tạo ngẫu nhiên sách
    dsSach = []
    dsTenMonHoc = [mon.ten for mon in dsMonHoc]
    for i in range(soSach):
        ten = random.choice(dsTenTheLoai) + ' ' + random.choice(dsTenMonHoc)
        sach = Sach(ten = ten, tacGia = random.choice(dsTacGia), nhaXuatBan = random.choice(dsNXB), theLoai = random.choices(dsTheLoai,k=random.randint(1,2)), namXuatBan = random.randint(1920, 2021), giaTien = random.randint(1, 200)*1000)
        dsSach.append(sach)

    # Tạo ngẫu nhiên đọc giả
    dsDocGia = []
    dsMuonSach=[]
    nguoi = random.sample(dsGV+dsHS+dsNV, soDocGia)
    for i in range(soDocGia):
        ten, gt = createRandomInfo()
        docGia = DocGia(docGia = nguoi[i], ngayCap = createRandomDate(2022, 2023), ngayHetHan = createRandomDate(2024, 2025))
        dsDocGia.append(docGia)
        # Tạo ngẫu nhiên mượn sách
        soSachMuon = random.randint(1, 5)
        for j in range(soSachMuon):
            sach = random.choice(dsSach)
            muon = PhieuMuon(docGia = docGia, sachMuon = random.choices(dsSach, k=random.randint(1,3)), ngayMuon = createRandomDate(2021, 2022), ngayTra = createRandomDate(2022, 2023))
            dsMuonSach.append(muon)
    
# Lưu CSDL ra file
onto.save(file="../app/data/education.owl", format='rdfxml') # 'ntriples' / "rdfxml"
with open("../app/data/education.owl", "r") as f:
    print(f.read())
# Out:
# <?xml version="1.0"?>
# <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#"
#          xmlns:xsd="http://www.w3.org/2001/XMLSchema#"
#          xmlns:rdfs="http://www.w3.org/2000/01/rdf-schema#"
#          xmlns:owl="http://www.w3.org/2002/07/owl#"
#          xml:base="http://hc.com/school"
#          xmlns="http://hc.com/school#">
#
# <owl:Ontology rdf:about="http://hc.com/school"/>
#
# <owl:ObjectProperty rdf:about="#thanhVien">
#   <rdfs:domain rdf:resource="#ToChuc"/>
#   <rdfs:range rdf:resource="#Nguoi"/>
#   <owl:inverseOf rdf:resource="#toChuc"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#phong">
#   <rdfs:domain rdf:resource="#ToChuc"/>
#   <rdfs:range rdf:resource="#Phong"/>
#   <owl:inverseOf rdf:resource="#suDungBoi"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#toChuc">
#   <rdfs:domain rdf:resource="#Nguoi"/>
#   <rdfs:range rdf:resource="#ToChuc"/>
#   <owl:inverseOf rdf:resource="#thanhVien"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#chucVu">
#   <rdfs:domain rdf:resource="#NhanVien"/>
#   <rdfs:range rdf:resource="#ChucVu"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#con">
#   <rdfs:domain rdf:resource="#PhuHuynh"/>
#   <rdfs:range rdf:resource="#HocSinh"/>
#   <owl:inverseOf rdf:resource="#phuHuynh"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#giaoVienChuNhiem">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#LopHoc"/>
#   <rdfs:range rdf:resource="#GiaoVien"/>
#   <owl:inverseOf rdf:resource="#lopChuNhiem"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#phongHoc">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#LopHoc"/>
#   <rdfs:range rdf:resource="#Phong"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#dsHocSinh">
#   <rdfs:domain rdf:resource="#LopHoc"/>
#   <rdfs:range rdf:resource="#HocSinh"/>
#   <owl:inverseOf rdf:resource="#hocLop"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#hocLop">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#LopHoc"/>
#   <owl:inverseOf rdf:resource="#dsHocSinh"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#phuHuynh">
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#PhuHuynh"/>
#   <owl:inverseOf rdf:resource="#con"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#diemSo">
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#DiemSo"/>
#   <owl:inverseOf rdf:resource="#hocSinh"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#dayMon">
#   <rdfs:domain rdf:resource="#GiaoVien"/>
#   <rdfs:range rdf:resource="#MonHoc"/>
#   <owl:inverseOf rdf:resource="#giaoVienDay"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#giangDay">
#   <rdfs:domain rdf:resource="#GiaoVien"/>
#   <rdfs:range rdf:resource="#GiangDay"/>
#   <owl:inverseOf rdf:resource="#giaoVien"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#lopChuNhiem">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#GiaoVien"/>
#   <rdfs:range rdf:resource="#LopHoc"/>
#   <owl:inverseOf rdf:resource="#giaoVienChuNhiem"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#giaoVienDay">
#   <rdfs:domain rdf:resource="#MonHoc"/>
#   <rdfs:range rdf:resource="#GiaoVien"/>
#   <owl:inverseOf rdf:resource="#dayMon"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#hocSinh">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="#HocSinh"/>
#   <owl:inverseOf rdf:resource="#diemSo"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#monHoc">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="#MonHoc"/>
#   <rdfs:domain rdf:resource="#GiangDay"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#giaoVien">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#GiangDay"/>
#   <rdfs:range rdf:resource="#GiaoVien"/>
#   <owl:inverseOf rdf:resource="#giangDay"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#lopHoc">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#GiangDay"/>
#   <rdfs:range rdf:resource="#LopHoc"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#docGia">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DocGia"/>
#   <rdfs:range rdf:resource="#Nguoi"/>
#   <rdfs:domain rdf:resource="#PhieuMuon"/>
#   <rdfs:range rdf:resource="#DocGia"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#sachDaDoc">
#   <rdfs:domain rdf:resource="#DocGia"/>
#   <rdfs:range rdf:resource="#Sach"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#dsSach">
#   <rdfs:domain rdf:resource="#TacGia"/>
#   <rdfs:range rdf:resource="#Sach"/>
#   <rdfs:domain rdf:resource="#NhaXuatBan"/>
#   <rdfs:domain rdf:resource="#TheLoai"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#tacGia">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Sach"/>
#   <rdfs:range rdf:resource="#TacGia"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#nhaXuatBan">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Sach"/>
#   <rdfs:range rdf:resource="#NhaXuatBan"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#theLoai">
#   <rdfs:domain rdf:resource="#Sach"/>
#   <rdfs:range rdf:resource="#TheLoai"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#sachMuon">
#   <rdfs:domain rdf:resource="#PhieuMuon"/>
#   <rdfs:range rdf:resource="#Sach"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#suDungBoi">
#   <rdfs:domain rdf:resource="#Phong"/>
#   <rdfs:range rdf:resource="#ToChuc"/>
#   <owl:inverseOf rdf:resource="#phong"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#quanLy">
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:range rdf:resource="#Nguoi"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#thamGia">
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:range rdf:resource="#Nguoi"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#nguoi">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemDanh"/>
#   <rdfs:range rdf:resource="#Nguoi"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#hoatDong">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemDanh"/>
#   <rdfs:range rdf:resource="#HoatDong"/>
# </owl:ObjectProperty>
#
# <owl:DatatypeProperty rdf:about="#ten">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#ChucVu"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
#   <rdfs:domain rdf:resource="#ToChuc"/>
#   <rdfs:domain rdf:resource="#MonHoc"/>
#   <rdfs:domain rdf:resource="#TacGia"/>
#   <rdfs:domain rdf:resource="#NhaXuatBan"/>
#   <rdfs:domain rdf:resource="#Sach"/>
#   <rdfs:domain rdf:resource="#TheLoai"/>
#   <rdfs:domain rdf:resource="#Phong"/>
#   <rdfs:domain rdf:resource="#HoatDong"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#phuCap">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#ChucVu"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#hoTen">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Nguoi"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngaySinh">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Nguoi"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#gioiTinh">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Nguoi"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#heSoLuong">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#NhanVien"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngheNghiep">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#PhuHuynh"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#trinhDo">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#GiaoVien"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#soTiet">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#MonHoc"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#integer"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#heSo1">
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#heSo2">
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#heSo3">
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayCap">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DocGia"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayHetHan">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DocGia"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#giaTien">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Sach"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#integer"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#soLuong">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Sach"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#integer"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayMuon">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#PhieuMuon"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayTra">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#PhieuMuon"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayBatDau">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayKetThuc">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayGio">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemDanh"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#dateTime"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#trangThai">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemDanh"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:Class rdf:about="#ChucVu">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#ToChuc">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#Nguoi">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#NhanVien">
#   <rdfs:subClassOf rdf:resource="#Nguoi"/>
# </owl:Class>
#
# <owl:Class rdf:about="#PhuHuynh">
#   <rdfs:subClassOf rdf:resource="#Nguoi"/>
# </owl:Class>
#
# <owl:Class rdf:about="#LopHoc">
#   <rdfs:subClassOf rdf:resource="#ToChuc"/>
# </owl:Class>
#
# <owl:Class rdf:about="#HocSinh">
#   <rdfs:subClassOf rdf:resource="#Nguoi"/>
# </owl:Class>
#
# <owl:Class rdf:about="#GiaoVien">
#   <rdfs:subClassOf rdf:resource="#NhanVien"/>
# </owl:Class>
#
# <owl:Class rdf:about="#MonHoc">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#DiemSo">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#GiangDay">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#DocGia">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#TacGia">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#NhaXuatBan">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#Sach">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#TheLoai">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#PhieuMuon">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#Phong">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#HoatDong">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#DiemDanh">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <LopHoc rdf:about="#lophoc1">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <ten rdf:datatype="http://www.w3.org/2001/XMLSchema#string">10C01</ten>
# </LopHoc>
#
# <HocSinh rdf:about="#hocsinh1">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc1"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đoàn Kim Linh</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">14/11/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
# </HocSinh>
#
# <PhuHuynh rdf:about="#phuhuynh1">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh1"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Bành Minh Xuân</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">12/07/1971</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Giáo viên</ngheNghiep>
# </PhuHuynh>
#
# <PhuHuynh rdf:about="#phuhuynh2">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh1"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tăng Thị Hiền</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">11/06/1977</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Bác sĩ</ngheNghiep>
# </PhuHuynh>
#
# <HocSinh rdf:about="#hocsinh2">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc1"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Quách Thị Tùng</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">31/12/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
# </HocSinh>
#
# <PhuHuynh rdf:about="#phuhuynh3">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh2"/>
#   <con rdf:resource="#hocsinh18"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Thái Kim Bình</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">10/12/1976</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Bác sĩ</ngheNghiep>
# </PhuHuynh>
#
# <PhuHuynh rdf:about="#phuhuynh4">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh2"/>
#   <con rdf:resource="#hocsinh18"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Trương Hoài Thiên</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">29/12/1970</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Giáo viên</ngheNghiep>
# </PhuHuynh>
#
# <HocSinh rdf:about="#hocsinh3">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc1"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Hồ Đình Thảo</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">04/05/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh4">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc1"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Lâm Bảo Khánh</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">28/05/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh5">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc1"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tôn Thị Xuân</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">15/10/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
# </HocSinh>
#
# <LopHoc rdf:about="#lophoc2">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <ten rdf:datatype="http://www.w3.org/2001/XMLSchema#string">10C02</ten>
# </LopHoc>
#
# <HocSinh rdf:about="#hocsinh6">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc2"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Ngô Bảo Vinh</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">05/05/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
# </HocSinh>
#
# <PhuHuynh rdf:about="#phuhuynh11">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh6"/>
#   <con rdf:resource="#hocsinh15"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Hồ Kim Quỳnh</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">04/01/1972</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Kỹ sư</ngheNghiep>
# </PhuHuynh>
#
# <PhuHuynh rdf:about="#phuhuynh12">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh6"/>
#   <con rdf:resource="#hocsinh15"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Hoàng Hoài Thiên</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">29/05/1978</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Chủ doanh nghiệp</ngheNghiep>
# </PhuHuynh>
#
# <HocSinh rdf:about="#hocsinh7">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc2"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Vũ Hồng Hải</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">06/12/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
# </HocSinh>
#
# <PhuHuynh rdf:about="#phuhuynh13">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh7"/>
#   <con rdf:resource="#hocsinh26"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tôn Mai Khánh</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">19/05/1971</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Bác sĩ</ngheNghiep>
# </PhuHuynh>
#
# <PhuHuynh rdf:about="#phuhuynh14">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh7"/>
#   <con rdf:resource="#hocsinh26"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Lâm Thu Nhật</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">15/12/1972</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Chủ doanh nghiệp</ngheNghiep>
# </PhuHuynh>
#
# <HocSinh rdf:about="#hocsinh8">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc2"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Lê Hồng Thuận</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">19/12/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh9">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc2"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Vũ Thu Quang</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">29/12/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
# </HocSinh>
#
# <PhuHuynh rdf:about="#phuhuynh17">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh9"/>
#   <con rdf:resource="#hocsinh14"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Vũ Thu Quân</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">29/07/1973</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Chủ doanh nghiệp</ngheNghiep>
# </PhuHuynh>
#
# <PhuHuynh rdf:about="#phuhuynh18">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh9"/>
#   <con rdf:resource="#hocsinh14"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tăng Kim Tùng</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">29/08/1971</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nông dân</ngheNghiep>
# </PhuHuynh>
#
# <HocSinh rdf:about="#hocsinh10">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc2"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Lê Hồng Dũng</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">14/05/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
# </HocSinh>
#
# <PhuHuynh rdf:about="#phuhuynh19">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh10"/>
#   <con rdf:resource="#hocsinh24"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Phan Văn Nam</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">26/07/1980</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Chủ doanh nghiệp</ngheNghiep>
# </PhuHuynh>
#
# <PhuHuynh rdf:about="#phuhuynh20">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh10"/>
#   <con rdf:resource="#hocsinh24"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Lý Bảo Thiên</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">22/10/1976</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Bác sĩ</ngheNghiep>
# </PhuHuynh>
#
# <LopHoc rdf:about="#lophoc3">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <ten rdf:datatype="http://www.w3.org/2001/XMLSchema#string">10C03</ten>
# </LopHoc>
#
# <HocSinh rdf:about="#hocsinh11">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc3"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Phùng Anh Sơn</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">11/01/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
# </HocSinh>
#
# <PhuHuynh rdf:about="#phuhuynh21">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh11"/>
#   <con rdf:resource="#hocsinh5"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Vũ Văn Nam</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">23/06/1971</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Bác sĩ</ngheNghiep>
# </PhuHuynh>
#
# <PhuHuynh rdf:about="#phuhuynh22">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh11"/>
#   <con rdf:resource="#hocsinh5"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Dương Minh Thúy</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">23/05/1978</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nông dân</ngheNghiep>
# </PhuHuynh>
#
# <HocSinh rdf:about="#hocsinh12">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc3"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Phan Mai Tú</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">30/06/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
# </HocSinh>
#
# <PhuHuynh rdf:about="#phuhuynh23">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh12"/>
#   <con rdf:resource="#hocsinh8"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Bành Mai Nhật</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">31/12/1979</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Bác sĩ</ngheNghiep>
# </PhuHuynh>
#
# <PhuHuynh rdf:about="#phuhuynh24">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh12"/>
#   <con rdf:resource="#hocsinh8"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tô Thu Dũng</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">08/06/1972</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Chủ doanh nghiệp</ngheNghiep>
# </PhuHuynh>
#
# <HocSinh rdf:about="#hocsinh13">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc3"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Phan Quý Hoàng</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">16/07/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
# </HocSinh>
#
# <PhuHuynh rdf:about="#phuhuynh25">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh13"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đỗ Minh Hiền</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">12/11/1975</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Chủ doanh nghiệp</ngheNghiep>
# </PhuHuynh>
#
# <PhuHuynh rdf:about="#phuhuynh26">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh13"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tăng Quý Sơn</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">03/10/1977</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Công nhân</ngheNghiep>
# </PhuHuynh>
#
# <HocSinh rdf:about="#hocsinh14">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc3"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Dương Văn Hiền</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">24/06/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh15">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc3"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Phạm Thị Thiện</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">07/09/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
# </HocSinh>
#
# <LopHoc rdf:about="#lophoc4">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <ten rdf:datatype="http://www.w3.org/2001/XMLSchema#string">11B01</ten>
# </LopHoc>
#
# <HocSinh rdf:about="#hocsinh16">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc4"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Lý Hữu Bình</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">20/08/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh17">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc4"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Trương Thu Linh</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">30/07/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh18">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc4"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Thái Bảo Xuân</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">15/06/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh19">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc4"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đoàn Ngọc Nam</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">27/11/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh20">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc4"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tăng Hồng Thúy</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">24/10/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
# </HocSinh>
#
# <LopHoc rdf:about="#lophoc5">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <ten rdf:datatype="http://www.w3.org/2001/XMLSchema#string">11B02</ten>
# </LopHoc>
#
# <HocSinh rdf:about="#hocsinh21">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc5"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tô Hữu Thúy</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">18/06/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
# </HocSinh>
#
# <PhuHuynh rdf:about="#phuhuynh41">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh21"/>
#   <con rdf:resource="#hocsinh20"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Mai Hoài Thúy</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">15/01/1973</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nông dân</ngheNghiep>
# </PhuHuynh>
#
# <PhuHuynh rdf:about="#phuhuynh42">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh21"/>
#   <con rdf:resource="#hocsinh20"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Bành Thị An</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">11/05/1976</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Chủ doanh nghiệp</ngheNghiep>
# </PhuHuynh>
#
# <HocSinh rdf:about="#hocsinh22">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc5"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Mai Thanh Quỳnh</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">22/08/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh23">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc5"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Trương Quý Tùng</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">22/12/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
# </HocSinh>
#
# <PhuHuynh rdf:about="#phuhuynh45">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh23"/>
#   <con rdf:resource="#hocsinh22"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Vũ Mai Tùng</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">23/10/1976</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Chủ doanh nghiệp</ngheNghiep>
# </PhuHuynh>
#
# <PhuHuynh rdf:about="#phuhuynh46">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh23"/>
#   <con rdf:resource="#hocsinh22"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Ngô Hồng Hoàng</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">27/02/1979</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nông dân</ngheNghiep>
# </PhuHuynh>
#
# <HocSinh rdf:about="#hocsinh24">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc5"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Võ Hữu Thiện</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">06/03/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh25">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc5"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đỗ Thị Long</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">12/04/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
# </HocSinh>
#
# <PhuHuynh rdf:about="#phuhuynh49">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh25"/>
#   <con rdf:resource="#hocsinh30"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Phạm Quý Thảo</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">02/11/1975</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Công nhân</ngheNghiep>
# </PhuHuynh>
#
# <PhuHuynh rdf:about="#phuhuynh50">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh25"/>
#   <con rdf:resource="#hocsinh30"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Lý Văn Vinh</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">22/11/1973</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Kỹ sư</ngheNghiep>
# </PhuHuynh>
#
# <LopHoc rdf:about="#lophoc6">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <ten rdf:datatype="http://www.w3.org/2001/XMLSchema#string">11B03</ten>
# </LopHoc>
#
# <HocSinh rdf:about="#hocsinh26">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc6"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đào Kim Linh</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">06/11/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh27">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc6"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Hồ Hữu Quang</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">07/03/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh28">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc6"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Bùi Kim Việt</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">23/05/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh29">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc6"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tôn Kim Thảo</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">20/09/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
# </HocSinh>
#
# <PhuHuynh rdf:about="#phuhuynh57">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh29"/>
#   <con rdf:resource="#hocsinh27"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tô Bảo Thúy</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">13/07/1971</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Công nhân</ngheNghiep>
# </PhuHuynh>
#
# <PhuHuynh rdf:about="#phuhuynh58">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh29"/>
#   <con rdf:resource="#hocsinh27"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đinh Hữu Hùng</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">23/09/1980</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Chủ doanh nghiệp</ngheNghiep>
# </PhuHuynh>
#
# <HocSinh rdf:about="#hocsinh30">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc6"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Võ Thị Ngọc</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">29/07/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
# </HocSinh>
#
# <LopHoc rdf:about="#lophoc7">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <ten rdf:datatype="http://www.w3.org/2001/XMLSchema#string">12A01</ten>
# </LopHoc>
#
# <HocSinh rdf:about="#hocsinh31">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc7"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đoàn Thị Thảo</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">14/09/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
# </HocSinh>
#
# <PhuHuynh rdf:about="#phuhuynh61">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh31"/>
#   <con rdf:resource="#hocsinh28"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Phan Kim Minh</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">15/05/1976</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Kỹ sư</ngheNghiep>
# </PhuHuynh>
#
# <PhuHuynh rdf:about="#phuhuynh62">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh31"/>
#   <con rdf:resource="#hocsinh28"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Quách Bảo Linh</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">26/11/1973</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Chủ doanh nghiệp</ngheNghiep>
# </PhuHuynh>
#
# <HocSinh rdf:about="#hocsinh32">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc7"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Huỳnh Mai Ngọc</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">14/09/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
# </HocSinh>
#
# <PhuHuynh rdf:about="#phuhuynh63">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh32"/>
#   <con rdf:resource="#hocsinh34"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đinh Bảo Xuân</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">29/08/1975</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nhân viên văn phòng</ngheNghiep>
# </PhuHuynh>
#
# <PhuHuynh rdf:about="#phuhuynh64">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh32"/>
#   <con rdf:resource="#hocsinh34"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Mai Đình Việt</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">20/01/1976</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nhân viên văn phòng</ngheNghiep>
# </PhuHuynh>
#
# <HocSinh rdf:about="#hocsinh33">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc7"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Lê Anh Hoàng</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">19/11/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
# </HocSinh>
#
# <PhuHuynh rdf:about="#phuhuynh65">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh33"/>
#   <con rdf:resource="#hocsinh19"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nguyễn Quý Ngọc</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">01/11/1972</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nhân viên văn phòng</ngheNghiep>
# </PhuHuynh>
#
# <PhuHuynh rdf:about="#phuhuynh66">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh33"/>
#   <con rdf:resource="#hocsinh19"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Bành Văn Long</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">25/11/1977</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nhân viên văn phòng</ngheNghiep>
# </PhuHuynh>
#
# <HocSinh rdf:about="#hocsinh34">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc7"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Trương Hữu Quang</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">18/11/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh35">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc7"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Phan Mai Việt</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">20/05/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
# </HocSinh>
#
# <PhuHuynh rdf:about="#phuhuynh69">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
# ...
#   <tacGia rdf:resource="#tacgia5"/>
#   <nhaXuatBan rdf:resource="#nhaxuatban2"/>
#   <theLoai rdf:resource="#theloai1"/>
#   <ten rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tài liệu tham khảo Lịch sử</ten>
#   <giaTien rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">123000</giaTien>
# </Sach>
#
# <Sach rdf:about="#sach15">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <tacGia rdf:resource="#tacgia4"/>
#   <nhaXuatBan rdf:resource="#nhaxuatban2"/>
#   <theLoai rdf:resource="#theloai4"/>
#   <ten rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Sách bài tập Thể dục</ten>
#   <giaTien rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">43000</giaTien>
# </Sach>
#
# <DocGia rdf:about="#docgia1">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <docGia rdf:resource="#hocsinh11"/>
#   <ngayCap rdf:datatype="http://www.w3.org/2001/XMLSchema#string">20/12/2023</ngayCap>
#   <ngayHetHan rdf:datatype="http://www.w3.org/2001/XMLSchema#string">14/11/2025</ngayHetHan>
# </DocGia>
#
# <PhieuMuon rdf:about="#phieumuon1">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <docGia rdf:resource="#docgia1"/>
#   <sachMuon rdf:resource="#sach13"/>
#   <sachMuon rdf:resource="#sach11"/>
#   <ngayMuon rdf:datatype="http://www.w3.org/2001/XMLSchema#string">25/08/2022</ngayMuon>
#   <ngayTra rdf:datatype="http://www.w3.org/2001/XMLSchema#string">19/07/2022</ngayTra>
# </PhieuMuon>
#
# <PhieuMuon rdf:about="#phieumuon2">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <docGia rdf:resource="#docgia1"/>
#   <sachMuon rdf:resource="#sach2"/>
#   <sachMuon rdf:resource="#sach3"/>
#   <sachMuon rdf:resource="#sach15"/>
#   <ngayMuon rdf:datatype="http://www.w3.org/2001/XMLSchema#string">29/10/2022</ngayMuon>
#   <ngayTra rdf:datatype="http://www.w3.org/2001/XMLSchema#string">04/06/2023</ngayTra>
# </PhieuMuon>
#
# <DocGia rdf:about="#docgia2">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <docGia rdf:resource="#hocsinh20"/>
#   <ngayCap rdf:datatype="http://www.w3.org/2001/XMLSchema#string">15/04/2022</ngayCap>
#   <ngayHetHan rdf:datatype="http://www.w3.org/2001/XMLSchema#string">30/03/2024</ngayHetHan>
# </DocGia>
#
# <PhieuMuon rdf:about="#phieumuon3">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <docGia rdf:resource="#docgia2"/>
#   <sachMuon rdf:resource="#sach9"/>
#   <ngayMuon rdf:datatype="http://www.w3.org/2001/XMLSchema#string">26/04/2022</ngayMuon>
#   <ngayTra rdf:datatype="http://www.w3.org/2001/XMLSchema#string">15/02/2022</ngayTra>
# </PhieuMuon>
#
# <DocGia rdf:about="#docgia3">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <docGia rdf:resource="#hocsinh7"/>
#   <ngayCap rdf:datatype="http://www.w3.org/2001/XMLSchema#string">06/09/2022</ngayCap>
#   <ngayHetHan rdf:datatype="http://www.w3.org/2001/XMLSchema#string">03/03/2024</ngayHetHan>
# </DocGia>
#
# <PhieuMuon rdf:about="#phieumuon4">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <docGia rdf:resource="#docgia3"/>
#   <sachMuon rdf:resource="#sach2"/>
#   <sachMuon rdf:resource="#sach9"/>
#   <ngayMuon rdf:datatype="http://www.w3.org/2001/XMLSchema#string">26/03/2021</ngayMuon>
#   <ngayTra rdf:datatype="http://www.w3.org/2001/XMLSchema#string">21/03/2023</ngayTra>
# </PhieuMuon>
#
# <PhieuMuon rdf:about="#phieumuon5">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <docGia rdf:resource="#docgia3"/>
#   <sachMuon rdf:resource="#sach7"/>
#   <sachMuon rdf:resource="#sach6"/>
#   <ngayMuon rdf:datatype="http://www.w3.org/2001/XMLSchema#string">04/01/2022</ngayMuon>
#   <ngayTra rdf:datatype="http://www.w3.org/2001/XMLSchema#string">16/06/2023</ngayTra>
# </PhieuMuon>
#
# <PhieuMuon rdf:about="#phieumuon6">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <docGia rdf:resource="#docgia3"/>
#   <sachMuon rdf:resource="#sach9"/>
#   <ngayMuon rdf:datatype="http://www.w3.org/2001/XMLSchema#string">26/07/2021</ngayMuon>
#   <ngayTra rdf:datatype="http://www.w3.org/2001/XMLSchema#string">24/10/2023</ngayTra>
# </PhieuMuon>
#
# <PhieuMuon rdf:about="#phieumuon7">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <docGia rdf:resource="#docgia3"/>
#   <sachMuon rdf:resource="#sach10"/>
#   <ngayMuon rdf:datatype="http://www.w3.org/2001/XMLSchema#string">26/08/2021</ngayMuon>
#   <ngayTra rdf:datatype="http://www.w3.org/2001/XMLSchema#string">16/01/2022</ngayTra>
# </PhieuMuon>
#
# <PhieuMuon rdf:about="#phieumuon8">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <docGia rdf:resource="#docgia3"/>
#   <sachMuon rdf:resource="#sach1"/>
#   <sachMuon rdf:resource="#sach9"/>
#   <sachMuon rdf:resource="#sach10"/>
#   <ngayMuon rdf:datatype="http://www.w3.org/2001/XMLSchema#string">01/10/2021</ngayMuon>
#   <ngayTra rdf:datatype="http://www.w3.org/2001/XMLSchema#string">02/05/2023</ngayTra>
# </PhieuMuon>
#
# <DocGia rdf:about="#docgia4">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <docGia rdf:resource="#hocsinh39"/>
#   <ngayCap rdf:datatype="http://www.w3.org/2001/XMLSchema#string">17/11/2022</ngayCap>
#   <ngayHetHan rdf:datatype="http://www.w3.org/2001/XMLSchema#string">12/09/2025</ngayHetHan>
# </DocGia>
#
# <PhieuMuon rdf:about="#phieumuon9">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <docGia rdf:resource="#docgia4"/>
#   <sachMuon rdf:resource="#sach2"/>
#   <sachMuon rdf:resource="#sach3"/>
#   <sachMuon rdf:resource="#sach6"/>
#   <ngayMuon rdf:datatype="http://www.w3.org/2001/XMLSchema#string">19/12/2022</ngayMuon>
#   <ngayTra rdf:datatype="http://www.w3.org/2001/XMLSchema#string">15/06/2022</ngayTra>
# </PhieuMuon>
#
# <PhieuMuon rdf:about="#phieumuon10">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <docGia rdf:resource="#docgia4"/>
#   <sachMuon rdf:resource="#sach3"/>
#   <sachMuon rdf:resource="#sach4"/>
#   <sachMuon rdf:resource="#sach14"/>
#   <ngayMuon rdf:datatype="http://www.w3.org/2001/XMLSchema#string">27/02/2021</ngayMuon>
#   <ngayTra rdf:datatype="http://www.w3.org/2001/XMLSchema#string">13/08/2023</ngayTra>
# </PhieuMuon>
#
# <PhieuMuon rdf:about="#phieumuon11">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <docGia rdf:resource="#docgia4"/>
#   <sachMuon rdf:resource="#sach8"/>
#   <sachMuon rdf:resource="#sach4"/>
#   <sachMuon rdf:resource="#sach15"/>
#   <ngayMuon rdf:datatype="http://www.w3.org/2001/XMLSchema#string">09/03/2022</ngayMuon>
#   <ngayTra rdf:datatype="http://www.w3.org/2001/XMLSchema#string">11/09/2022</ngayTra>
# </PhieuMuon>
#
# <DocGia rdf:about="#docgia5">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <docGia rdf:resource="#hocsinh23"/>
#   <ngayCap rdf:datatype="http://www.w3.org/2001/XMLSchema#string">01/07/2023</ngayCap>
#   <ngayHetHan rdf:datatype="http://www.w3.org/2001/XMLSchema#string">07/02/2025</ngayHetHan>
# </DocGia>
#
# <PhieuMuon rdf:about="#phieumuon12">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <docGia rdf:resource="#docgia5"/>
#   <sachMuon rdf:resource="#sach6"/>
#   <sachMuon rdf:resource="#sach7"/>
#   <ngayMuon rdf:datatype="http://www.w3.org/2001/XMLSchema#string">17/12/2021</ngayMuon>
#   <ngayTra rdf:datatype="http://www.w3.org/2001/XMLSchema#string">18/04/2023</ngayTra>
# </PhieuMuon>
#
# <PhieuMuon rdf:about="#phieumuon13">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <docGia rdf:resource="#docgia5"/>
#   <sachMuon rdf:resource="#sach12"/>
#   <sachMuon rdf:resource="#sach2"/>
#   <ngayMuon rdf:datatype="http://www.w3.org/2001/XMLSchema#string">21/02/2021</ngayMuon>
#   <ngayTra rdf:datatype="http://www.w3.org/2001/XMLSchema#string">20/09/2022</ngayTra>
# </PhieuMuon>
#
# <PhieuMuon rdf:about="#phieumuon14">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <docGia rdf:resource="#docgia5"/>
#   <sachMuon rdf:resource="#sach12"/>
#   <sachMuon rdf:resource="#sach1"/>
#   <sachMuon rdf:resource="#sach6"/>
#   <ngayMuon rdf:datatype="http://www.w3.org/2001/XMLSchema#string">27/03/2021</ngayMuon>
#   <ngayTra rdf:datatype="http://www.w3.org/2001/XMLSchema#string">19/01/2022</ngayTra>
# </PhieuMuon>
#
# <PhieuMuon rdf:about="#phieumuon15">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <docGia rdf:resource="#docgia5"/>
#   <sachMuon rdf:resource="#sach13"/>
#   <ngayMuon rdf:datatype="http://www.w3.org/2001/XMLSchema#string">10/01/2021</ngayMuon>
#   <ngayTra rdf:datatype="http://www.w3.org/2001/XMLSchema#string">05/04/2022</ngayTra>
# </PhieuMuon>
#
# <DocGia rdf:about="#docgia6">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <docGia rdf:resource="#giaovien22"/>
#   <ngayCap rdf:datatype="http://www.w3.org/2001/XMLSchema#string">05/02/2022</ngayCap>
#   <ngayHetHan rdf:datatype="http://www.w3.org/2001/XMLSchema#string">12/12/2024</ngayHetHan>
# </DocGia>
#
# <PhieuMuon rdf:about="#phieumuon16">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <docGia rdf:resource="#docgia6"/>
#   <sachMuon rdf:resource="#sach5"/>
#   <sachMuon rdf:resource="#sach14"/>
#   <sachMuon rdf:resource="#sach2"/>
#   <ngayMuon rdf:datatype="http://www.w3.org/2001/XMLSchema#string">13/09/2022</ngayMuon>
#   <ngayTra rdf:datatype="http://www.w3.org/2001/XMLSchema#string">13/10/2022</ngayTra>
# </PhieuMuon>
#
# <PhieuMuon rdf:about="#phieumuon17">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <docGia rdf:resource="#docgia6"/>
#   <sachMuon rdf:resource="#sach3"/>
#   <ngayMuon rdf:datatype="http://www.w3.org/2001/XMLSchema#string">07/03/2022</ngayMuon>
#   <ngayTra rdf:datatype="http://www.w3.org/2001/XMLSchema#string">23/02/2023</ngayTra>
# </PhieuMuon>
#
# <DocGia rdf:about="#docgia7">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <docGia rdf:resource="#giaovien3"/>
#   <ngayCap rdf:datatype="http://www.w3.org/2001/XMLSchema#string">27/07/2022</ngayCap>
#   <ngayHetHan rdf:datatype="http://www.w3.org/2001/XMLSchema#string">15/11/2025</ngayHetHan>
# </DocGia>
#
# <PhieuMuon rdf:about="#phieumuon18">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <docGia rdf:resource="#docgia7"/>
#   <sachMuon rdf:resource="#sach14"/>
#   <sachMuon rdf:resource="#sach7"/>
#   <sachMuon rdf:resource="#sach3"/>
#   <ngayMuon rdf:datatype="http://www.w3.org/2001/XMLSchema#string">22/12/2021</ngayMuon>
#   <ngayTra rdf:datatype="http://www.w3.org/2001/XMLSchema#string">30/10/2022</ngayTra>
# </PhieuMuon>
#
# <PhieuMuon rdf:about="#phieumuon19">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <docGia rdf:resource="#docgia7"/>
#   <sachMuon rdf:resource="#sach10"/>
#   <ngayMuon rdf:datatype="http://www.w3.org/2001/XMLSchema#string">29/11/2022</ngayMuon>
#   <ngayTra rdf:datatype="http://www.w3.org/2001/XMLSchema#string">15/04/2022</ngayTra>
# </PhieuMuon>
#
# <PhieuMuon rdf:about="#phieumuon20">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <docGia rdf:resource="#docgia7"/>
#   <sachMuon rdf:resource="#sach8"/>
#   <sachMuon rdf:resource="#sach12"/>
#   <ngayMuon rdf:datatype="http://www.w3.org/2001/XMLSchema#string">13/03/2022</ngayMuon>
#   <ngayTra rdf:datatype="http://www.w3.org/2001/XMLSchema#string">14/01/2022</ngayTra>
# </PhieuMuon>
#
# <DocGia rdf:about="#docgia8">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <docGia rdf:resource="#hocsinh14"/>
#   <ngayCap rdf:datatype="http://www.w3.org/2001/XMLSchema#string">17/07/2022</ngayCap>
#   <ngayHetHan rdf:datatype="http://www.w3.org/2001/XMLSchema#string">27/02/2025</ngayHetHan>
# </DocGia>
#
# <PhieuMuon rdf:about="#phieumuon21">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <docGia rdf:resource="#docgia8"/>
#   <sachMuon rdf:resource="#sach2"/>
#   <sachMuon rdf:resource="#sach10"/>
#   <ngayMuon rdf:datatype="http://www.w3.org/2001/XMLSchema#string">17/12/2021</ngayMuon>
#   <ngayTra rdf:datatype="http://www.w3.org/2001/XMLSchema#string">22/07/2022</ngayTra>
# </PhieuMuon>
#
# <PhieuMuon rdf:about="#phieumuon22">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <docGia rdf:resource="#docgia8"/>
#   <sachMuon rdf:resource="#sach2"/>
#   <ngayMuon rdf:datatype="http://www.w3.org/2001/XMLSchema#string">26/04/2022</ngayMuon>
#   <ngayTra rdf:datatype="http://www.w3.org/2001/XMLSchema#string">12/12/2022</ngayTra>
# </PhieuMuon>
#
# <PhieuMuon rdf:about="#phieumuon23">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <docGia rdf:resource="#docgia8"/>
#   <sachMuon rdf:resource="#sach7"/>
#   <sachMuon rdf:resource="#sach14"/>
#   <sachMuon rdf:resource="#sach5"/>
#   <ngayMuon rdf:datatype="http://www.w3.org/2001/XMLSchema#string">26/06/2021</ngayMuon>
#   <ngayTra rdf:datatype="http://www.w3.org/2001/XMLSchema#string">04/07/2023</ngayTra>
# </PhieuMuon>
#
# <DocGia rdf:about="#docgia9">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <docGia rdf:resource="#hocsinh10"/>
#   <ngayCap rdf:datatype="http://www.w3.org/2001/XMLSchema#string">22/04/2023</ngayCap>
#   <ngayHetHan rdf:datatype="http://www.w3.org/2001/XMLSchema#string">31/05/2025</ngayHetHan>
# </DocGia>
#
# <PhieuMuon rdf:about="#phieumuon24">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <docGia rdf:resource="#docgia9"/>
#   <sachMuon rdf:resource="#sach13"/>
#   <ngayMuon rdf:datatype="http://www.w3.org/2001/XMLSchema#string">20/05/2021</ngayMuon>
#   <ngayTra rdf:datatype="http://www.w3.org/2001/XMLSchema#string">29/12/2023</ngayTra>
# </PhieuMuon>
#
# <PhieuMuon rdf:about="#phieumuon25">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <docGia rdf:resource="#docgia9"/>
#   <sachMuon rdf:resource="#sach9"/>
#   <sachMuon rdf:resource="#sach7"/>
#   <ngayMuon rdf:datatype="http://www.w3.org/2001/XMLSchema#string">21/02/2022</ngayMuon>
#   <ngayTra rdf:datatype="http://www.w3.org/2001/XMLSchema#string">09/01/2022</ngayTra>
# </PhieuMuon>
#
# <PhieuMuon rdf:about="#phieumuon26">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <docGia rdf:resource="#docgia9"/>
#   <sachMuon rdf:resource="#sach15"/>
#   <ngayMuon rdf:datatype="http://www.w3.org/2001/XMLSchema#string">01/08/2022</ngayMuon>
#   <ngayTra rdf:datatype="http://www.w3.org/2001/XMLSchema#string">25/05/2023</ngayTra>
# </PhieuMuon>
#
# <DocGia rdf:about="#docgia10">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <docGia rdf:resource="#hocsinh8"/>
#   <ngayCap rdf:datatype="http://www.w3.org/2001/XMLSchema#string">21/06/2023</ngayCap>
#   <ngayHetHan rdf:datatype="http://www.w3.org/2001/XMLSchema#string">14/03/2024</ngayHetHan>
# </DocGia>
#
# <PhieuMuon rdf:about="#phieumuon27">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <docGia rdf:resource="#docgia10"/>
#   <sachMuon rdf:resource="#sach4"/>
#   <sachMuon rdf:resource="#sach14"/>
#   <ngayMuon rdf:datatype="http://www.w3.org/2001/XMLSchema#string">04/11/2022</ngayMuon>
#   <ngayTra rdf:datatype="http://www.w3.org/2001/XMLSchema#string">17/06/2022</ngayTra>
# </PhieuMuon>
#
# <PhieuMuon rdf:about="#phieumuon28">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <docGia rdf:resource="#docgia10"/>
#   <sachMuon rdf:resource="#sach5"/>
#   <sachMuon rdf:resource="#sach3"/>
#   <ngayMuon rdf:datatype="http://www.w3.org/2001/XMLSchema#string">15/11/2022</ngayMuon>
#   <ngayTra rdf:datatype="http://www.w3.org/2001/XMLSchema#string">01/06/2023</ngayTra>
# </PhieuMuon>
#
# <PhieuMuon rdf:about="#phieumuon29">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <docGia rdf:resource="#docgia10"/>
#   <sachMuon rdf:resource="#sach4"/>
#   <sachMuon rdf:resource="#sach6"/>
#   <sachMuon rdf:resource="#sach12"/>
#   <ngayMuon rdf:datatype="http://www.w3.org/2001/XMLSchema#string">10/11/2022</ngayMuon>
#   <ngayTra rdf:datatype="http://www.w3.org/2001/XMLSchema#string">28/02/2022</ngayTra>
# </PhieuMuon>
#
#
# </rdf:RDF>

# %%
# Đọc CSDL từ file
onto = get_ontology("../app/data/education.owl").load()

# In DS học sinh ra màn hình
print("Danh sách học sinh:")
stt = 1
for hs in onto.HocSinh.instances():
    print(stt, hs)
    stt += 1
# Out:
# Danh sách học sinh:
# 1 Đoàn Kim Linh - 14/11/2000 - Nam - 10C01
# 2 Quách Thị Tùng - 31/12/2000 - Nam - 10C01
# 3 Hồ Đình Thảo - 04/05/2000 - Nam - 10C01
# 4 Lâm Bảo Khánh - 28/05/2000 - Nữ - 10C01
# 5 Tôn Thị Xuân - 15/10/2000 - Khác - 10C01
# 6 Ngô Bảo Vinh - 05/05/2000 - Nữ - 10C02
# 7 Vũ Hồng Hải - 06/12/2000 - Nam - 10C02
# 8 Lê Hồng Thuận - 19/12/2000 - Nam - 10C02
# 9 Vũ Thu Quang - 29/12/2000 - Nữ - 10C02
# 10 Lê Hồng Dũng - 14/05/2000 - Nữ - 10C02
# 11 Phùng Anh Sơn - 11/01/2000 - Nam - 10C03
# 12 Phan Mai Tú - 30/06/2000 - Khác - 10C03
# 13 Phan Quý Hoàng - 16/07/2000 - Nữ - 10C03
# 14 Dương Văn Hiền - 24/06/2000 - Khác - 10C03
# 15 Phạm Thị Thiện - 07/09/2000 - Nam - 10C03
# 16 Lý Hữu Bình - 20/08/2000 - Khác - 11B01
# 17 Trương Thu Linh - 30/07/2000 - Khác - 11B01
# 18 Thái Bảo Xuân - 15/06/2000 - Nam - 11B01
# 19 Đoàn Ngọc Nam - 27/11/2000 - Nam - 11B01
# 20 Tăng Hồng Thúy - 24/10/2000 - Khác - 11B01
# 21 Tô Hữu Thúy - 18/06/2000 - Nam - 11B02
# 22 Mai Thanh Quỳnh - 22/08/2000 - Nam - 11B02
# 23 Trương Quý Tùng - 22/12/2000 - Khác - 11B02
# 24 Võ Hữu Thiện - 06/03/2000 - Nam - 11B02
# 25 Đỗ Thị Long - 12/04/2000 - Nam - 11B02
# 26 Đào Kim Linh - 06/11/2000 - Nữ - 11B03
# 27 Hồ Hữu Quang - 07/03/2000 - Nam - 11B03
# 28 Bùi Kim Việt - 23/05/2000 - Khác - 11B03
# 29 Tôn Kim Thảo - 20/09/2000 - Nam - 11B03
# 30 Võ Thị Ngọc - 29/07/2000 - Khác - 11B03
# 31 Đoàn Thị Thảo - 14/09/2000 - Nữ - 12A01
# 32 Huỳnh Mai Ngọc - 14/09/2000 - Nữ - 12A01
# 33 Lê Anh Hoàng - 19/11/2000 - Nam - 12A01
# 34 Trương Hữu Quang - 18/11/2000 - Khác - 12A01
# 35 Phan Mai Việt - 20/05/2000 - Nữ - 12A01
# 36 Tăng Văn Hoàng - 28/10/2000 - Khác - 12A02
# 37 Ngô Ngọc Nhật - 28/04/2000 - Nữ - 12A02
# 38 Ngô Đình Vân - 27/06/2000 - Khác - 12A02
# 39 Bành Bảo Cường - 31/12/2000 - Nam - 12A02
# 40 Bùi Mai Việt - 03/06/2000 - Khác - 12A02
# 41 Đỗ Hoài Khánh - 01/01/2000 - Nữ - 12A03
# 42 Lý Hoài Linh - 18/04/2000 - Nữ - 12A03
# 43 Bùi Mai Sơn - 22/01/2000 - Khác - 12A03
# 44 Bùi Thu Tú - 28/04/2000 - Khác - 12A03
# 45 Bành Ngọc Hiền - 17/05/2000 - Nam - 12A03

# %%
# In DS giáo viên
print("Danh sách giáo viên:")
for gv in onto.GiaoVien.instances():
    print(gv.hoTen, gv.ngaySinh, gv.gioiTinh, gv.trinhDo, getattr(gv.lopChuNhiem,'ten',''), *[mon.ten for mon in gv.dayMon])
# Out:
# Danh sách giáo viên:
# Lê Văn Thúy 03/08/1981 Nam Đại học  Toán học
# Đào Kim Sơn 07/06/1972 Khác Thạc sĩ  Toán học
# Tôn Mai Thảo 31/01/1989 Khác Đại học  Toán học
# Trương Hoài Hải 23/07/1970 Nam Đại học  Ngữ văn
# Thái Thanh Hoàng 08/08/1982 Khác Thạc sĩ  Ngữ văn
# Bùi Mai Hải 29/04/1974 Khác Thạc sĩ  Ngữ văn
# Trương Anh Cường 02/08/1983 Nam Thạc sĩ  Hóa học
# Đặng Mai Tú 16/04/1970 Khác Thạc sĩ  Hóa học
# Trần Bảo Sơn 18/12/1979 Nam Thạc sĩ 10C01 Hóa học
# Tô Hoài Vinh 10/01/1970 Nữ Thạc sĩ  Lịch sử
# Vũ Hoài Hiền 26/03/1972 Nữ Đại học 12A03 Lịch sử
# Tăng Hoài Minh 01/01/1979 Khác Thạc sĩ  Lịch sử Toán học
# Lương Thu Xuân 29/06/1974 Nam Đại học 12A01 Địa lý
# Đoàn Thanh Cường 06/10/1988 Nam Thạc sĩ  Địa lý
# Đỗ Anh Thúy 10/05/1984 Khác Thạc sĩ 12A02 Địa lý GDCD
# Tô Kim Phương 09/03/1982 Khác Thạc sĩ  Sinh học
# Lý Đình Thúy 22/05/1988 Khác Thạc sĩ 10C02 Sinh học
# Đoàn Anh Hùng 14/05/1987 Nữ Đại học  Sinh học
# Tô Bảo Minh 02/08/1987 Nữ Thạc sĩ  Tiếng Anh
# Tô Thu Vân 10/05/1985 Nam Đại học 11B03 Tiếng Anh
# Phan Thu Hiền 20/04/1984 Nam Đại học 11B01 Tiếng Anh Ngữ văn
# Phùng Thu Hùng 12/12/1978 Nữ Thạc sĩ  GDCD
# Đoàn Bảo Quân 15/04/1985 Khác Thạc sĩ  GDCD
# Phan Kim Tường 02/08/1980 Nam Đại học  GDCD
# Huỳnh Mai Quang 19/02/1973 Nam Đại học 10C03 Công nghệ
# Lương Hữu Dũng 24/05/1973 Nam Thạc sĩ  Công nghệ
# Lâm Thị Khánh 02/07/1988 Nữ Thạc sĩ  Công nghệ GDCD
# Trần Quý Phương 17/11/1982 Nam Đại học  Thể dục
# Đỗ Bảo Thảo 20/08/1977 Khác Thạc sĩ 11B02 Thể dục
# Quách Kim Vinh 08/05/1987 Nam Đại học  Thể dục Ngữ văn

# %%
# In DS HS trong lớp 10A01
print("Danh sách học sinh lớp 10A01:")
for hs in onto.HocSinh.instances():
    if hs.hocLop.ten == "10A01":
        print(hs)
# Out:
# Danh sách học sinh lớp 10A01:

# %%
# in ds GV chủ nhiệm của từng lớp
print("Danh sách giáo viên chủ nhiệm:")
for lop in onto.LopHoc.instances():
    gv = lop.giaoVienChuNhiem
    if gv:
        print(gv.hoTen, gv.ngaySinh, gv.gioiTinh, gv.trinhDo, getattr(gv.lopChuNhiem,'ten',''))
# Out:
# Danh sách giáo viên chủ nhiệm:
# Trần Bảo Sơn 18/12/1979 Nam Thạc sĩ 10C01
# Lý Đình Thúy 22/05/1988 Khác Thạc sĩ 10C02
# Huỳnh Mai Quang 19/02/1973 Nam Đại học 10C03
# Phan Thu Hiền 20/04/1984 Nam Đại học 11B01
# Đỗ Bảo Thảo 20/08/1977 Khác Thạc sĩ 11B02
# Tô Thu Vân 10/05/1985 Nam Đại học 11B03
# Lương Thu Xuân 29/06/1974 Nam Đại học 12A01
# Đỗ Anh Thúy 10/05/1984 Khác Thạc sĩ 12A02
# Vũ Hoài Hiền 26/03/1972 Nữ Đại học 12A03

# %%
# Sửa tên của giáo viên chủ nhiệm Nguyễn Văn X thành Nguyễn Văn Tèo
print("Sửa tên của giáo viên chủ nhiệm Nguyễn Văn X thành Nguyễn Văn Tèo")
for gv in onto.GiaoVien.instances():
    if gv.hoTen == "Nguyễn Văn X":
        gv.hoTen = "Nguyễn Văn Tèo"
        print(gv.hoTen, gv.ngaySinh, gv.gioiTinh, gv.trinhDo, getattr(gv.lopChuNhiem,'ten',''))
# Out:
# Sửa tên của giáo viên chủ nhiệm Nguyễn Văn X thành Nguyễn Văn Tèo

# %%
# Tạo mới một học sinh và thêm vào lớp 10A01
print("Tạo mới một học sinh và thêm vào lớp 10C01")
lop = onto.search_one(ten = "10C01", type = onto.LopHoc)
hs1 = HocSinh(hoTen = "Nguyễn Văn XXX", ngaySinh = "01/01/2011", gioiTinh = "Nam", hocLop = lop)
# In DS HS trong lớp 10A01
print("Danh sách học sinh lớp 10A01:")
print('\n'.join(str(hs) for hs in lop.dsHocSinh))
# Out:
# Tạo mới một học sinh và thêm vào lớp 10C01
# Danh sách học sinh lớp 10A01:
# Đoàn Kim Linh - 14/11/2000 - Nam - 10C01
# Quách Thị Tùng - 31/12/2000 - Nam - 10C01
# Hồ Đình Thảo - 04/05/2000 - Nam - 10C01
# Lâm Bảo Khánh - 28/05/2000 - Nữ - 10C01
# Tôn Thị Xuân - 15/10/2000 - Khác - 10C01
# Nguyễn Văn XXX - 01/01/2011 - Nam - 10C01

# %%
# Xoá học sinh có ngày sinh là 01/01/2011
print("Xoá học sinh có ngày sinh là 01/01/2011")
hs_ind = onto.search_one(ngaySinh="01/01/2011", type=onto.HocSinh)
# Nếu individual được tìm thấy, xoá individual đó
if hs_ind is not None:
    destroy_entity(hs_ind)
# Out:
# Xoá học sinh có ngày sinh là 01/01/2011

# %%
# In tất cả điểm số của một học sinh
print("In tất cả điểm số của một học sinh")
hs_ind = onto.search_one(type=onto.HocSinh)
if hs_ind is not None:
    for diem in hs_ind.diemSo:
        print(diem.monHoc.ten, *diem.heSo1, *diem.heSo2, *diem.heSo3)
# Out:
# In tất cả điểm số của một học sinh
# Toán học 3.3 1.5 3.5 3.5 9.8 5.3
# Ngữ văn 5.3 10 7.5 6.3 6.5 2.8
# Hóa học 6.5 5.5 7.3 7.3 7.5 7.5
# Lịch sử 8.5 4.3 9.8 1.5 6.8 6.8
# Địa lý 7.5 4.5 1.8 5.5 10 8.3
# Sinh học 10 7.5 5.5 2.8 8.8 4.8
# Tiếng Anh 10 7.3 7.5 8.5 10 1.5
# GDCD 8.8 2.3 8.3 6.8 8.8 3.8
# Công nghệ 9.5 10 1.8 0.3 8.8 7.8
# Thể dục 4.5 10 6.8 9.5 5.8 2.5

# %%
print(hoTen.iri)
print(HocSinh.iri)
# Out:
# http://hc.com/school#hoTen
# http://hc.com/school#HocSinh

# %%
print('In ra các lớp mà GV dạy')
gv = onto.search_one(type = onto.GiaoVien)
for gd in gv.giangDay:
    print(gd.lopHoc.ten, gd.monHoc.ten)
# Out:
# In ra các lớp mà GV dạy
# 10C01 Toán học
# 10C02 Toán học

# %%
print('In các GV dạy lớp 10C03')
lop = onto.search_one(type = onto.LopHoc, ten = '10C03')
gd = onto.search(type = onto.GiangDay, lopHoc = lop)
for g in gd:
    print(g.giaoVien.hoTen, g.monHoc.ten, g.lopHoc.ten)
# Out:
# In các GV dạy lớp 10C03
# Đào Kim Sơn Toán học 10C03
# Bùi Mai Hải Ngữ văn 10C03
# Trương Anh Cường Hóa học 10C03
# Tô Hoài Vinh Lịch sử 10C03
# Lương Thu Xuân Địa lý 10C03
# Tô Kim Phương Sinh học 10C03
# Tô Bảo Minh Tiếng Anh 10C03
# Đoàn Bảo Quân GDCD 10C03
# Huỳnh Mai Quang Công nghệ 10C03
# Trần Quý Phương Thể dục 10C03

# %%
print('- Liệt kê ban giám hiệu')
BGH = onto.search_one(type = onto.ToChuc, ten = 'Ban giám hiệu')
for nv in BGH.thanhVien:
    print(nv.hoTen, nv.chucVu[0].ten, nv.chucVu[0].phuCap)
print('- Liệt kê tổ Văn phòng')
VP = onto.search_one(type = onto.ToChuc, ten = 'Văn phòng')
for nv in VP.thanhVien:
    print(nv.hoTen, nv.chucVu[0].ten, nv.chucVu[0].phuCap)
# Out:
# - Liệt kê ban giám hiệu
# Tăng Quý Thuận Hiệu trưởng 0.7
# Phạm Hữu Thuận Phó hiệu Trưởng 0.5
# Hoàng Bảo Thiên Phó hiệu Trưởng 0.5
# - Liệt kê tổ Văn phòng
# Phạm Hữu Vân Bảo vệ 0
# Nguyễn Bảo Thiên Bảo vệ 0
# Đào Văn Tường Bảo vệ 0
# Tăng Thanh Thúy Phục vụ 0
# Nguyễn Thu Khánh Phục vụ 0
# Bùi Đình Cường Văn thư 0.3
# Trần Mai Hiền Thủ quỹ 0.3
# Mai Kim Cường Kế toán 0.5
# Tôn Bảo Hiền Thư viện 0
# Võ Hồng Hùng Thiết bị 0.25
# Huỳnh Thanh Thảo Thiết bị 0.25

# %%
print('Liệt kê các tổ trưởng và tổ phó của các tổ chuyên môn')
toChuyenMon = [x for x in onto.search(type = onto.ToChuc) if x.name.startswith('To')]
for tc in toChuyenMon:
    print(tc.ten)
    for nv in tc.thanhVien:
        print('   -', nv.hoTen, nv.chucVu[0].ten, nv.chucVu[0].phuCap, nv.dayMon)
# Out:
# Liệt kê các tổ trưởng và tổ phó của các tổ chuyên môn
# Tổ Toán học
#    - Lê Văn Thúy Tổ trưởng 0.2 [education.Toan]
#    - Đào Kim Sơn Tổ phó 0.15 [education.Toan]
#    - Tôn Mai Thảo Giáo viên 0 [education.Toan]
#    - Tăng Hoài Minh Giáo viên 0 [education.LichSu, education.Toan]
# Tổ Ngữ văn
#    - Trương Hoài Hải Tổ trưởng 0.2 [education.NguVan]
#    - Thái Thanh Hoàng Tổ phó 0.15 [education.NguVan]
#    - Bùi Mai Hải Giáo viên 0 [education.NguVan]
#    - Phan Thu Hiền Giáo viên 0 [education.TiengAnh, education.NguVan]
#    - Quách Kim Vinh Giáo viên 0 [education.TheDuc, education.NguVan]
# Tổ Hóa học
#    - Trương Anh Cường Tổ trưởng 0.2 [education.HoaHoc]
#    - Đặng Mai Tú Tổ phó 0.15 [education.HoaHoc]
#    - Trần Bảo Sơn Giáo viên 0 [education.HoaHoc]
# Tổ Lịch sử
#    - Tô Hoài Vinh Tổ trưởng 0.2 [education.LichSu]
#    - Vũ Hoài Hiền Tổ phó 0.15 [education.LichSu]
#    - Tăng Hoài Minh Giáo viên 0 [education.LichSu, education.Toan]
# Tổ Địa lý
#    - Lương Thu Xuân Tổ trưởng 0.2 [education.DiaLy]
#    - Đoàn Thanh Cường Tổ phó 0.15 [education.DiaLy]
#    - Đỗ Anh Thúy Giáo viên 0 [education.DiaLy, education.GDCD]
# Tổ Sinh học
#    - Tô Kim Phương Tổ trưởng 0.2 [education.SinhHoc]
#    - Lý Đình Thúy Tổ phó 0.15 [education.SinhHoc]
#    - Đoàn Anh Hùng Giáo viên 0 [education.SinhHoc]
# Tổ Tiếng Anh
#    - Tô Bảo Minh Tổ trưởng 0.2 [education.TiengAnh]
#    - Tô Thu Vân Tổ phó 0.15 [education.TiengAnh]
#    - Phan Thu Hiền Giáo viên 0 [education.TiengAnh, education.NguVan]
# Tổ GDCD
#    - Đỗ Anh Thúy Giáo viên 0 [education.DiaLy, education.GDCD]
#    - Phùng Thu Hùng Tổ trưởng 0.2 [education.GDCD]
#    - Đoàn Bảo Quân Tổ phó 0.15 [education.GDCD]
#    - Phan Kim Tường Giáo viên 0 [education.GDCD]
#    - Lâm Thị Khánh Giáo viên 0 [education.CongNghe, education.GDCD]
# Tổ Công nghệ
#    - Huỳnh Mai Quang Tổ trưởng 0.2 [education.CongNghe]
#    - Lương Hữu Dũng Tổ phó 0.15 [education.CongNghe]
#    - Lâm Thị Khánh Giáo viên 0 [education.CongNghe, education.GDCD]
# Tổ Thể dục
#    - Trần Quý Phương Tổ trưởng 0.2 [education.TheDuc]
#    - Đỗ Bảo Thảo Tổ phó 0.15 [education.TheDuc]
#    - Quách Kim Vinh Giáo viên 0 [education.TheDuc, education.NguVan]

# %%
print('Liệt kê sách trong thư viện')
for sach in onto.Sach.instances():
    print(sach.ten, [tl.ten for tl in sach.theLoai], sach.tacGia.ten, sach.nhaXuatBan.ten, sach.giaTien)
# Out:
# Liệt kê sách trong thư viện
# Sách bài tập Lịch sử ['Tài liệu tham khảo', 'Sách bài tập'] Tác giả 4 NXB 2 8000
# Sách bài tập Toán học ['Sách bài tập'] Tác giả 3 NXB 1 147000
# Tài liệu tham khảo Thể dục ['Sách bài tập', 'Tài liệu tham khảo'] Tác giả 3 NXB 2 20000
# SGK GDCD ['Sách bài tập', 'SGK'] Tác giả 3 NXB 2 61000
# Tài liệu tham khảo Công nghệ ['SGK', 'Truyện tranh'] Tác giả 2 NXB 2 114000
# Tài liệu tham khảo Sinh học ['Truyện tranh', 'Sách bài tập'] Tác giả 1 NXB 1 167000
# SGK Lịch sử ['SGK'] Tác giả 5 NXB 3 173000
# SGK Địa lý ['Sách bài tập', 'Truyện tranh'] Tác giả 4 NXB 3 12000
# Sách bài tập Toán học ['Truyện tranh'] Tác giả 5 NXB 3 195000
# Sách bài tập Công nghệ ['Truyện tranh'] Tác giả 3 NXB 2 6000
# Truyện tranh Hóa học ['Sách bài tập'] Tác giả 1 NXB 3 128000
# SGK Hóa học ['Truyện tranh'] Tác giả 5 NXB 1 76000
# Sách bài tập Sinh học ['Truyện tranh'] Tác giả 5 NXB 3 154000
# Tài liệu tham khảo Lịch sử ['SGK'] Tác giả 5 NXB 2 123000
# Sách bài tập Thể dục ['Truyện tranh'] Tác giả 4 NXB 2 43000
