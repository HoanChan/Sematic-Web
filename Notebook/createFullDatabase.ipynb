# %% [markdown]
# ### Cài đặt thư viện:
#
# Cài đặt các thư viện vào môi trường anaconda:
#
# ```bash
# conda install -c conda-forge owlready2
# ```

# %% [markdown]
# ### Tạo ontology

# %%
# %run ../app/models/model.py
# Out:
# * Owlready2 * Warning: optimized Cython parser module 'owlready2_optimized' is not available, defaulting to slower Python implementation

# %%
# Lưu CSDL ra file
onto.save(file="../app/data/education.owl")
with open("../app/data/education.owl", "r") as f:
    print(f.read())
# Out:
# <?xml version="1.0"?>
# <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#"
#          xmlns:xsd="http://www.w3.org/2001/XMLSchema#"
#          xmlns:rdfs="http://www.w3.org/2000/01/rdf-schema#"
#          xmlns:owl="http://www.w3.org/2002/07/owl#"
#          xml:base="http://hc.com/school"
#          xmlns="http://hc.com/school#">
#
# <owl:Ontology rdf:about="http://hc.com/school"/>
#
# <owl:ObjectProperty rdf:about="#moTa">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:domain rdf:resource="#TheLoai"/>
#   <rdfs:domain rdf:resource="#MonHoc"/>
#   <rdfs:domain rdf:resource="#ChucVu"/>
#   <rdfs:domain rdf:resource="#Phong"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#toChuc">
#   <rdfs:domain rdf:resource="#ChucVu"/>
#   <rdfs:range rdf:resource="#ToChuc"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#thanhVien">
#   <rdfs:domain rdf:resource="#ToChuc"/>
#   <rdfs:range rdf:resource="#Nguoi"/>
#   <owl:inverseOf rdf:resource="#thuocToChuc"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#phong">
#   <rdfs:domain rdf:resource="#ToChuc"/>
#   <rdfs:range rdf:resource="#Phong"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#thuocToChuc">
#   <rdfs:domain rdf:resource="#Nguoi"/>
#   <rdfs:range rdf:resource="#ToChuc"/>
#   <owl:inverseOf rdf:resource="#thanhVien"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#chucVu">
#   <rdfs:domain rdf:resource="#NhanVien"/>
#   <rdfs:range rdf:resource="#ChucVu"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#con">
#   <rdfs:domain rdf:resource="#PhuHuynh"/>
#   <rdfs:range rdf:resource="#HocSinh"/>
#   <owl:inverseOf rdf:resource="#phuHuynh"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#giaoVienChuNhiem">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#LopHoc"/>
#   <rdfs:range rdf:resource="#GiaoVien"/>
#   <owl:inverseOf rdf:resource="#lopChuNhiem"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#phongHoc">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#LopHoc"/>
#   <rdfs:range rdf:resource="#Phong"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#dsHocSinh">
#   <rdfs:domain rdf:resource="#LopHoc"/>
#   <rdfs:range rdf:resource="#HocSinh"/>
#   <owl:inverseOf rdf:resource="#hocLop"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#hocLop">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#LopHoc"/>
#   <owl:inverseOf rdf:resource="#dsHocSinh"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#phuHuynh">
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#PhuHuynh"/>
#   <owl:inverseOf rdf:resource="#con"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#diemSo">
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#DiemSo"/>
#   <owl:inverseOf rdf:resource="#hocSinh"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#dayMon">
#   <rdfs:domain rdf:resource="#GiaoVien"/>
#   <rdfs:range rdf:resource="#MonHoc"/>
#   <owl:inverseOf rdf:resource="#giaoVienDay"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#lopChuNhiem">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#GiaoVien"/>
#   <rdfs:range rdf:resource="#LopHoc"/>
#   <owl:inverseOf rdf:resource="#giaoVienChuNhiem"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#giaoVienDay">
#   <rdfs:domain rdf:resource="#MonHoc"/>
#   <rdfs:range rdf:resource="#GiaoVien"/>
#   <owl:inverseOf rdf:resource="#dayMon"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#hocSinh">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="#HocSinh"/>
#   <owl:inverseOf rdf:resource="#diemSo"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#monHoc">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="#MonHoc"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#docGia">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#TheDocGia"/>
#   <rdfs:range rdf:resource="#Nguoi"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#sachDaDoc">
#   <rdfs:domain rdf:resource="#TheDocGia"/>
#   <rdfs:range rdf:resource="#Sach"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#dsSach">
#   <rdfs:domain rdf:resource="#TheLoai"/>
#   <rdfs:domain rdf:resource="#NhaXuatBan"/>
#   <rdfs:domain rdf:resource="#TacGia"/>
#   <rdfs:range rdf:resource="#Sach"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#tacGia">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Sach"/>
#   <rdfs:range rdf:resource="#TacGia"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#nhaXuatBan">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Sach"/>
#   <rdfs:range rdf:resource="#NhaXuatBan"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#theLoai">
#   <rdfs:domain rdf:resource="#Sach"/>
#   <rdfs:range rdf:resource="#TheLoai"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#theDocGia">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#PhieuMuon"/>
#   <rdfs:range rdf:resource="#TheDocGia"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#sachMuon">
#   <rdfs:domain rdf:resource="#PhieuMuon"/>
#   <rdfs:range rdf:resource="#Sach"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#suDungBoi">
#   <rdfs:domain rdf:resource="#Phong"/>
#   <rdfs:range rdf:resource="#ToChuc"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#quanLy">
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:range rdf:resource="#Nguoi"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#thamGia">
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:range rdf:resource="#Nguoi"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#nguoiDiemDanh">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemDanh"/>
#   <rdfs:range rdf:resource="#Nguoi"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#hoatDong">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemDanh"/>
#   <rdfs:range rdf:resource="#HoatDong"/>
# </owl:ObjectProperty>
#
# <owl:DatatypeProperty rdf:about="#ten">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:domain rdf:resource="#MonHoc"/>
#   <rdfs:domain rdf:resource="#LopHoc"/>
#   <rdfs:domain rdf:resource="#TheLoai"/>
#   <rdfs:domain rdf:resource="#ToChuc"/>
#   <rdfs:domain rdf:resource="#ChucVu"/>
#   <rdfs:domain rdf:resource="#Phong"/>
#   <rdfs:domain rdf:resource="#NhaXuatBan"/>
#   <rdfs:domain rdf:resource="#Sach"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#phuCap">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#ChucVu"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#integer"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#hoTen">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Nguoi"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngaySinh">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Nguoi"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#gioiTinh">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Nguoi"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#luong">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#NhanVien"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#integer"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngheNghiep">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Nguoi"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#trinhDo">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#GiaoVien"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#soTiet">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#MonHoc"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#integer"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#heSo1">
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#heSo2">
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#heSo3">
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayCap">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#TheDocGia"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayHetHan">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#TheDocGia"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#giaTien">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Sach"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#integer"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#soLuong">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Sach"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#integer"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayMuon">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#PhieuMuon"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayTra">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#PhieuMuon"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayBatDau">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayKetThuc">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayGio">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemDanh"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#dateTime"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#trangThai">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemDanh"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:Class rdf:about="#ChucVu">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#ToChuc">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#Nguoi">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#NhanVien">
#   <rdfs:subClassOf rdf:resource="#Nguoi"/>
# </owl:Class>
#
# <owl:Class rdf:about="#PhuHuynh">
#   <rdfs:subClassOf rdf:resource="#Nguoi"/>
# </owl:Class>
#
# <owl:Class rdf:about="#LopHoc">
#   <rdfs:subClassOf rdf:resource="#ToChuc"/>
# </owl:Class>
#
# <owl:Class rdf:about="#HocSinh">
#   <rdfs:subClassOf rdf:resource="#Nguoi"/>
# </owl:Class>
#
# <owl:Class rdf:about="#GiaoVien">
#   <rdfs:subClassOf rdf:resource="#NhanVien"/>
# </owl:Class>
#
# <owl:Class rdf:about="#MonHoc">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#DiemSo">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#TheDocGia">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#TacGia">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#NhaXuatBan">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#Sach">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#TheLoai">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#PhieuMuon">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#Phong">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#HoatDong">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#DiemDanh">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
#
# </rdf:RDF>

# %% [markdown]
# ### Thêm dữ liệu

# %%
import random
from datetime import datetime, timedelta

def createRandomDate(start_year, end_year):
    # Tính toán số ngày trong năm bắt đầu và kết thúc
    start_date = datetime(year=start_year, month=1, day=1)
    end_date = datetime(year=end_year, month=12, day=31)
    days_in_range = (end_date - start_date).days + 1

    # Tạo ngẫu nhiên số ngày trong khoảng thời gian bắt đầu và kết thúc
    random_days = random.randint(0, days_in_range - 1)

    # Tính toán ngày sinh từ số ngày được chọn
    birth_date = start_date + timedelta(days=random_days)

    # Trả về chuỗi ngày sinh dạng dd/mm/yyyy
    return birth_date.strftime('%d/%m/%Y')

def createRandomInfo():
    ho = random.choice(["Nguyễn", "Trần", "Lê", "Phạm", "Hoàng", "Huỳnh", "Phan", "Vũ", "Võ", "Đặng", "Bùi", "Đỗ", "Hồ", "Ngô", "Dương", "Lý", "Lương", "Mai", "Trương", "Tạ", "Đào", 
                            "Đoàn", "Đinh", "Lâm", "Phùng", "Đoàn", "Bành", "Quách", "Thái", "Tô", "Tôn", "Tăng"])
    lot = random.choice(['Văn', 'Thị', 'Hồng', 'Anh', 'Quý', 'Bảo', "Thanh", "Thu", "Hữu", "Mai", "Đình", "Hoài", "Ngọc", "Minh", "Kim"])
    ten = random.choice(["An", "Bình", "Cường", "Dũng", "Hải", "Hiền", "Hoàng", "Hùng", "Khánh", "Linh", "Long", "Minh", "Nam", "Ngọc", "Nhật", "Phương", "Quân", "Quang", "Quỳnh", 
                            "Sơn", "Thảo", "Thiên", "Thiện", "Thúy", "Thuận", "Tùng", "Tú", "Tường", "Việt", "Vân", "Vinh", "Xuân"])
    gioiTinh = random.choice(["Nam", "Nữ", "Khác"])
    return f"{ho} {lot} {ten}", gioiTinh
def randScore():
    score = random.randint(0, 10)
    if score != 10:
        score += random.choice([0.3, 0.5, 0.8])
    return score

def getClassName(soLopMoiKhoi, index):
    khoi = index // soLopMoiKhoi
    lop = index % soLopMoiKhoi + 1
    tenLop = f'{khoi+10}{"CBA"[khoi]}'
    if lop < 10:
        return f'{tenLop}0{lop}'
    else:
        return f'{tenLop}{lop}'
# Đọc CSDL từ file
onto = get_ontology("../app/data/education.owl").load()

# Thêm dữ liệu cho từng đối tượng
with onto: 
    # Tạo ngẫu nhiên 10 lớp học mỗi khối lớp
    soLopMoiKhoi = 3
    tongSoLop = soLopMoiKhoi * 3
    soHSMoiLop = 5
    soHSCoAnhEm = 20
    soGVMoiMon = 3
    dsLop = []
    for i in range(tongSoLop):
        lop = LopHoc(ten = getClassName(soLopMoiKhoi, i))
        dsLop.append(lop)
        # Tạo ngẫu nhiên HS cho mỗi lớp
        for j in range(soHSMoiLop):
            ten, gt = createRandomInfo()
            hs = HocSinh(hoTen = ten, ngaySinh = createRandomDate(2000, 2000), gioiTinh = gt, hocLop = lop)
            # Tạo ngẫu nhiên 2 PH cho mỗi HS
            for k in range(2):
                ten, gt = createRandomInfo()
                nghe = random.choice(["Nông dân", "Công nhân", "Giáo viên", "Bác sĩ", "Kỹ sư", "Nhân viên văn phòng", "Chủ doanh nghiệp"])
                ph = PhuHuynh(hoTen = ten, ngaySinh = createRandomDate(1970, 1980), gioiTinh = gt, con = [hs], ngheNghiep = nghe)
    
    # Cho một số học sinh có chung phụ huynh
    my_list = list(onto.HocSinh.instances())
    random_items = random.sample(my_list, soHSCoAnhEm)
    remaining_items = list(set(my_list) - set(random_items))
    new_random_items = random.sample(remaining_items, soHSCoAnhEm)
    for hs, i in zip(random_items, range(soHSCoAnhEm)):
        for ph in hs.phuHuynh: destroy_entity(ph)
        hs.phuHuynh = []
        for ph in new_random_items[i].phuHuynh: 
            ph.con.append(hs)
            hs.phuHuynh.append(ph)

    # Tạo môn học
    id_mon_hoc = ['Toan', 'NguVan', 'HoaHoc', 'LichSu', 'DiaLy', 'SinhHoc', 'TiengAnh', 'GDCD', 'CongNghe', 'TheDuc']
    ds_mon_hoc = ['Toán học', 'Ngữ văn', 'Hóa học', 'Lịch sử', 'Địa lý', 'Sinh học', 'Tiếng Anh', 'GDCD', 'Công nghệ', 'Thể dục']
    so_tiet = [5, 3, 3, 3, 5, 2, 2, 3, 2]
    for id, mon, st in zip(id_mon_hoc, ds_mon_hoc, so_tiet):
        mon_hoc = MonHoc(id, ten = mon, soTiet = st)
        # Tạo ngẫu nhiên GV cho mỗi môn
        for j in range(soGVMoiMon):
            ten, gt = createRandomInfo()
            td = ['Đại học', 'Thạc sĩ'][random.randint(0,1)]
            gv = GiaoVien(hoTen = ten, ngaySinh = createRandomDate(1970, 1990), gioiTinh = gt, trinhDo = td, dayMon = [mon_hoc])
        # Tạo điểm số cho từng HS
        for hs in onto.HocSinh.instances():
            diem = DiemSo(hocSinh = hs, monHoc = mon_hoc, 
                          heSo1 = [randScore(),randScore(),randScore()], 
                          heSo2 = [randScore(),randScore()], 
                          heSo3 = [randScore()])
    
    # Gán GVCN cho từng lớp
    dsGVCN = random.sample(list(onto.GiaoVien.instances()), tongSoLop)
    for i in range(tongSoLop):
        dsGVCN[i].lopChuNhiem = dsLop[i]

# Lưu CSDL ra file
onto.save(file="../app/data/education.owl", format='rdfxml') # 'ntriples' / "rdfxml"
with open("../app/data/education.owl", "r") as f:
    print(f.read())
# Out:
# <?xml version="1.0"?>
# <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#"
#          xmlns:xsd="http://www.w3.org/2001/XMLSchema#"
#          xmlns:rdfs="http://www.w3.org/2000/01/rdf-schema#"
#          xmlns:owl="http://www.w3.org/2002/07/owl#"
#          xml:base="http://hc.com/school"
#          xmlns="http://hc.com/school#">
#
# <owl:Ontology rdf:about="http://hc.com/school"/>
#
# <owl:ObjectProperty rdf:about="#moTa">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:domain rdf:resource="#TheLoai"/>
#   <rdfs:domain rdf:resource="#MonHoc"/>
#   <rdfs:domain rdf:resource="#ChucVu"/>
#   <rdfs:domain rdf:resource="#Phong"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#toChuc">
#   <rdfs:domain rdf:resource="#ChucVu"/>
#   <rdfs:range rdf:resource="#ToChuc"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#thanhVien">
#   <rdfs:domain rdf:resource="#ToChuc"/>
#   <rdfs:range rdf:resource="#Nguoi"/>
#   <owl:inverseOf rdf:resource="#thuocToChuc"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#phong">
#   <rdfs:domain rdf:resource="#ToChuc"/>
#   <rdfs:range rdf:resource="#Phong"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#thuocToChuc">
#   <rdfs:domain rdf:resource="#Nguoi"/>
#   <rdfs:range rdf:resource="#ToChuc"/>
#   <owl:inverseOf rdf:resource="#thanhVien"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#chucVu">
#   <rdfs:domain rdf:resource="#NhanVien"/>
#   <rdfs:range rdf:resource="#ChucVu"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#con">
#   <rdfs:domain rdf:resource="#PhuHuynh"/>
#   <rdfs:range rdf:resource="#HocSinh"/>
#   <owl:inverseOf rdf:resource="#phuHuynh"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#giaoVienChuNhiem">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#LopHoc"/>
#   <rdfs:range rdf:resource="#GiaoVien"/>
#   <owl:inverseOf rdf:resource="#lopChuNhiem"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#phongHoc">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#LopHoc"/>
#   <rdfs:range rdf:resource="#Phong"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#dsHocSinh">
#   <rdfs:domain rdf:resource="#LopHoc"/>
#   <rdfs:range rdf:resource="#HocSinh"/>
#   <owl:inverseOf rdf:resource="#hocLop"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#hocLop">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#LopHoc"/>
#   <owl:inverseOf rdf:resource="#dsHocSinh"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#phuHuynh">
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#PhuHuynh"/>
#   <owl:inverseOf rdf:resource="#con"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#diemSo">
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#DiemSo"/>
#   <owl:inverseOf rdf:resource="#hocSinh"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#dayMon">
#   <rdfs:domain rdf:resource="#GiaoVien"/>
#   <rdfs:range rdf:resource="#MonHoc"/>
#   <owl:inverseOf rdf:resource="#giaoVienDay"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#lopChuNhiem">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#GiaoVien"/>
#   <rdfs:range rdf:resource="#LopHoc"/>
#   <owl:inverseOf rdf:resource="#giaoVienChuNhiem"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#giaoVienDay">
#   <rdfs:domain rdf:resource="#MonHoc"/>
#   <rdfs:range rdf:resource="#GiaoVien"/>
#   <owl:inverseOf rdf:resource="#dayMon"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#hocSinh">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="#HocSinh"/>
#   <owl:inverseOf rdf:resource="#diemSo"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#monHoc">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="#MonHoc"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#docGia">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#TheDocGia"/>
#   <rdfs:range rdf:resource="#Nguoi"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#sachDaDoc">
#   <rdfs:domain rdf:resource="#TheDocGia"/>
#   <rdfs:range rdf:resource="#Sach"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#dsSach">
#   <rdfs:domain rdf:resource="#TheLoai"/>
#   <rdfs:domain rdf:resource="#NhaXuatBan"/>
#   <rdfs:domain rdf:resource="#TacGia"/>
#   <rdfs:range rdf:resource="#Sach"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#tacGia">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Sach"/>
#   <rdfs:range rdf:resource="#TacGia"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#nhaXuatBan">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Sach"/>
#   <rdfs:range rdf:resource="#NhaXuatBan"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#theLoai">
#   <rdfs:domain rdf:resource="#Sach"/>
#   <rdfs:range rdf:resource="#TheLoai"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#theDocGia">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#PhieuMuon"/>
#   <rdfs:range rdf:resource="#TheDocGia"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#sachMuon">
#   <rdfs:domain rdf:resource="#PhieuMuon"/>
#   <rdfs:range rdf:resource="#Sach"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#suDungBoi">
#   <rdfs:domain rdf:resource="#Phong"/>
#   <rdfs:range rdf:resource="#ToChuc"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#quanLy">
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:range rdf:resource="#Nguoi"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#thamGia">
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:range rdf:resource="#Nguoi"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#nguoiDiemDanh">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemDanh"/>
#   <rdfs:range rdf:resource="#Nguoi"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#hoatDong">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemDanh"/>
#   <rdfs:range rdf:resource="#HoatDong"/>
# </owl:ObjectProperty>
#
# <owl:DatatypeProperty rdf:about="#ten">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:domain rdf:resource="#MonHoc"/>
#   <rdfs:domain rdf:resource="#LopHoc"/>
#   <rdfs:domain rdf:resource="#TheLoai"/>
#   <rdfs:domain rdf:resource="#ToChuc"/>
#   <rdfs:domain rdf:resource="#ChucVu"/>
#   <rdfs:domain rdf:resource="#Phong"/>
#   <rdfs:domain rdf:resource="#NhaXuatBan"/>
#   <rdfs:domain rdf:resource="#Sach"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#phuCap">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#ChucVu"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#integer"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#hoTen">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Nguoi"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngaySinh">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Nguoi"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#gioiTinh">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Nguoi"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#luong">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#NhanVien"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#integer"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngheNghiep">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Nguoi"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#trinhDo">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#GiaoVien"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#soTiet">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#MonHoc"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#integer"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#heSo1">
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#heSo2">
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#heSo3">
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayCap">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#TheDocGia"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayHetHan">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#TheDocGia"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#giaTien">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Sach"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#integer"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#soLuong">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Sach"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#integer"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayMuon">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#PhieuMuon"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayTra">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#PhieuMuon"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayBatDau">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayKetThuc">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayGio">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemDanh"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#dateTime"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#trangThai">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemDanh"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:Class rdf:about="#ChucVu">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#ToChuc">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#Nguoi">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#NhanVien">
#   <rdfs:subClassOf rdf:resource="#Nguoi"/>
# </owl:Class>
#
# <owl:Class rdf:about="#PhuHuynh">
#   <rdfs:subClassOf rdf:resource="#Nguoi"/>
# </owl:Class>
#
# <owl:Class rdf:about="#LopHoc">
#   <rdfs:subClassOf rdf:resource="#ToChuc"/>
# </owl:Class>
#
# <owl:Class rdf:about="#HocSinh">
#   <rdfs:subClassOf rdf:resource="#Nguoi"/>
# </owl:Class>
#
# <owl:Class rdf:about="#GiaoVien">
#   <rdfs:subClassOf rdf:resource="#NhanVien"/>
# </owl:Class>
#
# <owl:Class rdf:about="#MonHoc">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#DiemSo">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#TheDocGia">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#TacGia">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#NhaXuatBan">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#Sach">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#TheLoai">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#PhieuMuon">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#Phong">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#HoatDong">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#DiemDanh">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <LopHoc rdf:about="#lophoc1">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <ten rdf:datatype="http://www.w3.org/2001/XMLSchema#string">10C01</ten>
# </LopHoc>
#
# <HocSinh rdf:about="#hocsinh1">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc1"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Bùi Hữu Nam</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">15/08/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh2">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc1"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tăng Thanh Hoàng</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">14/09/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
# </HocSinh>
#
# <PhuHuynh rdf:about="#phuhuynh3">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh2"/>
#   <con rdf:resource="#hocsinh5"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Hồ Minh Thiên</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">12/07/1978</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nông dân</ngheNghiep>
# </PhuHuynh>
#
# <PhuHuynh rdf:about="#phuhuynh4">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh2"/>
#   <con rdf:resource="#hocsinh5"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Lâm Bảo Dũng</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">12/07/1978</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Giáo viên</ngheNghiep>
# </PhuHuynh>
#
# <HocSinh rdf:about="#hocsinh3">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc1"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đào Anh Xuân</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">31/08/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh4">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc1"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Lê Thanh Minh</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">07/12/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh5">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc1"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Mai Kim Dũng</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">24/01/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
# </HocSinh>
#
# <LopHoc rdf:about="#lophoc2">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <ten rdf:datatype="http://www.w3.org/2001/XMLSchema#string">10C02</ten>
# </LopHoc>
#
# <HocSinh rdf:about="#hocsinh6">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc2"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Huỳnh Đình Thiên</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">18/12/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh7">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc2"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Lê Ngọc Sơn</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">14/09/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh8">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc2"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Phạm Bảo Bình</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">10/07/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
# </HocSinh>
#
# <PhuHuynh rdf:about="#phuhuynh15">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh8"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đào Minh Hoàng</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">04/11/1979</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Công nhân</ngheNghiep>
# </PhuHuynh>
#
# <PhuHuynh rdf:about="#phuhuynh16">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh8"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Phan Kim An</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">01/10/1974</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nhân viên văn phòng</ngheNghiep>
# </PhuHuynh>
#
# <HocSinh rdf:about="#hocsinh9">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc2"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Hồ Anh Ngọc</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">28/01/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh10">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc2"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tô Anh Nam</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">03/11/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
# </HocSinh>
#
# <LopHoc rdf:about="#lophoc3">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <ten rdf:datatype="http://www.w3.org/2001/XMLSchema#string">10C03</ten>
# </LopHoc>
#
# <HocSinh rdf:about="#hocsinh11">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc3"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tăng Thu Tùng</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">24/10/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
# </HocSinh>
#
# <PhuHuynh rdf:about="#phuhuynh21">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh11"/>
#   <con rdf:resource="#hocsinh4"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Dương Minh Linh</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">03/02/1978</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nhân viên văn phòng</ngheNghiep>
# </PhuHuynh>
#
# <PhuHuynh rdf:about="#phuhuynh22">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh11"/>
#   <con rdf:resource="#hocsinh4"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đặng Thị Tú</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">23/03/1976</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Bác sĩ</ngheNghiep>
# </PhuHuynh>
#
# <HocSinh rdf:about="#hocsinh12">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc3"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Dương Thị Cường</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">25/01/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
# </HocSinh>
#
# <PhuHuynh rdf:about="#phuhuynh23">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh12"/>
#   <con rdf:resource="#hocsinh6"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Trương Văn Long</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">10/07/1974</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Kỹ sư</ngheNghiep>
# </PhuHuynh>
#
# <PhuHuynh rdf:about="#phuhuynh24">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh12"/>
#   <con rdf:resource="#hocsinh6"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Quách Mai Thảo</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">11/12/1973</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Chủ doanh nghiệp</ngheNghiep>
# </PhuHuynh>
#
# <HocSinh rdf:about="#hocsinh13">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc3"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tôn Mai Việt</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">17/05/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
# </HocSinh>
#
# <PhuHuynh rdf:about="#phuhuynh25">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh13"/>
#   <con rdf:resource="#hocsinh26"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Trương Quý Vinh</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">08/03/1971</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nông dân</ngheNghiep>
# </PhuHuynh>
#
# <PhuHuynh rdf:about="#phuhuynh26">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh13"/>
#   <con rdf:resource="#hocsinh26"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đoàn Kim Tú</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">15/08/1971</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Công nhân</ngheNghiep>
# </PhuHuynh>
#
# <HocSinh rdf:about="#hocsinh14">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc3"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Quách Mai Thiện</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">02/11/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh15">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc3"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Ngô Mai Việt</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">19/03/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
# </HocSinh>
#
# <PhuHuynh rdf:about="#phuhuynh29">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh15"/>
#   <con rdf:resource="#hocsinh14"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Hoàng Đình Thiện</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">11/04/1975</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Chủ doanh nghiệp</ngheNghiep>
# </PhuHuynh>
#
# <PhuHuynh rdf:about="#phuhuynh30">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh15"/>
#   <con rdf:resource="#hocsinh14"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tăng Minh Tú</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">07/06/1973</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Kỹ sư</ngheNghiep>
# </PhuHuynh>
#
# <LopHoc rdf:about="#lophoc4">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <ten rdf:datatype="http://www.w3.org/2001/XMLSchema#string">11B01</ten>
# </LopHoc>
#
# <HocSinh rdf:about="#hocsinh16">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc4"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đỗ Mai Hùng</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">14/04/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
# </HocSinh>
#
# <PhuHuynh rdf:about="#phuhuynh31">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh16"/>
#   <con rdf:resource="#hocsinh9"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Bùi Mai Việt</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">08/11/1974</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nông dân</ngheNghiep>
# </PhuHuynh>
#
# <PhuHuynh rdf:about="#phuhuynh32">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh16"/>
#   <con rdf:resource="#hocsinh9"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đỗ Minh Ngọc</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">14/03/1974</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nhân viên văn phòng</ngheNghiep>
# </PhuHuynh>
#
# <HocSinh rdf:about="#hocsinh17">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc4"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Hồ Thanh Thiên</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">12/08/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh18">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc4"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tăng Bảo Khánh</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">28/09/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh19">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc4"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đào Thu Xuân</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">24/11/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh20">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc4"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Lâm Hồng Nhật</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">30/05/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
# </HocSinh>
#
# <LopHoc rdf:about="#lophoc5">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <ten rdf:datatype="http://www.w3.org/2001/XMLSchema#string">11B02</ten>
# </LopHoc>
#
# <HocSinh rdf:about="#hocsinh21">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc5"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nguyễn Hoài Linh</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">31/03/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh22">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc5"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Bành Văn Long</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">04/04/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh23">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc5"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Quách Hoài Khánh</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">02/06/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
# </HocSinh>
#
# <PhuHuynh rdf:about="#phuhuynh45">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh23"/>
#   <con rdf:resource="#hocsinh32"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nguyễn Bảo Phương</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">13/08/1978</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Bác sĩ</ngheNghiep>
# </PhuHuynh>
#
# <PhuHuynh rdf:about="#phuhuynh46">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh23"/>
#   <con rdf:resource="#hocsinh32"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Trương Minh Quân</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">10/03/1980</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Bác sĩ</ngheNghiep>
# </PhuHuynh>
#
# <HocSinh rdf:about="#hocsinh24">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc5"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Bành Quý Long</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">10/10/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
# </HocSinh>
#
# <PhuHuynh rdf:about="#phuhuynh47">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh24"/>
#   <con rdf:resource="#hocsinh44"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đoàn Hồng Thiện</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">22/07/1971</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Giáo viên</ngheNghiep>
# </PhuHuynh>
#
# <PhuHuynh rdf:about="#phuhuynh48">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh24"/>
#   <con rdf:resource="#hocsinh44"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Quách Hữu Quỳnh</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">24/05/1970</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Bác sĩ</ngheNghiep>
# </PhuHuynh>
#
# <HocSinh rdf:about="#hocsinh25">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc5"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Quách Hữu Hùng</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">11/08/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
# </HocSinh>
#
# <PhuHuynh rdf:about="#phuhuynh49">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh25"/>
#   <con rdf:resource="#hocsinh33"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tăng Thị Quang</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">25/11/1979</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Kỹ sư</ngheNghiep>
# </PhuHuynh>
#
# <PhuHuynh rdf:about="#phuhuynh50">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh25"/>
#   <con rdf:resource="#hocsinh33"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đỗ Ngọc Nam</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">08/06/1979</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Kỹ sư</ngheNghiep>
# </PhuHuynh>
#
# <LopHoc rdf:about="#lophoc6">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <ten rdf:datatype="http://www.w3.org/2001/XMLSchema#string">11B03</ten>
# </LopHoc>
#
# <HocSinh rdf:about="#hocsinh26">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc6"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Phạm Mai Nhật</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">30/09/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh27">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc6"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Phan Đình Tú</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">31/05/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
# </HocSinh>
#
# <PhuHuynh rdf:about="#phuhuynh53">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh27"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đoàn Minh Hoàng</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">30/04/1979</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Bác sĩ</ngheNghiep>
# </PhuHuynh>
#
# <PhuHuynh rdf:about="#phuhuynh54">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh27"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đoàn Văn Nhật</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">04/06/1974</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Chủ doanh nghiệp</ngheNghiep>
# </PhuHuynh>
#
# <HocSinh rdf:about="#hocsinh28">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc6"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Hồ Mai Tùng</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">07/11/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
# </HocSinh>
#
# <PhuHuynh rdf:about="#phuhuynh55">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh28"/>
#   <con rdf:resource="#hocsinh7"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đào Kim Ngọc</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">07/02/1978</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Bác sĩ</ngheNghiep>
# </PhuHuynh>
#
# <PhuHuynh rdf:about="#phuhuynh56">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh28"/>
#   <con rdf:resource="#hocsinh7"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đinh Quý Quang</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">07/03/1976</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Chủ doanh nghiệp</ngheNghiep>
# </PhuHuynh>
#
# <HocSinh rdf:about="#hocsinh29">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc6"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đặng Quý Thiện</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">21/10/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
# </HocSinh>
#
# <PhuHuynh rdf:about="#phuhuynh57">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh29"/>
#   <con rdf:resource="#hocsinh36"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Huỳnh Kim Linh</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">26/12/1971</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Bác sĩ</ngheNghiep>
# </PhuHuynh>
#
# <PhuHuynh rdf:about="#phuhuynh58">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh29"/>
#   <con rdf:resource="#hocsinh36"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Phan Thị Thuận</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">07/10/1975</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Kỹ sư</ngheNghiep>
# </PhuHuynh>
#
# <HocSinh rdf:about="#hocsinh30">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc6"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Lâm Văn Tùng</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">05/08/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
# </HocSinh>
#
# <PhuHuynh rdf:about="#phuhuynh59">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh30"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tạ Anh Bình</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">09/09/1973</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Chủ doanh nghiệp</ngheNghiep>
# </PhuHuynh>
#
# <PhuHuynh rdf:about="#phuhuynh60">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh30"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Mai Minh Nhật</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">07/02/1973</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nông dân</ngheNghiep>
# </PhuHuynh>
#
# <LopHoc rdf:about="#lophoc7">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <ten rdf:datatype="http://www.w3.org/2001/XMLSchema#string">12A01</ten>
# </LopHoc>
#
# <HocSinh rdf:about="#hocsinh31">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc7"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Quách Kim Thảo</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">01/12/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
# </HocSinh>
#
# <PhuHuynh rdf:about="#phuhuynh61">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh31"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Phạm Mai Ngọc</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">18/05/1971</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Bác sĩ</ngheNghiep>
# </PhuHuynh>
#
# <PhuHuynh rdf:about="#phuhuynh62">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh31"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đỗ Thị Quang</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">19/10/1971</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nông dân</ngheNghiep>
# </PhuHuynh>
#
# <HocSinh rdf:about="#hocsinh32">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc7"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Lâm Đình Hùng</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">03/04/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh33">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc7"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tôn Đình Tú</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">22/10/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh34">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc7"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Võ Văn Phương</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">10/12/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
# </HocSinh>
#
# <PhuHuynh rdf:about="#phuhuynh67">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh34"/>
#   <con rdf:resource="#hocsinh10"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nguyễn Hoài Vân</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">08/05/1972</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Giáo viên</ngheNghiep>
# </PhuHuynh>
#
# <PhuHuynh rdf:about="#phuhuynh68">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh34"/>
#   <con rdf:resource="#hocsinh10"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Hoàng Hoài Thiện</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">31/12/1972</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nhân viên văn phòng</ngheNghiep>
# </PhuHuynh>
#
# <HocSinh rdf:about="#hocsinh35">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc7"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đặng Hoài Thúy</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">06/11/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
# </HocSinh>
#
# <PhuHuynh rdf:about="#phuhuynh69">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh35"/>
#   <con rdf:resource="#hocsinh22"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Bành Minh Dũng</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">17/02/1980</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
# ...
# </DiemSo>
#
# <DiemSo rdf:about="#diemso381">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocSinh rdf:resource="#hocsinh21"/>
#   <monHoc rdf:resource="#CongNghe"/>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">7.5</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">7.8</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">6.5</heSo1>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">4.3</heSo2>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">4.8</heSo2>
#   <heSo3 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">7.3</heSo3>
# </DiemSo>
#
# <DiemSo rdf:about="#diemso382">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocSinh rdf:resource="#hocsinh22"/>
#   <monHoc rdf:resource="#CongNghe"/>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">7.8</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">7.5</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">0.5</heSo1>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">9.8</heSo2>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">2.3</heSo2>
#   <heSo3 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">8.3</heSo3>
# </DiemSo>
#
# <DiemSo rdf:about="#diemso383">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocSinh rdf:resource="#hocsinh23"/>
#   <monHoc rdf:resource="#CongNghe"/>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">9.8</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">8.5</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">7.5</heSo1>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">8.8</heSo2>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">2.8</heSo2>
#   <heSo3 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">1.5</heSo3>
# </DiemSo>
#
# <DiemSo rdf:about="#diemso384">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocSinh rdf:resource="#hocsinh24"/>
#   <monHoc rdf:resource="#CongNghe"/>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">3.5</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">0.8</heSo1>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">9.8</heSo2>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">6.3</heSo2>
#   <heSo3 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">2.8</heSo3>
# </DiemSo>
#
# <DiemSo rdf:about="#diemso385">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocSinh rdf:resource="#hocsinh25"/>
#   <monHoc rdf:resource="#CongNghe"/>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">0.5</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">6.5</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">0.8</heSo1>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">6.3</heSo2>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">6.8</heSo2>
#   <heSo3 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">8.3</heSo3>
# </DiemSo>
#
# <DiemSo rdf:about="#diemso386">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocSinh rdf:resource="#hocsinh26"/>
#   <monHoc rdf:resource="#CongNghe"/>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">4.3</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">6.8</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">6.5</heSo1>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">5.8</heSo2>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">1.8</heSo2>
#   <heSo3 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">9.8</heSo3>
# </DiemSo>
#
# <DiemSo rdf:about="#diemso387">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocSinh rdf:resource="#hocsinh27"/>
#   <monHoc rdf:resource="#CongNghe"/>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">0.5</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">1.8</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">3.3</heSo1>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">6.3</heSo2>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">10</heSo2>
#   <heSo3 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">4.3</heSo3>
# </DiemSo>
#
# <DiemSo rdf:about="#diemso388">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocSinh rdf:resource="#hocsinh28"/>
#   <monHoc rdf:resource="#CongNghe"/>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">3.3</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">7.3</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">6.5</heSo1>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">6.8</heSo2>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">1.8</heSo2>
#   <heSo3 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">8.3</heSo3>
# </DiemSo>
#
# <DiemSo rdf:about="#diemso389">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocSinh rdf:resource="#hocsinh29"/>
#   <monHoc rdf:resource="#CongNghe"/>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">0.8</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">9.5</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">6.3</heSo1>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">2.5</heSo2>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">7.8</heSo2>
#   <heSo3 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">8.3</heSo3>
# </DiemSo>
#
# <DiemSo rdf:about="#diemso390">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocSinh rdf:resource="#hocsinh30"/>
#   <monHoc rdf:resource="#CongNghe"/>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">7.3</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">8.8</heSo1>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">6.8</heSo2>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">3.5</heSo2>
#   <heSo3 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">2.5</heSo3>
# </DiemSo>
#
# <DiemSo rdf:about="#diemso391">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocSinh rdf:resource="#hocsinh31"/>
#   <monHoc rdf:resource="#CongNghe"/>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">8.3</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">0.5</heSo1>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">7.8</heSo2>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">7.3</heSo2>
#   <heSo3 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">9.3</heSo3>
# </DiemSo>
#
# <DiemSo rdf:about="#diemso392">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocSinh rdf:resource="#hocsinh32"/>
#   <monHoc rdf:resource="#CongNghe"/>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">3.8</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">6.3</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">10</heSo1>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">3.5</heSo2>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">2.3</heSo2>
#   <heSo3 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">5.5</heSo3>
# </DiemSo>
#
# <DiemSo rdf:about="#diemso393">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocSinh rdf:resource="#hocsinh33"/>
#   <monHoc rdf:resource="#CongNghe"/>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">6.5</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">9.3</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">1.3</heSo1>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">9.3</heSo2>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">4.5</heSo2>
#   <heSo3 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">5.3</heSo3>
# </DiemSo>
#
# <DiemSo rdf:about="#diemso394">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocSinh rdf:resource="#hocsinh34"/>
#   <monHoc rdf:resource="#CongNghe"/>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">2.3</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">1.5</heSo1>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">9.8</heSo2>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">5.8</heSo2>
#   <heSo3 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">4.8</heSo3>
# </DiemSo>
#
# <DiemSo rdf:about="#diemso395">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocSinh rdf:resource="#hocsinh35"/>
#   <monHoc rdf:resource="#CongNghe"/>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">0.8</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">4.3</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">9.3</heSo1>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">9.3</heSo2>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">6.8</heSo2>
#   <heSo3 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">0.8</heSo3>
# </DiemSo>
#
# <DiemSo rdf:about="#diemso396">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocSinh rdf:resource="#hocsinh36"/>
#   <monHoc rdf:resource="#CongNghe"/>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">8.8</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">4.5</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">2.5</heSo1>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">2.8</heSo2>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">0.8</heSo2>
#   <heSo3 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">7.3</heSo3>
# </DiemSo>
#
# <DiemSo rdf:about="#diemso397">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocSinh rdf:resource="#hocsinh37"/>
#   <monHoc rdf:resource="#CongNghe"/>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">8.8</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">0.8</heSo1>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">3.8</heSo2>
#   <heSo3 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">5.5</heSo3>
# </DiemSo>
#
# <DiemSo rdf:about="#diemso398">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocSinh rdf:resource="#hocsinh38"/>
#   <monHoc rdf:resource="#CongNghe"/>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">8.3</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">4.5</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">1.8</heSo1>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">10</heSo2>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">7.5</heSo2>
#   <heSo3 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">9.3</heSo3>
# </DiemSo>
#
# <DiemSo rdf:about="#diemso399">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocSinh rdf:resource="#hocsinh39"/>
#   <monHoc rdf:resource="#CongNghe"/>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">5.8</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">3.5</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">10</heSo1>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">10</heSo2>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">4.8</heSo2>
#   <heSo3 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">1.3</heSo3>
# </DiemSo>
#
# <DiemSo rdf:about="#diemso400">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocSinh rdf:resource="#hocsinh40"/>
#   <monHoc rdf:resource="#CongNghe"/>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">0.5</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">2.8</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">7.3</heSo1>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">8.3</heSo2>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">6.8</heSo2>
#   <heSo3 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">4.8</heSo3>
# </DiemSo>
#
# <DiemSo rdf:about="#diemso401">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocSinh rdf:resource="#hocsinh41"/>
#   <monHoc rdf:resource="#CongNghe"/>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">7.5</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">2.3</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">6.3</heSo1>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">6.8</heSo2>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">8.3</heSo2>
#   <heSo3 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">1.3</heSo3>
# </DiemSo>
#
# <DiemSo rdf:about="#diemso402">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocSinh rdf:resource="#hocsinh42"/>
#   <monHoc rdf:resource="#CongNghe"/>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">4.3</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">10</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">4.8</heSo1>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">8.3</heSo2>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">4.3</heSo2>
#   <heSo3 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">0.5</heSo3>
# </DiemSo>
#
# <DiemSo rdf:about="#diemso403">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocSinh rdf:resource="#hocsinh43"/>
#   <monHoc rdf:resource="#CongNghe"/>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">1.8</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">3.8</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">9.8</heSo1>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">9.5</heSo2>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">8.3</heSo2>
#   <heSo3 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">6.5</heSo3>
# </DiemSo>
#
# <DiemSo rdf:about="#diemso404">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocSinh rdf:resource="#hocsinh44"/>
#   <monHoc rdf:resource="#CongNghe"/>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">10</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">1.5</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">6.8</heSo1>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">3.8</heSo2>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">3.5</heSo2>
#   <heSo3 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">4.8</heSo3>
# </DiemSo>
#
# <DiemSo rdf:about="#diemso405">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocSinh rdf:resource="#hocsinh45"/>
#   <monHoc rdf:resource="#CongNghe"/>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">4.8</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">6.8</heSo1>
#   <heSo1 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">0.5</heSo1>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">10</heSo2>
#   <heSo2 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">6.3</heSo2>
#   <heSo3 rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">0.8</heSo3>
# </DiemSo>
#
#
# </rdf:RDF>

# %%
# Đọc CSDL từ file
onto = get_ontology("../app/data/education.owl").load()

# In DS học sinh ra màn hình
print("Danh sách học sinh:")
stt = 1
for hs in onto.HocSinh.instances():
    print(stt, hs)
    stt += 1
# Out:
# Danh sách học sinh:
# 1 Bùi Hữu Nam - 15/08/2000 - Khác - 10C01
# 2 Tăng Thanh Hoàng - 14/09/2000 - Khác - 10C01
# 3 Đào Anh Xuân - 31/08/2000 - Nữ - 10C01
# 4 Lê Thanh Minh - 07/12/2000 - Khác - 10C01
# 5 Mai Kim Dũng - 24/01/2000 - Nam - 10C01
# 6 Huỳnh Đình Thiên - 18/12/2000 - Khác - 10C02
# 7 Lê Ngọc Sơn - 14/09/2000 - Khác - 10C02
# 8 Phạm Bảo Bình - 10/07/2000 - Nam - 10C02
# 9 Hồ Anh Ngọc - 28/01/2000 - Nữ - 10C02
# 10 Tô Anh Nam - 03/11/2000 - Nữ - 10C02
# 11 Tăng Thu Tùng - 24/10/2000 - Khác - 10C03
# 12 Dương Thị Cường - 25/01/2000 - Khác - 10C03
# 13 Tôn Mai Việt - 17/05/2000 - Khác - 10C03
# 14 Quách Mai Thiện - 02/11/2000 - Khác - 10C03
# 15 Ngô Mai Việt - 19/03/2000 - Nam - 10C03
# 16 Đỗ Mai Hùng - 14/04/2000 - Khác - 11B01
# 17 Hồ Thanh Thiên - 12/08/2000 - Nữ - 11B01
# 18 Tăng Bảo Khánh - 28/09/2000 - Nam - 11B01
# 19 Đào Thu Xuân - 24/11/2000 - Khác - 11B01
# 20 Lâm Hồng Nhật - 30/05/2000 - Khác - 11B01
# 21 Nguyễn Hoài Linh - 31/03/2000 - Khác - 11B02
# 22 Bành Văn Long - 04/04/2000 - Nữ - 11B02
# 23 Quách Hoài Khánh - 02/06/2000 - Nam - 11B02
# 24 Bành Quý Long - 10/10/2000 - Nữ - 11B02
# 25 Quách Hữu Hùng - 11/08/2000 - Nam - 11B02
# 26 Phạm Mai Nhật - 30/09/2000 - Khác - 11B03
# 27 Phan Đình Tú - 31/05/2000 - Nữ - 11B03
# 28 Hồ Mai Tùng - 07/11/2000 - Nam - 11B03
# 29 Đặng Quý Thiện - 21/10/2000 - Nam - 11B03
# 30 Lâm Văn Tùng - 05/08/2000 - Nữ - 11B03
# 31 Quách Kim Thảo - 01/12/2000 - Khác - 12A01
# 32 Lâm Đình Hùng - 03/04/2000 - Nữ - 12A01
# 33 Tôn Đình Tú - 22/10/2000 - Nữ - 12A01
# 34 Võ Văn Phương - 10/12/2000 - Nữ - 12A01
# 35 Đặng Hoài Thúy - 06/11/2000 - Nữ - 12A01
# 36 Bành Thu Quỳnh - 30/07/2000 - Khác - 12A02
# 37 Bành Anh Quân - 04/12/2000 - Nam - 12A02
# 38 Quách Thu Tùng - 06/07/2000 - Khác - 12A02
# 39 Hồ Hoài Quang - 27/07/2000 - Nữ - 12A02
# 40 Quách Quý Quỳnh - 23/12/2000 - Nữ - 12A02
# 41 Hồ Hữu Dũng - 16/03/2000 - Nam - 12A03
# 42 Lý Văn Long - 12/11/2000 - Nữ - 12A03
# 43 Hoàng Quý Thiên - 29/04/2000 - Khác - 12A03
# 44 Tô Hữu Xuân - 27/05/2000 - Khác - 12A03
# 45 Phan Mai Quân - 12/11/2000 - Khác - 12A03

# %%
print('Lấy ra 1 lớp')
hocLop = '10A01'
lop = onto.search_one(ten = hocLop, type = onto.LopHoc)
print(lop.ten)
# Out:
# Lấy ra 1 lớp
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 4
#       2 hocLop = '10A01'
#       3 lop = onto.search_one(ten = hocLop, type = onto.LopHoc)
# ----> 4 print(lop.ten)
#
# AttributeError: 'NoneType' object has no attribute 'ten'

# %%
# In DS giáo viên
print("Danh sách giáo viên:")
for gv in onto.GiaoVien.instances():
    print(gv.hoTen, gv.ngaySinh, gv.gioiTinh, gv.trinhDo, getattr(gv.lopChuNhiem,'ten',''), *[mon.ten for mon in gv.dayMon])
# Out:
# Danh sách giáo viên:
# Đoàn Minh Cường 23/11/1980 Nam ['Đại học'] 10A06 Toán học
# Võ Anh Quỳnh 13/02/1990 Nam ['Đại học'] 12A01 Toán học
# Đoàn Hoài Hùng 20/12/1981 Nam ['Thạc sĩ']  Toán học
# Hồ Văn Nam 25/08/1971 Nữ ['Thạc sĩ'] 10A02 Toán học
# Đào Thị Cường 07/05/1981 Nữ ['Thạc sĩ'] 10C02 Toán học
# Trần Kim Tùng 18/07/1972 Nữ ['Đại học'] 12A08 Ngữ văn
# Quách Hồng Thúy 29/05/1970 Khác ['Thạc sĩ'] 10C02 Ngữ văn
# Đinh Minh Nam 19/09/1984 Khác ['Thạc sĩ'] 10A05 Ngữ văn
# Trần Thanh Phương 02/03/1989 Khác ['Thạc sĩ']  Ngữ văn
# Lương Anh Phương 17/09/1982 Nam ['Thạc sĩ'] 12A07 Ngữ văn
# Trần Thị Linh 08/08/1985 Nam ['Đại học'] 10C06 Hóa học
# Quách Quý Ngọc 01/10/1972 Nữ ['Đại học'] 10A08 Hóa học
# Đoàn Hữu Thúy 25/04/1986 Nam ['Thạc sĩ'] 10A02 Hóa học
# Tạ Bảo Bình 07/01/1986 Nam ['Thạc sĩ'] 10A07 GDCD
# Nguyễn Hữu Thuận 26/07/1986 Nữ ['Đại học'] 10C04 GDCD
# Võ Thanh Sơn 26/02/1973 Nữ ['Thạc sĩ'] 12A06 Công nghệ
# Huỳnh Thị Hùng 20/08/1982 Khác ['Đại học']  Công nghệ
# Tô Anh Khánh 01/04/1990 Khác ['Thạc sĩ'] 10C10 Công nghệ
# Lâm Văn Sơn 05/11/1981 Nữ ['Đại học'] 12A02 Công nghệ
# Trần Thanh Sơn 15/09/1984 Nữ ['Thạc sĩ'] 10C07 Công nghệ
# Bành Đình Cường 24/05/1976 Nữ ['Thạc sĩ']  Toán học
# Đào Đình Xuân 10/02/1989 Khác ['Đại học'] 10C01 Toán học
# Đinh Kim Dũng 25/02/1981 Khác ['Đại học']  Toán học
# Trần Văn Sơn 14/05/1976 Nam ['Đại học'] 12A04 Toán học
# Hồ Thu Thúy 11/03/1973 Nữ ['Đại học'] 11B05 Toán học
# Ngô Thị Nhật 01/05/1989 Khác ['Đại học']  Ngữ văn
# Đặng Hữu Hải 08/10/1970 Khác ['Thạc sĩ']  Ngữ văn
# Trần Thanh Vân 19/10/1980 Nam ['Thạc sĩ'] 11B06 Ngữ văn
# Phạm Thu Việt 05/06/1988 Khác ['Thạc sĩ']  Ngữ văn
# Đoàn Bảo Long 05/06/1984 Nam ['Thạc sĩ']  Ngữ văn
# Bành Kim Hiền 31/01/1975 Nữ ['Thạc sĩ'] 11B02 Hóa học
# Hoàng Kim Hải 16/06/1988 Nữ ['Thạc sĩ']  Hóa học
# Đinh Thanh Quang 31/10/1979 Khác ['Thạc sĩ'] 10C08 Hóa học
# Mai Minh Phương 25/04/1985 Nam ['Đại học'] 10C05 Hóa học
# Đinh Hồng Vân 16/02/1988 Khác ['Thạc sĩ']  Hóa học
# Nguyễn Ngọc Hiền 22/01/1980 Nam ['Đại học'] 10C05 Lịch sử
# Ngô Bảo Quân 24/02/1973 Nữ ['Đại học'] 10C04 Lịch sử
# Tăng Anh Hải 02/02/1984 Nữ ['Đại học']  Lịch sử
# Vũ Bảo Bình 02/09/1972 Nam ['Đại học'] 11B03 Lịch sử
# Đoàn Văn Xuân 16/03/1988 Khác ['Đại học']  Lịch sử
# Huỳnh Hoài Nam 18/09/1986 Khác ['Thạc sĩ'] 10C08 Địa lý
# Tô Bảo Quân 15/10/1983 Khác ['Đại học'] 11B02 Địa lý
# Tô Hoài Thảo 25/04/1980 Nữ ['Đại học']  Địa lý
# Bành Hoài Khánh 24/01/1989 Nam ['Đại học']  Địa lý
# Đào Thanh Long 25/02/1981 Khác ['Thạc sĩ']  Địa lý
# Lý Anh Khánh 27/10/1980 Nữ ['Thạc sĩ']  Sinh học
# Phạm Thanh Bình 09/07/1985 Khác ['Thạc sĩ']  Sinh học
# Ngô Thị Thiện 20/02/1981 Khác ['Thạc sĩ']  Sinh học
# Tạ Ngọc Hiền 14/11/1977 Khác ['Đại học']  Sinh học
# Phạm Hồng Hải 17/10/1976 Khác ['Thạc sĩ'] 11B09 Sinh học
# Bành Đình Thuận - 22/01/2000 - Nam - 10A01
# Trần Minh Thảo - 29/06/2000 - Nữ - 10A01
# Phạm Quý Việt - 17/04/2000 - Nam - 10A01
# Đặng Thu Minh - 06/09/2000 - Nữ - 10A01
# Tăng Văn Tùng - 13/11/2000 - Nam - 10A01
# Lý Bảo Tường - 29/02/2000 - Nữ - 10A01
# Ngô Quý Tú - 16/02/2000 - Nữ - 10A01
# Phan Hồng Quang - 30/08/2000 - Nam - 10A01
# Bùi Quý Việt - 20/07/2000 - Nữ - 10A01
# Hồ Văn Cường - 27/04/2000 - Nam - 10A01
# Tạ Đình Phương - 19/01/2000 - Nữ - 10A01
# Thái Thanh Hùng - 11/10/2000 - Nam - 10A01
# Trương Văn Thuận - 23/09/2000 - Khác - 10A01
# Ngô Quý Tùng - 22/09/2000 - Nữ - 10A01
# Tạ Ngọc Nam - 17/07/2000 - Nam - 10A01
# Tăng Thị Quỳnh - 18/01/2000 - Nam - 10A01
# Phan Kim Tú - 06/08/2000 - Nữ - 10A01
# Tăng Hồng Linh - 28/02/2000 - Khác - 10A01
# Đinh Hoài Nhật - 12/05/2000 - Nam - 10A01
# Đào Hoài Vinh - 23/05/2000 - Nữ - 10A01

# %%
# in ds GV chủ nhiệm của từng lớp
print("Danh sách giáo viên chủ nhiệm:")
for lop in onto.LopHoc.instances():
    gv = lop.giaoVienChuNhiem
    if gv:
        print(gv.hoTen, gv.ngaySinh, gv.gioiTinh, gv.trinhDo, getattr(gv.lopChuNhiem,'ten',''))
# Out:
# Danh sách giáo viên chủ nhiệm:
# Phan Thanh Tường 30/09/1972 Nam ['Đại học'] 10A01
# Đoàn Hữu Thúy 25/04/1986 Nam ['Thạc sĩ'] 10A02
# Ngô Mai Thiên 19/03/1975 Nữ ['Thạc sĩ'] 10A03
# Huỳnh Mai Vân 11/06/1978 Khác ['Đại học'] 10A04
# Đinh Minh Nam 19/09/1984 Khác ['Thạc sĩ'] 10A05
# Đoàn Minh Cường 23/11/1980 Nam ['Đại học'] 10A06
# Vũ Thị Hoàng 14/12/1973 Nam ['Thạc sĩ'] 10A07
# Đoàn Hữu Tú 26/09/1981 Khác ['Thạc sĩ'] 10A08
# Đoàn Hữu Hùng 06/06/1989 Nữ ['Thạc sĩ'] 10A09
# Hồ Văn Nam 25/08/1971 Nữ ['Thạc sĩ'] 10A02
# Vũ Mai Xuân 15/07/1986 Nữ ['Đại học'] 10A03
# Lý Hữu An 03/03/1970 Nam ['Thạc sĩ'] 10A05
# Đào Hồng Vân 16/06/1975 Khác ['Đại học'] 10A06
# Quách Quý Ngọc 01/10/1972 Nữ ['Đại học'] 10A08
# Lý Kim Long 23/03/1974 Nữ ['Đại học'] 10A10
# Đinh Thị Quân 15/04/1990 Khác ['Thạc sĩ'] 11B02
# Phạm Hoài Linh 15/04/1973 Nam ['Đại học'] 11B03
# Lý Kim Linh 27/02/1978 Nữ ['Đại học'] 11B06
# Phạm Quý Vinh 14/06/1972 Nữ ['Thạc sĩ'] 11B07
# Bành Đình Long 17/01/1985 Nữ Thạc sĩ 10C10
# Lâm Thị Quân 02/06/1987 Nam Đại học 11B01
# Tô Bảo Quân 15/10/1983 Khác ['Đại học'] 11B02
# Quách Mai Sơn 10/04/1976 Nữ ['Thạc sĩ'] 11B03
# Lý Hữu Thuận 07/02/1980 Nữ Đại học 11B04
# Hồ Thu Thúy 11/03/1973 Nữ ['Đại học'] 11B05
# Đỗ Đình Quỳnh 31/03/1987 Khác Đại học 11B06
# Tô Bảo Dũng 12/10/1975 Nam ['Đại học'] 11B07
# Dương Hoài Quân 25/08/1983 Khác ['Thạc sĩ'] 11B08
# Lương Hoài Tú 03/06/1989 Nam ['Thạc sĩ'] 11B09
# Ngô Minh Thiên 20/12/1978 Khác Đại học 11B10
# Đoàn Mai Nam 23/11/1987 Nữ ['Thạc sĩ'] 12A01
# Bùi Hồng Ngọc 08/01/1975 Khác ['Đại học'] 12A02
# Đào Ngọc Long 24/01/1984 Khác Đại học 12A03
# Tôn Bảo Vinh 08/06/1983 Khác ['Đại học'] 12A04
# Phan Minh Tú 03/10/1974 Nam Thạc sĩ 12A05
# Lâm Đình Ngọc 02/05/1983 Khác Đại học 12A06
# Đặng Thu Linh 07/09/1987 Nam ['Thạc sĩ'] 12A07
# Bùi Mai Vân 08/01/1983 Nam Đại học 12A08
# Trương Minh Thuận 01/10/1970 Khác Thạc sĩ 12A09
# Tôn Ngọc Quang 27/02/1988 Nữ ['Đại học'] 12A10

# %%
# Sửa tên của giáo viên chủ nhiệm Nguyễn Văn X thành Nguyễn Văn Tèo
print("Sửa tên của giáo viên chủ nhiệm Nguyễn Văn X thành Nguyễn Văn Tèo")
for gv in onto.GiaoVien.instances():
    if gv.hoTen == "Nguyễn Văn X":
        gv.hoTen = "Nguyễn Văn Tèo"
        print(gv.hoTen, gv.ngaySinh, gv.gioiTinh, gv.trinhDo, getattr(gv.lopChuNhiem,'ten',''))
# Out:
# Sửa tên của giáo viên chủ nhiệm Nguyễn Văn X thành Nguyễn Văn Tèo

# %%
# Tạo mới một học sinh và thêm vào lớp 10A01
print("Tạo mới một học sinh và thêm vào lớp 10A01")
lop = onto.search_one(ten = "10A01", type = onto.LopHoc)
hs1 = HocSinh(hoTen = "Nguyễn Văn XXX", ngaySinh = "01/01/2011", gioiTinh = "Nam", lopHoc = lop)
# In DS HS trong lớp 10A01
print("Danh sách học sinh lớp 10A01:")
print('\n'.join(str(hs) for hs in lop.dsHocSinh))
# Out:
# Tạo mới một học sinh và thêm vào lớp 10A01
# Danh sách học sinh lớp 10A01:
# Bành Đình Thuận - 22/01/2000 - Nam - 10A01
# Trần Minh Thảo - 29/06/2000 - Nữ - 10A01
# Phạm Quý Việt - 17/04/2000 - Nam - 10A01
# Đặng Thu Minh - 06/09/2000 - Nữ - 10A01
# Tăng Văn Tùng - 13/11/2000 - Nam - 10A01
# Lý Bảo Tường - 29/02/2000 - Nữ - 10A01
# Ngô Quý Tú - 16/02/2000 - Nữ - 10A01
# Phan Hồng Quang - 30/08/2000 - Nam - 10A01
# Bùi Quý Việt - 20/07/2000 - Nữ - 10A01
# Hồ Văn Cường - 27/04/2000 - Nam - 10A01

# %%
# Xoá học sinh có ngày sinh là 01/01/2011
print("Xoá học sinh có ngày sinh là 01/01/2011")
hs_ind = onto.search_one(ngaySinh="01/01/2011", type=onto.HocSinh)
# Nếu individual được tìm thấy, xoá individual đó
if hs_ind is not None:
    destroy_entity(hs_ind)
# Out:
# Xoá học sinh có ngày sinh là 01/01/2011

# %%
# In tất cả điểm số của một học sinh
print("In tất cả điểm số của một học sinh")
hs_ind = onto.search_one(type=onto.HocSinh)
if hs_ind is not None:
    for diem in hs_ind.diemSo:
        print(diem.monHoc.ten, *diem.heSo1, *diem.heSo2, *diem.heSo3)
# Out:
# In tất cả điểm số của một học sinh
# Toán học 4.3 0.8 4.8 8.5 4.5 4.5
# Ngữ văn 8.8 6.3 10 10 3.5 7.3
# Hóa học 5.3 5.8 0.3 3.3 7.5 5.5
# Lịch sử 9.8 5.3 8.5 6.3 4.3 8.5
# Địa lý 0.3 8.8 3.3 3.3 9.8 1.5
# Sinh học 0.5 7.8 1.5 10 3.5 10
# Tiếng Anh 7.3 10 8.5 4.8 7.8 9.8
# GDCD 2.8 5.8 4.3 3.8 6.5 9.5
# Công nghệ 7.8 10 1.8 3.8 3.3 6.3
# Toán học 4.8 5.5 3.8 10 4.3 5.8
# Ngữ văn 3.8 5.3 7.3 7.5 1.5 4.3
# Hóa học 2.3 5.5 8.5 10 5.3 0.5
# Lịch sử 5.3 8.3 10 6.8 3.5
# Địa lý 5.5 6.5 2.5 5.3 1.8 8.5
# Sinh học 5.3 5.5 4.8 8.3 3.5
# Tiếng Anh 2.5 7.5 0.5 4.5 8.8 9.8
# GDCD 3.8 1.8 5.8 8.5 7.8 1.3
# Công nghệ 3.8 2.3 10 3.3 7.8 9.5
# Toán học 1.5 10 8.8 9.3 6.5 3.3
# Ngữ văn 0.3 8.8 9.8 3.5 7.5 0.8
# Hóa học 8.8 10 4.5 9.8 3.5 6.3
# Lịch sử 2.5 0.3 3.5 8.3 6.3 5.8
# Địa lý 2.8 6.5 1.3 7.5 5.5 2.5
# Sinh học 2.8 4.5 10 2.8 10 0.8
# Tiếng Anh 7.8 10 9.5 9.8 4.5 0.8
# GDCD 0.5 3.3 1.3 5.5 2.5 3.8
# Công nghệ 10 9.5 2.8 7.8 5.8 7.3
# Toán học 9.8 4.8 10 8.3 5.5 0.8
# Ngữ văn 9.5 6.3 3.5 6.5 7.8 10
# Hóa học 2.8 6.3 2.3 6.8 3.3 9.5
# Lịch sử 6.5 5.3 0.5 6.3 6.5
# Địa lý 4.5 8.8 10 6.3 10 1.5
# Sinh học 8.5 4.8 2.3 7.8 2.5 10
# Tiếng Anh 3.3 7.5 1.8 2.3 6.8 9.8
# GDCD 5.5 4.8 1.8 3.8 4.3
# Công nghệ 10 0.8 2.5 7.5 9.3 8.3
# Toán học 1.3 1.5 3.5 7.5 9.8 5.5
# Ngữ văn 5.5 8.8 10 3.3 0.8 2.3
# Hóa học 9.5 6.8 10 8.3 4.5 3.5
# Lịch sử 3.5 2.3 0.8 7.8 10
# Địa lý 10 7.3 2.8 10 2.3 1.8
# Sinh học 10 4.5 6.5 5.3 5.5 5.5
# Tiếng Anh 3.5 5.8 7.3 9.8 3.8 1.8
# GDCD 0.5 9.5 2.5 7.8 10 3.8
# Công nghệ 9.3 8.3 2.3 2.5 10 6.5
# Toán học 2.3 10 9.8 0.8 1.8 4.3
# Ngữ văn 7.5 8.5 5.5 3.8 10 10
# Hóa học 3.8 5.5 7.5 0.3 3.3 10
# Lịch sử 1.5 5.8 8.5 8.8 10 0.3
# Địa lý 10 2.3 9.3 0.8 9.5
# Sinh học 0.8 3.3 6.8 7.5 3.5 6.8
# Tiếng Anh 6.5 8.5 8.3 7.5 4.8 0.3
# GDCD 7.3 0.3 10 5.5 0.5 5.3
# Công nghệ 1.8 10 4.8 3.3 7.5 7.3
# Toán học 10 8.5 1.3 0.3 1.3 10
# Ngữ văn 6.3 6.5 0.8 3.5 7.3 0.3
# Hóa học 9.3 7.5 6.3 2.5 1.8 3.5
# Lịch sử 9.3 10 7.5 5.8 7.8 10
# Địa lý 2.3 2.5 9.8 0.5 1.3 7.8
# Sinh học 4.5 8.5 0.5 10 6.3 6.8
# Tiếng Anh 10 9.3 7.3 5.5 1.3
# GDCD 10 2.3 9.5 0.3 2.3 7.3
# Công nghệ 6.5 9.3 5.3 4.5 10 4.8

# %%
print(hoTen.iri)
print(HocSinh.iri)
# Out:
# http://hc.com/school#hoTen
# http://hc.com/school#HocSinh

# %%
lsPro = list(onto.properties())
def get_properties(obj):
    return [p for p in lsPro if obj.is_a[0] in p.domain] + [p for p in lsPro if obj in p.domain]
print('Liệt kê toàn bộ các đối tượng trong ontology')
lsClass= list(onto.classes())
for i, class_ in zip(range(len(lsClass)), lsClass):
    # print(class_.name, '[', ', '.join([x.name for x in get_properties(class_)]), ']')
    print(str(i+1)+'.', class_.name, 'kế thừa từ', class_.is_a)
    for x in get_properties(class_) :
        print('-', x.name, ':', x.range)
# Out:
# Liệt kê toàn bộ các đối tượng trong ontology
# 1. ChucVu kế thừa từ [owl.Thing]
# - ten : [<class 'str'>, <class 'str'>, <class 'str'>]
# - phuCap : [<class 'int'>, <class 'int'>, <class 'int'>]
# - moTa : [<class 'str'>, <class 'str'>, <class 'str'>]
# - toChuc : [school.ToChuc, school.ToChuc, school.ToChuc]
# 2. ToChuc kế thừa từ [owl.Thing]
# - ten : [<class 'str'>, <class 'str'>, <class 'str'>]
# - thanhVien : [school.Nguoi, school.Nguoi, school.Nguoi]
# - phong : [school.Phong, school.Phong, school.Phong]
# 3. Nguoi kế thừa từ [owl.Thing]
# - hoTen : [<class 'str'>, <class 'str'>, <class 'str'>]
# - ngaySinh : [<class 'datetime.date'>, <class 'datetime.date'>, <class 'datetime.date'>]
# - gioiTinh : [<class 'str'>, <class 'str'>, <class 'str'>]
# - ngheNghiep : [<class 'str'>, <class 'str'>, <class 'str'>]
# - thuocToChuc : [school.ToChuc, school.ToChuc, school.ToChuc]
# 4. NhanVien kế thừa từ [school.Nguoi]
# - hoTen : [<class 'str'>, <class 'str'>, <class 'str'>]
# - ngaySinh : [<class 'datetime.date'>, <class 'datetime.date'>, <class 'datetime.date'>]
# - gioiTinh : [<class 'str'>, <class 'str'>, <class 'str'>]
# - ngheNghiep : [<class 'str'>, <class 'str'>, <class 'str'>]
# - thuocToChuc : [school.ToChuc, school.ToChuc, school.ToChuc]
# - luong : [<class 'int'>, <class 'int'>, <class 'int'>]
# - chucVu : [school.ChucVu, school.ChucVu, school.ChucVu]
# 5. PhuHuynh kế thừa từ [school.Nguoi]
# - hoTen : [<class 'str'>, <class 'str'>, <class 'str'>]
# - ngaySinh : [<class 'datetime.date'>, <class 'datetime.date'>, <class 'datetime.date'>]
# - gioiTinh : [<class 'str'>, <class 'str'>, <class 'str'>]
# - ngheNghiep : [<class 'str'>, <class 'str'>, <class 'str'>]
# - thuocToChuc : [school.ToChuc, school.ToChuc, school.ToChuc]
# - con : [school.HocSinh, school.HocSinh, school.HocSinh]
# 6. LopHoc kế thừa từ [school.ToChuc]
# - ten : [<class 'str'>, <class 'str'>, <class 'str'>]
# - thanhVien : [school.Nguoi, school.Nguoi, school.Nguoi]
# - phong : [school.Phong, school.Phong, school.Phong]
# - ten : [<class 'str'>, <class 'str'>, <class 'str'>]
# - giaoVienChuNhiem : [school.GiaoVien, school.GiaoVien, school.GiaoVien]
# - phongHoc : [school.Phong, school.Phong, school.Phong]
# - dsHocSinh : [school.HocSinh, school.HocSinh, school.HocSinh]
# 7. HocSinh kế thừa từ [school.Nguoi]
# - hoTen : [<class 'str'>, <class 'str'>, <class 'str'>]
# - ngaySinh : [<class 'datetime.date'>, <class 'datetime.date'>, <class 'datetime.date'>]
# - gioiTinh : [<class 'str'>, <class 'str'>, <class 'str'>]
# - ngheNghiep : [<class 'str'>, <class 'str'>, <class 'str'>]
# - thuocToChuc : [school.ToChuc, school.ToChuc, school.ToChuc]
# - hocLop : [school.LopHoc, school.LopHoc, school.LopHoc]
# - phuHuynh : [school.PhuHuynh, school.PhuHuynh, school.PhuHuynh]
# - diemSo : [school.DiemSo, school.DiemSo, school.DiemSo]
# 8. GiaoVien kế thừa từ [school.NhanVien]
# - luong : [<class 'int'>, <class 'int'>, <class 'int'>]
# - chucVu : [school.ChucVu, school.ChucVu, school.ChucVu]
# - trinhDo : [<class 'str'>, <class 'str'>, <class 'str'>]
# - dayMon : [school.MonHoc, school.MonHoc, school.MonHoc]
# - lopChuNhiem : [school.LopHoc, school.LopHoc, school.LopHoc]
# 9. MonHoc kế thừa từ [owl.Thing]
# - ten : [<class 'str'>, <class 'str'>, <class 'str'>]
# - soTiet : [<class 'int'>, <class 'int'>, <class 'int'>]
# - moTa : [<class 'str'>, <class 'str'>, <class 'str'>]
# - giaoVienDay : [school.GiaoVien, school.GiaoVien, school.GiaoVien]
# 10. DiemSo kế thừa từ [owl.Thing]
# - heSo1 : [<class 'float'>, <class 'float'>, <class 'float'>]
# - heSo2 : [<class 'float'>, <class 'float'>, <class 'float'>]
# - heSo3 : [<class 'float'>, <class 'float'>, <class 'float'>]
# - hocSinh : [school.HocSinh, school.HocSinh, school.HocSinh]
# - monHoc : [school.MonHoc, school.MonHoc, school.MonHoc]
# 11. TheDocGia kế thừa từ [owl.Thing]
# - ngayCap : [<class 'datetime.date'>, <class 'datetime.date'>, <class 'datetime.date'>]
# - ngayHetHan : [<class 'datetime.date'>, <class 'datetime.date'>, <class 'datetime.date'>]
# - docGia : [school.Nguoi, school.Nguoi, school.Nguoi]
# - sachDaDoc : [school.Sach, school.Sach, school.Sach]
# 12. TacGia kế thừa từ [owl.Thing]
# - dsSach : [school.Sach, school.Sach, school.Sach]
# 13. NhaXuatBan kế thừa từ [owl.Thing]
# - ten : [<class 'str'>, <class 'str'>, <class 'str'>]
# - dsSach : [school.Sach, school.Sach, school.Sach]
# 14. Sach kế thừa từ [owl.Thing]
# - ten : [<class 'str'>, <class 'str'>, <class 'str'>]
# - giaTien : [<class 'int'>, <class 'int'>, <class 'int'>]
# - soLuong : [<class 'int'>, <class 'int'>, <class 'int'>]
# - tacGia : [school.TacGia, school.TacGia, school.TacGia]
# - nhaXuatBan : [school.NhaXuatBan, school.NhaXuatBan, school.NhaXuatBan]
# - theLoai : [school.TheLoai, school.TheLoai, school.TheLoai]
# 15. TheLoai kế thừa từ [owl.Thing]
# - ten : [<class 'str'>, <class 'str'>, <class 'str'>]
# - moTa : [<class 'str'>, <class 'str'>, <class 'str'>]
# - dsSach : [school.Sach, school.Sach, school.Sach]
# 16. PhieuMuon kế thừa từ [owl.Thing]
# - ngayMuon : [<class 'datetime.date'>, <class 'datetime.date'>, <class 'datetime.date'>]
# - ngayTra : [<class 'datetime.date'>, <class 'datetime.date'>, <class 'datetime.date'>]
# - theDocGia : [school.TheDocGia, school.TheDocGia, school.TheDocGia]
# - sachMuon : [school.Sach, school.Sach, school.Sach]
# 17. Phong kế thừa từ [owl.Thing]
# - ten : [<class 'str'>, <class 'str'>, <class 'str'>]
# - moTa : [<class 'str'>, <class 'str'>, <class 'str'>]
# - suDungBoi : [school.ToChuc, school.ToChuc, school.ToChuc]
# 18. HoatDong kế thừa từ [owl.Thing]
# - ten : [<class 'str'>, <class 'str'>, <class 'str'>]
# - ngayBatDau : [<class 'datetime.date'>, <class 'datetime.date'>, <class 'datetime.date'>]
# - ngayKetThuc : [<class 'datetime.date'>, <class 'datetime.date'>, <class 'datetime.date'>]
# - moTa : [<class 'str'>, <class 'str'>, <class 'str'>]
# - quanLy : [school.Nguoi, school.Nguoi, school.Nguoi]
# - thamGia : [school.Nguoi, school.Nguoi, school.Nguoi]
# 19. DiemDanh kế thừa từ [owl.Thing]
# - ngayGio : [<class 'datetime.datetime'>, <class 'datetime.datetime'>, <class 'datetime.datetime'>]
# - trangThai : [<class 'str'>, <class 'str'>, <class 'str'>]
# - nguoiDiemDanh : [school.Nguoi, school.Nguoi, school.Nguoi]
# - hoatDong : [school.HoatDong, school.HoatDong, school.HoatDong]
