# %% [markdown]
# ### Cài đặt thư viện:
#
# Cài đặt các thư viện vào môi trường anaconda:
#
# ```bash
# conda install -c conda-forge owlready2
# ```

# %% [markdown]
# ### Tạo ontology

# %%
# %run ../app/models/model.py
# Out:
# * Owlready2 * Warning: optimized Cython parser module 'owlready2_optimized' is not available, defaulting to slower Python implementation

# %%
# Lưu CSDL ra file
onto.save(file="../app/data/education.owl")
with open("../app/data/education.owl", "r") as f:
    print(f.read())
# Out:
# <?xml version="1.0"?>
# <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#"
#          xmlns:xsd="http://www.w3.org/2001/XMLSchema#"
#          xmlns:rdfs="http://www.w3.org/2000/01/rdf-schema#"
#          xmlns:owl="http://www.w3.org/2002/07/owl#"
#          xml:base="http://hc.com/school"
#          xmlns="http://hc.com/school#">
#
# <owl:Ontology rdf:about="http://hc.com/school"/>
#
# <owl:ObjectProperty rdf:about="#moTa">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#MonHoc"/>
#   <rdfs:domain rdf:resource="#Phong"/>
#   <rdfs:domain rdf:resource="#TheLoai"/>
#   <rdfs:domain rdf:resource="#ChucVu"/>
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#toChuc">
#   <rdfs:domain rdf:resource="#ChucVu"/>
#   <rdfs:range rdf:resource="#ToChuc"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#thanhVien">
#   <rdfs:domain rdf:resource="#ToChuc"/>
#   <rdfs:range rdf:resource="#Nguoi"/>
#   <owl:inverseOf rdf:resource="#thuocToChuc"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#phong">
#   <rdfs:domain rdf:resource="#ToChuc"/>
#   <rdfs:range rdf:resource="#Phong"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#thuocToChuc">
#   <rdfs:domain rdf:resource="#Nguoi"/>
#   <rdfs:range rdf:resource="#ToChuc"/>
#   <owl:inverseOf rdf:resource="#thanhVien"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#chucVu">
#   <rdfs:domain rdf:resource="#NhanVien"/>
#   <rdfs:range rdf:resource="#ChucVu"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#con">
#   <rdfs:domain rdf:resource="#PhuHuynh"/>
#   <rdfs:range rdf:resource="#HocSinh"/>
#   <owl:inverseOf rdf:resource="#phuHuynh"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#giaoVienChuNhiem">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#LopHoc"/>
#   <rdfs:range rdf:resource="#GiaoVien"/>
#   <owl:inverseOf rdf:resource="#lopChuNhiem"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#phongHoc">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#LopHoc"/>
#   <rdfs:range rdf:resource="#Phong"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#dsHocSinh">
#   <rdfs:domain rdf:resource="#LopHoc"/>
#   <rdfs:range rdf:resource="#HocSinh"/>
#   <owl:inverseOf rdf:resource="#hocLop"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#hocLop">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#LopHoc"/>
#   <owl:inverseOf rdf:resource="#dsHocSinh"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#phuHuynh">
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#PhuHuynh"/>
#   <owl:inverseOf rdf:resource="#con"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#diemSo">
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#DiemSo"/>
#   <owl:inverseOf rdf:resource="#hocSinh"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#dayMon">
#   <rdfs:domain rdf:resource="#GiaoVien"/>
#   <rdfs:range rdf:resource="#MonHoc"/>
#   <owl:inverseOf rdf:resource="#giaoVienDay"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#giangDay">
#   <rdfs:domain rdf:resource="#GiaoVien"/>
#   <rdfs:range rdf:resource="#GiangDay"/>
#   <owl:inverseOf rdf:resource="#giaoVien"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#lopChuNhiem">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#GiaoVien"/>
#   <rdfs:range rdf:resource="#LopHoc"/>
#   <owl:inverseOf rdf:resource="#giaoVienChuNhiem"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#giaoVienDay">
#   <rdfs:domain rdf:resource="#MonHoc"/>
#   <rdfs:range rdf:resource="#GiaoVien"/>
#   <owl:inverseOf rdf:resource="#dayMon"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#hocSinh">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="#HocSinh"/>
#   <owl:inverseOf rdf:resource="#diemSo"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#monHoc">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="#MonHoc"/>
#   <rdfs:domain rdf:resource="#GiangDay"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#giaoVien">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#GiangDay"/>
#   <rdfs:range rdf:resource="#GiaoVien"/>
#   <owl:inverseOf rdf:resource="#giangDay"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#lopHoc">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#GiangDay"/>
#   <rdfs:range rdf:resource="#LopHoc"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#docGia">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#TheDocGia"/>
#   <rdfs:range rdf:resource="#Nguoi"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#sachDaDoc">
#   <rdfs:domain rdf:resource="#TheDocGia"/>
#   <rdfs:range rdf:resource="#Sach"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#dsSach">
#   <rdfs:domain rdf:resource="#TacGia"/>
#   <rdfs:domain rdf:resource="#TheLoai"/>
#   <rdfs:domain rdf:resource="#NhaXuatBan"/>
#   <rdfs:range rdf:resource="#Sach"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#tacGia">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Sach"/>
#   <rdfs:range rdf:resource="#TacGia"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#nhaXuatBan">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Sach"/>
#   <rdfs:range rdf:resource="#NhaXuatBan"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#theLoai">
#   <rdfs:domain rdf:resource="#Sach"/>
#   <rdfs:range rdf:resource="#TheLoai"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#theDocGia">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#PhieuMuon"/>
#   <rdfs:range rdf:resource="#TheDocGia"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#sachMuon">
#   <rdfs:domain rdf:resource="#PhieuMuon"/>
#   <rdfs:range rdf:resource="#Sach"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#suDungBoi">
#   <rdfs:domain rdf:resource="#Phong"/>
#   <rdfs:range rdf:resource="#ToChuc"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#quanLy">
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:range rdf:resource="#Nguoi"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#thamGia">
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:range rdf:resource="#Nguoi"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#nguoiDiemDanh">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemDanh"/>
#   <rdfs:range rdf:resource="#Nguoi"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#hoatDong">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemDanh"/>
#   <rdfs:range rdf:resource="#HoatDong"/>
# </owl:ObjectProperty>
#
# <owl:DatatypeProperty rdf:about="#ten">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Sach"/>
#   <rdfs:domain rdf:resource="#NhaXuatBan"/>
#   <rdfs:domain rdf:resource="#ToChuc"/>
#   <rdfs:domain rdf:resource="#ChucVu"/>
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:domain rdf:resource="#MonHoc"/>
#   <rdfs:domain rdf:resource="#Phong"/>
#   <rdfs:domain rdf:resource="#TheLoai"/>
#   <rdfs:domain rdf:resource="#LopHoc"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#phuCap">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#ChucVu"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#integer"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#hoTen">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Nguoi"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngaySinh">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Nguoi"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#gioiTinh">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Nguoi"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#luong">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#NhanVien"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#integer"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngheNghiep">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Nguoi"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#trinhDo">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#GiaoVien"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#soTiet">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#MonHoc"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#integer"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#heSo1">
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#heSo2">
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#heSo3">
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayCap">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#TheDocGia"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayHetHan">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#TheDocGia"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#giaTien">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Sach"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#integer"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#soLuong">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Sach"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#integer"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayMuon">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#PhieuMuon"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayTra">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#PhieuMuon"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayBatDau">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayKetThuc">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayGio">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemDanh"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#dateTime"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#trangThai">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemDanh"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:Class rdf:about="#ChucVu">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#ToChuc">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#Nguoi">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#NhanVien">
#   <rdfs:subClassOf rdf:resource="#Nguoi"/>
# </owl:Class>
#
# <owl:Class rdf:about="#PhuHuynh">
#   <rdfs:subClassOf rdf:resource="#Nguoi"/>
# </owl:Class>
#
# <owl:Class rdf:about="#LopHoc">
#   <rdfs:subClassOf rdf:resource="#ToChuc"/>
# </owl:Class>
#
# <owl:Class rdf:about="#HocSinh">
#   <rdfs:subClassOf rdf:resource="#Nguoi"/>
# </owl:Class>
#
# <owl:Class rdf:about="#GiaoVien">
#   <rdfs:subClassOf rdf:resource="#NhanVien"/>
# </owl:Class>
#
# <owl:Class rdf:about="#MonHoc">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#DiemSo">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#GiangDay">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#TheDocGia">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#TacGia">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#NhaXuatBan">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#Sach">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#TheLoai">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#PhieuMuon">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#Phong">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#HoatDong">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#DiemDanh">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
#
# </rdf:RDF>

# %%
lsPro = list(onto.properties())
def get_properties(obj):
    return [p for p in lsPro if obj.is_a[0] in p.domain] + [p for p in lsPro if obj in p.domain]
print('Liệt kê toàn bộ các đối tượng trong ontology')
lsClass= list(onto.classes())
for i, class_ in zip(range(len(lsClass)), lsClass):
    # print(class_.name, '[', ', '.join([x.name for x in get_properties(class_)]), ']')
    print(str(i+1)+'.', class_.name, 'kế thừa từ', class_.is_a)
    for x in get_properties(class_) :
        print('-', x.name, ':', x.range)
# Out:
# Liệt kê toàn bộ các đối tượng trong ontology
# 1. ChucVu kế thừa từ [owl.Thing]
# - ten : [<class 'str'>, <class 'str'>, <class 'str'>]
# - phuCap : [<class 'int'>, <class 'int'>, <class 'int'>]
# - moTa : [<class 'str'>, <class 'str'>, <class 'str'>]
# - toChuc : [school.ToChuc, school.ToChuc, school.ToChuc]
# 2. ToChuc kế thừa từ [owl.Thing]
# - ten : [<class 'str'>, <class 'str'>, <class 'str'>]
# - thanhVien : [school.Nguoi, school.Nguoi, school.Nguoi]
# - phong : [school.Phong, school.Phong, school.Phong]
# 3. Nguoi kế thừa từ [owl.Thing]
# - hoTen : [<class 'str'>, <class 'str'>, <class 'str'>]
# - ngaySinh : [<class 'datetime.date'>, <class 'datetime.date'>, <class 'datetime.date'>]
# - gioiTinh : [<class 'str'>, <class 'str'>, <class 'str'>]
# - ngheNghiep : [<class 'str'>, <class 'str'>, <class 'str'>]
# - thuocToChuc : [school.ToChuc, school.ToChuc, school.ToChuc]
# 4. NhanVien kế thừa từ [school.Nguoi]
# - hoTen : [<class 'str'>, <class 'str'>, <class 'str'>]
# - ngaySinh : [<class 'datetime.date'>, <class 'datetime.date'>, <class 'datetime.date'>]
# - gioiTinh : [<class 'str'>, <class 'str'>, <class 'str'>]
# - ngheNghiep : [<class 'str'>, <class 'str'>, <class 'str'>]
# - thuocToChuc : [school.ToChuc, school.ToChuc, school.ToChuc]
# - luong : [<class 'int'>, <class 'int'>, <class 'int'>]
# - chucVu : [school.ChucVu, school.ChucVu, school.ChucVu]
# 5. PhuHuynh kế thừa từ [school.Nguoi]
# - hoTen : [<class 'str'>, <class 'str'>, <class 'str'>]
# - ngaySinh : [<class 'datetime.date'>, <class 'datetime.date'>, <class 'datetime.date'>]
# - gioiTinh : [<class 'str'>, <class 'str'>, <class 'str'>]
# - ngheNghiep : [<class 'str'>, <class 'str'>, <class 'str'>]
# - thuocToChuc : [school.ToChuc, school.ToChuc, school.ToChuc]
# - con : [school.HocSinh, school.HocSinh, school.HocSinh]
# 6. LopHoc kế thừa từ [school.ToChuc]
# - ten : [<class 'str'>, <class 'str'>, <class 'str'>]
# - thanhVien : [school.Nguoi, school.Nguoi, school.Nguoi]
# - phong : [school.Phong, school.Phong, school.Phong]
# - ten : [<class 'str'>, <class 'str'>, <class 'str'>]
# - giaoVienChuNhiem : [school.GiaoVien, school.GiaoVien, school.GiaoVien]
# - phongHoc : [school.Phong, school.Phong, school.Phong]
# - dsHocSinh : [school.HocSinh, school.HocSinh, school.HocSinh]
# 7. HocSinh kế thừa từ [school.Nguoi]
# - hoTen : [<class 'str'>, <class 'str'>, <class 'str'>]
# - ngaySinh : [<class 'datetime.date'>, <class 'datetime.date'>, <class 'datetime.date'>]
# - gioiTinh : [<class 'str'>, <class 'str'>, <class 'str'>]
# - ngheNghiep : [<class 'str'>, <class 'str'>, <class 'str'>]
# - thuocToChuc : [school.ToChuc, school.ToChuc, school.ToChuc]
# - hocLop : [school.LopHoc, school.LopHoc, school.LopHoc]
# - phuHuynh : [school.PhuHuynh, school.PhuHuynh, school.PhuHuynh]
# - diemSo : [school.DiemSo, school.DiemSo, school.DiemSo]
# 8. GiaoVien kế thừa từ [school.NhanVien]
# - luong : [<class 'int'>, <class 'int'>, <class 'int'>]
# - chucVu : [school.ChucVu, school.ChucVu, school.ChucVu]
# - trinhDo : [<class 'str'>, <class 'str'>, <class 'str'>]
# - dayMon : [school.MonHoc, school.MonHoc, school.MonHoc]
# - lopChuNhiem : [school.LopHoc, school.LopHoc, school.LopHoc]
# 9. MonHoc kế thừa từ [owl.Thing]
# - ten : [<class 'str'>, <class 'str'>, <class 'str'>]
# - soTiet : [<class 'int'>, <class 'int'>, <class 'int'>]
# - moTa : [<class 'str'>, <class 'str'>, <class 'str'>]
# - giaoVienDay : [school.GiaoVien, school.GiaoVien, school.GiaoVien]
# 10. DiemSo kế thừa từ [owl.Thing]
# - heSo1 : [<class 'float'>, <class 'float'>, <class 'float'>]
# - heSo2 : [<class 'float'>, <class 'float'>, <class 'float'>]
# - heSo3 : [<class 'float'>, <class 'float'>, <class 'float'>]
# - hocSinh : [school.HocSinh, school.HocSinh, school.HocSinh]
# - monHoc : [school.MonHoc, school.MonHoc, school.MonHoc]
# 11. TheDocGia kế thừa từ [owl.Thing]
# - ngayCap : [<class 'datetime.date'>, <class 'datetime.date'>, <class 'datetime.date'>]
# - ngayHetHan : [<class 'datetime.date'>, <class 'datetime.date'>, <class 'datetime.date'>]
# - docGia : [school.Nguoi, school.Nguoi, school.Nguoi]
# - sachDaDoc : [school.Sach, school.Sach, school.Sach]
# 12. TacGia kế thừa từ [owl.Thing]
# - dsSach : [school.Sach, school.Sach, school.Sach]
# 13. NhaXuatBan kế thừa từ [owl.Thing]
# - ten : [<class 'str'>, <class 'str'>, <class 'str'>]
# - dsSach : [school.Sach, school.Sach, school.Sach]
# 14. Sach kế thừa từ [owl.Thing]
# - ten : [<class 'str'>, <class 'str'>, <class 'str'>]
# - giaTien : [<class 'int'>, <class 'int'>, <class 'int'>]
# - soLuong : [<class 'int'>, <class 'int'>, <class 'int'>]
# - tacGia : [school.TacGia, school.TacGia, school.TacGia]
# - nhaXuatBan : [school.NhaXuatBan, school.NhaXuatBan, school.NhaXuatBan]
# - theLoai : [school.TheLoai, school.TheLoai, school.TheLoai]
# 15. TheLoai kế thừa từ [owl.Thing]
# - ten : [<class 'str'>, <class 'str'>, <class 'str'>]
# - moTa : [<class 'str'>, <class 'str'>, <class 'str'>]
# - dsSach : [school.Sach, school.Sach, school.Sach]
# 16. PhieuMuon kế thừa từ [owl.Thing]
# - ngayMuon : [<class 'datetime.date'>, <class 'datetime.date'>, <class 'datetime.date'>]
# - ngayTra : [<class 'datetime.date'>, <class 'datetime.date'>, <class 'datetime.date'>]
# - theDocGia : [school.TheDocGia, school.TheDocGia, school.TheDocGia]
# - sachMuon : [school.Sach, school.Sach, school.Sach]
# 17. Phong kế thừa từ [owl.Thing]
# - ten : [<class 'str'>, <class 'str'>, <class 'str'>]
# - moTa : [<class 'str'>, <class 'str'>, <class 'str'>]
# - suDungBoi : [school.ToChuc, school.ToChuc, school.ToChuc]
# 18. HoatDong kế thừa từ [owl.Thing]
# - ten : [<class 'str'>, <class 'str'>, <class 'str'>]
# - ngayBatDau : [<class 'datetime.date'>, <class 'datetime.date'>, <class 'datetime.date'>]
# - ngayKetThuc : [<class 'datetime.date'>, <class 'datetime.date'>, <class 'datetime.date'>]
# - moTa : [<class 'str'>, <class 'str'>, <class 'str'>]
# - quanLy : [school.Nguoi, school.Nguoi, school.Nguoi]
# - thamGia : [school.Nguoi, school.Nguoi, school.Nguoi]
# 19. DiemDanh kế thừa từ [owl.Thing]
# - ngayGio : [<class 'datetime.datetime'>, <class 'datetime.datetime'>, <class 'datetime.datetime'>]
# - trangThai : [<class 'str'>, <class 'str'>, <class 'str'>]
# - nguoiDiemDanh : [school.Nguoi, school.Nguoi, school.Nguoi]
# - hoatDong : [school.HoatDong, school.HoatDong, school.HoatDong]

# %% [markdown]
# ### Thêm dữ liệu

# %%
import random
from datetime import datetime, timedelta

def createRandomDate(start_year, end_year):
    # Tính toán số ngày trong năm bắt đầu và kết thúc
    start_date = datetime(year=start_year, month=1, day=1)
    end_date = datetime(year=end_year, month=12, day=31)
    days_in_range = (end_date - start_date).days + 1

    # Tạo ngẫu nhiên số ngày trong khoảng thời gian bắt đầu và kết thúc
    random_days = random.randint(0, days_in_range - 1)

    # Tính toán ngày sinh từ số ngày được chọn
    birth_date = start_date + timedelta(days=random_days)

    # Trả về chuỗi ngày sinh dạng dd/mm/yyyy
    return birth_date.strftime('%d/%m/%Y')

def createRandomInfo():
    ho = random.choice(["Nguyễn", "Trần", "Lê", "Phạm", "Hoàng", "Huỳnh", "Phan", "Vũ", "Võ", "Đặng", "Bùi", "Đỗ", "Hồ", "Ngô", "Dương", "Lý", "Lương", "Mai", "Trương", "Tạ", "Đào", 
                            "Đoàn", "Đinh", "Lâm", "Phùng", "Đoàn", "Bành", "Quách", "Thái", "Tô", "Tôn", "Tăng"])
    lot = random.choice(['Văn', 'Thị', 'Hồng', 'Anh', 'Quý', 'Bảo', "Thanh", "Thu", "Hữu", "Mai", "Đình", "Hoài", "Ngọc", "Minh", "Kim"])
    ten = random.choice(["An", "Bình", "Cường", "Dũng", "Hải", "Hiền", "Hoàng", "Hùng", "Khánh", "Linh", "Long", "Minh", "Nam", "Ngọc", "Nhật", "Phương", "Quân", "Quang", "Quỳnh", 
                            "Sơn", "Thảo", "Thiên", "Thiện", "Thúy", "Thuận", "Tùng", "Tú", "Tường", "Việt", "Vân", "Vinh", "Xuân"])
    gioiTinh = random.choice(["Nam", "Nữ", "Khác"])
    return f"{ho} {lot} {ten}", gioiTinh
def randScore():
    score = random.randint(0, 10)
    if score != 10:
        score += random.choice([0.3, 0.5, 0.8])
    return score

def getClassName(soLopMoiKhoi, index):
    khoi = index // soLopMoiKhoi
    lop = index % soLopMoiKhoi + 1
    tenLop = f'{khoi+10}{"CBA"[khoi]}'
    if lop < 10:
        return f'{tenLop}0{lop}'
    else:
        return f'{tenLop}{lop}'
# Đọc CSDL từ file
onto = get_ontology("../app/data/education.owl").load()

# Thêm dữ liệu cho từng đối tượng
with onto: 
    # Tạo ngẫu nhiên 10 lớp học mỗi khối lớp
    soLopMoiKhoi = 3
    tongSoLop = soLopMoiKhoi * 3
    soHSMoiLop = 5
    soHSCoAnhEm = 20
    soGVMoiMon = 3
    soGVDay2Mon = 5
    dsLop, dsHS, dsGV, dsMonHoc = [], [], [], []
    for i in range(tongSoLop):
        lop = LopHoc(ten = getClassName(soLopMoiKhoi, i))
        dsLop.append(lop)
        # Tạo ngẫu nhiên HS cho mỗi lớp
        for j in range(soHSMoiLop):
            ten, gt = createRandomInfo()
            hs = HocSinh(hoTen = ten, ngaySinh = createRandomDate(2000, 2000), gioiTinh = gt, hocLop = lop)
            dsHS.append(hs)
            # Tạo ngẫu nhiên 2 PH cho mỗi HS
            for k in range(2):
                ten, gt = createRandomInfo()
                nghe = random.choice(["Nông dân", "Công nhân", "Giáo viên", "Bác sĩ", "Kỹ sư", "Nhân viên văn phòng", "Chủ doanh nghiệp"])
                ph = PhuHuynh(hoTen = ten, ngaySinh = createRandomDate(1970, 1980), gioiTinh = gt, con = [hs], ngheNghiep = nghe)
    
    # Cho một số học sinh có chung phụ huynh
    random_items = random.sample(dsHS, soHSCoAnhEm)
    remaining_items = list(set(dsHS) - set(random_items))
    new_random_items = random.sample(remaining_items, soHSCoAnhEm)
    for hs, i in zip(random_items, range(soHSCoAnhEm)):
        for ph in hs.phuHuynh: destroy_entity(ph)
        hs.phuHuynh = []
        for ph in new_random_items[i].phuHuynh: 
            ph.con.append(hs)
            hs.phuHuynh.append(ph)

    # Tạo môn học
    id_mon_hoc = ['Toan', 'NguVan', 'HoaHoc', 'LichSu', 'DiaLy', 'SinhHoc', 'TiengAnh', 'GDCD', 'CongNghe', 'TheDuc']
    ds_mon_hoc = ['Toán học', 'Ngữ văn', 'Hóa học', 'Lịch sử', 'Địa lý', 'Sinh học', 'Tiếng Anh', 'GDCD', 'Công nghệ', 'Thể dục']
    so_tiet = [5, 3, 3, 3, 5, 2, 2, 3, 2, 2]
    for id, mon, st in zip(id_mon_hoc, ds_mon_hoc, so_tiet):
        mon_hoc = MonHoc(id, ten = mon, soTiet = st)
        dsMonHoc.append(mon_hoc)
        # Tạo ngẫu nhiên GV cho mỗi môn
        for j in range(soGVMoiMon):
            ten, gt = createRandomInfo()
            td = ['Đại học', 'Thạc sĩ'][random.randint(0,1)]
            gv = GiaoVien(hoTen = ten, ngaySinh = createRandomDate(1970, 1990), gioiTinh = gt, trinhDo = td, dayMon = [mon_hoc])
            dsGV.append(gv)
        # Tạo điểm số cho từng HS
        for hs in dsHS:
            diem = DiemSo(hocSinh = hs, monHoc = mon_hoc, 
                          heSo1 = [randScore(),randScore(),randScore()], 
                          heSo2 = [randScore(),randScore()], 
                          heSo3 = [randScore()])
    # Cho một số GV dạy 2 môn
    for gv in random.sample(dsGV, soGVDay2Mon):
        monChuaDay = [mon for mon in dsMonHoc if mon not in gv.dayMon]
        gv.dayMon.append(random.choice(monChuaDay))

    # Gán GVCN cho từng lớp
    dsGVCN = random.sample(dsGV, tongSoLop)
    for i in range(tongSoLop):
        dsGVCN[i].lopChuNhiem = dsLop[i]

    # Phân công giáo viên dạy môn học
    for mon in dsMonHoc:
        dsGVDayMon = [gv for gv in dsGV if mon in gv.dayMon]
        soLopMoiGV = len(dsLop) // len(dsGVDayMon)
        index = 0
        for gv in dsGVDayMon:
            for i in range(soLopMoiGV):
                tenLop = getClassName(soLopMoiKhoi, index)
                lop = [l for l in dsLop if l.ten == tenLop][0]
                gd = GiangDay(giaoVien = gv, monHoc = mon, lopHoc = lop)
                index += 1
        # Phân công giáo viên dạy môn học cho lớp còn lại
        for i in range(index, tongSoLop):
            tenLop = getClassName(soLopMoiKhoi, i)
            lop = [l for l in dsLop if l.ten == tenLop][0]
            gv = random.choice(dsGVDayMon)
            gd = GiangDay(giaoVien = gv, monHoc = mon, lopHoc = lop)

# Lưu CSDL ra file
onto.save(file="../app/data/education.owl", format='rdfxml') # 'ntriples' / "rdfxml"
with open("../app/data/education.owl", "r") as f:
    print(f.read())
# Out:
# <?xml version="1.0"?>
# <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#"
#          xmlns:xsd="http://www.w3.org/2001/XMLSchema#"
#          xmlns:rdfs="http://www.w3.org/2000/01/rdf-schema#"
#          xmlns:owl="http://www.w3.org/2002/07/owl#"
#          xml:base="http://hc.com/school"
#          xmlns="http://hc.com/school#">
#
# <owl:Ontology rdf:about="http://hc.com/school"/>
#
# <owl:ObjectProperty rdf:about="#moTa">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#MonHoc"/>
#   <rdfs:domain rdf:resource="#Phong"/>
#   <rdfs:domain rdf:resource="#TheLoai"/>
#   <rdfs:domain rdf:resource="#ChucVu"/>
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#toChuc">
#   <rdfs:domain rdf:resource="#ChucVu"/>
#   <rdfs:range rdf:resource="#ToChuc"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#thanhVien">
#   <rdfs:domain rdf:resource="#ToChuc"/>
#   <rdfs:range rdf:resource="#Nguoi"/>
#   <owl:inverseOf rdf:resource="#thuocToChuc"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#phong">
#   <rdfs:domain rdf:resource="#ToChuc"/>
#   <rdfs:range rdf:resource="#Phong"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#thuocToChuc">
#   <rdfs:domain rdf:resource="#Nguoi"/>
#   <rdfs:range rdf:resource="#ToChuc"/>
#   <owl:inverseOf rdf:resource="#thanhVien"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#chucVu">
#   <rdfs:domain rdf:resource="#NhanVien"/>
#   <rdfs:range rdf:resource="#ChucVu"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#con">
#   <rdfs:domain rdf:resource="#PhuHuynh"/>
#   <rdfs:range rdf:resource="#HocSinh"/>
#   <owl:inverseOf rdf:resource="#phuHuynh"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#giaoVienChuNhiem">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#LopHoc"/>
#   <rdfs:range rdf:resource="#GiaoVien"/>
#   <owl:inverseOf rdf:resource="#lopChuNhiem"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#phongHoc">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#LopHoc"/>
#   <rdfs:range rdf:resource="#Phong"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#dsHocSinh">
#   <rdfs:domain rdf:resource="#LopHoc"/>
#   <rdfs:range rdf:resource="#HocSinh"/>
#   <owl:inverseOf rdf:resource="#hocLop"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#hocLop">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#LopHoc"/>
#   <owl:inverseOf rdf:resource="#dsHocSinh"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#phuHuynh">
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#PhuHuynh"/>
#   <owl:inverseOf rdf:resource="#con"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#diemSo">
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#DiemSo"/>
#   <owl:inverseOf rdf:resource="#hocSinh"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#dayMon">
#   <rdfs:domain rdf:resource="#GiaoVien"/>
#   <rdfs:range rdf:resource="#MonHoc"/>
#   <owl:inverseOf rdf:resource="#giaoVienDay"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#giangDay">
#   <rdfs:domain rdf:resource="#GiaoVien"/>
#   <rdfs:range rdf:resource="#GiangDay"/>
#   <owl:inverseOf rdf:resource="#giaoVien"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#lopChuNhiem">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#GiaoVien"/>
#   <rdfs:range rdf:resource="#LopHoc"/>
#   <owl:inverseOf rdf:resource="#giaoVienChuNhiem"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#giaoVienDay">
#   <rdfs:domain rdf:resource="#MonHoc"/>
#   <rdfs:range rdf:resource="#GiaoVien"/>
#   <owl:inverseOf rdf:resource="#dayMon"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#hocSinh">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="#HocSinh"/>
#   <owl:inverseOf rdf:resource="#diemSo"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#monHoc">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="#MonHoc"/>
#   <rdfs:domain rdf:resource="#GiangDay"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#giaoVien">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#GiangDay"/>
#   <rdfs:range rdf:resource="#GiaoVien"/>
#   <owl:inverseOf rdf:resource="#giangDay"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#lopHoc">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#GiangDay"/>
#   <rdfs:range rdf:resource="#LopHoc"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#docGia">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#TheDocGia"/>
#   <rdfs:range rdf:resource="#Nguoi"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#sachDaDoc">
#   <rdfs:domain rdf:resource="#TheDocGia"/>
#   <rdfs:range rdf:resource="#Sach"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#dsSach">
#   <rdfs:domain rdf:resource="#TacGia"/>
#   <rdfs:domain rdf:resource="#TheLoai"/>
#   <rdfs:domain rdf:resource="#NhaXuatBan"/>
#   <rdfs:range rdf:resource="#Sach"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#tacGia">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Sach"/>
#   <rdfs:range rdf:resource="#TacGia"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#nhaXuatBan">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Sach"/>
#   <rdfs:range rdf:resource="#NhaXuatBan"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#theLoai">
#   <rdfs:domain rdf:resource="#Sach"/>
#   <rdfs:range rdf:resource="#TheLoai"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#theDocGia">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#PhieuMuon"/>
#   <rdfs:range rdf:resource="#TheDocGia"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#sachMuon">
#   <rdfs:domain rdf:resource="#PhieuMuon"/>
#   <rdfs:range rdf:resource="#Sach"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#suDungBoi">
#   <rdfs:domain rdf:resource="#Phong"/>
#   <rdfs:range rdf:resource="#ToChuc"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#quanLy">
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:range rdf:resource="#Nguoi"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#thamGia">
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:range rdf:resource="#Nguoi"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#nguoiDiemDanh">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemDanh"/>
#   <rdfs:range rdf:resource="#Nguoi"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#hoatDong">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemDanh"/>
#   <rdfs:range rdf:resource="#HoatDong"/>
# </owl:ObjectProperty>
#
# <owl:DatatypeProperty rdf:about="#ten">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Sach"/>
#   <rdfs:domain rdf:resource="#NhaXuatBan"/>
#   <rdfs:domain rdf:resource="#ToChuc"/>
#   <rdfs:domain rdf:resource="#ChucVu"/>
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:domain rdf:resource="#MonHoc"/>
#   <rdfs:domain rdf:resource="#Phong"/>
#   <rdfs:domain rdf:resource="#TheLoai"/>
#   <rdfs:domain rdf:resource="#LopHoc"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#phuCap">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#ChucVu"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#integer"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#hoTen">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Nguoi"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngaySinh">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Nguoi"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#gioiTinh">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Nguoi"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#luong">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#NhanVien"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#integer"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngheNghiep">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Nguoi"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#trinhDo">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#GiaoVien"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#soTiet">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#MonHoc"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#integer"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#heSo1">
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#heSo2">
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#heSo3">
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayCap">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#TheDocGia"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayHetHan">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#TheDocGia"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#giaTien">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Sach"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#integer"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#soLuong">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Sach"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#integer"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayMuon">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#PhieuMuon"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayTra">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#PhieuMuon"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayBatDau">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayKetThuc">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayGio">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemDanh"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#dateTime"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#trangThai">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemDanh"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:Class rdf:about="#ChucVu">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#ToChuc">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#Nguoi">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#NhanVien">
#   <rdfs:subClassOf rdf:resource="#Nguoi"/>
# </owl:Class>
#
# <owl:Class rdf:about="#PhuHuynh">
#   <rdfs:subClassOf rdf:resource="#Nguoi"/>
# </owl:Class>
#
# <owl:Class rdf:about="#LopHoc">
#   <rdfs:subClassOf rdf:resource="#ToChuc"/>
# </owl:Class>
#
# <owl:Class rdf:about="#HocSinh">
#   <rdfs:subClassOf rdf:resource="#Nguoi"/>
# </owl:Class>
#
# <owl:Class rdf:about="#GiaoVien">
#   <rdfs:subClassOf rdf:resource="#NhanVien"/>
# </owl:Class>
#
# <owl:Class rdf:about="#MonHoc">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#DiemSo">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#GiangDay">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#TheDocGia">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#TacGia">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#NhaXuatBan">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#Sach">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#TheLoai">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#PhieuMuon">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#Phong">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#HoatDong">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#DiemDanh">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <LopHoc rdf:about="#lophoc1">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <ten rdf:datatype="http://www.w3.org/2001/XMLSchema#string">10C01</ten>
# </LopHoc>
#
# <HocSinh rdf:about="#hocsinh1">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc1"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Bùi Minh Cường</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">30/04/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
# </HocSinh>
#
# <PhuHuynh rdf:about="#phuhuynh1">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh1"/>
#   <con rdf:resource="#hocsinh24"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Lý Ngọc Quang</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">23/11/1975</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Giáo viên</ngheNghiep>
# </PhuHuynh>
#
# <PhuHuynh rdf:about="#phuhuynh2">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh1"/>
#   <con rdf:resource="#hocsinh24"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Bùi Hoài Tường</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">26/07/1977</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Công nhân</ngheNghiep>
# </PhuHuynh>
#
# <HocSinh rdf:about="#hocsinh2">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc1"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Lâm Quý Minh</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">19/02/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
# </HocSinh>
#
# <PhuHuynh rdf:about="#phuhuynh3">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh2"/>
#   <con rdf:resource="#hocsinh12"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Lê Bảo Cường</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">25/03/1971</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Công nhân</ngheNghiep>
# </PhuHuynh>
#
# <PhuHuynh rdf:about="#phuhuynh4">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh2"/>
#   <con rdf:resource="#hocsinh12"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Thái Anh Thuận</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">04/12/1980</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Bác sĩ</ngheNghiep>
# </PhuHuynh>
#
# <HocSinh rdf:about="#hocsinh3">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc1"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Bành Kim Vân</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">06/06/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
# </HocSinh>
#
# <PhuHuynh rdf:about="#phuhuynh5">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh3"/>
#   <con rdf:resource="#hocsinh5"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Ngô Ngọc Tùng</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">11/10/1979</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Kỹ sư</ngheNghiep>
# </PhuHuynh>
#
# <PhuHuynh rdf:about="#phuhuynh6">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh3"/>
#   <con rdf:resource="#hocsinh5"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tạ Hồng Vinh</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">10/05/1970</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Chủ doanh nghiệp</ngheNghiep>
# </PhuHuynh>
#
# <HocSinh rdf:about="#hocsinh4">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc1"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đoàn Thị Thúy</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">14/03/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh5">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc1"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Hồ Hoài Hùng</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">21/07/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
# </HocSinh>
#
# <LopHoc rdf:about="#lophoc2">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <ten rdf:datatype="http://www.w3.org/2001/XMLSchema#string">10C02</ten>
# </LopHoc>
#
# <HocSinh rdf:about="#hocsinh6">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc2"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Lê Anh Thiên</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">21/02/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh7">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc2"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Trần Hoài Sơn</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">09/12/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
# </HocSinh>
#
# <PhuHuynh rdf:about="#phuhuynh13">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh7"/>
#   <con rdf:resource="#hocsinh11"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đào Hồng Minh</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">14/01/1980</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Chủ doanh nghiệp</ngheNghiep>
# </PhuHuynh>
#
# <PhuHuynh rdf:about="#phuhuynh14">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh7"/>
#   <con rdf:resource="#hocsinh11"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Trương Bảo Sơn</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">18/03/1976</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Giáo viên</ngheNghiep>
# </PhuHuynh>
#
# <HocSinh rdf:about="#hocsinh8">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc2"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đoàn Đình Nhật</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">07/06/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh9">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc2"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Huỳnh Quý Long</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">14/06/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
# </HocSinh>
#
# <PhuHuynh rdf:about="#phuhuynh17">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh9"/>
#   <con rdf:resource="#hocsinh25"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đoàn Thu Tùng</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">09/08/1975</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Giáo viên</ngheNghiep>
# </PhuHuynh>
#
# <PhuHuynh rdf:about="#phuhuynh18">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh9"/>
#   <con rdf:resource="#hocsinh25"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đỗ Hoài Tường</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">21/05/1973</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Công nhân</ngheNghiep>
# </PhuHuynh>
#
# <HocSinh rdf:about="#hocsinh10">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc2"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Hoàng Bảo Tú</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">19/12/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
# </HocSinh>
#
# <PhuHuynh rdf:about="#phuhuynh19">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh10"/>
#   <con rdf:resource="#hocsinh6"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đoàn Mai Xuân</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">26/11/1974</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nhân viên văn phòng</ngheNghiep>
# </PhuHuynh>
#
# <PhuHuynh rdf:about="#phuhuynh20">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh10"/>
#   <con rdf:resource="#hocsinh6"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Huỳnh Văn Thiên</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">12/08/1974</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Công nhân</ngheNghiep>
# </PhuHuynh>
#
# <LopHoc rdf:about="#lophoc3">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <ten rdf:datatype="http://www.w3.org/2001/XMLSchema#string">10C03</ten>
# </LopHoc>
#
# <HocSinh rdf:about="#hocsinh11">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc3"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nguyễn Đình Minh</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">24/08/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh12">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc3"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Mai Thu Việt</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">10/01/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh13">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc3"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đào Hồng Thiên</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">25/10/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
# </HocSinh>
#
# <PhuHuynh rdf:about="#phuhuynh25">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh13"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Trương Minh Thiện</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">09/03/1974</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Bác sĩ</ngheNghiep>
# </PhuHuynh>
#
# <PhuHuynh rdf:about="#phuhuynh26">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh13"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Bành Minh Tường</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">19/10/1975</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nhân viên văn phòng</ngheNghiep>
# </PhuHuynh>
#
# <HocSinh rdf:about="#hocsinh14">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc3"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Phùng Bảo Tường</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">30/07/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
# </HocSinh>
#
# <PhuHuynh rdf:about="#phuhuynh27">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh14"/>
#   <con rdf:resource="#hocsinh8"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Phùng Đình Thiện</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">15/06/1973</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Giáo viên</ngheNghiep>
# </PhuHuynh>
#
# <PhuHuynh rdf:about="#phuhuynh28">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh14"/>
#   <con rdf:resource="#hocsinh8"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Ngô Hồng Sơn</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">14/09/1974</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Chủ doanh nghiệp</ngheNghiep>
# </PhuHuynh>
#
# <HocSinh rdf:about="#hocsinh15">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc3"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Lý Anh Nam</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">24/05/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
# </HocSinh>
#
# <PhuHuynh rdf:about="#phuhuynh29">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh15"/>
#   <con rdf:resource="#hocsinh35"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Hoàng Kim Tú</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">06/12/1979</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Chủ doanh nghiệp</ngheNghiep>
# </PhuHuynh>
#
# <PhuHuynh rdf:about="#phuhuynh30">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh15"/>
#   <con rdf:resource="#hocsinh35"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đặng Kim Hùng</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">23/01/1972</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nông dân</ngheNghiep>
# </PhuHuynh>
#
# <LopHoc rdf:about="#lophoc4">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <ten rdf:datatype="http://www.w3.org/2001/XMLSchema#string">11B01</ten>
# </LopHoc>
#
# <HocSinh rdf:about="#hocsinh16">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc4"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Trương Thu Tùng</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">04/07/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh17">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc4"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Hồ Mai Tường</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">06/04/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh18">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc4"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đỗ Đình Thiên</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">20/05/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
# </HocSinh>
#
# <PhuHuynh rdf:about="#phuhuynh35">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh18"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tôn Mai Dũng</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">09/08/1975</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Bác sĩ</ngheNghiep>
# </PhuHuynh>
#
# <PhuHuynh rdf:about="#phuhuynh36">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh18"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Dương Hoài Nam</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">04/05/1978</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nhân viên văn phòng</ngheNghiep>
# </PhuHuynh>
#
# <HocSinh rdf:about="#hocsinh19">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc4"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Bành Thu Hải</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">09/07/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
# </HocSinh>
#
# <PhuHuynh rdf:about="#phuhuynh37">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh19"/>
#   <con rdf:resource="#hocsinh38"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Huỳnh Thu Hiền</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">10/01/1975</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nông dân</ngheNghiep>
# </PhuHuynh>
#
# <PhuHuynh rdf:about="#phuhuynh38">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh19"/>
#   <con rdf:resource="#hocsinh38"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Trương Thanh Quỳnh</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">05/10/1980</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Chủ doanh nghiệp</ngheNghiep>
# </PhuHuynh>
#
# <HocSinh rdf:about="#hocsinh20">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc4"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đỗ Mai Thuận</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">03/10/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
# </HocSinh>
#
# <PhuHuynh rdf:about="#phuhuynh39">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh20"/>
#   <con rdf:resource="#hocsinh4"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Hồ Mai Linh</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">22/08/1980</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nông dân</ngheNghiep>
# </PhuHuynh>
#
# <PhuHuynh rdf:about="#phuhuynh40">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh20"/>
#   <con rdf:resource="#hocsinh4"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Quách Đình Hiền</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">28/01/1972</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Bác sĩ</ngheNghiep>
# </PhuHuynh>
#
# <LopHoc rdf:about="#lophoc5">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <ten rdf:datatype="http://www.w3.org/2001/XMLSchema#string">11B02</ten>
# </LopHoc>
#
# <HocSinh rdf:about="#hocsinh21">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc5"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Huỳnh Hồng Thảo</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">11/03/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
# </HocSinh>
#
# <PhuHuynh rdf:about="#phuhuynh41">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh21"/>
#   <con rdf:resource="#hocsinh17"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Bành Đình Hải</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">06/02/1974</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Chủ doanh nghiệp</ngheNghiep>
# </PhuHuynh>
#
# <PhuHuynh rdf:about="#phuhuynh42">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh21"/>
#   <con rdf:resource="#hocsinh17"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đoàn Hoài Vinh</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">25/11/1972</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Bác sĩ</ngheNghiep>
# </PhuHuynh>
#
# <HocSinh rdf:about="#hocsinh22">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc5"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Trương Đình Vân</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">19/04/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
# </HocSinh>
#
# <PhuHuynh rdf:about="#phuhuynh43">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh22"/>
#   <con rdf:resource="#hocsinh44"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đào Văn Sơn</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">12/10/1976</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Bác sĩ</ngheNghiep>
# </PhuHuynh>
#
# <PhuHuynh rdf:about="#phuhuynh44">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh22"/>
#   <con rdf:resource="#hocsinh44"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Vũ Hữu Thiện</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">19/11/1974</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Giáo viên</ngheNghiep>
# </PhuHuynh>
#
# <HocSinh rdf:about="#hocsinh23">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc5"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Lê Thanh Bình</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">11/07/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh24">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc5"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đào Thanh Xuân</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">27/05/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh25">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc5"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tăng Hữu Thiên</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">30/08/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
# </HocSinh>
#
# <LopHoc rdf:about="#lophoc6">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <ten rdf:datatype="http://www.w3.org/2001/XMLSchema#string">11B03</ten>
# </LopHoc>
#
# <HocSinh rdf:about="#hocsinh26">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc6"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Huỳnh Minh Hiền</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">17/01/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh27">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc6"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đinh Quý Nam</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">31/12/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh28">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc6"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Hồ Hồng Minh</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">15/05/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
# </HocSinh>
#
# <PhuHuynh rdf:about="#phuhuynh55">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh28"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đỗ Quý Nhật</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">18/09/1978</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Chủ doanh nghiệp</ngheNghiep>
# </PhuHuynh>
#
# <PhuHuynh rdf:about="#phuhuynh56">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh28"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Dương Bảo Hải</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">16/03/1975</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Công nhân</ngheNghiep>
# </PhuHuynh>
#
# <HocSinh rdf:about="#hocsinh29">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc6"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Quách Thị Vinh</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">25/12/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
# </HocSinh>
#
# <PhuHuynh rdf:about="#phuhuynh57">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh29"/>
#   <con rdf:resource="#hocsinh39"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Thái Ngọc Khánh</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">17/03/1975</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Kỹ sư</ngheNghiep>
# </PhuHuynh>
#
# <PhuHuynh rdf:about="#phuhuynh58">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh29"/>
#   <con rdf:resource="#hocsinh39"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Thái Thanh Việt</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">02/01/1980</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nhân viên văn phòng</ngheNghiep>
# </PhuHuynh>
#
# <HocSinh rdf:about="#hocsinh30">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc6"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Trương Hữu Quỳnh</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">29/04/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
# </HocSinh>
#
# <PhuHuynh rdf:about="#phuhuynh59">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh30"/>
#   <con rdf:resource="#hocsinh16"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tăng Hữu Việt</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">10/11/1971</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Bác sĩ</ngheNghiep>
# </PhuHuynh>
#
# <PhuHuynh rdf:about="#phuhuynh60">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh30"/>
#   <con rdf:resource="#hocsinh16"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tô Anh Ngọc</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">09/07/1976</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khác</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Chủ doanh nghiệp</ngheNghiep>
# </PhuHuynh>
#
# <LopHoc rdf:about="#lophoc7">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <ten rdf:datatype="http://www.w3.org/2001/XMLSchema#string">12A01</ten>
# </LopHoc>
#
# <HocSinh rdf:about="#hocsinh31">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc7"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đào Hữu Nam</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">15/02/2000</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh32">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
# ...
#
# <GiangDay rdf:about="#giangday14">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <giaoVien rdf:resource="#giaovien5"/>
#   <monHoc rdf:resource="#NguVan"/>
#   <lopHoc rdf:resource="#lophoc5"/>
# </GiangDay>
#
# <GiangDay rdf:about="#giangday15">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <giaoVien rdf:resource="#giaovien5"/>
#   <monHoc rdf:resource="#NguVan"/>
#   <lopHoc rdf:resource="#lophoc6"/>
# </GiangDay>
#
# <GiangDay rdf:about="#giangday16">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <giaoVien rdf:resource="#giaovien6"/>
#   <monHoc rdf:resource="#NguVan"/>
#   <lopHoc rdf:resource="#lophoc7"/>
# </GiangDay>
#
# <GiangDay rdf:about="#giangday17">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <giaoVien rdf:resource="#giaovien6"/>
#   <monHoc rdf:resource="#NguVan"/>
#   <lopHoc rdf:resource="#lophoc8"/>
# </GiangDay>
#
# <GiangDay rdf:about="#giangday18">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <giaoVien rdf:resource="#giaovien6"/>
#   <monHoc rdf:resource="#NguVan"/>
#   <lopHoc rdf:resource="#lophoc9"/>
# </GiangDay>
#
# <GiangDay rdf:about="#giangday19">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <giaoVien rdf:resource="#giaovien7"/>
#   <monHoc rdf:resource="#HoaHoc"/>
#   <lopHoc rdf:resource="#lophoc1"/>
# </GiangDay>
#
# <GiangDay rdf:about="#giangday20">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <giaoVien rdf:resource="#giaovien7"/>
#   <monHoc rdf:resource="#HoaHoc"/>
#   <lopHoc rdf:resource="#lophoc2"/>
# </GiangDay>
#
# <GiangDay rdf:about="#giangday21">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <giaoVien rdf:resource="#giaovien7"/>
#   <monHoc rdf:resource="#HoaHoc"/>
#   <lopHoc rdf:resource="#lophoc3"/>
# </GiangDay>
#
# <GiangDay rdf:about="#giangday22">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <giaoVien rdf:resource="#giaovien8"/>
#   <monHoc rdf:resource="#HoaHoc"/>
#   <lopHoc rdf:resource="#lophoc4"/>
# </GiangDay>
#
# <GiangDay rdf:about="#giangday23">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <giaoVien rdf:resource="#giaovien8"/>
#   <monHoc rdf:resource="#HoaHoc"/>
#   <lopHoc rdf:resource="#lophoc5"/>
# </GiangDay>
#
# <GiangDay rdf:about="#giangday24">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <giaoVien rdf:resource="#giaovien8"/>
#   <monHoc rdf:resource="#HoaHoc"/>
#   <lopHoc rdf:resource="#lophoc6"/>
# </GiangDay>
#
# <GiangDay rdf:about="#giangday25">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <giaoVien rdf:resource="#giaovien9"/>
#   <monHoc rdf:resource="#HoaHoc"/>
#   <lopHoc rdf:resource="#lophoc7"/>
# </GiangDay>
#
# <GiangDay rdf:about="#giangday26">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <giaoVien rdf:resource="#giaovien9"/>
#   <monHoc rdf:resource="#HoaHoc"/>
#   <lopHoc rdf:resource="#lophoc8"/>
# </GiangDay>
#
# <GiangDay rdf:about="#giangday27">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <giaoVien rdf:resource="#giaovien9"/>
#   <monHoc rdf:resource="#HoaHoc"/>
#   <lopHoc rdf:resource="#lophoc9"/>
# </GiangDay>
#
# <GiangDay rdf:about="#giangday28">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <giaoVien rdf:resource="#giaovien8"/>
#   <monHoc rdf:resource="#LichSu"/>
#   <lopHoc rdf:resource="#lophoc1"/>
# </GiangDay>
#
# <GiangDay rdf:about="#giangday29">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <giaoVien rdf:resource="#giaovien10"/>
#   <monHoc rdf:resource="#LichSu"/>
#   <lopHoc rdf:resource="#lophoc2"/>
# </GiangDay>
#
# <GiangDay rdf:about="#giangday30">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <giaoVien rdf:resource="#giaovien11"/>
#   <monHoc rdf:resource="#LichSu"/>
#   <lopHoc rdf:resource="#lophoc3"/>
# </GiangDay>
#
# <GiangDay rdf:about="#giangday31">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <giaoVien rdf:resource="#giaovien12"/>
#   <monHoc rdf:resource="#LichSu"/>
#   <lopHoc rdf:resource="#lophoc4"/>
# </GiangDay>
#
# <GiangDay rdf:about="#giangday32">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <giaoVien rdf:resource="#giaovien16"/>
#   <monHoc rdf:resource="#LichSu"/>
#   <lopHoc rdf:resource="#lophoc5"/>
# </GiangDay>
#
# <GiangDay rdf:about="#giangday33">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <giaoVien rdf:resource="#giaovien12"/>
#   <monHoc rdf:resource="#LichSu"/>
#   <lopHoc rdf:resource="#lophoc6"/>
# </GiangDay>
#
# <GiangDay rdf:about="#giangday34">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <giaoVien rdf:resource="#giaovien11"/>
#   <monHoc rdf:resource="#LichSu"/>
#   <lopHoc rdf:resource="#lophoc7"/>
# </GiangDay>
#
# <GiangDay rdf:about="#giangday35">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <giaoVien rdf:resource="#giaovien16"/>
#   <monHoc rdf:resource="#LichSu"/>
#   <lopHoc rdf:resource="#lophoc8"/>
# </GiangDay>
#
# <GiangDay rdf:about="#giangday36">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <giaoVien rdf:resource="#giaovien12"/>
#   <monHoc rdf:resource="#LichSu"/>
#   <lopHoc rdf:resource="#lophoc9"/>
# </GiangDay>
#
# <GiangDay rdf:about="#giangday37">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <giaoVien rdf:resource="#giaovien13"/>
#   <monHoc rdf:resource="#DiaLy"/>
#   <lopHoc rdf:resource="#lophoc1"/>
# </GiangDay>
#
# <GiangDay rdf:about="#giangday38">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <giaoVien rdf:resource="#giaovien13"/>
#   <monHoc rdf:resource="#DiaLy"/>
#   <lopHoc rdf:resource="#lophoc2"/>
# </GiangDay>
#
# <GiangDay rdf:about="#giangday39">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <giaoVien rdf:resource="#giaovien14"/>
#   <monHoc rdf:resource="#DiaLy"/>
#   <lopHoc rdf:resource="#lophoc3"/>
# </GiangDay>
#
# <GiangDay rdf:about="#giangday40">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <giaoVien rdf:resource="#giaovien14"/>
#   <monHoc rdf:resource="#DiaLy"/>
#   <lopHoc rdf:resource="#lophoc4"/>
# </GiangDay>
#
# <GiangDay rdf:about="#giangday41">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <giaoVien rdf:resource="#giaovien15"/>
#   <monHoc rdf:resource="#DiaLy"/>
#   <lopHoc rdf:resource="#lophoc5"/>
# </GiangDay>
#
# <GiangDay rdf:about="#giangday42">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <giaoVien rdf:resource="#giaovien15"/>
#   <monHoc rdf:resource="#DiaLy"/>
#   <lopHoc rdf:resource="#lophoc6"/>
# </GiangDay>
#
# <GiangDay rdf:about="#giangday43">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <giaoVien rdf:resource="#giaovien19"/>
#   <monHoc rdf:resource="#DiaLy"/>
#   <lopHoc rdf:resource="#lophoc7"/>
# </GiangDay>
#
# <GiangDay rdf:about="#giangday44">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <giaoVien rdf:resource="#giaovien19"/>
#   <monHoc rdf:resource="#DiaLy"/>
#   <lopHoc rdf:resource="#lophoc8"/>
# </GiangDay>
#
# <GiangDay rdf:about="#giangday45">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <giaoVien rdf:resource="#giaovien14"/>
#   <monHoc rdf:resource="#DiaLy"/>
#   <lopHoc rdf:resource="#lophoc9"/>
# </GiangDay>
#
# <GiangDay rdf:about="#giangday46">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <giaoVien rdf:resource="#giaovien16"/>
#   <monHoc rdf:resource="#SinhHoc"/>
#   <lopHoc rdf:resource="#lophoc1"/>
# </GiangDay>
#
# <GiangDay rdf:about="#giangday47">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <giaoVien rdf:resource="#giaovien16"/>
#   <monHoc rdf:resource="#SinhHoc"/>
#   <lopHoc rdf:resource="#lophoc2"/>
# </GiangDay>
#
# <GiangDay rdf:about="#giangday48">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <giaoVien rdf:resource="#giaovien16"/>
#   <monHoc rdf:resource="#SinhHoc"/>
#   <lopHoc rdf:resource="#lophoc3"/>
# </GiangDay>
#
# <GiangDay rdf:about="#giangday49">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <giaoVien rdf:resource="#giaovien17"/>
#   <monHoc rdf:resource="#SinhHoc"/>
#   <lopHoc rdf:resource="#lophoc4"/>
# </GiangDay>
#
# <GiangDay rdf:about="#giangday50">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <giaoVien rdf:resource="#giaovien17"/>
#   <monHoc rdf:resource="#SinhHoc"/>
#   <lopHoc rdf:resource="#lophoc5"/>
# </GiangDay>
#
# <GiangDay rdf:about="#giangday51">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <giaoVien rdf:resource="#giaovien17"/>
#   <monHoc rdf:resource="#SinhHoc"/>
#   <lopHoc rdf:resource="#lophoc6"/>
# </GiangDay>
#
# <GiangDay rdf:about="#giangday52">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <giaoVien rdf:resource="#giaovien18"/>
#   <monHoc rdf:resource="#SinhHoc"/>
#   <lopHoc rdf:resource="#lophoc7"/>
# </GiangDay>
#
# <GiangDay rdf:about="#giangday53">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <giaoVien rdf:resource="#giaovien18"/>
#   <monHoc rdf:resource="#SinhHoc"/>
#   <lopHoc rdf:resource="#lophoc8"/>
# </GiangDay>
#
# <GiangDay rdf:about="#giangday54">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <giaoVien rdf:resource="#giaovien18"/>
#   <monHoc rdf:resource="#SinhHoc"/>
#   <lopHoc rdf:resource="#lophoc9"/>
# </GiangDay>
#
# <GiangDay rdf:about="#giangday55">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <giaoVien rdf:resource="#giaovien19"/>
#   <monHoc rdf:resource="#TiengAnh"/>
#   <lopHoc rdf:resource="#lophoc1"/>
# </GiangDay>
#
# <GiangDay rdf:about="#giangday56">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <giaoVien rdf:resource="#giaovien19"/>
#   <monHoc rdf:resource="#TiengAnh"/>
#   <lopHoc rdf:resource="#lophoc2"/>
# </GiangDay>
#
# <GiangDay rdf:about="#giangday57">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <giaoVien rdf:resource="#giaovien19"/>
#   <monHoc rdf:resource="#TiengAnh"/>
#   <lopHoc rdf:resource="#lophoc3"/>
# </GiangDay>
#
# <GiangDay rdf:about="#giangday58">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <giaoVien rdf:resource="#giaovien20"/>
#   <monHoc rdf:resource="#TiengAnh"/>
#   <lopHoc rdf:resource="#lophoc4"/>
# </GiangDay>
#
# <GiangDay rdf:about="#giangday59">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <giaoVien rdf:resource="#giaovien20"/>
#   <monHoc rdf:resource="#TiengAnh"/>
#   <lopHoc rdf:resource="#lophoc5"/>
# </GiangDay>
#
# <GiangDay rdf:about="#giangday60">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <giaoVien rdf:resource="#giaovien20"/>
#   <monHoc rdf:resource="#TiengAnh"/>
#   <lopHoc rdf:resource="#lophoc6"/>
# </GiangDay>
#
# <GiangDay rdf:about="#giangday61">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <giaoVien rdf:resource="#giaovien21"/>
#   <monHoc rdf:resource="#TiengAnh"/>
#   <lopHoc rdf:resource="#lophoc7"/>
# </GiangDay>
#
# <GiangDay rdf:about="#giangday62">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <giaoVien rdf:resource="#giaovien21"/>
#   <monHoc rdf:resource="#TiengAnh"/>
#   <lopHoc rdf:resource="#lophoc8"/>
# </GiangDay>
#
# <GiangDay rdf:about="#giangday63">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <giaoVien rdf:resource="#giaovien21"/>
#   <monHoc rdf:resource="#TiengAnh"/>
#   <lopHoc rdf:resource="#lophoc9"/>
# </GiangDay>
#
# <GiangDay rdf:about="#giangday64">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <giaoVien rdf:resource="#giaovien22"/>
#   <monHoc rdf:resource="#GDCD"/>
#   <lopHoc rdf:resource="#lophoc1"/>
# </GiangDay>
#
# <GiangDay rdf:about="#giangday65">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <giaoVien rdf:resource="#giaovien22"/>
#   <monHoc rdf:resource="#GDCD"/>
#   <lopHoc rdf:resource="#lophoc2"/>
# </GiangDay>
#
# <GiangDay rdf:about="#giangday66">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <giaoVien rdf:resource="#giaovien22"/>
#   <monHoc rdf:resource="#GDCD"/>
#   <lopHoc rdf:resource="#lophoc3"/>
# </GiangDay>
#
# <GiangDay rdf:about="#giangday67">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <giaoVien rdf:resource="#giaovien23"/>
#   <monHoc rdf:resource="#GDCD"/>
#   <lopHoc rdf:resource="#lophoc4"/>
# </GiangDay>
#
# <GiangDay rdf:about="#giangday68">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <giaoVien rdf:resource="#giaovien23"/>
#   <monHoc rdf:resource="#GDCD"/>
#   <lopHoc rdf:resource="#lophoc5"/>
# </GiangDay>
#
# <GiangDay rdf:about="#giangday69">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <giaoVien rdf:resource="#giaovien23"/>
#   <monHoc rdf:resource="#GDCD"/>
#   <lopHoc rdf:resource="#lophoc6"/>
# </GiangDay>
#
# <GiangDay rdf:about="#giangday70">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <giaoVien rdf:resource="#giaovien24"/>
#   <monHoc rdf:resource="#GDCD"/>
#   <lopHoc rdf:resource="#lophoc7"/>
# </GiangDay>
#
# <GiangDay rdf:about="#giangday71">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <giaoVien rdf:resource="#giaovien24"/>
#   <monHoc rdf:resource="#GDCD"/>
#   <lopHoc rdf:resource="#lophoc8"/>
# </GiangDay>
#
# <GiangDay rdf:about="#giangday72">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <giaoVien rdf:resource="#giaovien24"/>
#   <monHoc rdf:resource="#GDCD"/>
#   <lopHoc rdf:resource="#lophoc9"/>
# </GiangDay>
#
# <GiangDay rdf:about="#giangday73">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <giaoVien rdf:resource="#giaovien21"/>
#   <monHoc rdf:resource="#CongNghe"/>
#   <lopHoc rdf:resource="#lophoc1"/>
# </GiangDay>
#
# <GiangDay rdf:about="#giangday74">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <giaoVien rdf:resource="#giaovien21"/>
#   <monHoc rdf:resource="#CongNghe"/>
#   <lopHoc rdf:resource="#lophoc2"/>
# </GiangDay>
#
# <GiangDay rdf:about="#giangday75">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <giaoVien rdf:resource="#giaovien25"/>
#   <monHoc rdf:resource="#CongNghe"/>
#   <lopHoc rdf:resource="#lophoc3"/>
# </GiangDay>
#
# <GiangDay rdf:about="#giangday76">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <giaoVien rdf:resource="#giaovien25"/>
#   <monHoc rdf:resource="#CongNghe"/>
#   <lopHoc rdf:resource="#lophoc4"/>
# </GiangDay>
#
# <GiangDay rdf:about="#giangday77">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <giaoVien rdf:resource="#giaovien26"/>
#   <monHoc rdf:resource="#CongNghe"/>
#   <lopHoc rdf:resource="#lophoc5"/>
# </GiangDay>
#
# <GiangDay rdf:about="#giangday78">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <giaoVien rdf:resource="#giaovien26"/>
#   <monHoc rdf:resource="#CongNghe"/>
#   <lopHoc rdf:resource="#lophoc6"/>
# </GiangDay>
#
# <GiangDay rdf:about="#giangday79">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <giaoVien rdf:resource="#giaovien27"/>
#   <monHoc rdf:resource="#CongNghe"/>
#   <lopHoc rdf:resource="#lophoc7"/>
# </GiangDay>
#
# <GiangDay rdf:about="#giangday80">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <giaoVien rdf:resource="#giaovien27"/>
#   <monHoc rdf:resource="#CongNghe"/>
#   <lopHoc rdf:resource="#lophoc8"/>
# </GiangDay>
#
# <GiangDay rdf:about="#giangday81">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <giaoVien rdf:resource="#giaovien21"/>
#   <monHoc rdf:resource="#CongNghe"/>
#   <lopHoc rdf:resource="#lophoc9"/>
# </GiangDay>
#
#
# </rdf:RDF>

# %%
# Đọc CSDL từ file
onto = get_ontology("../app/data/education.owl").load()

# In DS học sinh ra màn hình
print("Danh sách học sinh:")
stt = 1
for hs in onto.HocSinh.instances():
    print(stt, hs)
    stt += 1
# Out:
# Danh sách học sinh:
# 1 Bùi Minh Cường - 30/04/2000 - Nam - 10C01
# 2 Đào Thanh Xuân - 27/05/2000 - Nữ - 11B02
# 3 Lâm Quý Minh - 19/02/2000 - Khác - 10C01
# 4 Mai Thu Việt - 10/01/2000 - Nam - 10C03
# 5 Bành Kim Vân - 06/06/2000 - Khác - 10C01
# 6 Hồ Hoài Hùng - 21/07/2000 - Nữ - 10C01
# 7 Đoàn Thị Thúy - 14/03/2000 - Nam - 10C01
# 8 Lê Anh Thiên - 21/02/2000 - Nam - 10C02
# 9 Trần Hoài Sơn - 09/12/2000 - Nam - 10C02
# 10 Nguyễn Đình Minh - 24/08/2000 - Nữ - 10C03
# 11 Đoàn Đình Nhật - 07/06/2000 - Nam - 10C02
# 12 Huỳnh Quý Long - 14/06/2000 - Nam - 10C02
# 13 Tăng Hữu Thiên - 30/08/2000 - Khác - 11B02
# 14 Hoàng Bảo Tú - 19/12/2000 - Nam - 10C02
# 15 Đào Hồng Thiên - 25/10/2000 - Khác - 10C03
# 16 Phùng Bảo Tường - 30/07/2000 - Nữ - 10C03
# 17 Lý Anh Nam - 24/05/2000 - Khác - 10C03
# 18 Đoàn Quý Bình - 23/12/2000 - Khác - 12A01
# 19 Trương Thu Tùng - 04/07/2000 - Nữ - 11B01
# 20 Hồ Mai Tường - 06/04/2000 - Khác - 11B01
# 21 Đỗ Đình Thiên - 20/05/2000 - Nữ - 11B01
# 22 Bành Thu Hải - 09/07/2000 - Nữ - 11B01
# 23 Đoàn Thanh Bình - 03/03/2000 - Nữ - 12A02
# 24 Đỗ Mai Thuận - 03/10/2000 - Khác - 11B01
# 25 Huỳnh Hồng Thảo - 11/03/2000 - Nữ - 11B02
# 26 Trương Đình Vân - 19/04/2000 - Khác - 11B02
# 27 Tô Ngọc Tùng - 25/12/2000 - Nam - 12A03
# 28 Lê Thanh Bình - 11/07/2000 - Nữ - 11B02
# 29 Huỳnh Minh Hiền - 17/01/2000 - Nữ - 11B03
# 30 Đinh Quý Nam - 31/12/2000 - Khác - 11B03
# 31 Hồ Hồng Minh - 15/05/2000 - Nữ - 11B03
# 32 Quách Thị Vinh - 25/12/2000 - Nam - 11B03
# 33 Dương Mai Thúy - 17/10/2000 - Khác - 12A02
# 34 Trương Hữu Quỳnh - 29/04/2000 - Khác - 11B03
# 35 Đào Hữu Nam - 15/02/2000 - Nam - 12A01
# 36 Quách Kim Vinh - 24/07/2000 - Nữ - 12A01
# 37 Hoàng Hữu Hiền - 04/11/2000 - Nam - 12A03
# 38 Lương Mai Quân - 12/09/2000 - Khác - 12A01
# 39 Tôn Minh Ngọc - 23/03/2000 - Khác - 12A01
# 40 Đỗ Thanh Ngọc - 25/07/2000 - Khác - 12A03
# 41 Ngô Kim Tú - 27/03/2000 - Nam - 12A02
# 42 Bùi Văn Quỳnh - 03/06/2000 - Khác - 12A02
# 43 Hoàng Hoài Long - 02/02/2000 - Nữ - 12A02
# 44 Đoàn Minh Quỳnh - 07/10/2000 - Nam - 12A03
# 45 Lý Ngọc Thảo - 28/08/2000 - Nữ - 12A03

# %%
# In DS giáo viên
print("Danh sách giáo viên:")
for gv in onto.GiaoVien.instances():
    print(gv.hoTen, gv.ngaySinh, gv.gioiTinh, gv.trinhDo, getattr(gv.lopChuNhiem,'ten',''), *[mon.ten for mon in gv.dayMon])
# Out:
# Danh sách giáo viên:
# Phan Hồng Thuận 11/01/1988 Nữ Đại học  Toán học
# Phùng Đình Thiện 04/03/1985 Khác Thạc sĩ 11B03 Toán học
# Quách Thanh Hiền 19/04/1980 Khác Thạc sĩ 10C01 Toán học
# Tôn Hồng Cường 28/08/1977 Khác Thạc sĩ  Toán học Ngữ văn
# Mai Bảo Tú 12/05/1974 Nam Thạc sĩ  Ngữ văn
# Phạm Thị Dũng 08/06/1981 Khác Thạc sĩ  Ngữ văn
# Lâm Hữu Phương 05/02/1979 Khác Thạc sĩ 12A01 Hóa học
# Võ Anh Hoàng 19/03/1982 Nam Thạc sĩ  Hóa học Lịch sử
# Đinh Bảo Nhật 21/10/1971 Nam Đại học 11B02 Hóa học
# Trương Minh Quân 14/04/1988 Nam Thạc sĩ  Lịch sử
# Phạm Mai Tường 18/03/1987 Nữ Thạc sĩ  Lịch sử
# Bành Mai Linh 10/02/1983 Nữ Thạc sĩ 12A02 Lịch sử
# Nguyễn Minh Khánh 07/12/1981 Nữ Đại học 11B01 Địa lý
# Đoàn Thị Phương 03/11/1989 Nữ Thạc sĩ  Địa lý
# Hồ Quý Cường 24/01/1979 Khác Thạc sĩ  Địa lý
# Bùi Văn Khánh 01/12/1977 Nam Đại học  Lịch sử Sinh học
# Đoàn Thanh Sơn 04/12/1988 Nữ Thạc sĩ  Sinh học
# Hồ Kim Quang 24/07/1986 Nam Đại học  Sinh học
# Phan Thanh Vân 03/03/1981 Khác Đại học  Địa lý Tiếng Anh
# Ngô Ngọc Xuân 14/10/1980 Khác Đại học  Tiếng Anh
# Phạm Hoài Tú 21/10/1978 Nam Thạc sĩ  Tiếng Anh Công nghệ
# Nguyễn Minh Vân 07/10/1985 Khác Thạc sĩ  GDCD
# Tăng Hữu Ngọc 24/12/1985 Nam Đại học 10C03 GDCD
# Lê Hoài Quân 17/06/1990 Nữ Thạc sĩ 10C02 GDCD
# Huỳnh Hoài Long 23/09/1970 Nam Đại học 12A03 Công nghệ
# Tô Anh Vân 05/04/1982 Khác Đại học  Công nghệ
# Bành Kim Ngọc 05/01/1979 Nam Thạc sĩ  Công nghệ

# %%
# In DS HS trong lớp 10A01
print("Danh sách học sinh lớp 10A01:")
for hs in onto.HocSinh.instances():
    if hs.hocLop.ten == "10A01":
        print(hs)
# Out:
# Danh sách học sinh lớp 10A01:

# %%
# in ds GV chủ nhiệm của từng lớp
print("Danh sách giáo viên chủ nhiệm:")
for lop in onto.LopHoc.instances():
    gv = lop.giaoVienChuNhiem
    if gv:
        print(gv.hoTen, gv.ngaySinh, gv.gioiTinh, gv.trinhDo, getattr(gv.lopChuNhiem,'ten',''))
# Out:
# Danh sách giáo viên chủ nhiệm:
# Quách Thanh Hiền 19/04/1980 Khác Thạc sĩ 10C01
# Lê Hoài Quân 17/06/1990 Nữ Thạc sĩ 10C02
# Tăng Hữu Ngọc 24/12/1985 Nam Đại học 10C03
# Nguyễn Minh Khánh 07/12/1981 Nữ Đại học 11B01
# Đinh Bảo Nhật 21/10/1971 Nam Đại học 11B02
# Phùng Đình Thiện 04/03/1985 Khác Thạc sĩ 11B03
# Lâm Hữu Phương 05/02/1979 Khác Thạc sĩ 12A01
# Bành Mai Linh 10/02/1983 Nữ Thạc sĩ 12A02
# Huỳnh Hoài Long 23/09/1970 Nam Đại học 12A03

# %%
# Sửa tên của giáo viên chủ nhiệm Nguyễn Văn X thành Nguyễn Văn Tèo
print("Sửa tên của giáo viên chủ nhiệm Nguyễn Văn X thành Nguyễn Văn Tèo")
for gv in onto.GiaoVien.instances():
    if gv.hoTen == "Nguyễn Văn X":
        gv.hoTen = "Nguyễn Văn Tèo"
        print(gv.hoTen, gv.ngaySinh, gv.gioiTinh, gv.trinhDo, getattr(gv.lopChuNhiem,'ten',''))
# Out:
# Sửa tên của giáo viên chủ nhiệm Nguyễn Văn X thành Nguyễn Văn Tèo

# %%
# Tạo mới một học sinh và thêm vào lớp 10A01
print("Tạo mới một học sinh và thêm vào lớp 10C01")
lop = onto.search_one(ten = "10C01", type = onto.LopHoc)
hs1 = HocSinh(hoTen = "Nguyễn Văn XXX", ngaySinh = "01/01/2011", gioiTinh = "Nam", hocLop = lop)
# In DS HS trong lớp 10A01
print("Danh sách học sinh lớp 10A01:")
print('\n'.join(str(hs) for hs in lop.dsHocSinh))
# Out:
# Tạo mới một học sinh và thêm vào lớp 10C01
# Danh sách học sinh lớp 10A01:
# Bùi Minh Cường - 30/04/2000 - Nam - 10C01
# Lâm Quý Minh - 19/02/2000 - Khác - 10C01
# Bành Kim Vân - 06/06/2000 - Khác - 10C01
# Đoàn Thị Thúy - 14/03/2000 - Nam - 10C01
# Hồ Hoài Hùng - 21/07/2000 - Nữ - 10C01
# Nguyễn Văn XXX - 01/01/2011 - Nam - 10C01

# %%
# Xoá học sinh có ngày sinh là 01/01/2011
print("Xoá học sinh có ngày sinh là 01/01/2011")
hs_ind = onto.search_one(ngaySinh="01/01/2011", type=onto.HocSinh)
# Nếu individual được tìm thấy, xoá individual đó
if hs_ind is not None:
    destroy_entity(hs_ind)
# Out:
# Xoá học sinh có ngày sinh là 01/01/2011

# %%
# In tất cả điểm số của một học sinh
print("In tất cả điểm số của một học sinh")
hs_ind = onto.search_one(type=onto.HocSinh)
if hs_ind is not None:
    for diem in hs_ind.diemSo:
        print(diem.monHoc.ten, *diem.heSo1, *diem.heSo2, *diem.heSo3)
# Out:
# In tất cả điểm số của một học sinh
# Toán học 6.5 10 5.3 1.3 4.5 4.5
# Ngữ văn 8.8 10 9.3 0.3 6.8 8.5
# Hóa học 7.8 5.8 5.5 9.3 2.8 2.3
# Lịch sử 3.8 0.5 4.3 0.3 3.5 0.5
# Địa lý 1.3 7.3 1.8 7.3 10 9.5
# Sinh học 5.5 10 1.5 9.5 7.8 3.8
# Tiếng Anh 4.3 2.8 6.8 6.5 7.3 2.8
# GDCD 0.5 1.3 4.3 6.3 8.3 0.5
# Công nghệ 1.8 8.3 5.8 8.5 9.3

# %%
print(hoTen.iri)
print(HocSinh.iri)
# Out:
# http://hc.com/school#hoTen
# http://hc.com/school#HocSinh

# %%
print('In ra các lớp mà GV dạy')
gv = onto.search_one(type = onto.GiaoVien)
for gd in gv.giangDay:
    print(gd.lopHoc.ten, gd.monHoc.ten)
# Out:
# In ra các lớp mà GV dạy
# 10C01 Toán học
# 10C02 Toán học

# %%
print('In các GV dạy lớp 10C03')
lop = onto.search_one(type = onto.LopHoc, ten = '10C03')
gd = onto.search(type = onto.GiangDay, lopHoc = lop)
for g in gd:
    print(g.giaoVien.hoTen, g.monHoc.ten, g.lopHoc.ten)
# Out:
# In các GV dạy lớp 10C03
# Phùng Đình Thiện Toán học 10C03
# Tôn Hồng Cường Ngữ văn 10C03
# Lâm Hữu Phương Hóa học 10C03
# Phạm Mai Tường Lịch sử 10C03
# Đoàn Thị Phương Địa lý 10C03
# Bùi Văn Khánh Sinh học 10C03
# Phan Thanh Vân Tiếng Anh 10C03
# Nguyễn Minh Vân GDCD 10C03
# Huỳnh Hoài Long Công nghệ 10C03
