# %% [markdown]
# ### Cài đặt thư viện:
#
# Cài đặt các thư viện vào môi trường anaconda:
#
# ```bash
# conda install -c conda-forge owlready2
# ```

# %% [markdown]
# ### Tạo ontology

# %%
# %run ../app/models/model.py

# %%
lsPro = list(onto.properties())
def get_properties(obj):
    return [p for p in lsPro if obj.is_a[0] in p.domain] + [p for p in lsPro if obj in p.domain]
print('STT\tTên lớp\tKế thừa từ\tThuộc tính')
lsClass= list(onto.classes())
for i, class_ in zip(range(len(lsClass)), lsClass):
    print(f"{str(i+1)}\t{class_.name}\t{str(class_.is_a).split('.')[1][:-1]}\t{', '.join([x.name for x in get_properties(class_)])}")
    # print(str(i+1)+'.', class_.name, 'kế thừa từ', class_.is_a)
    # for x in get_properties(class_) :
    #     print('-', x.name, ':', x.range[0])
# Out:
# STT	Tên lớp	Kế thừa từ	Thuộc tính
# 1	ChucVu	Thing	ten, phuCap
# 2	ToChuc	Thing	ten, thanhVien, phong
# 3	Nguoi	Thing	hoTen, ngaySinh, gioiTinh, trangThai, toChuc
# 4	NhanVien	Nguoi	hoTen, ngaySinh, gioiTinh, trangThai, toChuc, heSoLuong, chucVu, phongLamViec
# 5	PhuHuynh	Nguoi	hoTen, ngaySinh, gioiTinh, trangThai, toChuc, ngheNghiep, con
# 6	Cha	PhuHuynh	ngheNghiep, con, vo
# 7	Me	PhuHuynh	ngheNghiep, con, chong
# 8	LopHoc	ToChuc	ten, thanhVien, phong, giaoVienChuNhiem, dsHocSinh
# 9	HocSinh	Nguoi	hoTen, ngaySinh, gioiTinh, trangThai, toChuc, diemTB, hanhKiem, hocLuc, danhHieu, hocLop, phuHuynh, me, cha, diemSo, anhChiEm, anh, chi, em
# 10	Anh	HocSinh	diemTB, hanhKiem, hocLuc, danhHieu, hocLop, phuHuynh, me, cha, diemSo, anhChiEm, anh, chi, em
# 11	Chi	HocSinh	diemTB, hanhKiem, hocLuc, danhHieu, hocLop, phuHuynh, me, cha, diemSo, anhChiEm, anh, chi, em
# 12	Em	HocSinh	diemTB, hanhKiem, hocLuc, danhHieu, hocLop, phuHuynh, me, cha, diemSo, anhChiEm, anh, chi, em
# 13	GiaoVien	NhanVien	heSoLuong, chucVu, phongLamViec, trinhDo, dayMon, giangDay, lopChuNhiem
# 14	MonHoc	Thing	ten, soTiet, giaoVienDay
# 15	DiemSo	Thing	diemTB, tx1, tx2, tx3, gk, ck, hocSinh, monHoc
# 16	GiangDay	Thing	monHoc, giaoVien, lopHoc
# 17	Phong	Thing	ten, loaiPhong, suDungBoi, dsThietBi
# 18	HoatDong	Thing	ten, ngayBatDau, ngayKetThuc, quanLy, thamGia
# 19	DiemDanh	Thing	trangThai, ngayGio, nguoi, hoatDong
# 20	ThietBi	Thing	ten, soLuong, phong

# %%
print('\nSTT\tTên thuộc tính\tDomain\tRange\tLoại')
import re
i=1
for p in lsPro:
    if p.is_a[0].name == 'ObjectProperty': continue
    domains = set([str(d).split('.')[1] for d in p.domain])
    ranges = []
    for r in p.range:
        data = re.findall(r"[\w']+", str(r))
        ranges.append(data[1].replace("'", ''))
    stype = [a.name for a in p.is_a][1:]
    print(f"{i}\t{p.name}\t{', '.join(domains)}\t{', '.join(set(ranges))}\t{', '.join(stype)}")
    i+=1
# Out:
# STT	Tên thuộc tính	Domain	Range	Loại
# 1	ten	ThietBi, ChucVu, MonHoc, Phong, ToChuc, HoatDong	str	FunctionalProperty
# 2	phuCap	ChucVu	float	FunctionalProperty
# 3	hoTen	Nguoi	str	FunctionalProperty
# 4	ngaySinh	Nguoi	datetime	FunctionalProperty
# 5	gioiTinh	Nguoi	str	FunctionalProperty
# 6	trangThai	DiemDanh, Nguoi	str	FunctionalProperty
# 7	heSoLuong	NhanVien	float	FunctionalProperty
# 8	ngheNghiep	PhuHuynh	str	FunctionalProperty
# 9	diemTB	HocSinh, DiemSo	float	FunctionalProperty
# 10	hanhKiem	HocSinh	str	FunctionalProperty
# 11	trinhDo	GiaoVien	str	FunctionalProperty
# 12	soTiet	MonHoc	int	FunctionalProperty
# 13	tx1	DiemSo	float	FunctionalProperty
# 14	tx2	DiemSo	float	FunctionalProperty
# 15	tx3	DiemSo	float	FunctionalProperty
# 16	gk	DiemSo	float	FunctionalProperty
# 17	ck	DiemSo	float	FunctionalProperty
# 18	loaiPhong	Phong	str	FunctionalProperty
# 19	ngayBatDau	HoatDong	datetime	FunctionalProperty
# 20	ngayKetThuc	HoatDong	datetime	FunctionalProperty
# 21	ngayGio	DiemDanh	datetime	FunctionalProperty
# 22	soLuong	ThietBi	int	FunctionalProperty
# 23	hocLuc	HocSinh	str	FunctionalProperty
# 24	danhHieu	HocSinh	str	FunctionalProperty

# %%
print('\nSTT\tTên thuộc tính\tDomain\tRange\tLoại')
import re
i=1
for p in lsPro:
    if p.is_a[0].name != 'ObjectProperty': continue
    domains = set([str(d).split('.')[1] for d in p.domain])
    ranges = []
    for r in p.range:
        data = re.findall(r"[\w']+", str(r))
        ranges.append(data[1].replace("'", ''))
    stype = [a.name for a in p.is_a][1:]
    print(f"{i}\t{p.name}\t{', '.join(domains)}\t{', '.join(set(ranges))}\t{', '.join(stype)}")
    i+=1
# Out:
# STT	Tên thuộc tính	Domain	Range	Loại
# 1	thanhVien	ToChuc	Nguoi
# 2	phong	ThietBi, ToChuc	Phong	FunctionalProperty
# 3	toChuc	Nguoi	ToChuc
# 4	chucVu	NhanVien	ChucVu
# 5	con	PhuHuynh	HocSinh
# 6	giaoVienChuNhiem	LopHoc	GiaoVien	FunctionalProperty
# 7	dsHocSinh	LopHoc	HocSinh
# 8	hocLop	HocSinh	LopHoc	FunctionalProperty
# 9	phuHuynh	HocSinh	PhuHuynh
# 10	me	HocSinh	Me	FunctionalProperty, phuHuynh
# 11	cha	HocSinh	Cha	FunctionalProperty, phuHuynh
# 12	diemSo	HocSinh	DiemSo
# 13	dayMon	GiaoVien	MonHoc
# 14	giangDay	GiaoVien	GiangDay
# 15	lopChuNhiem	GiaoVien	LopHoc	FunctionalProperty
# 16	giaoVienDay	MonHoc	GiaoVien
# 17	hocSinh	DiemSo	HocSinh	FunctionalProperty
# 18	monHoc	GiangDay, DiemSo	MonHoc	FunctionalProperty
# 19	giaoVien	GiangDay	GiaoVien	FunctionalProperty
# 20	lopHoc	GiangDay	LopHoc	FunctionalProperty
# 21	suDungBoi	Phong	ToChuc	FunctionalProperty
# 22	dsThietBi	Phong	ThietBi
# 23	quanLy	HoatDong	Nguoi
# 24	thamGia	HoatDong	Nguoi
# 25	nguoi	DiemDanh	Nguoi	FunctionalProperty
# 26	hoatDong	DiemDanh	HoatDong	FunctionalProperty
# 27	anhChiEm	HocSinh	HocSinh
# 28	anh	HocSinh	Anh	anhChiEm
# 29	chi	HocSinh	Chi	anhChiEm
# 30	em	HocSinh	Em	anhChiEm
# 31	vo	Cha	Me	FunctionalProperty
# 32	chong	Me	Cha	FunctionalProperty
# 33	phongLamViec	NhanVien	Phong

# %%
# Lưu CSDL ra file
onto.save(file="../app/data/education.owl")
with open("../app/data/education.owl", "r") as f:
    print(f.read())
# Out:
# <?xml version="1.0"?>
# <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#"
#          xmlns:xsd="http://www.w3.org/2001/XMLSchema#"
#          xmlns:rdfs="http://www.w3.org/2000/01/rdf-schema#"
#          xmlns:owl="http://www.w3.org/2002/07/owl#"
#          xml:base="http://hc.com/school"
#          xmlns="http://hc.com/school#"
#          xmlns:swrl="http://www.w3.org/2003/11/swrl#">
#
# <owl:Ontology rdf:about="http://hc.com/school"/>
#
# <owl:ObjectProperty rdf:about="#thanhVien">
#   <rdfs:domain rdf:resource="#ToChuc"/>
#   <rdfs:range rdf:resource="#Nguoi"/>
#   <owl:inverseOf rdf:resource="#toChuc"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#phong">
#   <rdfs:domain rdf:resource="#ToChuc"/>
#   <rdfs:range rdf:resource="#Phong"/>
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#ThietBi"/>
#   <owl:inverseOf rdf:resource="#dsThietBi"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#toChuc">
#   <rdfs:domain rdf:resource="#Nguoi"/>
#   <rdfs:range rdf:resource="#ToChuc"/>
#   <owl:inverseOf rdf:resource="#thanhVien"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#chucVu">
#   <rdfs:domain rdf:resource="#NhanVien"/>
#   <rdfs:range rdf:resource="#ChucVu"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#con">
#   <rdfs:domain rdf:resource="#PhuHuynh"/>
#   <rdfs:range rdf:resource="#HocSinh"/>
#   <owl:inverseOf rdf:resource="#phuHuynh"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#giaoVienChuNhiem">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#LopHoc"/>
#   <rdfs:range rdf:resource="#GiaoVien"/>
#   <owl:inverseOf rdf:resource="#lopChuNhiem"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#dsHocSinh">
#   <rdfs:domain rdf:resource="#LopHoc"/>
#   <rdfs:range rdf:resource="#HocSinh"/>
#   <owl:inverseOf rdf:resource="#hocLop"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#hocLop">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#LopHoc"/>
#   <owl:inverseOf rdf:resource="#dsHocSinh"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#phuHuynh">
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#PhuHuynh"/>
#   <owl:inverseOf rdf:resource="#con"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#me">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:subPropertyOf rdf:resource="#phuHuynh"/>
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#Me"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#cha">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:subPropertyOf rdf:resource="#phuHuynh"/>
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#Cha"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#diemSo">
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#DiemSo"/>
#   <owl:inverseOf rdf:resource="#hocSinh"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#dayMon">
#   <rdfs:domain rdf:resource="#GiaoVien"/>
#   <rdfs:range rdf:resource="#MonHoc"/>
#   <owl:inverseOf rdf:resource="#giaoVienDay"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#giangDay">
#   <rdfs:domain rdf:resource="#GiaoVien"/>
#   <rdfs:range rdf:resource="#GiangDay"/>
#   <owl:inverseOf rdf:resource="#giaoVien"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#lopChuNhiem">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#GiaoVien"/>
#   <rdfs:range rdf:resource="#LopHoc"/>
#   <owl:inverseOf rdf:resource="#giaoVienChuNhiem"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#giaoVienDay">
#   <rdfs:domain rdf:resource="#MonHoc"/>
#   <rdfs:range rdf:resource="#GiaoVien"/>
#   <owl:inverseOf rdf:resource="#dayMon"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#hocSinh">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="#HocSinh"/>
#   <owl:inverseOf rdf:resource="#diemSo"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#monHoc">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="#MonHoc"/>
#   <rdfs:domain rdf:resource="#GiangDay"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#giaoVien">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#GiangDay"/>
#   <rdfs:range rdf:resource="#GiaoVien"/>
#   <owl:inverseOf rdf:resource="#giangDay"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#lopHoc">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#GiangDay"/>
#   <rdfs:range rdf:resource="#LopHoc"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#suDungBoi">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Phong"/>
#   <rdfs:range rdf:resource="#ToChuc"/>
#   <owl:inverseOf rdf:resource="#phong"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#dsThietBi">
#   <rdfs:domain rdf:resource="#Phong"/>
#   <rdfs:range rdf:resource="#ThietBi"/>
#   <owl:inverseOf rdf:resource="#phong"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#quanLy">
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:range rdf:resource="#Nguoi"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#thamGia">
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:range rdf:resource="#Nguoi"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#nguoi">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemDanh"/>
#   <rdfs:range rdf:resource="#Nguoi"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#hoatDong">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemDanh"/>
#   <rdfs:range rdf:resource="#HoatDong"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#anhChiEm">
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#HocSinh"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#anh">
#   <rdfs:subPropertyOf rdf:resource="#anhChiEm"/>
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#Anh"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#chi">
#   <rdfs:subPropertyOf rdf:resource="#anhChiEm"/>
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#Chi"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#em">
#   <rdfs:subPropertyOf rdf:resource="#anhChiEm"/>
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#Em"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#vo">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Cha"/>
#   <rdfs:range rdf:resource="#Me"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#chong">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Me"/>
#   <rdfs:range rdf:resource="#Cha"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#phongLamViec">
#   <rdfs:domain rdf:resource="#NhanVien"/>
#   <rdfs:range rdf:resource="#Phong"/>
# </owl:ObjectProperty>
#
# <owl:DatatypeProperty rdf:about="#ten">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#ChucVu"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
#   <rdfs:domain rdf:resource="#ToChuc"/>
#   <rdfs:domain rdf:resource="#MonHoc"/>
#   <rdfs:domain rdf:resource="#Phong"/>
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:domain rdf:resource="#ThietBi"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#phuCap">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#ChucVu"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#hoTen">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Nguoi"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngaySinh">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Nguoi"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#gioiTinh">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Nguoi"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#trangThai">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Nguoi"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
#   <rdfs:domain rdf:resource="#DiemDanh"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#heSoLuong">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#NhanVien"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngheNghiep">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#PhuHuynh"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#diemTB">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
#   <rdfs:domain rdf:resource="#DiemSo"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#hanhKiem">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#trinhDo">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#GiaoVien"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#soTiet">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#MonHoc"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#integer"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#tx1">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#tx2">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#tx3">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#gk">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ck">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#loaiPhong">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Phong"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayBatDau">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayKetThuc">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayGio">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemDanh"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#dateTime"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#soLuong">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#ThietBi"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#integer"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#hocLuc">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#danhHieu">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:Class rdf:about="#ChucVu">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#ToChuc">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#Nguoi">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#NhanVien">
#   <rdfs:subClassOf rdf:resource="#Nguoi"/>
# </owl:Class>
#
# <owl:Class rdf:about="#PhuHuynh">
#   <rdfs:subClassOf rdf:resource="#Nguoi"/>
# </owl:Class>
#
# <owl:Class rdf:about="#Cha">
#   <rdfs:subClassOf rdf:resource="#PhuHuynh"/>
# </owl:Class>
#
# <owl:Class rdf:about="#Me">
#   <rdfs:subClassOf rdf:resource="#PhuHuynh"/>
# </owl:Class>
#
# <owl:Class rdf:about="#LopHoc">
#   <rdfs:subClassOf rdf:resource="#ToChuc"/>
# </owl:Class>
#
# <owl:Class rdf:about="#HocSinh">
#   <rdfs:subClassOf rdf:resource="#Nguoi"/>
# </owl:Class>
#
# <owl:Class rdf:about="#Anh">
#   <rdfs:subClassOf rdf:resource="#HocSinh"/>
# </owl:Class>
#
# <owl:Class rdf:about="#Chi">
#   <rdfs:subClassOf rdf:resource="#HocSinh"/>
# </owl:Class>
#
# <owl:Class rdf:about="#Em">
#   <rdfs:subClassOf rdf:resource="#HocSinh"/>
# </owl:Class>
#
# <owl:Class rdf:about="#GiaoVien">
#   <rdfs:subClassOf rdf:resource="#NhanVien"/>
# </owl:Class>
#
# <owl:Class rdf:about="#MonHoc">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#DiemSo">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#GiangDay">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#Phong">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#HoatDong">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#DiemDanh">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#ThietBi">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <swrl:Variable rdf:about="urn:swrl#hs"/>
#
# <swrl:Variable rdf:about="urn:swrl#c"/>
#
# <swrl:Variable rdf:about="urn:swrl#m"/>
#
# <swrl:Variable rdf:about="urn:swrl#ph1"/>
#
# <swrl:Variable rdf:about="urn:swrl#ph2"/>
#
# <swrl:Variable rdf:about="urn:swrl#ds"/>
#
# <swrl:Variable rdf:about="urn:swrl#d1"/>
#
# <swrl:Variable rdf:about="urn:swrl#d2"/>
#
# <swrl:Variable rdf:about="urn:swrl#d3"/>
#
# <swrl:Variable rdf:about="urn:swrl#d4"/>
#
# <swrl:Variable rdf:about="urn:swrl#d5"/>
#
# <swrl:Variable rdf:about="urn:swrl#t"/>
#
# <swrl:Variable rdf:about="urn:swrl#p"/>
#
# <swrl:Variable rdf:about="urn:swrl#r"/>
#
# <swrl:Variable rdf:about="urn:swrl#rs"/>
#
# <swrl:Variable rdf:about="urn:swrl#dtb"/>
#
# <swrl:Variable rdf:about="urn:swrl#hl"/>
#
# <swrl:Variable rdf:about="urn:swrl#hk"/>
#
# <swrl:Imp>
#   <swrl:body>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:ClassAtom>
#           <swrl:classPredicate rdf:resource="#HocSinh"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#         </swrl:ClassAtom>
#       </rdf:first>
#       <rdf:rest>
#         <rdf:Description>
#           <rdf:first>
#             <swrl:DatavaluedPropertyAtom>
#               <swrl:propertyPredicate rdf:resource="#hocLuc"/>
#               <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#               <swrl:argument2 rdf:resource="urn:swrl#hl"/>
#             </swrl:DatavaluedPropertyAtom>
#           </rdf:first>
#           <rdf:rest>
#             <rdf:Description>
#               <rdf:first>
#                 <swrl:DatavaluedPropertyAtom>
#                   <swrl:propertyPredicate rdf:resource="#hanhKiem"/>
#                   <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#                   <swrl:argument2 rdf:resource="urn:swrl#hk"/>
#                 </swrl:DatavaluedPropertyAtom>
#               </rdf:first>
#               <rdf:rest>
#                 <rdf:Description>
#                   <rdf:first>
#                     <swrl:BuiltinAtom>
#                       <swrl:builtin rdf:resource="http://www.w3.org/2003/11/swrlb#startsWith"/>
#                       <swrl:arguments>
#                         <rdf:Description>
#                           <rdf:first rdf:resource="urn:swrl#hl"/>
#                           <rdf:rest>
#                             <rdf:Description>
#                               <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                               <rdf:first rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Kh</rdf:first>
#                             </rdf:Description>
#                           </rdf:rest>
#                         </rdf:Description>
#                       </swrl:arguments>
#                     </swrl:BuiltinAtom>
#                   </rdf:first>
#                   <rdf:rest>
#                     <rdf:Description>
#                       <rdf:first>
#                         <swrl:BuiltinAtom>
#                           <swrl:builtin rdf:resource="http://www.w3.org/2003/11/swrlb#startsWith"/>
#                           <swrl:arguments>
#                             <rdf:Description>
#                               <rdf:first rdf:resource="urn:swrl#hk"/>
#                               <rdf:rest>
#                                 <rdf:Description>
#                                   <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                                   <rdf:first rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Kh</rdf:first>
#                                 </rdf:Description>
#                               </rdf:rest>
#                             </rdf:Description>
#                           </swrl:arguments>
#                         </swrl:BuiltinAtom>
#                       </rdf:first>
#                       <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                     </rdf:Description>
#                   </rdf:rest>
#                 </rdf:Description>
#               </rdf:rest>
#             </rdf:Description>
#           </rdf:rest>
#         </rdf:Description>
#       </rdf:rest>
#     </rdf:Description>
#   </swrl:body>
#   <swrl:head>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:DatavaluedPropertyAtom>
#           <swrl:propertyPredicate rdf:resource="#danhHieu"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#           <swrl:argument2 rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Học sinh tiên tiến</swrl:argument2>
#         </swrl:DatavaluedPropertyAtom>
#       </rdf:first>
#       <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#     </rdf:Description>
#   </swrl:head>
# </swrl:Imp>
#
# <swrl:Imp>
#   <swrl:body>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:ClassAtom>
#           <swrl:classPredicate rdf:resource="#HocSinh"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#         </swrl:ClassAtom>
#       </rdf:first>
#       <rdf:rest>
#         <rdf:Description>
#           <rdf:first>
#             <swrl:DatavaluedPropertyAtom>
#               <swrl:propertyPredicate rdf:resource="#hocLuc"/>
#               <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#               <swrl:argument2 rdf:resource="urn:swrl#hl"/>
#             </swrl:DatavaluedPropertyAtom>
#           </rdf:first>
#           <rdf:rest>
#             <rdf:Description>
#               <rdf:first>
#                 <swrl:DatavaluedPropertyAtom>
#                   <swrl:propertyPredicate rdf:resource="#hanhKiem"/>
#                   <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#                   <swrl:argument2 rdf:resource="urn:swrl#hk"/>
#                 </swrl:DatavaluedPropertyAtom>
#               </rdf:first>
#               <rdf:rest>
#                 <rdf:Description>
#                   <rdf:first>
#                     <swrl:BuiltinAtom>
#                       <swrl:builtin rdf:resource="http://www.w3.org/2003/11/swrlb#startsWith"/>
#                       <swrl:arguments>
#                         <rdf:Description>
#                           <rdf:first rdf:resource="urn:swrl#hl"/>
#                           <rdf:rest>
#                             <rdf:Description>
#                               <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                               <rdf:first rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Kh</rdf:first>
#                             </rdf:Description>
#                           </rdf:rest>
#                         </rdf:Description>
#                       </swrl:arguments>
#                     </swrl:BuiltinAtom>
#                   </rdf:first>
#                   <rdf:rest>
#                     <rdf:Description>
#                       <rdf:first>
#                         <swrl:BuiltinAtom>
#                           <swrl:builtin rdf:resource="http://www.w3.org/2003/11/swrlb#endsWith"/>
#                           <swrl:arguments>
#                             <rdf:Description>
#                               <rdf:first rdf:resource="urn:swrl#hk"/>
#                               <rdf:rest>
#                                 <rdf:Description>
#                                   <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                                   <rdf:first rdf:datatype="http://www.w3.org/2001/XMLSchema#string">t</rdf:first>
#                                 </rdf:Description>
#                               </rdf:rest>
#                             </rdf:Description>
#                           </swrl:arguments>
#                         </swrl:BuiltinAtom>
#                       </rdf:first>
#                       <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                     </rdf:Description>
#                   </rdf:rest>
#                 </rdf:Description>
#               </rdf:rest>
#             </rdf:Description>
#           </rdf:rest>
#         </rdf:Description>
#       </rdf:rest>
#     </rdf:Description>
#   </swrl:body>
#   <swrl:head>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:DatavaluedPropertyAtom>
#           <swrl:propertyPredicate rdf:resource="#danhHieu"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#           <swrl:argument2 rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Học sinh tiên tiến</swrl:argument2>
#         </swrl:DatavaluedPropertyAtom>
#       </rdf:first>
#       <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#     </rdf:Description>
#   </swrl:head>
# </swrl:Imp>
#
# <swrl:Imp>
#   <swrl:body>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:ClassAtom>
#           <swrl:classPredicate rdf:resource="#HocSinh"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#         </swrl:ClassAtom>
#       </rdf:first>
#       <rdf:rest>
#         <rdf:Description>
#           <rdf:first>
#             <swrl:DatavaluedPropertyAtom>
#               <swrl:propertyPredicate rdf:resource="#hocLuc"/>
#               <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#               <swrl:argument2 rdf:resource="urn:swrl#hl"/>
#             </swrl:DatavaluedPropertyAtom>
#           </rdf:first>
#           <rdf:rest>
#             <rdf:Description>
#               <rdf:first>
#                 <swrl:DatavaluedPropertyAtom>
#                   <swrl:propertyPredicate rdf:resource="#hanhKiem"/>
#                   <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#                   <swrl:argument2 rdf:resource="urn:swrl#hk"/>
#                 </swrl:DatavaluedPropertyAtom>
#               </rdf:first>
#               <rdf:rest>
#                 <rdf:Description>
#                   <rdf:first>
#                     <swrl:BuiltinAtom>
#                       <swrl:builtin rdf:resource="http://www.w3.org/2003/11/swrlb#startsWith"/>
#                       <swrl:arguments>
#                         <rdf:Description>
#                           <rdf:first rdf:resource="urn:swrl#hl"/>
#                           <rdf:rest>
#                             <rdf:Description>
#                               <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                               <rdf:first rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Gi</rdf:first>
#                             </rdf:Description>
#                           </rdf:rest>
#                         </rdf:Description>
#                       </swrl:arguments>
#                     </swrl:BuiltinAtom>
#                   </rdf:first>
#                   <rdf:rest>
#                     <rdf:Description>
#                       <rdf:first>
#                         <swrl:BuiltinAtom>
#                           <swrl:builtin rdf:resource="http://www.w3.org/2003/11/swrlb#startsWith"/>
#                           <swrl:arguments>
#                             <rdf:Description>
#                               <rdf:first rdf:resource="urn:swrl#hk"/>
#                               <rdf:rest>
#                                 <rdf:Description>
#                                   <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                                   <rdf:first rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Kh</rdf:first>
#                                 </rdf:Description>
#                               </rdf:rest>
#                             </rdf:Description>
#                           </swrl:arguments>
#                         </swrl:BuiltinAtom>
#                       </rdf:first>
#                       <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                     </rdf:Description>
#                   </rdf:rest>
#                 </rdf:Description>
#               </rdf:rest>
#             </rdf:Description>
#           </rdf:rest>
#         </rdf:Description>
#       </rdf:rest>
#     </rdf:Description>
#   </swrl:body>
#   <swrl:head>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:DatavaluedPropertyAtom>
#           <swrl:propertyPredicate rdf:resource="#danhHieu"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#           <swrl:argument2 rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Học sinh giỏi</swrl:argument2>
#         </swrl:DatavaluedPropertyAtom>
#       </rdf:first>
#       <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#     </rdf:Description>
#   </swrl:head>
# </swrl:Imp>
#
# <swrl:Imp>
#   <swrl:body>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:ClassAtom>
#           <swrl:classPredicate rdf:resource="#HocSinh"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#         </swrl:ClassAtom>
#       </rdf:first>
#       <rdf:rest>
#         <rdf:Description>
#           <rdf:first>
#             <swrl:DatavaluedPropertyAtom>
#               <swrl:propertyPredicate rdf:resource="#hocLuc"/>
#               <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#               <swrl:argument2 rdf:resource="urn:swrl#hl"/>
#             </swrl:DatavaluedPropertyAtom>
#           </rdf:first>
#           <rdf:rest>
#             <rdf:Description>
#               <rdf:first>
#                 <swrl:DatavaluedPropertyAtom>
#                   <swrl:propertyPredicate rdf:resource="#hanhKiem"/>
#                   <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#                   <swrl:argument2 rdf:resource="urn:swrl#hk"/>
#                 </swrl:DatavaluedPropertyAtom>
#               </rdf:first>
#               <rdf:rest>
#                 <rdf:Description>
#                   <rdf:first>
#                     <swrl:BuiltinAtom>
#                       <swrl:builtin rdf:resource="http://www.w3.org/2003/11/swrlb#startsWith"/>
#                       <swrl:arguments>
#                         <rdf:Description>
#                           <rdf:first rdf:resource="urn:swrl#hl"/>
#                           <rdf:rest>
#                             <rdf:Description>
#                               <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                               <rdf:first rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Gi</rdf:first>
#                             </rdf:Description>
#                           </rdf:rest>
#                         </rdf:Description>
#                       </swrl:arguments>
#                     </swrl:BuiltinAtom>
#                   </rdf:first>
#                   <rdf:rest>
#                     <rdf:Description>
#                       <rdf:first>
#                         <swrl:BuiltinAtom>
#                           <swrl:builtin rdf:resource="http://www.w3.org/2003/11/swrlb#endsWith"/>
#                           <swrl:arguments>
#                             <rdf:Description>
#                               <rdf:first rdf:resource="urn:swrl#hk"/>
#                               <rdf:rest>
#                                 <rdf:Description>
#                                   <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                                   <rdf:first rdf:datatype="http://www.w3.org/2001/XMLSchema#string">t</rdf:first>
#                                 </rdf:Description>
#                               </rdf:rest>
#                             </rdf:Description>
#                           </swrl:arguments>
#                         </swrl:BuiltinAtom>
#                       </rdf:first>
#                       <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                     </rdf:Description>
#                   </rdf:rest>
#                 </rdf:Description>
#               </rdf:rest>
#             </rdf:Description>
#           </rdf:rest>
#         </rdf:Description>
#       </rdf:rest>
#     </rdf:Description>
#   </swrl:body>
#   <swrl:head>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:DatavaluedPropertyAtom>
#           <swrl:propertyPredicate rdf:resource="#danhHieu"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#           <swrl:argument2 rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Học sinh giỏi</swrl:argument2>
#         </swrl:DatavaluedPropertyAtom>
#       </rdf:first>
#       <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#     </rdf:Description>
#   </swrl:head>
# </swrl:Imp>
#
# <swrl:Imp>
#   <swrl:body>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:ClassAtom>
#           <swrl:classPredicate rdf:resource="#HocSinh"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#         </swrl:ClassAtom>
#       </rdf:first>
#       <rdf:rest>
#         <rdf:Description>
#           <rdf:first>
#             <swrl:DatavaluedPropertyAtom>
#               <swrl:propertyPredicate rdf:resource="#diemTB"/>
#               <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#               <swrl:argument2 rdf:resource="urn:swrl#dtb"/>
#             </swrl:DatavaluedPropertyAtom>
#           </rdf:first>
#           <rdf:rest>
#             <rdf:Description>
#               <rdf:first>
#                 <swrl:BuiltinAtom>
#                   <swrl:builtin rdf:resource="http://www.w3.org/2003/11/swrlb#lessThan"/>
#                   <swrl:arguments>
#                     <rdf:Description>
#                       <rdf:first rdf:resource="urn:swrl#dtb"/>
#                       <rdf:rest>
#                         <rdf:Description>
#                           <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                           <rdf:first rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">5.0</rdf:first>
#                         </rdf:Description>
#                       </rdf:rest>
#                     </rdf:Description>
#                   </swrl:arguments>
#                 </swrl:BuiltinAtom>
#               </rdf:first>
#               <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#             </rdf:Description>
#           </rdf:rest>
#         </rdf:Description>
#       </rdf:rest>
#     </rdf:Description>
#   </swrl:body>
#   <swrl:head>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:DatavaluedPropertyAtom>
#           <swrl:propertyPredicate rdf:resource="#hocLuc"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#           <swrl:argument2 rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Yếu</swrl:argument2>
#         </swrl:DatavaluedPropertyAtom>
#       </rdf:first>
#       <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#     </rdf:Description>
#   </swrl:head>
# </swrl:Imp>
#
# <swrl:Imp>
#   <swrl:body>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:ClassAtom>
#           <swrl:classPredicate rdf:resource="#HocSinh"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#         </swrl:ClassAtom>
#       </rdf:first>
#       <rdf:rest>
#         <rdf:Description>
#           <rdf:first>
#             <swrl:DatavaluedPropertyAtom>
#               <swrl:propertyPredicate rdf:resource="#diemTB"/>
#               <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#               <swrl:argument2 rdf:resource="urn:swrl#dtb"/>
#             </swrl:DatavaluedPropertyAtom>
#           </rdf:first>
#           <rdf:rest>
#             <rdf:Description>
#               <rdf:first>
#                 <swrl:BuiltinAtom>
#                   <swrl:builtin rdf:resource="http://www.w3.org/2003/11/swrlb#greaterThanOrEqual"/>
#                   <swrl:arguments>
#                     <rdf:Description>
#                       <rdf:first rdf:resource="urn:swrl#dtb"/>
#                       <rdf:rest>
#                         <rdf:Description>
#                           <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                           <rdf:first rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">5.0</rdf:first>
#                         </rdf:Description>
#                       </rdf:rest>
#                     </rdf:Description>
#                   </swrl:arguments>
#                 </swrl:BuiltinAtom>
#               </rdf:first>
#               <rdf:rest>
#                 <rdf:Description>
#                   <rdf:first>
#                     <swrl:BuiltinAtom>
#                       <swrl:builtin rdf:resource="http://www.w3.org/2003/11/swrlb#lessThan"/>
#                       <swrl:arguments>
#                         <rdf:Description>
#                           <rdf:first rdf:resource="urn:swrl#dtb"/>
#                           <rdf:rest>
#                             <rdf:Description>
#                               <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                               <rdf:first rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">6.5</rdf:first>
#                             </rdf:Description>
#                           </rdf:rest>
#                         </rdf:Description>
#                       </swrl:arguments>
#                     </swrl:BuiltinAtom>
#                   </rdf:first>
#                   <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                 </rdf:Description>
#               </rdf:rest>
#             </rdf:Description>
#           </rdf:rest>
#         </rdf:Description>
#       </rdf:rest>
#     </rdf:Description>
#   </swrl:body>
#   <swrl:head>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:DatavaluedPropertyAtom>
#           <swrl:propertyPredicate rdf:resource="#hocLuc"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#           <swrl:argument2 rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Trung bình</swrl:argument2>
#         </swrl:DatavaluedPropertyAtom>
#       </rdf:first>
#       <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#     </rdf:Description>
#   </swrl:head>
# </swrl:Imp>
#
# <swrl:Imp>
#   <swrl:body>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:ClassAtom>
#           <swrl:classPredicate rdf:resource="#HocSinh"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#         </swrl:ClassAtom>
#       </rdf:first>
#       <rdf:rest>
#         <rdf:Description>
#           <rdf:first>
#             <swrl:DatavaluedPropertyAtom>
#               <swrl:propertyPredicate rdf:resource="#diemTB"/>
#               <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#               <swrl:argument2 rdf:resource="urn:swrl#dtb"/>
#             </swrl:DatavaluedPropertyAtom>
#           </rdf:first>
#           <rdf:rest>
#             <rdf:Description>
#               <rdf:first>
#                 <swrl:BuiltinAtom>
#                   <swrl:builtin rdf:resource="http://www.w3.org/2003/11/swrlb#greaterThanOrEqual"/>
#                   <swrl:arguments>
#                     <rdf:Description>
#                       <rdf:first rdf:resource="urn:swrl#dtb"/>
#                       <rdf:rest>
#                         <rdf:Description>
#                           <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                           <rdf:first rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">6.5</rdf:first>
#                         </rdf:Description>
#                       </rdf:rest>
#                     </rdf:Description>
#                   </swrl:arguments>
#                 </swrl:BuiltinAtom>
#               </rdf:first>
#               <rdf:rest>
#                 <rdf:Description>
#                   <rdf:first>
#                     <swrl:BuiltinAtom>
#                       <swrl:builtin rdf:resource="http://www.w3.org/2003/11/swrlb#lessThan"/>
#                       <swrl:arguments>
#                         <rdf:Description>
#                           <rdf:first rdf:resource="urn:swrl#dtb"/>
#                           <rdf:rest>
#                             <rdf:Description>
#                               <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                               <rdf:first rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">8.0</rdf:first>
#                             </rdf:Description>
#                           </rdf:rest>
#                         </rdf:Description>
#                       </swrl:arguments>
#                     </swrl:BuiltinAtom>
#                   </rdf:first>
#                   <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                 </rdf:Description>
#               </rdf:rest>
#             </rdf:Description>
#           </rdf:rest>
#         </rdf:Description>
#       </rdf:rest>
#     </rdf:Description>
#   </swrl:body>
#   <swrl:head>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:DatavaluedPropertyAtom>
#           <swrl:propertyPredicate rdf:resource="#hocLuc"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#           <swrl:argument2 rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khá</swrl:argument2>
#         </swrl:DatavaluedPropertyAtom>
#       </rdf:first>
#       <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#     </rdf:Description>
#   </swrl:head>
# </swrl:Imp>
#
# <swrl:Imp>
#   <swrl:body>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:ClassAtom>
#           <swrl:classPredicate rdf:resource="#HocSinh"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#         </swrl:ClassAtom>
#       </rdf:first>
#       <rdf:rest>
#         <rdf:Description>
#           <rdf:first>
#             <swrl:DatavaluedPropertyAtom>
#               <swrl:propertyPredicate rdf:resource="#diemTB"/>
#               <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#               <swrl:argument2 rdf:resource="urn:swrl#dtb"/>
#             </swrl:DatavaluedPropertyAtom>
#           </rdf:first>
#           <rdf:rest>
#             <rdf:Description>
#               <rdf:first>
#                 <swrl:BuiltinAtom>
#                   <swrl:builtin rdf:resource="http://www.w3.org/2003/11/swrlb#greaterThanOrEqual"/>
#                   <swrl:arguments>
#                     <rdf:Description>
#                       <rdf:first rdf:resource="urn:swrl#dtb"/>
#                       <rdf:rest>
#                         <rdf:Description>
#                           <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                           <rdf:first rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">8.0</rdf:first>
#                         </rdf:Description>
#                       </rdf:rest>
#                     </rdf:Description>
#                   </swrl:arguments>
#                 </swrl:BuiltinAtom>
#               </rdf:first>
#               <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#             </rdf:Description>
#           </rdf:rest>
#         </rdf:Description>
#       </rdf:rest>
#     </rdf:Description>
#   </swrl:body>
#   <swrl:head>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:DatavaluedPropertyAtom>
#           <swrl:propertyPredicate rdf:resource="#hocLuc"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#           <swrl:argument2 rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Giỏi</swrl:argument2>
#         </swrl:DatavaluedPropertyAtom>
#       </rdf:first>
#       <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#     </rdf:Description>
#   </swrl:head>
# </swrl:Imp>
#
# <swrl:Imp>
#   <swrl:body>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:ClassAtom>
#           <swrl:classPredicate rdf:resource="#DiemSo"/>
#           <swrl:argument1 rdf:resource="urn:swrl#ds"/>
#         </swrl:ClassAtom>
#       </rdf:first>
#       <rdf:rest>
#         <rdf:Description>
#           <rdf:first>
#             <swrl:DatavaluedPropertyAtom>
#               <swrl:propertyPredicate rdf:resource="#tx1"/>
#               <swrl:argument1 rdf:resource="urn:swrl#ds"/>
#               <swrl:argument2 rdf:resource="urn:swrl#d1"/>
#             </swrl:DatavaluedPropertyAtom>
#           </rdf:first>
#           <rdf:rest>
#             <rdf:Description>
#               <rdf:first>
#                 <swrl:DatavaluedPropertyAtom>
#                   <swrl:propertyPredicate rdf:resource="#tx2"/>
#                   <swrl:argument1 rdf:resource="urn:swrl#ds"/>
#                   <swrl:argument2 rdf:resource="urn:swrl#d2"/>
#                 </swrl:DatavaluedPropertyAtom>
#               </rdf:first>
#               <rdf:rest>
#                 <rdf:Description>
#                   <rdf:first>
#                     <swrl:DatavaluedPropertyAtom>
#                       <swrl:propertyPredicate rdf:resource="#tx3"/>
#                       <swrl:argument1 rdf:resource="urn:swrl#ds"/>
#                       <swrl:argument2 rdf:resource="urn:swrl#d3"/>
#                     </swrl:DatavaluedPropertyAtom>
#                   </rdf:first>
#                   <rdf:rest>
#                     <rdf:Description>
#                       <rdf:first>
#                         <swrl:DatavaluedPropertyAtom>
#                           <swrl:propertyPredicate rdf:resource="#gk"/>
#                           <swrl:argument1 rdf:resource="urn:swrl#ds"/>
#                           <swrl:argument2 rdf:resource="urn:swrl#d4"/>
#                         </swrl:DatavaluedPropertyAtom>
#                       </rdf:first>
#                       <rdf:rest>
#                         <rdf:Description>
#                           <rdf:first>
#                             <swrl:DatavaluedPropertyAtom>
#                               <swrl:propertyPredicate rdf:resource="#ck"/>
#                               <swrl:argument1 rdf:resource="urn:swrl#ds"/>
#                               <swrl:argument2 rdf:resource="urn:swrl#d5"/>
#                             </swrl:DatavaluedPropertyAtom>
#                           </rdf:first>
#                           <rdf:rest>
#                             <rdf:Description>
#                               <rdf:first>
#                                 <swrl:BuiltinAtom>
#                                   <swrl:builtin rdf:resource="http://www.w3.org/2003/11/swrlb#add"/>
#                                   <swrl:arguments>
#                                     <rdf:Description>
#                                       <rdf:first rdf:resource="urn:swrl#t"/>
#                                       <rdf:rest>
#                                         <rdf:Description>
#                                           <rdf:first rdf:resource="urn:swrl#d1"/>
#                                           <rdf:rest>
#                                             <rdf:Description>
#                                               <rdf:first rdf:resource="urn:swrl#d2"/>
#                                               <rdf:rest>
#                                                 <rdf:Description>
#                                                   <rdf:first rdf:resource="urn:swrl#d3"/>
#                                                   <rdf:rest>
#                                                     <rdf:Description>
#                                                       <rdf:first rdf:resource="urn:swrl#d4"/>
#                                                       <rdf:rest>
#                                                         <rdf:Description>
#                                                           <rdf:first rdf:resource="urn:swrl#d4"/>
#                                                           <rdf:rest>
#                                                             <rdf:Description>
#                                                               <rdf:first rdf:resource="urn:swrl#d5"/>
#                                                               <rdf:rest>
#                                                                 <rdf:Description>
#                                                                   <rdf:first rdf:resource="urn:swrl#d5"/>
#                                                                   <rdf:rest>
#                                                                     <rdf:Description>
#                                                                       <rdf:first rdf:resource="urn:swrl#d5"/>
#                                                                       <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                                                                     </rdf:Description>
#                                                                   </rdf:rest>
#                                                                 </rdf:Description>
#                                                               </rdf:rest>
#                                                             </rdf:Description>
#                                                           </rdf:rest>
#                                                         </rdf:Description>
#                                                       </rdf:rest>
#                                                     </rdf:Description>
#                                                   </rdf:rest>
#                                                 </rdf:Description>
#                                               </rdf:rest>
#                                             </rdf:Description>
#                                           </rdf:rest>
#                                         </rdf:Description>
#                                       </rdf:rest>
#                                     </rdf:Description>
#                                   </swrl:arguments>
#                                 </swrl:BuiltinAtom>
#                               </rdf:first>
#                               <rdf:rest>
#                                 <rdf:Description>
#                                   <rdf:first>
#                                     <swrl:BuiltinAtom>
#                                       <swrl:builtin rdf:resource="http://www.w3.org/2003/11/swrlb#multiply"/>
#                                       <swrl:arguments>
#                                         <rdf:Description>
#                                           <rdf:first rdf:resource="urn:swrl#p"/>
#                                           <rdf:rest>
#                                             <rdf:Description>
#                                               <rdf:first rdf:resource="urn:swrl#t"/>
#                                               <rdf:rest>
#                                                 <rdf:Description>
#                                                   <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                                                   <rdf:first rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">100</rdf:first>
#                                                 </rdf:Description>
#                                               </rdf:rest>
#                                             </rdf:Description>
#                                           </rdf:rest>
#                                         </rdf:Description>
#                                       </swrl:arguments>
#                                     </swrl:BuiltinAtom>
#                                   </rdf:first>
#                                   <rdf:rest>
#                                     <rdf:Description>
#                                       <rdf:first>
#                                         <swrl:BuiltinAtom>
#                                           <swrl:builtin rdf:resource="http://www.w3.org/2003/11/swrlb#divide"/>
#                                           <swrl:arguments>
#                                             <rdf:Description>
#                                               <rdf:first rdf:resource="urn:swrl#c"/>
#                                               <rdf:rest>
#                                                 <rdf:Description>
#                                                   <rdf:first rdf:resource="urn:swrl#p"/>
#                                                   <rdf:rest>
#                                                     <rdf:Description>
#                                                       <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                                                       <rdf:first rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">8</rdf:first>
#                                                     </rdf:Description>
#                                                   </rdf:rest>
#                                                 </rdf:Description>
#                                               </rdf:rest>
#                                             </rdf:Description>
#                                           </swrl:arguments>
#                                         </swrl:BuiltinAtom>
#                                       </rdf:first>
#                                       <rdf:rest>
#                                         <rdf:Description>
#                                           <rdf:first>
#                                             <swrl:BuiltinAtom>
#                                               <swrl:builtin rdf:resource="http://www.w3.org/2003/11/swrlb#floor"/>
#                                               <swrl:arguments>
#                                                 <rdf:Description>
#                                                   <rdf:first rdf:resource="urn:swrl#r"/>
#                                                   <rdf:rest>
#                                                     <rdf:Description>
#                                                       <rdf:first rdf:resource="urn:swrl#c"/>
#                                                       <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                                                     </rdf:Description>
#                                                   </rdf:rest>
#                                                 </rdf:Description>
#                                               </swrl:arguments>
#                                             </swrl:BuiltinAtom>
#                                           </rdf:first>
#                                           <rdf:rest>
#                                             <rdf:Description>
#                                               <rdf:first>
#                                                 <swrl:BuiltinAtom>
#                                                   <swrl:builtin rdf:resource="http://www.w3.org/2003/11/swrlb#divide"/>
#                                                   <swrl:arguments>
#                                                     <rdf:Description>
#                                                       <rdf:first rdf:resource="urn:swrl#rs"/>
#                                                       <rdf:rest>
#                                                         <rdf:Description>
#                                                           <rdf:first rdf:resource="urn:swrl#r"/>
#                                                           <rdf:rest>
#                                                             <rdf:Description>
#                                                               <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                                                               <rdf:first rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">100</rdf:first>
#                                                             </rdf:Description>
#                                                           </rdf:rest>
#                                                         </rdf:Description>
#                                                       </rdf:rest>
#                                                     </rdf:Description>
#                                                   </swrl:arguments>
#                                                 </swrl:BuiltinAtom>
#                                               </rdf:first>
#                                               <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                                             </rdf:Description>
#                                           </rdf:rest>
#                                         </rdf:Description>
#                                       </rdf:rest>
#                                     </rdf:Description>
#                                   </rdf:rest>
#                                 </rdf:Description>
#                               </rdf:rest>
#                             </rdf:Description>
#                           </rdf:rest>
#                         </rdf:Description>
#                       </rdf:rest>
#                     </rdf:Description>
#                   </rdf:rest>
#                 </rdf:Description>
#               </rdf:rest>
#             </rdf:Description>
#           </rdf:rest>
#         </rdf:Description>
#       </rdf:rest>
#     </rdf:Description>
#   </swrl:body>
#   <swrl:head>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:DatavaluedPropertyAtom>
#           <swrl:propertyPredicate rdf:resource="#diemTB"/>
#           <swrl:argument1 rdf:resource="urn:swrl#ds"/>
#           <swrl:argument2 rdf:resource="urn:swrl#rs"/>
#         </swrl:DatavaluedPropertyAtom>
#       </rdf:first>
#       <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#     </rdf:Description>
#   </swrl:head>
# </swrl:Imp>
#
# <swrl:Imp>
#   <swrl:body>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:ClassAtom>
#           <swrl:classPredicate rdf:resource="#HocSinh"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#         </swrl:ClassAtom>
#       </rdf:first>
#       <rdf:rest>
#         <rdf:Description>
#           <rdf:first>
#             <swrl:IndividualPropertyAtom>
#               <swrl:propertyPredicate rdf:resource="#cha"/>
#               <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#               <swrl:argument2 rdf:resource="urn:swrl#ph1"/>
#             </swrl:IndividualPropertyAtom>
#           </rdf:first>
#           <rdf:rest>
#             <rdf:Description>
#               <rdf:first>
#                 <swrl:IndividualPropertyAtom>
#                   <swrl:propertyPredicate rdf:resource="#me"/>
#                   <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#                   <swrl:argument2 rdf:resource="urn:swrl#ph2"/>
#                 </swrl:IndividualPropertyAtom>
#               </rdf:first>
#               <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#             </rdf:Description>
#           </rdf:rest>
#         </rdf:Description>
#       </rdf:rest>
#     </rdf:Description>
#   </swrl:body>
#   <swrl:head>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:IndividualPropertyAtom>
#           <swrl:propertyPredicate rdf:resource="#vo"/>
#           <swrl:argument1 rdf:resource="urn:swrl#ph1"/>
#           <swrl:argument2 rdf:resource="urn:swrl#ph2"/>
#         </swrl:IndividualPropertyAtom>
#       </rdf:first>
#       <rdf:rest>
#         <rdf:Description>
#           <rdf:first>
#             <swrl:IndividualPropertyAtom>
#               <swrl:propertyPredicate rdf:resource="#chong"/>
#               <swrl:argument1 rdf:resource="urn:swrl#ph2"/>
#               <swrl:argument2 rdf:resource="urn:swrl#ph1"/>
#             </swrl:IndividualPropertyAtom>
#           </rdf:first>
#           <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#         </rdf:Description>
#       </rdf:rest>
#     </rdf:Description>
#   </swrl:head>
# </swrl:Imp>
#
# <swrl:Imp>
#   <swrl:body>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:ClassAtom>
#           <swrl:classPredicate rdf:resource="#HocSinh"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#         </swrl:ClassAtom>
#       </rdf:first>
#       <rdf:rest>
#         <rdf:Description>
#           <rdf:first>
#             <swrl:IndividualPropertyAtom>
#               <swrl:propertyPredicate rdf:resource="#cha"/>
#               <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#               <swrl:argument2 rdf:resource="urn:swrl#c"/>
#             </swrl:IndividualPropertyAtom>
#           </rdf:first>
#           <rdf:rest>
#             <rdf:Description>
#               <rdf:first>
#                 <swrl:IndividualPropertyAtom>
#                   <swrl:propertyPredicate rdf:resource="#me"/>
#                   <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#                   <swrl:argument2 rdf:resource="urn:swrl#m"/>
#                 </swrl:IndividualPropertyAtom>
#               </rdf:first>
#               <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#             </rdf:Description>
#           </rdf:rest>
#         </rdf:Description>
#       </rdf:rest>
#     </rdf:Description>
#   </swrl:body>
#   <swrl:head>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:IndividualPropertyAtom>
#           <swrl:propertyPredicate rdf:resource="#phuHuynh"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#           <swrl:argument2 rdf:resource="urn:swrl#c"/>
#         </swrl:IndividualPropertyAtom>
#       </rdf:first>
#       <rdf:rest>
#         <rdf:Description>
#           <rdf:first>
#             <swrl:IndividualPropertyAtom>
#               <swrl:propertyPredicate rdf:resource="#phuHuynh"/>
#               <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#               <swrl:argument2 rdf:resource="urn:swrl#m"/>
#             </swrl:IndividualPropertyAtom>
#           </rdf:first>
#           <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#         </rdf:Description>
#       </rdf:rest>
#     </rdf:Description>
#   </swrl:head>
# </swrl:Imp>
#
#
# </rdf:RDF>

# %% [markdown]
# ### Thêm dữ liệu

# %%
# # Đọc CSDL từ file
# onto = get_ontology("../app/data/education.owl").load()

# %%
# %run ../app/models/data.py
create_Data(soLopMoiKhoi = 3, soHSMoiLop = 5, soHSCoAnhEm = 20, soGVMoiMon = 3, soGVDay2Mon = 5)
# Lưu CSDL ra file
onto.save(file="../app/data/education.owl", format='rdfxml') # 'ntriples' / "rdfxml"
with open("../app/data/education.owl", "r") as f:
    print(f.read())
# Out:
# <?xml version="1.0"?>
# <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#"
#          xmlns:xsd="http://www.w3.org/2001/XMLSchema#"
#          xmlns:rdfs="http://www.w3.org/2000/01/rdf-schema#"
#          xmlns:owl="http://www.w3.org/2002/07/owl#"
#          xml:base="http://hc.com/school"
#          xmlns="http://hc.com/school#"
#          xmlns:swrl="http://www.w3.org/2003/11/swrl#">
#
# <owl:Ontology rdf:about="http://hc.com/school"/>
#
# <owl:ObjectProperty rdf:about="#thanhVien">
#   <rdfs:domain rdf:resource="#ToChuc"/>
#   <rdfs:range rdf:resource="#Nguoi"/>
#   <owl:inverseOf rdf:resource="#toChuc"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#phong">
#   <rdfs:domain rdf:resource="#ToChuc"/>
#   <rdfs:range rdf:resource="#Phong"/>
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#ThietBi"/>
#   <owl:inverseOf rdf:resource="#dsThietBi"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#toChuc">
#   <rdfs:domain rdf:resource="#Nguoi"/>
#   <rdfs:range rdf:resource="#ToChuc"/>
#   <owl:inverseOf rdf:resource="#thanhVien"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#chucVu">
#   <rdfs:domain rdf:resource="#NhanVien"/>
#   <rdfs:range rdf:resource="#ChucVu"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#con">
#   <rdfs:domain rdf:resource="#PhuHuynh"/>
#   <rdfs:range rdf:resource="#HocSinh"/>
#   <owl:inverseOf rdf:resource="#phuHuynh"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#giaoVienChuNhiem">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#LopHoc"/>
#   <rdfs:range rdf:resource="#GiaoVien"/>
#   <owl:inverseOf rdf:resource="#lopChuNhiem"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#dsHocSinh">
#   <rdfs:domain rdf:resource="#LopHoc"/>
#   <rdfs:range rdf:resource="#HocSinh"/>
#   <owl:inverseOf rdf:resource="#hocLop"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#hocLop">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#LopHoc"/>
#   <owl:inverseOf rdf:resource="#dsHocSinh"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#phuHuynh">
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#PhuHuynh"/>
#   <owl:inverseOf rdf:resource="#con"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#me">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:subPropertyOf rdf:resource="#phuHuynh"/>
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#Me"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#cha">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:subPropertyOf rdf:resource="#phuHuynh"/>
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#Cha"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#diemSo">
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#DiemSo"/>
#   <owl:inverseOf rdf:resource="#hocSinh"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#dayMon">
#   <rdfs:domain rdf:resource="#GiaoVien"/>
#   <rdfs:range rdf:resource="#MonHoc"/>
#   <owl:inverseOf rdf:resource="#giaoVienDay"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#giangDay">
#   <rdfs:domain rdf:resource="#GiaoVien"/>
#   <rdfs:range rdf:resource="#GiangDay"/>
#   <owl:inverseOf rdf:resource="#giaoVien"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#lopChuNhiem">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#GiaoVien"/>
#   <rdfs:range rdf:resource="#LopHoc"/>
#   <owl:inverseOf rdf:resource="#giaoVienChuNhiem"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#giaoVienDay">
#   <rdfs:domain rdf:resource="#MonHoc"/>
#   <rdfs:range rdf:resource="#GiaoVien"/>
#   <owl:inverseOf rdf:resource="#dayMon"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#hocSinh">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="#HocSinh"/>
#   <owl:inverseOf rdf:resource="#diemSo"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#monHoc">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="#MonHoc"/>
#   <rdfs:domain rdf:resource="#GiangDay"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#giaoVien">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#GiangDay"/>
#   <rdfs:range rdf:resource="#GiaoVien"/>
#   <owl:inverseOf rdf:resource="#giangDay"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#lopHoc">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#GiangDay"/>
#   <rdfs:range rdf:resource="#LopHoc"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#suDungBoi">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Phong"/>
#   <rdfs:range rdf:resource="#ToChuc"/>
#   <owl:inverseOf rdf:resource="#phong"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#dsThietBi">
#   <rdfs:domain rdf:resource="#Phong"/>
#   <rdfs:range rdf:resource="#ThietBi"/>
#   <owl:inverseOf rdf:resource="#phong"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#quanLy">
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:range rdf:resource="#Nguoi"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#thamGia">
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:range rdf:resource="#Nguoi"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#nguoi">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemDanh"/>
#   <rdfs:range rdf:resource="#Nguoi"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#hoatDong">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemDanh"/>
#   <rdfs:range rdf:resource="#HoatDong"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#anhChiEm">
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#HocSinh"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#anh">
#   <rdfs:subPropertyOf rdf:resource="#anhChiEm"/>
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#Anh"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#chi">
#   <rdfs:subPropertyOf rdf:resource="#anhChiEm"/>
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#Chi"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#em">
#   <rdfs:subPropertyOf rdf:resource="#anhChiEm"/>
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#Em"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#vo">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Cha"/>
#   <rdfs:range rdf:resource="#Me"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#chong">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Me"/>
#   <rdfs:range rdf:resource="#Cha"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#phongLamViec">
#   <rdfs:domain rdf:resource="#NhanVien"/>
#   <rdfs:range rdf:resource="#Phong"/>
# </owl:ObjectProperty>
#
# <owl:DatatypeProperty rdf:about="#ten">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#ChucVu"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
#   <rdfs:domain rdf:resource="#ToChuc"/>
#   <rdfs:domain rdf:resource="#MonHoc"/>
#   <rdfs:domain rdf:resource="#Phong"/>
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:domain rdf:resource="#ThietBi"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#phuCap">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#ChucVu"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#hoTen">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Nguoi"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngaySinh">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Nguoi"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#gioiTinh">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Nguoi"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#trangThai">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Nguoi"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
#   <rdfs:domain rdf:resource="#DiemDanh"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#heSoLuong">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#NhanVien"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngheNghiep">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#PhuHuynh"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#diemTB">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
#   <rdfs:domain rdf:resource="#DiemSo"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#hanhKiem">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#trinhDo">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#GiaoVien"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#soTiet">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#MonHoc"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#integer"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#tx1">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#tx2">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#tx3">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#gk">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ck">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#loaiPhong">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Phong"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayBatDau">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayKetThuc">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayGio">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemDanh"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#dateTime"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#soLuong">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#ThietBi"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#integer"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#hocLuc">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#danhHieu">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:Class rdf:about="#ChucVu">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#ToChuc">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#Nguoi">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#NhanVien">
#   <rdfs:subClassOf rdf:resource="#Nguoi"/>
# </owl:Class>
#
# <owl:Class rdf:about="#PhuHuynh">
#   <rdfs:subClassOf rdf:resource="#Nguoi"/>
# </owl:Class>
#
# <owl:Class rdf:about="#Cha">
#   <rdfs:subClassOf rdf:resource="#PhuHuynh"/>
# </owl:Class>
#
# <owl:Class rdf:about="#Me">
#   <rdfs:subClassOf rdf:resource="#PhuHuynh"/>
# </owl:Class>
#
# <owl:Class rdf:about="#LopHoc">
#   <rdfs:subClassOf rdf:resource="#ToChuc"/>
# </owl:Class>
#
# <owl:Class rdf:about="#HocSinh">
#   <rdfs:subClassOf rdf:resource="#Nguoi"/>
# </owl:Class>
#
# <owl:Class rdf:about="#Anh">
#   <rdfs:subClassOf rdf:resource="#HocSinh"/>
# </owl:Class>
#
# <owl:Class rdf:about="#Chi">
#   <rdfs:subClassOf rdf:resource="#HocSinh"/>
# </owl:Class>
#
# <owl:Class rdf:about="#Em">
#   <rdfs:subClassOf rdf:resource="#HocSinh"/>
# </owl:Class>
#
# <owl:Class rdf:about="#GiaoVien">
#   <rdfs:subClassOf rdf:resource="#NhanVien"/>
# </owl:Class>
#
# <owl:Class rdf:about="#MonHoc">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#DiemSo">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#GiangDay">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#Phong">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#HoatDong">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#DiemDanh">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#ThietBi">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <swrl:Variable rdf:about="urn:swrl#hs"/>
#
# <swrl:Variable rdf:about="urn:swrl#c"/>
#
# <swrl:Variable rdf:about="urn:swrl#m"/>
#
# <swrl:Variable rdf:about="urn:swrl#ph1"/>
#
# <swrl:Variable rdf:about="urn:swrl#ph2"/>
#
# <swrl:Variable rdf:about="urn:swrl#ds"/>
#
# <swrl:Variable rdf:about="urn:swrl#d1"/>
#
# <swrl:Variable rdf:about="urn:swrl#d2"/>
#
# <swrl:Variable rdf:about="urn:swrl#d3"/>
#
# <swrl:Variable rdf:about="urn:swrl#d4"/>
#
# <swrl:Variable rdf:about="urn:swrl#d5"/>
#
# <swrl:Variable rdf:about="urn:swrl#t"/>
#
# <swrl:Variable rdf:about="urn:swrl#p"/>
#
# <swrl:Variable rdf:about="urn:swrl#r"/>
#
# <swrl:Variable rdf:about="urn:swrl#rs"/>
#
# <swrl:Variable rdf:about="urn:swrl#dtb"/>
#
# <swrl:Variable rdf:about="urn:swrl#hl"/>
#
# <swrl:Variable rdf:about="urn:swrl#hk"/>
#
# <LopHoc rdf:about="#lophoc1">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <ten rdf:datatype="http://www.w3.org/2001/XMLSchema#string">10C01</ten>
# </LopHoc>
#
# <Phong rdf:about="#Phong10C01">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <suDungBoi rdf:resource="#lophoc1"/>
#   <ten rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Phòng 10C01</ten>
#   <loaiPhong rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Phòng học</loaiPhong>
# </Phong>
#
# <HocSinh rdf:about="#hocsinh1">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc1"/>
#   <cha rdf:resource="#cha27"/>
#   <me rdf:resource="#me27"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Dương Quốc Quỳnh</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-10-01</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <hanhKiem rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tốt</hanhKiem>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đã chuyển trường</trangThai>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh2">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc1"/>
#   <cha rdf:resource="#cha6"/>
#   <me rdf:resource="#me6"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Bành Văn Hoàng</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-01-20</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <hanhKiem rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khá</hanhKiem>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đã chuyển trường</trangThai>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh3">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc1"/>
#   <cha rdf:resource="#cha3"/>
#   <me rdf:resource="#me3"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Hoàng Thanh Hùng</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-09-17</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đang học</trangThai>
#   <hanhKiem rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tốt</hanhKiem>
# </HocSinh>
#
# <Cha rdf:about="#cha3">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nguyễn Bảo Minh</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1978-06-06</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nông dân</ngheNghiep>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Còn sống</trangThai>
# </Cha>
#
# <Me rdf:about="#me3">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đoàn Ngọc Tú</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1973-07-30</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nhân viên văn phòng</ngheNghiep>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Còn sống</trangThai>
# </Me>
#
# <HocSinh rdf:about="#hocsinh4">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc1"/>
#   <cha rdf:resource="#cha4"/>
#   <me rdf:resource="#me4"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tô Kim Vinh</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-01-14</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đang học</trangThai>
#   <hanhKiem rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Trung bình</hanhKiem>
# </HocSinh>
#
# <Cha rdf:about="#cha4">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Phan Minh Thảo</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1971-09-21</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Chủ doanh nghiệp</ngheNghiep>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đã chết</trangThai>
# </Cha>
#
# <Me rdf:about="#me4">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Võ Thanh Việt</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1976-09-13</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Kỹ sư</ngheNghiep>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Còn sống</trangThai>
# </Me>
#
# <HocSinh rdf:about="#hocsinh5">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc1"/>
#   <cha rdf:resource="#cha45"/>
#   <me rdf:resource="#me45"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tạ Mai Hùng</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-06-24</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đang học</trangThai>
#   <hanhKiem rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Trung bình</hanhKiem>
# </HocSinh>
#
# <LopHoc rdf:about="#lophoc2">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <ten rdf:datatype="http://www.w3.org/2001/XMLSchema#string">10C02</ten>
# </LopHoc>
#
# <Phong rdf:about="#Phong10C02">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <suDungBoi rdf:resource="#lophoc2"/>
#   <ten rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Phòng 10C02</ten>
#   <loaiPhong rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Phòng học</loaiPhong>
# </Phong>
#
# <HocSinh rdf:about="#hocsinh6">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc2"/>
#   <cha rdf:resource="#cha6"/>
#   <me rdf:resource="#me6"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Phan Quốc Khánh</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-11-25</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đang học</trangThai>
#   <hanhKiem rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khá</hanhKiem>
# </HocSinh>
#
# <Cha rdf:about="#cha6">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đinh Hồng Bình</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1980-07-29</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Bác sĩ</ngheNghiep>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Còn sống</trangThai>
# </Cha>
#
# <Me rdf:about="#me6">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Dương Kim Hiền</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1979-07-27</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Công nhân</ngheNghiep>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Còn sống</trangThai>
# </Me>
#
# <HocSinh rdf:about="#hocsinh7">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc2"/>
#   <cha rdf:resource="#cha7"/>
#   <me rdf:resource="#me7"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tăng Quý Hải</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-08-31</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <hanhKiem rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khá</hanhKiem>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đã chuyển trường</trangThai>
# </HocSinh>
#
# <Cha rdf:about="#cha7">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Huỳnh Văn Hải</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1972-10-28</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nông dân</ngheNghiep>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đã chết</trangThai>
# </Cha>
#
# <Me rdf:about="#me7">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Võ Bảo Quỳnh</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1970-03-11</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Giáo viên</ngheNghiep>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Còn sống</trangThai>
# </Me>
#
# <HocSinh rdf:about="#hocsinh8">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc2"/>
#   <cha rdf:resource="#cha35"/>
#   <me rdf:resource="#me35"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đinh Ngọc Vinh</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-03-03</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đang học</trangThai>
#   <hanhKiem rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Trung bình</hanhKiem>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh9">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc2"/>
#   <cha rdf:resource="#cha9"/>
#   <me rdf:resource="#me9"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tăng Anh Tường</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-06-12</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đang học</trangThai>
#   <hanhKiem rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tốt</hanhKiem>
# </HocSinh>
#
# <Cha rdf:about="#cha9">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đoàn Đình Tú</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1973-12-27</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nhân viên văn phòng</ngheNghiep>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Còn sống</trangThai>
# </Cha>
#
# <Me rdf:about="#me9">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Dương Quý An</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1978-05-20</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Bác sĩ</ngheNghiep>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Còn sống</trangThai>
# </Me>
#
# <HocSinh rdf:about="#hocsinh10">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc2"/>
#   <cha rdf:resource="#cha26"/>
#   <me rdf:resource="#me26"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tô Quý Thiện</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-03-28</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đang học</trangThai>
#   <hanhKiem rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tốt</hanhKiem>
# </HocSinh>
#
# <LopHoc rdf:about="#lophoc3">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <ten rdf:datatype="http://www.w3.org/2001/XMLSchema#string">10C03</ten>
# </LopHoc>
#
# <Phong rdf:about="#Phong10C03">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <suDungBoi rdf:resource="#lophoc3"/>
#   <ten rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Phòng 10C03</ten>
#   <loaiPhong rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Phòng học</loaiPhong>
# </Phong>
#
# <HocSinh rdf:about="#hocsinh11">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc3"/>
#   <cha rdf:resource="#cha15"/>
#   <me rdf:resource="#me15"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Phùng Kim Tùng</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-03-30</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đang học</trangThai>
#   <hanhKiem rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khá</hanhKiem>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh12">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc3"/>
#   <cha rdf:resource="#cha12"/>
#   <me rdf:resource="#me12"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Quách Quý Việt</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-12-12</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đang học</trangThai>
#   <hanhKiem rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khá</hanhKiem>
# </HocSinh>
#
# <Cha rdf:about="#cha12">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đặng Thanh Nam</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1979-02-08</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Kỹ sư</ngheNghiep>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Còn sống</trangThai>
# </Cha>
#
# <Me rdf:about="#me12">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Bành Văn Thuận</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1977-04-14</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Bác sĩ</ngheNghiep>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Còn sống</trangThai>
# </Me>
#
# <HocSinh rdf:about="#hocsinh13">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc3"/>
#   <cha rdf:resource="#cha13"/>
#   <me rdf:resource="#me13"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Lương Quốc Long</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-06-10</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <hanhKiem rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Trung bình</hanhKiem>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đã chuyển trường</trangThai>
# </HocSinh>
#
# <Cha rdf:about="#cha13">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Bành Thị Hiền</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1970-08-22</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Giáo viên</ngheNghiep>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Còn sống</trangThai>
# </Cha>
#
# <Me rdf:about="#me13">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Mai Quốc Khánh</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1978-10-22</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Giáo viên</ngheNghiep>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Còn sống</trangThai>
# </Me>
#
# <HocSinh rdf:about="#hocsinh14">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc3"/>
#   <cha rdf:resource="#cha25"/>
#   <me rdf:resource="#me25"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đoàn Thị Thúy</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-10-08</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đang học</trangThai>
#   <hanhKiem rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tốt</hanhKiem>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh15">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc3"/>
#   <cha rdf:resource="#cha15"/>
#   <me rdf:resource="#me15"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tôn Hữu Tùng</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-05-25</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đang học</trangThai>
#   <hanhKiem rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khá</hanhKiem>
# </HocSinh>
#
# <Cha rdf:about="#cha15">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tăng Văn An</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1978-11-13</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Bác sĩ</ngheNghiep>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Còn sống</trangThai>
# </Cha>
#
# <Me rdf:about="#me15">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nguyễn Quý Sơn</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1973-10-26</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nông dân</ngheNghiep>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Còn sống</trangThai>
# </Me>
#
# <LopHoc rdf:about="#lophoc4">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <ten rdf:datatype="http://www.w3.org/2001/XMLSchema#string">11B01</ten>
# </LopHoc>
#
# <Phong rdf:about="#Phong11B01">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <suDungBoi rdf:resource="#lophoc4"/>
#   <ten rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Phòng 11B01</ten>
#   <loaiPhong rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Phòng học</loaiPhong>
# </Phong>
#
# <HocSinh rdf:about="#hocsinh16">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc4"/>
#   <cha rdf:resource="#cha16"/>
#   <me rdf:resource="#me16"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nguyễn Quý Nam</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-01-28</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đang học</trangThai>
#   <hanhKiem rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Trung bình</hanhKiem>
# </HocSinh>
#
# <Cha rdf:about="#cha16">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đoàn Mai Nhật</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1971-07-22</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Chủ doanh nghiệp</ngheNghiep>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Còn sống</trangThai>
# </Cha>
#
# <Me rdf:about="#me16">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Phùng Thanh Hoàng</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1974-09-14</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Chủ doanh nghiệp</ngheNghiep>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Còn sống</trangThai>
# </Me>
#
# <HocSinh rdf:about="#hocsinh17">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc4"/>
#   <cha rdf:resource="#cha43"/>
#   <me rdf:resource="#me43"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Dương Thanh Tường</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-02-09</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đang học</trangThai>
#   <hanhKiem rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khá</hanhKiem>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh18">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc4"/>
#   <cha rdf:resource="#cha18"/>
#   <me rdf:resource="#me18"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tăng Anh Thuận</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-06-11</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đang học</trangThai>
#   <hanhKiem rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khá</hanhKiem>
# </HocSinh>
#
# <Cha rdf:about="#cha18">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Phan Thanh Quỳnh</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1973-12-25</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Công nhân</ngheNghiep>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Còn sống</trangThai>
# </Cha>
#
# <Me rdf:about="#me18">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Thái Mai Thuận</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1978-01-20</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nhân viên văn phòng</ngheNghiep>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Còn sống</trangThai>
# </Me>
#
# <HocSinh rdf:about="#hocsinh19">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc4"/>
#   <cha rdf:resource="#cha22"/>
#   <me rdf:resource="#me22"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đào Mai Ngọc</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-09-15</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đang học</trangThai>
#   <hanhKiem rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khá</hanhKiem>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh20">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc4"/>
#   <cha rdf:resource="#cha7"/>
#   <me rdf:resource="#me7"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Phùng Thanh Thảo</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-01-26</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đang học</trangThai>
#   <hanhKiem rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Yếu</hanhKiem>
# </HocSinh>
#
# <LopHoc rdf:about="#lophoc5">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <ten rdf:datatype="http://www.w3.org/2001/XMLSchema#string">11B02</ten>
# </LopHoc>
#
# <Phong rdf:about="#Phong11B02">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <suDungBoi rdf:resource="#lophoc5"/>
#   <ten rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Phòng 11B02</ten>
#   <loaiPhong rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Phòng học</loaiPhong>
# </Phong>
#
# <HocSinh rdf:about="#hocsinh21">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc5"/>
#   <cha rdf:resource="#cha32"/>
#   <me rdf:resource="#me32"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đặng Mai Thiện</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-07-08</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đang học</trangThai>
#   <hanhKiem rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Yếu</hanhKiem>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh22">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc5"/>
#   <cha rdf:resource="#cha22"/>
#   <me rdf:resource="#me22"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Huỳnh Mai Dũng</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-06-07</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đang học</trangThai>
#   <hanhKiem rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tốt</hanhKiem>
# </HocSinh>
#
# <Cha rdf:about="#cha22">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đoàn Anh Bình</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1971-04-20</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Giáo viên</ngheNghiep>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Còn sống</trangThai>
# </Cha>
#
# <Me rdf:about="#me22">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Vũ Quý Việt</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1970-06-30</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nông dân</ngheNghiep>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Còn sống</trangThai>
# </Me>
#
# <HocSinh rdf:about="#hocsinh23">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc5"/>
#   <cha rdf:resource="#cha28"/>
#   <me rdf:resource="#me28"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Bành Mai Tường</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-12-12</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đang học</trangThai>
#   <hanhKiem rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tốt</hanhKiem>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh24">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc5"/>
#   <cha rdf:resource="#cha24"/>
#   <me rdf:resource="#me24"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Phan Quốc Thiện</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-05-15</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đang học</trangThai>
#   <hanhKiem rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khá</hanhKiem>
# </HocSinh>
#
# <Cha rdf:about="#cha24">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tô Đình Nhật</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1976-05-04</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Công nhân</ngheNghiep>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Còn sống</trangThai>
# </Cha>
#
# <Me rdf:about="#me24">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Vũ Kim An</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1973-02-02</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Bác sĩ</ngheNghiep>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Còn sống</trangThai>
# </Me>
#
# <HocSinh rdf:about="#hocsinh25">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#lophoc5"/>
#   <cha rdf:resource="#cha25"/>
# ...
#                           <rdf:first>
#                             <swrl:DatavaluedPropertyAtom>
#                               <swrl:propertyPredicate rdf:resource="#ck"/>
#                               <swrl:argument1 rdf:resource="urn:swrl#ds"/>
#                               <swrl:argument2 rdf:resource="urn:swrl#d5"/>
#                             </swrl:DatavaluedPropertyAtom>
#                           </rdf:first>
#                           <rdf:rest>
#                             <rdf:Description>
#                               <rdf:first>
#                                 <swrl:BuiltinAtom>
#                                   <swrl:builtin rdf:resource="http://www.w3.org/2003/11/swrlb#add"/>
#                                   <swrl:arguments>
#                                     <rdf:Description>
#                                       <rdf:first rdf:resource="urn:swrl#t"/>
#                                       <rdf:rest>
#                                         <rdf:Description>
#                                           <rdf:first rdf:resource="urn:swrl#d1"/>
#                                           <rdf:rest>
#                                             <rdf:Description>
#                                               <rdf:first rdf:resource="urn:swrl#d2"/>
#                                               <rdf:rest>
#                                                 <rdf:Description>
#                                                   <rdf:first rdf:resource="urn:swrl#d3"/>
#                                                   <rdf:rest>
#                                                     <rdf:Description>
#                                                       <rdf:first rdf:resource="urn:swrl#d4"/>
#                                                       <rdf:rest>
#                                                         <rdf:Description>
#                                                           <rdf:first rdf:resource="urn:swrl#d4"/>
#                                                           <rdf:rest>
#                                                             <rdf:Description>
#                                                               <rdf:first rdf:resource="urn:swrl#d5"/>
#                                                               <rdf:rest>
#                                                                 <rdf:Description>
#                                                                   <rdf:first rdf:resource="urn:swrl#d5"/>
#                                                                   <rdf:rest>
#                                                                     <rdf:Description>
#                                                                       <rdf:first rdf:resource="urn:swrl#d5"/>
#                                                                       <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                                                                     </rdf:Description>
#                                                                   </rdf:rest>
#                                                                 </rdf:Description>
#                                                               </rdf:rest>
#                                                             </rdf:Description>
#                                                           </rdf:rest>
#                                                         </rdf:Description>
#                                                       </rdf:rest>
#                                                     </rdf:Description>
#                                                   </rdf:rest>
#                                                 </rdf:Description>
#                                               </rdf:rest>
#                                             </rdf:Description>
#                                           </rdf:rest>
#                                         </rdf:Description>
#                                       </rdf:rest>
#                                     </rdf:Description>
#                                   </swrl:arguments>
#                                 </swrl:BuiltinAtom>
#                               </rdf:first>
#                               <rdf:rest>
#                                 <rdf:Description>
#                                   <rdf:first>
#                                     <swrl:BuiltinAtom>
#                                       <swrl:builtin rdf:resource="http://www.w3.org/2003/11/swrlb#multiply"/>
#                                       <swrl:arguments>
#                                         <rdf:Description>
#                                           <rdf:first rdf:resource="urn:swrl#p"/>
#                                           <rdf:rest>
#                                             <rdf:Description>
#                                               <rdf:first rdf:resource="urn:swrl#t"/>
#                                               <rdf:rest>
#                                                 <rdf:Description>
#                                                   <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                                                   <rdf:first rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">100</rdf:first>
#                                                 </rdf:Description>
#                                               </rdf:rest>
#                                             </rdf:Description>
#                                           </rdf:rest>
#                                         </rdf:Description>
#                                       </swrl:arguments>
#                                     </swrl:BuiltinAtom>
#                                   </rdf:first>
#                                   <rdf:rest>
#                                     <rdf:Description>
#                                       <rdf:first>
#                                         <swrl:BuiltinAtom>
#                                           <swrl:builtin rdf:resource="http://www.w3.org/2003/11/swrlb#divide"/>
#                                           <swrl:arguments>
#                                             <rdf:Description>
#                                               <rdf:first rdf:resource="urn:swrl#c"/>
#                                               <rdf:rest>
#                                                 <rdf:Description>
#                                                   <rdf:first rdf:resource="urn:swrl#p"/>
#                                                   <rdf:rest>
#                                                     <rdf:Description>
#                                                       <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                                                       <rdf:first rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">8</rdf:first>
#                                                     </rdf:Description>
#                                                   </rdf:rest>
#                                                 </rdf:Description>
#                                               </rdf:rest>
#                                             </rdf:Description>
#                                           </swrl:arguments>
#                                         </swrl:BuiltinAtom>
#                                       </rdf:first>
#                                       <rdf:rest>
#                                         <rdf:Description>
#                                           <rdf:first>
#                                             <swrl:BuiltinAtom>
#                                               <swrl:builtin rdf:resource="http://www.w3.org/2003/11/swrlb#floor"/>
#                                               <swrl:arguments>
#                                                 <rdf:Description>
#                                                   <rdf:first rdf:resource="urn:swrl#r"/>
#                                                   <rdf:rest>
#                                                     <rdf:Description>
#                                                       <rdf:first rdf:resource="urn:swrl#c"/>
#                                                       <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                                                     </rdf:Description>
#                                                   </rdf:rest>
#                                                 </rdf:Description>
#                                               </swrl:arguments>
#                                             </swrl:BuiltinAtom>
#                                           </rdf:first>
#                                           <rdf:rest>
#                                             <rdf:Description>
#                                               <rdf:first>
#                                                 <swrl:BuiltinAtom>
#                                                   <swrl:builtin rdf:resource="http://www.w3.org/2003/11/swrlb#divide"/>
#                                                   <swrl:arguments>
#                                                     <rdf:Description>
#                                                       <rdf:first rdf:resource="urn:swrl#rs"/>
#                                                       <rdf:rest>
#                                                         <rdf:Description>
#                                                           <rdf:first rdf:resource="urn:swrl#r"/>
#                                                           <rdf:rest>
#                                                             <rdf:Description>
#                                                               <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                                                               <rdf:first rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">100</rdf:first>
#                                                             </rdf:Description>
#                                                           </rdf:rest>
#                                                         </rdf:Description>
#                                                       </rdf:rest>
#                                                     </rdf:Description>
#                                                   </swrl:arguments>
#                                                 </swrl:BuiltinAtom>
#                                               </rdf:first>
#                                               <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                                             </rdf:Description>
#                                           </rdf:rest>
#                                         </rdf:Description>
#                                       </rdf:rest>
#                                     </rdf:Description>
#                                   </rdf:rest>
#                                 </rdf:Description>
#                               </rdf:rest>
#                             </rdf:Description>
#                           </rdf:rest>
#                         </rdf:Description>
#                       </rdf:rest>
#                     </rdf:Description>
#                   </rdf:rest>
#                 </rdf:Description>
#               </rdf:rest>
#             </rdf:Description>
#           </rdf:rest>
#         </rdf:Description>
#       </rdf:rest>
#     </rdf:Description>
#   </swrl:body>
#   <swrl:head>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:DatavaluedPropertyAtom>
#           <swrl:propertyPredicate rdf:resource="#diemTB"/>
#           <swrl:argument1 rdf:resource="urn:swrl#ds"/>
#           <swrl:argument2 rdf:resource="urn:swrl#rs"/>
#         </swrl:DatavaluedPropertyAtom>
#       </rdf:first>
#       <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#     </rdf:Description>
#   </swrl:head>
# </swrl:Imp>
#
# <swrl:Imp>
#   <swrl:body>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:ClassAtom>
#           <swrl:classPredicate rdf:resource="#HocSinh"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#         </swrl:ClassAtom>
#       </rdf:first>
#       <rdf:rest>
#         <rdf:Description>
#           <rdf:first>
#             <swrl:IndividualPropertyAtom>
#               <swrl:propertyPredicate rdf:resource="#cha"/>
#               <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#               <swrl:argument2 rdf:resource="urn:swrl#ph1"/>
#             </swrl:IndividualPropertyAtom>
#           </rdf:first>
#           <rdf:rest>
#             <rdf:Description>
#               <rdf:first>
#                 <swrl:IndividualPropertyAtom>
#                   <swrl:propertyPredicate rdf:resource="#me"/>
#                   <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#                   <swrl:argument2 rdf:resource="urn:swrl#ph2"/>
#                 </swrl:IndividualPropertyAtom>
#               </rdf:first>
#               <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#             </rdf:Description>
#           </rdf:rest>
#         </rdf:Description>
#       </rdf:rest>
#     </rdf:Description>
#   </swrl:body>
#   <swrl:head>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:IndividualPropertyAtom>
#           <swrl:propertyPredicate rdf:resource="#vo"/>
#           <swrl:argument1 rdf:resource="urn:swrl#ph1"/>
#           <swrl:argument2 rdf:resource="urn:swrl#ph2"/>
#         </swrl:IndividualPropertyAtom>
#       </rdf:first>
#       <rdf:rest>
#         <rdf:Description>
#           <rdf:first>
#             <swrl:IndividualPropertyAtom>
#               <swrl:propertyPredicate rdf:resource="#chong"/>
#               <swrl:argument1 rdf:resource="urn:swrl#ph2"/>
#               <swrl:argument2 rdf:resource="urn:swrl#ph1"/>
#             </swrl:IndividualPropertyAtom>
#           </rdf:first>
#           <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#         </rdf:Description>
#       </rdf:rest>
#     </rdf:Description>
#   </swrl:head>
# </swrl:Imp>
#
# <swrl:Imp>
#   <swrl:body>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:ClassAtom>
#           <swrl:classPredicate rdf:resource="#HocSinh"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#         </swrl:ClassAtom>
#       </rdf:first>
#       <rdf:rest>
#         <rdf:Description>
#           <rdf:first>
#             <swrl:IndividualPropertyAtom>
#               <swrl:propertyPredicate rdf:resource="#cha"/>
#               <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#               <swrl:argument2 rdf:resource="urn:swrl#c"/>
#             </swrl:IndividualPropertyAtom>
#           </rdf:first>
#           <rdf:rest>
#             <rdf:Description>
#               <rdf:first>
#                 <swrl:IndividualPropertyAtom>
#                   <swrl:propertyPredicate rdf:resource="#me"/>
#                   <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#                   <swrl:argument2 rdf:resource="urn:swrl#m"/>
#                 </swrl:IndividualPropertyAtom>
#               </rdf:first>
#               <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#             </rdf:Description>
#           </rdf:rest>
#         </rdf:Description>
#       </rdf:rest>
#     </rdf:Description>
#   </swrl:body>
#   <swrl:head>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:IndividualPropertyAtom>
#           <swrl:propertyPredicate rdf:resource="#phuHuynh"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#           <swrl:argument2 rdf:resource="urn:swrl#c"/>
#         </swrl:IndividualPropertyAtom>
#       </rdf:first>
#       <rdf:rest>
#         <rdf:Description>
#           <rdf:first>
#             <swrl:IndividualPropertyAtom>
#               <swrl:propertyPredicate rdf:resource="#phuHuynh"/>
#               <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#               <swrl:argument2 rdf:resource="urn:swrl#m"/>
#             </swrl:IndividualPropertyAtom>
#           </rdf:first>
#           <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#         </rdf:Description>
#       </rdf:rest>
#     </rdf:Description>
#   </swrl:head>
# </swrl:Imp>
#
#
# </rdf:RDF>

# %%
# Đọc CSDL từ file
onto = get_ontology("../app/data/education.owl").load()

# In DS học sinh ra màn hình
print("Danh sách học sinh:")
stt = 1
for hs in onto.HocSinh.instances():
    print(stt, hs.hoTen)
    stt += 1
# Out:
# Danh sách học sinh:
# 1 Dương Quốc Quỳnh
# 2 Bành Văn Hoàng
# 3 Hoàng Thanh Hùng
# 4 Tô Kim Vinh
# 5 Tạ Mai Hùng
# 6 Phan Quốc Khánh
# 7 Tăng Quý Hải
# 8 Đinh Ngọc Vinh
# 9 Tăng Anh Tường
# 10 Tô Quý Thiện
# 11 Phùng Kim Tùng
# 12 Quách Quý Việt
# 13 Lương Quốc Long
# 14 Đoàn Thị Thúy
# 15 Tôn Hữu Tùng
# 16 Nguyễn Quý Nam
# 17 Dương Thanh Tường
# 18 Tăng Anh Thuận
# 19 Đào Mai Ngọc
# 20 Phùng Thanh Thảo
# 21 Đặng Mai Thiện
# 22 Huỳnh Mai Dũng
# 23 Bành Mai Tường
# 24 Phan Quốc Thiện
# 25 Đặng Kim Hiền
# 26 Trần Kim Cường
# 27 Tạ Hữu Thiên
# 28 Bùi Bảo Thiện
# 29 Bành Hồng Long
# 30 Trần Bảo Tùng
# 31 Huỳnh Thanh Vân
# 32 Phùng Văn Sơn
# 33 Nguyễn Văn Hoàng
# 34 Phạm Văn Tường
# 35 Đinh Anh Ngọc
# 36 Quách Hoài An
# 37 Đinh Quý Sơn
# 38 Tăng Minh Hoàng
# 39 Đinh Hồng Tú
# 40 Phùng Thị Thuận
# 41 Bùi Hữu Minh
# 42 Phạm Hoài Thiện
# 43 Trương Hồng Khánh
# 44 Ngô Hữu Tường
# 45 Tăng Anh Phương

# %%
# In DS giáo viên
print("Danh sách giáo viên:")
for gv in onto.GiaoVien.instances():
    print(gv.hoTen, gv.ngaySinh, gv.gioiTinh, gv.trinhDo, getattr(gv.lopChuNhiem,'ten',''), *[mon.ten for mon in gv.dayMon])
# Out:
# Danh sách giáo viên:
# Quách Anh Hoàng 1971-12-02 Nam Thạc sĩ  Toán học
# Đặng Hữu Thảo 1978-03-03 Nam Đại học 11B01 Toán học
# Võ Mai Hiền 1970-08-05 Nữ Đại học  Toán học
# Tô Đình Quang 1973-10-15 Nam Thạc sĩ  Ngữ văn
# Đỗ Mai Thuận 1988-08-31 Nữ Thạc sĩ 12A01 Ngữ văn
# Hoàng Đình An 1971-08-29 Nam Thạc sĩ  Ngữ văn
# Trần Đình Hoàng 1974-06-25 Nam Đại học  Hóa học
# Đoàn Minh Minh 1975-08-16 Nam Thạc sĩ 11B03 Hóa học
# Nguyễn Hữu Quang 1988-02-02 Nam Thạc sĩ  Hóa học Lịch sử
# Tô Anh Thảo 1983-01-15 Nam Thạc sĩ  Lịch sử
# Nguyễn Đình Thiên 1983-01-06 Nam Thạc sĩ  Lịch sử
# Thái Hồng Vân 1985-01-27 Nữ Đại học  Lịch sử
# Quách Hữu Hùng 1971-05-26 Nam Đại học 11B02 Địa lý
# Hồ Hoài Tùng 1973-08-13 Nữ Thạc sĩ 10C02 Địa lý
# Lê Minh Ngọc 1990-04-30 Nam Đại học  Địa lý Toán học
# Đinh Mai Tùng 1973-03-15 Nữ Đại học 12A03 Sinh học
# Đinh Kim Thảo 1983-07-13 Nữ Đại học  Sinh học
# Tăng Quốc Vinh 1984-01-03 Nam Đại học  Sinh học
# Hồ Quý An 1973-04-30 Nam Thạc sĩ  Tiếng Anh
# Quách Mai Quang 1982-03-05 Nữ Thạc sĩ  Tiếng Anh
# Mai Minh Việt 1983-12-12 Nam Thạc sĩ  Tiếng Anh Toán học
# Lương Quý Việt 1988-04-10 Nam Đại học  GDCD
# Đào Hồng Quang 1981-09-05 Nữ Đại học  GDCD
# Lý Thanh Sơn 1970-07-19 Nữ Đại học 10C01 GDCD Sinh học
# Võ Hoài Phương 1974-03-09 Nữ Đại học  Công nghệ
# Thái Minh Thiện 1979-11-15 Nam Đại học  Công nghệ
# Tôn Minh Quỳnh 1988-02-24 Nam Đại học 12A02 Công nghệ Tiếng Anh
# Nguyễn Văn Thúy 1979-04-03 Nam Thạc sĩ  Thể dục
# Tôn Anh Tú 1989-01-11 Nam Thạc sĩ 10C03 Thể dục
# Phạm Hồng Phương 1981-08-21 Nữ Đại học  Thể dục

# %%
# In DS HS trong lớp 10C01
print("Danh sách học sinh lớp 10C01:")
for hs in onto.HocSinh.instances():
    if hs.hocLop.ten == "10C01":
        print(hs.hoTen, hs.ngaySinh, hs.gioiTinh, hs.hocLop.ten)
# Out:
# Danh sách học sinh lớp 10C01:
# Dương Quốc Quỳnh 2000-10-01 Nam 10C01
# Bành Văn Hoàng 2000-01-20 Nam 10C01
# Hoàng Thanh Hùng 2000-09-17 Nữ 10C01
# Tô Kim Vinh 2000-01-14 Nữ 10C01
# Tạ Mai Hùng 2000-06-24 Nữ 10C01

# %%
# in ds GV chủ nhiệm của từng lớp
print("Danh sách giáo viên chủ nhiệm:")
for lop in onto.LopHoc.instances():
    gv = lop.giaoVienChuNhiem
    if gv:
        print(gv.hoTen, gv.ngaySinh, gv.gioiTinh, gv.trinhDo, getattr(gv.lopChuNhiem,'ten',''))
# Out:
# Danh sách giáo viên chủ nhiệm:
# Lý Thanh Sơn 1970-07-19 Nữ Đại học 10C01
# Hồ Hoài Tùng 1973-08-13 Nữ Thạc sĩ 10C02
# Tôn Anh Tú 1989-01-11 Nam Thạc sĩ 10C03
# Đặng Hữu Thảo 1978-03-03 Nam Đại học 11B01
# Quách Hữu Hùng 1971-05-26 Nam Đại học 11B02
# Đoàn Minh Minh 1975-08-16 Nam Thạc sĩ 11B03
# Đỗ Mai Thuận 1988-08-31 Nữ Thạc sĩ 12A01
# Tôn Minh Quỳnh 1988-02-24 Nam Đại học 12A02
# Đinh Mai Tùng 1973-03-15 Nữ Đại học 12A03

# %%
# Sửa tên của giáo viên chủ nhiệm Nguyễn Văn X thành Nguyễn Văn Tèo
print("Sửa tên của giáo viên chủ nhiệm Nguyễn Văn X thành Nguyễn Văn Tèo")
for gv in onto.GiaoVien.instances():
    if gv.hoTen == "Nguyễn Văn X":
        gv.hoTen = "Nguyễn Văn Tèo"
        print(gv.hoTen, gv.ngaySinh, gv.gioiTinh, gv.trinhDo, getattr(gv.lopChuNhiem,'ten',''))
# Out:
# Sửa tên của giáo viên chủ nhiệm Nguyễn Văn X thành Nguyễn Văn Tèo

# %%
# Tạo mới một học sinh và thêm vào lớp 10A01
print("Tạo mới một học sinh và thêm vào lớp 10C01")
lop = onto.search_one(ten = "10C01", type = onto.LopHoc)
hs1 = HocSinh(hoTen = "Nguyễn Văn XXX", ngaySinh = "01/01/2011", gioiTinh = "Nam", hocLop = lop)
# In DS HS trong lớp 10A01
print("Danh sách học sinh lớp 10A01:")
print('\n'.join(str(hs.hoTen) for hs in lop.dsHocSinh))
# Out:
# Tạo mới một học sinh và thêm vào lớp 10C01
# Danh sách học sinh lớp 10A01:
# Dương Quốc Quỳnh
# Bành Văn Hoàng
# Hoàng Thanh Hùng
# Tô Kim Vinh
# Tạ Mai Hùng
# Nguyễn Văn XXX

# %%
# Xoá học sinh có ngày sinh là 01/01/2011
print("Xoá học sinh có ngày sinh là 01/01/2011")
hs_ind = onto.search_one(ngaySinh="01/01/2011", type=onto.HocSinh)
# Nếu individual được tìm thấy, xoá individual đó
if hs_ind is not None:
    destroy_entity(hs_ind)
# Out:
# Xoá học sinh có ngày sinh là 01/01/2011

# %%
# In tất cả điểm số của một học sinh
print("In tất cả điểm số của một học sinh")
hs_ind = onto.search_one(type=onto.HocSinh)
if hs_ind is not None:
    for diem in hs_ind.diemSo:
        print(diem.monHoc.ten, diem.tx1, diem.tx2, diem.tx3, diem.gk, diem.ck, diem.diemTB)
# Out:
# In tất cả điểm số của một học sinh
# Toán học 8.8 6.3 10 10.0 8.8 None
# Ngữ văn 10 10.0 10 9.8 10 None
# Hóa học 9.8 10 10 7.3 10 None
# Lịch sử 10 10 8.8 8.3 10 None
# Địa lý 10 9.5 10 10.0 9.3 None
# Sinh học 9.3 10.0 7.3 6.8 9.5 None
# Tiếng Anh 10.0 10 10.0 10 10 None
# GDCD 10.0 8.5 9.8 10 10 None
# Công nghệ 10 10 10.0 10 9.8 None
# Thể dục 7.5 8.3 9.8 10 8.3 None

# %%
print(hoTen.iri)
print(HocSinh.iri)
# Out:
# http://hc.com/school#hoTen
# http://hc.com/school#HocSinh

# %%
print('In ra các lớp mà GV dạy')
gv = onto.search_one(type = onto.GiaoVien)
for gd in gv.giangDay:
    print(gd.lopHoc.ten, gd.monHoc.ten)
# Out:
# In ra các lớp mà GV dạy
# 10C01 Toán học
# 11B03 Toán học

# %%
print('In các GV dạy lớp 10C03')
lop = onto.search_one(type = onto.LopHoc, ten = '10C03')
gd = onto.search(type = onto.GiangDay, lopHoc = lop)
for g in gd:
    print(g.giaoVien.hoTen, g.monHoc.ten, g.lopHoc.ten)
# Out:
# In các GV dạy lớp 10C03
# Võ Mai Hiền Toán học 10C03
# Tô Đình Quang Ngữ văn 10C03
# Trần Đình Hoàng Hóa học 10C03
# Tô Anh Thảo Lịch sử 10C03
# Quách Hữu Hùng Địa lý 10C03
# Đinh Kim Thảo Sinh học 10C03
# Quách Mai Quang Tiếng Anh 10C03
# Lương Quý Việt GDCD 10C03
# Võ Hoài Phương Công nghệ 10C03
# Nguyễn Văn Thúy Thể dục 10C03

# %%
print('- Liệt kê ban giám hiệu')
BGH = onto.search_one(type = onto.ToChuc, ten = 'Ban giám hiệu')
for nv in BGH.thanhVien:
    print(nv.hoTen, nv.chucVu[0].ten, nv.chucVu[0].phuCap)
print('- Liệt kê tổ Văn phòng')
VP = onto.search_one(type = onto.ToChuc, ten = 'Văn phòng')
for nv in VP.thanhVien:
    print(nv.hoTen, nv.chucVu[0].ten, nv.chucVu[0].phuCap)
# Out:
# - Liệt kê ban giám hiệu
# Tôn Mai Khánh Hiệu trưởng 0.7
# Thái Hoài Thiện Phó hiệu Trưởng 0.5
# Mai Bảo Long Phó hiệu Trưởng 0.5
# - Liệt kê tổ Văn phòng
# Đào Kim Quỳnh Bảo vệ 0
# Trương Kim Hoàng Bảo vệ 0
# Hoàng Anh Hoàng Bảo vệ 0
# Hồ Anh Thuận Phục vụ 0
# Lương Quốc Bình Phục vụ 0
# Lý Bảo Linh Văn thư 0.3
# Đỗ Anh Vinh Thủ quỹ 0.3
# Đoàn Anh Sơn Kế toán 0.5
# Đào Thanh Quỳnh Thư viện 0
# Tôn Đình Cường Thiết bị 0.25
# Phạm Hoài Thiện Thiết bị 0.25

# %%
print('Liệt kê các tổ trưởng và tổ phó của các tổ chuyên môn')
toChuyenMon = [x for x in onto.search(type = onto.ToChuc) if x.name.startswith('To')]
for tc in toChuyenMon:
    print(tc.ten)
    for nv in tc.thanhVien:
        print('   -', nv.hoTen, nv.chucVu[0].ten, nv.chucVu[0].phuCap, nv.dayMon)
# Out:
# Liệt kê các tổ trưởng và tổ phó của các tổ chuyên môn
# Tổ Toán học
#    - Quách Anh Hoàng Tổ trưởng 0.2 [school.Toan]
#    - Đặng Hữu Thảo Tổ phó 0.15 [school.Toan]
#    - Võ Mai Hiền Giáo viên 0 [school.Toan]
#    - Lê Minh Ngọc Giáo viên 0 [school.DiaLy, school.Toan]
#    - Mai Minh Việt Giáo viên 0 [school.TiengAnh, school.Toan]
# Tổ Ngữ văn
#    - Tô Đình Quang Tổ trưởng 0.2 [school.NguVan]
#    - Đỗ Mai Thuận Tổ phó 0.15 [school.NguVan]
#    - Hoàng Đình An Giáo viên 0 [school.NguVan]
# Tổ Hóa học
#    - Trần Đình Hoàng Tổ trưởng 0.2 [school.HoaHoc]
#    - Đoàn Minh Minh Tổ phó 0.15 [school.HoaHoc]
#    - Nguyễn Hữu Quang Giáo viên 0 [school.HoaHoc, school.LichSu]
# Tổ Lịch sử
#    - Nguyễn Hữu Quang Giáo viên 0 [school.HoaHoc, school.LichSu]
#    - Tô Anh Thảo Tổ trưởng 0.2 [school.LichSu]
#    - Nguyễn Đình Thiên Tổ phó 0.15 [school.LichSu]
#    - Thái Hồng Vân Giáo viên 0 [school.LichSu]
# Tổ Địa lý
#    - Quách Hữu Hùng Tổ trưởng 0.2 [school.DiaLy]
#    - Hồ Hoài Tùng Tổ phó 0.15 [school.DiaLy]
#    - Lê Minh Ngọc Giáo viên 0 [school.DiaLy, school.Toan]
# Tổ Sinh học
#    - Đinh Mai Tùng Tổ trưởng 0.2 [school.SinhHoc]
#    - Đinh Kim Thảo Tổ phó 0.15 [school.SinhHoc]
#    - Tăng Quốc Vinh Giáo viên 0 [school.SinhHoc]
#    - Lý Thanh Sơn Giáo viên 0 [school.GDCD, school.SinhHoc]
# Tổ Tiếng Anh
#    - Hồ Quý An Tổ trưởng 0.2 [school.TiengAnh]
#    - Quách Mai Quang Tổ phó 0.15 [school.TiengAnh]
#    - Mai Minh Việt Giáo viên 0 [school.TiengAnh, school.Toan]
#    - Tôn Minh Quỳnh Giáo viên 0 [school.CongNghe, school.TiengAnh]
# Tổ GDCD
#    - Lương Quý Việt Tổ trưởng 0.2 [school.GDCD]
#    - Đào Hồng Quang Tổ phó 0.15 [school.GDCD]
#    - Lý Thanh Sơn Giáo viên 0 [school.GDCD, school.SinhHoc]
# Tổ Công nghệ
#    - Võ Hoài Phương Tổ trưởng 0.2 [school.CongNghe]
#    - Thái Minh Thiện Tổ phó 0.15 [school.CongNghe]
#    - Tôn Minh Quỳnh Giáo viên 0 [school.CongNghe, school.TiengAnh]
# Tổ Thể dục
#    - Nguyễn Văn Thúy Tổ trưởng 0.2 [school.TheDuc]
#    - Tôn Anh Tú Tổ phó 0.15 [school.TheDuc]
#    - Phạm Hồng Phương Giáo viên 0 [school.TheDuc]

# %%
print('Liệt kê các phòng kèm tổ chức sử dụng')
for p in onto.Phong.instances():
    print(p.ten, end = ' ')
    print('-', p.suDungBoi.ten if p.suDungBoi else '', end = ' ')
    print()
# Out:
# Liệt kê các phòng kèm tổ chức sử dụng
# Phòng 10C01 - 10C01
# Phòng 10C02 - 10C02
# Phòng 10C03 - 10C03
# Phòng 11B01 - 11B01
# Phòng 11B02 - 11B02
# Phòng 11B03 - 11B03
# Phòng 12A01 - 12A01
# Phòng 12A02 - 12A02
# Phòng 12A03 - 12A03
# Phòng Toán học - Tổ Toán học
# Phòng Ngữ văn - Tổ Ngữ văn
# Phòng Hóa học - Tổ Hóa học
# Phòng Lịch sử - Tổ Lịch sử
# Phòng Địa lý - Tổ Địa lý
# Phòng Sinh học - Tổ Sinh học
# Phòng Tiếng Anh - Tổ Tiếng Anh
# Phòng GDCD - Tổ GDCD
# Phòng Công nghệ - Tổ Công nghệ
# Phòng Thể dục - Tổ Thể dục
# Phòng Hiệu trưởng - Ban giám hiệu
# Phòng Phó hiệu Trưởng 1 - Ban giám hiệu
# Phòng Phó hiệu Trưởng 2 - Ban giám hiệu
# Phòng Bảo vệ 1 - Văn phòng
# Phòng Bảo vệ 2 - Văn phòng
# Phòng Bảo vệ 3 - Văn phòng
# Phòng Phục vụ 1 - Văn phòng
# Phòng Phục vụ 2 - Văn phòng
# Phòng Văn thư - Văn phòng
# Phòng Thủ quỹ - Văn phòng
# Phòng Kế toán - Văn phòng
# Phòng Thư viện - Văn phòng
# Phòng Thiết bị 1 - Văn phòng
# Phòng Thiết bị 2 - Văn phòng

# %%
print('Liệt kê các hoạt động')
for hd in onto.HoatDong.instances():
    print(hd.ten, hd.ngayBatDau, hd.ngayKetThuc,[gv.hoTen for gv in hd.quanLy], [ng.hoTen for ng in hd.thamGia])
# Out:
# Liệt kê các hoạt động
# Học tập 2021-11-07 2022-04-13 ['Mai Minh Việt', 'Thái Minh Thiện', 'Tô Đình Quang', 'Mai Minh Việt', 'Thái Minh Thiện', 'Tô Đình Quang'] ['Bành Văn Hoàng', 'Tạ Hữu Thiên', 'Đặng Kim Hiền', 'Đào Mai Ngọc']
# Thể thao 2021-10-05 2022-05-01 ['Lương Quý Việt', 'Lương Quý Việt'] ['Phạm Hoài Thiện', 'Tôn Hữu Tùng']
# Văn hóa 2021-11-01 2022-02-12 ['Tôn Minh Quỳnh', 'Tôn Minh Quỳnh'] ['Tăng Anh Thuận', 'Tạ Mai Hùng', 'Đinh Ngọc Vinh']
# Nghệ thuật 2021-11-10 2022-03-08 ['Tô Đình Quang', 'Tô Đình Quang'] ['Dương Quốc Quỳnh', 'Đặng Mai Thiện', 'Trương Hồng Khánh', 'Nguyễn Văn Hoàng', 'Phùng Văn Sơn', 'Đặng Kim Hiền', 'Phan Quốc Khánh', 'Trần Bảo Tùng', 'Dương Thanh Tường', 'Quách Hoài An']
# Tình nguyện 2021-11-23 2022-02-19 ['Tôn Minh Quỳnh', 'Tôn Minh Quỳnh'] ['Dương Thanh Tường', 'Phạm Hoài Thiện', 'Bùi Hữu Minh', 'Quách Quý Việt']
# Khoa học 2021-09-22 2022-01-01 ['Đinh Kim Thảo', 'Quách Mai Quang', 'Đinh Kim Thảo', 'Quách Mai Quang'] ['Đinh Quý Sơn', 'Lương Quốc Long', 'Phùng Thị Thuận', 'Quách Hoài An', 'Phùng Thanh Thảo', 'Đinh Hồng Tú']
# Kỹ năng sống 2021-11-17 2022-05-03 ['Hồ Hoài Tùng', 'Hồ Hoài Tùng'] ['Quách Hoài An', 'Tạ Mai Hùng', 'Trương Hồng Khánh', 'Bùi Hữu Minh', 'Bành Mai Tường', 'Hoàng Thanh Hùng', 'Trần Bảo Tùng', 'Phạm Hoài Thiện', 'Phan Quốc Khánh']
# Ngoại khóa 2021-12-24 2022-05-09 ['Tôn Anh Tú', 'Tôn Anh Tú'] ['Phạm Hoài Thiện', 'Bùi Bảo Thiện']

# %%
print('Liệt kê các HS điểm danh ở 1 hoạt động')
hd = onto.search(type = onto.HoatDong)[4]
dd = onto.search(type = onto.DiemDanh, hoatDong = hd)
for d in dd:
    print(d.nguoi.hoTen, d.ngayGio, d.trangThai)
# Out:
# Liệt kê các HS điểm danh ở 1 hoạt động
# Dương Thanh Tường 2021-11-23 07:00:00 Có mặt
# Phạm Hoài Thiện 2021-11-23 09:00:00 Vắng
# Bùi Hữu Minh 2021-11-23 09:00:00 Vắng
# Quách Quý Việt 2021-11-23 08:00:00 Vắng

# %%
print('Liệt kê danh mục phòng kèm theo danh sách thiết bị trong phòng')
for p in onto.Phong.instances():
    print(p.ten, end=' ')
    dsTB = [tb for tb in onto.ThietBi.instances() if tb.phong == p]
    for tb in dsTB:
        print('\t-', tb.ten, tb.soLuong, end=' ')
    print()
# Out:
# Liệt kê danh mục phòng kèm theo danh sách thiết bị trong phòng
# Phòng 10C01 	- Bàn học 12 	- Ghế học sinh 12 	- Bảng phấn 1 	- Bàn giáo viên 1 	- Ghế 1 	- Tivi 1 	- Quạt 4
# Phòng 10C02 	- Bàn học 12 	- Ghế học sinh 12 	- Bảng phấn 1 	- Bàn giáo viên 1 	- Ghế 1 	- Tivi 1 	- Quạt 4
# Phòng 10C03 	- Bàn học 12 	- Ghế học sinh 12 	- Bảng phấn 1 	- Bàn giáo viên 1 	- Ghế 1 	- Tivi 1 	- Quạt 4
# Phòng 11B01 	- Bàn học 12 	- Ghế học sinh 12 	- Bảng phấn 1 	- Bàn giáo viên 1 	- Ghế 1 	- Tivi 1 	- Quạt 4
# Phòng 11B02 	- Bàn học 12 	- Ghế học sinh 12 	- Bảng phấn 1 	- Bàn giáo viên 1 	- Ghế 1 	- Tivi 1 	- Quạt 4
# Phòng 11B03 	- Bàn học 12 	- Ghế học sinh 12 	- Bảng phấn 1 	- Bàn giáo viên 1 	- Ghế 1 	- Tivi 1 	- Quạt 4
# Phòng 12A01 	- Bàn học 12 	- Ghế học sinh 12 	- Bảng phấn 1 	- Bàn giáo viên 1 	- Ghế 1 	- Tivi 1 	- Quạt 4
# Phòng 12A02 	- Bàn học 12 	- Ghế học sinh 12 	- Bảng phấn 1 	- Bàn giáo viên 1 	- Ghế 1 	- Tivi 1 	- Quạt 4
# Phòng 12A03 	- Bàn học 12 	- Ghế học sinh 12 	- Bảng phấn 1 	- Bàn giáo viên 1 	- Ghế 1 	- Tivi 1 	- Quạt 4
# Phòng Toán học 	- Bàn lớn 2 	- Ghế 8 	- Bảng trắng 1 	- Quạt 1
# Phòng Ngữ văn 	- Bàn lớn 2 	- Ghế 8 	- Bảng trắng 1 	- Quạt 1
# Phòng Hóa học 	- Bàn lớn 2 	- Ghế 8 	- Bảng trắng 1 	- Quạt 1
# Phòng Lịch sử 	- Bàn lớn 2 	- Ghế 8 	- Bảng trắng 1 	- Quạt 1
# Phòng Địa lý 	- Bàn lớn 2 	- Ghế 8 	- Bảng trắng 1 	- Quạt 1
# Phòng Sinh học 	- Bàn lớn 2 	- Ghế 8 	- Bảng trắng 1 	- Quạt 1
# Phòng Tiếng Anh 	- Bàn lớn 2 	- Ghế 8 	- Bảng trắng 1 	- Quạt 1
# Phòng GDCD 	- Bàn lớn 2 	- Ghế 8 	- Bảng trắng 1 	- Quạt 1
# Phòng Công nghệ 	- Bàn lớn 2 	- Ghế 8 	- Bảng trắng 1 	- Quạt 1
# Phòng Thể dục 	- Bàn lớn 2 	- Ghế 8 	- Bảng trắng 1 	- Quạt 1
# Phòng Hiệu trưởng 	- Bàn làm việc 1 	- Ghế 1 	- Máy tính 1 	- Máy in 1
# Phòng Phó hiệu Trưởng 1 	- Bàn làm việc 1 	- Ghế 1 	- Máy tính 1 	- Máy in 1
# Phòng Phó hiệu Trưởng 2 	- Bàn làm việc 1 	- Ghế 1 	- Máy tính 1 	- Máy in 1
# Phòng Bảo vệ 1 	- Bàn làm việc 1 	- Ghế 1 	- Máy tính 1 	- Máy in 1
# Phòng Bảo vệ 2 	- Bàn làm việc 1 	- Ghế 1 	- Máy tính 1 	- Máy in 1
# Phòng Bảo vệ 3 	- Bàn làm việc 1 	- Ghế 1 	- Máy tính 1 	- Máy in 1
# Phòng Phục vụ 1 	- Bàn làm việc 1 	- Ghế 1 	- Máy tính 1 	- Máy in 1
# Phòng Phục vụ 2 	- Bàn làm việc 1 	- Ghế 1 	- Máy tính 1 	- Máy in 1
# Phòng Văn thư 	- Bàn làm việc 1 	- Ghế 1 	- Máy tính 1 	- Máy in 1
# Phòng Thủ quỹ 	- Bàn làm việc 1 	- Ghế 1 	- Máy tính 1 	- Máy in 1
# Phòng Kế toán 	- Bàn làm việc 1 	- Ghế 1 	- Máy tính 1 	- Máy in 1
# Phòng Thư viện 	- Bàn làm việc 1 	- Ghế 1 	- Máy tính 1 	- Máy in 1
# Phòng Thiết bị 1 	- Bàn làm việc 1 	- Ghế 1 	- Máy tính 1 	- Máy in 1
# Phòng Thiết bị 2 	- Bàn làm việc 1 	- Ghế 1 	- Máy tính 1 	- Máy in 1

# %%
print('Liệt kê các đối tượng chưa có dữ liệu trong CSDL')
for x in onto.classes():
    if len(x.instances()) == 0:
        print(x.name)
# Out:
# Liệt kê các đối tượng chưa có dữ liệu trong CSDL
# Anh
# Chi
# Em
