# %% [markdown]
# ### Cài đặt thư viện:
#
# Cài đặt các thư viện vào môi trường anaconda:
#
# ```bash
# conda install -c conda-forge owlready2
# ```

# %% [markdown]
# ### Tạo ontology

# %%
# %run ../app/models/model.py

# %%
lsPro = list(onto.properties())
def get_properties(obj):
    return [p for p in lsPro if obj.is_a[0] in p.domain] + [p for p in lsPro if obj in p.domain]
print('STT\tTên lớp\tKế thừa từ\tThuộc tính')
lsClass= list(onto.classes())
for i, class_ in zip(range(len(lsClass)), lsClass):
    print(f"{str(i+1)}\t{class_.name}\t{str(class_.is_a).split('.')[1][:-1]}\t{', '.join([x.name for x in get_properties(class_)])}")
    # print(str(i+1)+'.', class_.name, 'kế thừa từ', class_.is_a)
    # for x in get_properties(class_) :
    #     print('-', x.name, ':', x.range[0])
# Out:
# STT	Tên lớp	Kế thừa từ	Thuộc tính
# 1	ChucVu	Thing	ten, phuCap
# 2	ToChuc	Thing	ten, thanhVien, phong
# 3	Nguoi	Thing	hoTen, ngaySinh, gioiTinh, toChuc
# 4	NhanVien	Nguoi	hoTen, ngaySinh, gioiTinh, toChuc, heSoLuong, chucVu, phongLamViec
# 5	PhuHuynh	Nguoi	hoTen, ngaySinh, gioiTinh, toChuc, ngheNghiep, con
# 6	Cha	PhuHuynh	ngheNghiep, con, vo
# 7	Me	PhuHuynh	ngheNghiep, con, chong
# 8	LopHoc	ToChuc	ten, thanhVien, phong, giaoVienChuNhiem, dsHocSinh
# 9	HocSinh	Nguoi	hoTen, ngaySinh, gioiTinh, toChuc, diemTB, hanhKiem, hocLuc, danhHieu, hocLop, phuHuynh, me, cha, diemSo, anhChiEm, anh, chi, em
# 10	Anh	HocSinh	diemTB, hanhKiem, hocLuc, danhHieu, hocLop, phuHuynh, me, cha, diemSo, anhChiEm, anh, chi, em
# 11	Chi	HocSinh	diemTB, hanhKiem, hocLuc, danhHieu, hocLop, phuHuynh, me, cha, diemSo, anhChiEm, anh, chi, em
# 12	Em	HocSinh	diemTB, hanhKiem, hocLuc, danhHieu, hocLop, phuHuynh, me, cha, diemSo, anhChiEm, anh, chi, em
# 13	GiaoVien	NhanVien	heSoLuong, chucVu, phongLamViec, trinhDo, dayMon, giangDay, lopChuNhiem
# 14	MonHoc	Thing	ten, soTiet, giaoVienDay
# 15	DiemSo	Thing	diemTB, heSo1, heSo2, heSo3, hocSinh, monHoc
# 16	GiangDay	Thing	monHoc, giaoVien, lopHoc
# 17	Phong	Thing	ten, suDungBoi
# 18	HoatDong	Thing	ten, ngayBatDau, ngayKetThuc, quanLy, thamGia
# 19	DiemDanh	Thing	ngayGio, trangThai, nguoi, hoatDong

# %%
print('\nSTT\tTên thuộc tính\tDomain\tRange\tLoại')
import re
i=1
for p in lsPro:
    if p.is_a[0].name == 'ObjectProperty': continue
    domains = set([str(d).split('.')[1] for d in p.domain])
    ranges = []
    for r in p.range:
        data = re.findall(r"[\w']+", str(r))
        ranges.append(data[1].replace("'", ''))
    stype = [a.name for a in p.is_a][1:]
    print(f"{i}\t{p.name}\t{', '.join(domains)}\t{', '.join(set(ranges))}\t{', '.join(stype)}")
    i+=1
# Out:
# STT	Tên thuộc tính	Domain	Range	Loại
# 1	ten	ToChuc, HoatDong, ChucVu, Phong, MonHoc	str	FunctionalProperty
# 2	phuCap	ChucVu	float	FunctionalProperty
# 3	hoTen	Nguoi	str	FunctionalProperty
# 4	ngaySinh	Nguoi	datetime	FunctionalProperty
# 5	gioiTinh	Nguoi	str	FunctionalProperty
# 6	heSoLuong	NhanVien	float	FunctionalProperty
# 7	ngheNghiep	PhuHuynh	str	FunctionalProperty
# 8	diemTB	HocSinh, DiemSo	float	FunctionalProperty
# 9	hanhKiem	HocSinh	str	FunctionalProperty
# 10	trinhDo	GiaoVien	str	FunctionalProperty
# 11	soTiet	MonHoc	int	FunctionalProperty
# 12	heSo1	DiemSo	float
# 13	heSo2	DiemSo	float
# 14	heSo3	DiemSo	float
# 15	ngayBatDau	HoatDong	datetime	FunctionalProperty
# 16	ngayKetThuc	HoatDong	datetime	FunctionalProperty
# 17	ngayGio	DiemDanh	datetime	FunctionalProperty
# 18	trangThai	DiemDanh	str	FunctionalProperty
# 19	hocLuc	HocSinh	str	FunctionalProperty
# 20	danhHieu	HocSinh	str	FunctionalProperty

# %%
print('\nSTT\tTên thuộc tính\tDomain\tRange\tLoại')
import re
i=1
for p in lsPro:
    if p.is_a[0].name != 'ObjectProperty': continue
    domains = set([str(d).split('.')[1] for d in p.domain])
    ranges = []
    for r in p.range:
        data = re.findall(r"[\w']+", str(r))
        ranges.append(data[1].replace("'", ''))
    stype = [a.name for a in p.is_a][1:]
    print(f"{i}\t{p.name}\t{', '.join(domains)}\t{', '.join(set(ranges))}\t{', '.join(stype)}")
    i+=1
# Out:
# STT	Tên thuộc tính	Domain	Range	Loại
# 1	thanhVien	ToChuc	Nguoi
# 2	phong	ToChuc	Phong
# 3	toChuc	Nguoi	ToChuc
# 4	chucVu	NhanVien	ChucVu
# 5	con	PhuHuynh	HocSinh
# 6	giaoVienChuNhiem	LopHoc	GiaoVien	FunctionalProperty
# 7	dsHocSinh	LopHoc	HocSinh
# 8	hocLop	HocSinh	LopHoc	FunctionalProperty
# 9	phuHuynh	HocSinh	PhuHuynh
# 10	me	HocSinh	Me	FunctionalProperty, phuHuynh
# 11	cha	HocSinh	Cha	FunctionalProperty, phuHuynh
# 12	diemSo	HocSinh	DiemSo
# 13	dayMon	GiaoVien	MonHoc
# 14	giangDay	GiaoVien	GiangDay
# 15	lopChuNhiem	GiaoVien	LopHoc	FunctionalProperty
# 16	giaoVienDay	MonHoc	GiaoVien
# 17	hocSinh	DiemSo	HocSinh	FunctionalProperty
# 18	monHoc	GiangDay, DiemSo	MonHoc	FunctionalProperty
# 19	giaoVien	GiangDay	GiaoVien	FunctionalProperty
# 20	lopHoc	GiangDay	LopHoc	FunctionalProperty
# 21	suDungBoi	Phong	ToChuc
# 22	quanLy	HoatDong	Nguoi
# 23	thamGia	HoatDong	Nguoi
# 24	nguoi	DiemDanh	Nguoi	FunctionalProperty
# 25	hoatDong	DiemDanh	HoatDong	FunctionalProperty
# 26	anhChiEm	HocSinh	HocSinh
# 27	anh	HocSinh	Anh	anhChiEm
# 28	chi	HocSinh	Chi	anhChiEm
# 29	em	HocSinh	Em	anhChiEm
# 30	vo	Cha	Me	FunctionalProperty
# 31	chong	Me	Cha	FunctionalProperty
# 32	phongLamViec	NhanVien	Phong

# %%
# Lưu CSDL ra file
onto.save(file="../app/data/education.owl")
with open("../app/data/education.owl", "r") as f:
    print(f.read())
# Out:
# <?xml version="1.0"?>
# <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#"
#          xmlns:xsd="http://www.w3.org/2001/XMLSchema#"
#          xmlns:rdfs="http://www.w3.org/2000/01/rdf-schema#"
#          xmlns:owl="http://www.w3.org/2002/07/owl#"
#          xml:base="http://hc.com/school"
#          xmlns="http://hc.com/school#"
#          xmlns:swrl="http://www.w3.org/2003/11/swrl#">
#
# <owl:Ontology rdf:about="http://hc.com/school"/>
#
# <owl:ObjectProperty rdf:about="#thanhVien">
#   <rdfs:domain rdf:resource="#ToChuc"/>
#   <rdfs:range rdf:resource="#Nguoi"/>
#   <owl:inverseOf rdf:resource="#toChuc"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#phong">
#   <rdfs:domain rdf:resource="#ToChuc"/>
#   <rdfs:range rdf:resource="#Phong"/>
#   <owl:inverseOf rdf:resource="#suDungBoi"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#toChuc">
#   <rdfs:domain rdf:resource="#Nguoi"/>
#   <rdfs:range rdf:resource="#ToChuc"/>
#   <owl:inverseOf rdf:resource="#thanhVien"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#chucVu">
#   <rdfs:domain rdf:resource="#NhanVien"/>
#   <rdfs:range rdf:resource="#ChucVu"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#con">
#   <rdfs:domain rdf:resource="#PhuHuynh"/>
#   <rdfs:range rdf:resource="#HocSinh"/>
#   <owl:inverseOf rdf:resource="#phuHuynh"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#giaoVienChuNhiem">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#LopHoc"/>
#   <rdfs:range rdf:resource="#GiaoVien"/>
#   <owl:inverseOf rdf:resource="#lopChuNhiem"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#dsHocSinh">
#   <rdfs:domain rdf:resource="#LopHoc"/>
#   <rdfs:range rdf:resource="#HocSinh"/>
#   <owl:inverseOf rdf:resource="#hocLop"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#hocLop">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#LopHoc"/>
#   <owl:inverseOf rdf:resource="#dsHocSinh"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#phuHuynh">
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#PhuHuynh"/>
#   <owl:inverseOf rdf:resource="#con"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#me">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:subPropertyOf rdf:resource="#phuHuynh"/>
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#Me"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#cha">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:subPropertyOf rdf:resource="#phuHuynh"/>
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#Cha"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#diemSo">
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#DiemSo"/>
#   <owl:inverseOf rdf:resource="#hocSinh"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#dayMon">
#   <rdfs:domain rdf:resource="#GiaoVien"/>
#   <rdfs:range rdf:resource="#MonHoc"/>
#   <owl:inverseOf rdf:resource="#giaoVienDay"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#giangDay">
#   <rdfs:domain rdf:resource="#GiaoVien"/>
#   <rdfs:range rdf:resource="#GiangDay"/>
#   <owl:inverseOf rdf:resource="#giaoVien"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#lopChuNhiem">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#GiaoVien"/>
#   <rdfs:range rdf:resource="#LopHoc"/>
#   <owl:inverseOf rdf:resource="#giaoVienChuNhiem"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#giaoVienDay">
#   <rdfs:domain rdf:resource="#MonHoc"/>
#   <rdfs:range rdf:resource="#GiaoVien"/>
#   <owl:inverseOf rdf:resource="#dayMon"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#hocSinh">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="#HocSinh"/>
#   <owl:inverseOf rdf:resource="#diemSo"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#monHoc">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="#MonHoc"/>
#   <rdfs:domain rdf:resource="#GiangDay"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#giaoVien">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#GiangDay"/>
#   <rdfs:range rdf:resource="#GiaoVien"/>
#   <owl:inverseOf rdf:resource="#giangDay"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#lopHoc">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#GiangDay"/>
#   <rdfs:range rdf:resource="#LopHoc"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#suDungBoi">
#   <rdfs:domain rdf:resource="#Phong"/>
#   <rdfs:range rdf:resource="#ToChuc"/>
#   <owl:inverseOf rdf:resource="#phong"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#quanLy">
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:range rdf:resource="#Nguoi"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#thamGia">
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:range rdf:resource="#Nguoi"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#nguoi">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemDanh"/>
#   <rdfs:range rdf:resource="#Nguoi"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#hoatDong">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemDanh"/>
#   <rdfs:range rdf:resource="#HoatDong"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#anhChiEm">
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#HocSinh"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#anh">
#   <rdfs:subPropertyOf rdf:resource="#anhChiEm"/>
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#Anh"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#chi">
#   <rdfs:subPropertyOf rdf:resource="#anhChiEm"/>
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#Chi"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#em">
#   <rdfs:subPropertyOf rdf:resource="#anhChiEm"/>
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#Em"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#vo">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Cha"/>
#   <rdfs:range rdf:resource="#Me"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#chong">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Me"/>
#   <rdfs:range rdf:resource="#Cha"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#phongLamViec">
#   <rdfs:domain rdf:resource="#NhanVien"/>
#   <rdfs:range rdf:resource="#Phong"/>
# </owl:ObjectProperty>
#
# <owl:DatatypeProperty rdf:about="#ten">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#ChucVu"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
#   <rdfs:domain rdf:resource="#ToChuc"/>
#   <rdfs:domain rdf:resource="#MonHoc"/>
#   <rdfs:domain rdf:resource="#Phong"/>
#   <rdfs:domain rdf:resource="#HoatDong"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#phuCap">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#ChucVu"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#hoTen">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Nguoi"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngaySinh">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Nguoi"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#gioiTinh">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Nguoi"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#heSoLuong">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#NhanVien"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngheNghiep">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#PhuHuynh"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#diemTB">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
#   <rdfs:domain rdf:resource="#DiemSo"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#hanhKiem">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#trinhDo">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#GiaoVien"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#soTiet">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#MonHoc"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#integer"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#heSo1">
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#heSo2">
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#heSo3">
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayBatDau">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayKetThuc">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayGio">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemDanh"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#dateTime"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#trangThai">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemDanh"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#hocLuc">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#danhHieu">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:Class rdf:about="#ChucVu">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#ToChuc">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#Nguoi">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#NhanVien">
#   <rdfs:subClassOf rdf:resource="#Nguoi"/>
# </owl:Class>
#
# <owl:Class rdf:about="#PhuHuynh">
#   <rdfs:subClassOf rdf:resource="#Nguoi"/>
# </owl:Class>
#
# <owl:Class rdf:about="#Cha">
#   <rdfs:subClassOf rdf:resource="#PhuHuynh"/>
# </owl:Class>
#
# <owl:Class rdf:about="#Me">
#   <rdfs:subClassOf rdf:resource="#PhuHuynh"/>
# </owl:Class>
#
# <owl:Class rdf:about="#LopHoc">
#   <rdfs:subClassOf rdf:resource="#ToChuc"/>
# </owl:Class>
#
# <owl:Class rdf:about="#HocSinh">
#   <rdfs:subClassOf rdf:resource="#Nguoi"/>
# </owl:Class>
#
# <owl:Class rdf:about="#Anh">
#   <rdfs:subClassOf rdf:resource="#HocSinh"/>
# </owl:Class>
#
# <owl:Class rdf:about="#Chi">
#   <rdfs:subClassOf rdf:resource="#HocSinh"/>
# </owl:Class>
#
# <owl:Class rdf:about="#Em">
#   <rdfs:subClassOf rdf:resource="#HocSinh"/>
# </owl:Class>
#
# <owl:Class rdf:about="#GiaoVien">
#   <rdfs:subClassOf rdf:resource="#NhanVien"/>
# </owl:Class>
#
# <owl:Class rdf:about="#MonHoc">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#DiemSo">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#GiangDay">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#Phong">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#HoatDong">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#DiemDanh">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <swrl:Variable rdf:about="urn:swrl#hs"/>
#
# <swrl:Variable rdf:about="urn:swrl#c"/>
#
# <swrl:Variable rdf:about="urn:swrl#m"/>
#
# <swrl:Variable rdf:about="urn:swrl#ph1"/>
#
# <swrl:Variable rdf:about="urn:swrl#ph2"/>
#
# <swrl:Variable rdf:about="urn:swrl#dtb"/>
#
# <swrl:Variable rdf:about="urn:swrl#hl"/>
#
# <swrl:Variable rdf:about="urn:swrl#hk"/>
#
# <swrl:Imp>
#   <swrl:body>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:ClassAtom>
#           <swrl:classPredicate rdf:resource="#HocSinh"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#         </swrl:ClassAtom>
#       </rdf:first>
#       <rdf:rest>
#         <rdf:Description>
#           <rdf:first>
#             <swrl:DatavaluedPropertyAtom>
#               <swrl:propertyPredicate rdf:resource="#hocLuc"/>
#               <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#               <swrl:argument2 rdf:resource="urn:swrl#hl"/>
#             </swrl:DatavaluedPropertyAtom>
#           </rdf:first>
#           <rdf:rest>
#             <rdf:Description>
#               <rdf:first>
#                 <swrl:DatavaluedPropertyAtom>
#                   <swrl:propertyPredicate rdf:resource="#hanhKiem"/>
#                   <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#                   <swrl:argument2 rdf:resource="urn:swrl#hk"/>
#                 </swrl:DatavaluedPropertyAtom>
#               </rdf:first>
#               <rdf:rest>
#                 <rdf:Description>
#                   <rdf:first>
#                     <swrl:BuiltinAtom>
#                       <swrl:builtin rdf:resource="http://www.w3.org/2003/11/swrlb#startsWith"/>
#                       <swrl:arguments>
#                         <rdf:Description>
#                           <rdf:first rdf:resource="urn:swrl#hl"/>
#                           <rdf:rest>
#                             <rdf:Description>
#                               <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                               <rdf:first rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Kh</rdf:first>
#                             </rdf:Description>
#                           </rdf:rest>
#                         </rdf:Description>
#                       </swrl:arguments>
#                     </swrl:BuiltinAtom>
#                   </rdf:first>
#                   <rdf:rest>
#                     <rdf:Description>
#                       <rdf:first>
#                         <swrl:BuiltinAtom>
#                           <swrl:builtin rdf:resource="http://www.w3.org/2003/11/swrlb#startsWith"/>
#                           <swrl:arguments>
#                             <rdf:Description>
#                               <rdf:first rdf:resource="urn:swrl#hk"/>
#                               <rdf:rest>
#                                 <rdf:Description>
#                                   <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                                   <rdf:first rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Kh</rdf:first>
#                                 </rdf:Description>
#                               </rdf:rest>
#                             </rdf:Description>
#                           </swrl:arguments>
#                         </swrl:BuiltinAtom>
#                       </rdf:first>
#                       <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                     </rdf:Description>
#                   </rdf:rest>
#                 </rdf:Description>
#               </rdf:rest>
#             </rdf:Description>
#           </rdf:rest>
#         </rdf:Description>
#       </rdf:rest>
#     </rdf:Description>
#   </swrl:body>
#   <swrl:head>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:DatavaluedPropertyAtom>
#           <swrl:propertyPredicate rdf:resource="#danhHieu"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#           <swrl:argument2 rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Học sinh tiên tiến</swrl:argument2>
#         </swrl:DatavaluedPropertyAtom>
#       </rdf:first>
#       <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#     </rdf:Description>
#   </swrl:head>
# </swrl:Imp>
#
# <swrl:Imp>
#   <swrl:body>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:ClassAtom>
#           <swrl:classPredicate rdf:resource="#HocSinh"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#         </swrl:ClassAtom>
#       </rdf:first>
#       <rdf:rest>
#         <rdf:Description>
#           <rdf:first>
#             <swrl:DatavaluedPropertyAtom>
#               <swrl:propertyPredicate rdf:resource="#hocLuc"/>
#               <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#               <swrl:argument2 rdf:resource="urn:swrl#hl"/>
#             </swrl:DatavaluedPropertyAtom>
#           </rdf:first>
#           <rdf:rest>
#             <rdf:Description>
#               <rdf:first>
#                 <swrl:DatavaluedPropertyAtom>
#                   <swrl:propertyPredicate rdf:resource="#hanhKiem"/>
#                   <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#                   <swrl:argument2 rdf:resource="urn:swrl#hk"/>
#                 </swrl:DatavaluedPropertyAtom>
#               </rdf:first>
#               <rdf:rest>
#                 <rdf:Description>
#                   <rdf:first>
#                     <swrl:BuiltinAtom>
#                       <swrl:builtin rdf:resource="http://www.w3.org/2003/11/swrlb#startsWith"/>
#                       <swrl:arguments>
#                         <rdf:Description>
#                           <rdf:first rdf:resource="urn:swrl#hl"/>
#                           <rdf:rest>
#                             <rdf:Description>
#                               <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                               <rdf:first rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Kh</rdf:first>
#                             </rdf:Description>
#                           </rdf:rest>
#                         </rdf:Description>
#                       </swrl:arguments>
#                     </swrl:BuiltinAtom>
#                   </rdf:first>
#                   <rdf:rest>
#                     <rdf:Description>
#                       <rdf:first>
#                         <swrl:BuiltinAtom>
#                           <swrl:builtin rdf:resource="http://www.w3.org/2003/11/swrlb#endsWith"/>
#                           <swrl:arguments>
#                             <rdf:Description>
#                               <rdf:first rdf:resource="urn:swrl#hk"/>
#                               <rdf:rest>
#                                 <rdf:Description>
#                                   <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                                   <rdf:first rdf:datatype="http://www.w3.org/2001/XMLSchema#string">t</rdf:first>
#                                 </rdf:Description>
#                               </rdf:rest>
#                             </rdf:Description>
#                           </swrl:arguments>
#                         </swrl:BuiltinAtom>
#                       </rdf:first>
#                       <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                     </rdf:Description>
#                   </rdf:rest>
#                 </rdf:Description>
#               </rdf:rest>
#             </rdf:Description>
#           </rdf:rest>
#         </rdf:Description>
#       </rdf:rest>
#     </rdf:Description>
#   </swrl:body>
#   <swrl:head>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:DatavaluedPropertyAtom>
#           <swrl:propertyPredicate rdf:resource="#danhHieu"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#           <swrl:argument2 rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Học sinh tiên tiến</swrl:argument2>
#         </swrl:DatavaluedPropertyAtom>
#       </rdf:first>
#       <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#     </rdf:Description>
#   </swrl:head>
# </swrl:Imp>
#
# <swrl:Imp>
#   <swrl:body>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:ClassAtom>
#           <swrl:classPredicate rdf:resource="#HocSinh"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#         </swrl:ClassAtom>
#       </rdf:first>
#       <rdf:rest>
#         <rdf:Description>
#           <rdf:first>
#             <swrl:DatavaluedPropertyAtom>
#               <swrl:propertyPredicate rdf:resource="#hocLuc"/>
#               <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#               <swrl:argument2 rdf:resource="urn:swrl#hl"/>
#             </swrl:DatavaluedPropertyAtom>
#           </rdf:first>
#           <rdf:rest>
#             <rdf:Description>
#               <rdf:first>
#                 <swrl:DatavaluedPropertyAtom>
#                   <swrl:propertyPredicate rdf:resource="#hanhKiem"/>
#                   <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#                   <swrl:argument2 rdf:resource="urn:swrl#hk"/>
#                 </swrl:DatavaluedPropertyAtom>
#               </rdf:first>
#               <rdf:rest>
#                 <rdf:Description>
#                   <rdf:first>
#                     <swrl:BuiltinAtom>
#                       <swrl:builtin rdf:resource="http://www.w3.org/2003/11/swrlb#startsWith"/>
#                       <swrl:arguments>
#                         <rdf:Description>
#                           <rdf:first rdf:resource="urn:swrl#hl"/>
#                           <rdf:rest>
#                             <rdf:Description>
#                               <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                               <rdf:first rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Gi</rdf:first>
#                             </rdf:Description>
#                           </rdf:rest>
#                         </rdf:Description>
#                       </swrl:arguments>
#                     </swrl:BuiltinAtom>
#                   </rdf:first>
#                   <rdf:rest>
#                     <rdf:Description>
#                       <rdf:first>
#                         <swrl:BuiltinAtom>
#                           <swrl:builtin rdf:resource="http://www.w3.org/2003/11/swrlb#startsWith"/>
#                           <swrl:arguments>
#                             <rdf:Description>
#                               <rdf:first rdf:resource="urn:swrl#hk"/>
#                               <rdf:rest>
#                                 <rdf:Description>
#                                   <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                                   <rdf:first rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Kh</rdf:first>
#                                 </rdf:Description>
#                               </rdf:rest>
#                             </rdf:Description>
#                           </swrl:arguments>
#                         </swrl:BuiltinAtom>
#                       </rdf:first>
#                       <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                     </rdf:Description>
#                   </rdf:rest>
#                 </rdf:Description>
#               </rdf:rest>
#             </rdf:Description>
#           </rdf:rest>
#         </rdf:Description>
#       </rdf:rest>
#     </rdf:Description>
#   </swrl:body>
#   <swrl:head>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:DatavaluedPropertyAtom>
#           <swrl:propertyPredicate rdf:resource="#danhHieu"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#           <swrl:argument2 rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Học sinh giỏi</swrl:argument2>
#         </swrl:DatavaluedPropertyAtom>
#       </rdf:first>
#       <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#     </rdf:Description>
#   </swrl:head>
# </swrl:Imp>
#
# <swrl:Imp>
#   <swrl:body>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:ClassAtom>
#           <swrl:classPredicate rdf:resource="#HocSinh"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#         </swrl:ClassAtom>
#       </rdf:first>
#       <rdf:rest>
#         <rdf:Description>
#           <rdf:first>
#             <swrl:DatavaluedPropertyAtom>
#               <swrl:propertyPredicate rdf:resource="#hocLuc"/>
#               <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#               <swrl:argument2 rdf:resource="urn:swrl#hl"/>
#             </swrl:DatavaluedPropertyAtom>
#           </rdf:first>
#           <rdf:rest>
#             <rdf:Description>
#               <rdf:first>
#                 <swrl:DatavaluedPropertyAtom>
#                   <swrl:propertyPredicate rdf:resource="#hanhKiem"/>
#                   <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#                   <swrl:argument2 rdf:resource="urn:swrl#hk"/>
#                 </swrl:DatavaluedPropertyAtom>
#               </rdf:first>
#               <rdf:rest>
#                 <rdf:Description>
#                   <rdf:first>
#                     <swrl:BuiltinAtom>
#                       <swrl:builtin rdf:resource="http://www.w3.org/2003/11/swrlb#startsWith"/>
#                       <swrl:arguments>
#                         <rdf:Description>
#                           <rdf:first rdf:resource="urn:swrl#hl"/>
#                           <rdf:rest>
#                             <rdf:Description>
#                               <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                               <rdf:first rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Gi</rdf:first>
#                             </rdf:Description>
#                           </rdf:rest>
#                         </rdf:Description>
#                       </swrl:arguments>
#                     </swrl:BuiltinAtom>
#                   </rdf:first>
#                   <rdf:rest>
#                     <rdf:Description>
#                       <rdf:first>
#                         <swrl:BuiltinAtom>
#                           <swrl:builtin rdf:resource="http://www.w3.org/2003/11/swrlb#endsWith"/>
#                           <swrl:arguments>
#                             <rdf:Description>
#                               <rdf:first rdf:resource="urn:swrl#hk"/>
#                               <rdf:rest>
#                                 <rdf:Description>
#                                   <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                                   <rdf:first rdf:datatype="http://www.w3.org/2001/XMLSchema#string">t</rdf:first>
#                                 </rdf:Description>
#                               </rdf:rest>
#                             </rdf:Description>
#                           </swrl:arguments>
#                         </swrl:BuiltinAtom>
#                       </rdf:first>
#                       <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                     </rdf:Description>
#                   </rdf:rest>
#                 </rdf:Description>
#               </rdf:rest>
#             </rdf:Description>
#           </rdf:rest>
#         </rdf:Description>
#       </rdf:rest>
#     </rdf:Description>
#   </swrl:body>
#   <swrl:head>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:DatavaluedPropertyAtom>
#           <swrl:propertyPredicate rdf:resource="#danhHieu"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#           <swrl:argument2 rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Học sinh giỏi</swrl:argument2>
#         </swrl:DatavaluedPropertyAtom>
#       </rdf:first>
#       <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#     </rdf:Description>
#   </swrl:head>
# </swrl:Imp>
#
# <swrl:Imp>
#   <swrl:body>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:ClassAtom>
#           <swrl:classPredicate rdf:resource="#HocSinh"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#         </swrl:ClassAtom>
#       </rdf:first>
#       <rdf:rest>
#         <rdf:Description>
#           <rdf:first>
#             <swrl:DatavaluedPropertyAtom>
#               <swrl:propertyPredicate rdf:resource="#diemTB"/>
#               <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#               <swrl:argument2 rdf:resource="urn:swrl#dtb"/>
#             </swrl:DatavaluedPropertyAtom>
#           </rdf:first>
#           <rdf:rest>
#             <rdf:Description>
#               <rdf:first>
#                 <swrl:BuiltinAtom>
#                   <swrl:builtin rdf:resource="http://www.w3.org/2003/11/swrlb#lessThan"/>
#                   <swrl:arguments>
#                     <rdf:Description>
#                       <rdf:first rdf:resource="urn:swrl#dtb"/>
#                       <rdf:rest>
#                         <rdf:Description>
#                           <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                           <rdf:first rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">5.0</rdf:first>
#                         </rdf:Description>
#                       </rdf:rest>
#                     </rdf:Description>
#                   </swrl:arguments>
#                 </swrl:BuiltinAtom>
#               </rdf:first>
#               <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#             </rdf:Description>
#           </rdf:rest>
#         </rdf:Description>
#       </rdf:rest>
#     </rdf:Description>
#   </swrl:body>
#   <swrl:head>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:DatavaluedPropertyAtom>
#           <swrl:propertyPredicate rdf:resource="#hocLuc"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#           <swrl:argument2 rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Yếu</swrl:argument2>
#         </swrl:DatavaluedPropertyAtom>
#       </rdf:first>
#       <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#     </rdf:Description>
#   </swrl:head>
# </swrl:Imp>
#
# <swrl:Imp>
#   <swrl:body>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:ClassAtom>
#           <swrl:classPredicate rdf:resource="#HocSinh"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#         </swrl:ClassAtom>
#       </rdf:first>
#       <rdf:rest>
#         <rdf:Description>
#           <rdf:first>
#             <swrl:DatavaluedPropertyAtom>
#               <swrl:propertyPredicate rdf:resource="#diemTB"/>
#               <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#               <swrl:argument2 rdf:resource="urn:swrl#dtb"/>
#             </swrl:DatavaluedPropertyAtom>
#           </rdf:first>
#           <rdf:rest>
#             <rdf:Description>
#               <rdf:first>
#                 <swrl:BuiltinAtom>
#                   <swrl:builtin rdf:resource="http://www.w3.org/2003/11/swrlb#greaterThanOrEqual"/>
#                   <swrl:arguments>
#                     <rdf:Description>
#                       <rdf:first rdf:resource="urn:swrl#dtb"/>
#                       <rdf:rest>
#                         <rdf:Description>
#                           <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                           <rdf:first rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">5.0</rdf:first>
#                         </rdf:Description>
#                       </rdf:rest>
#                     </rdf:Description>
#                   </swrl:arguments>
#                 </swrl:BuiltinAtom>
#               </rdf:first>
#               <rdf:rest>
#                 <rdf:Description>
#                   <rdf:first>
#                     <swrl:BuiltinAtom>
#                       <swrl:builtin rdf:resource="http://www.w3.org/2003/11/swrlb#lessThan"/>
#                       <swrl:arguments>
#                         <rdf:Description>
#                           <rdf:first rdf:resource="urn:swrl#dtb"/>
#                           <rdf:rest>
#                             <rdf:Description>
#                               <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                               <rdf:first rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">6.5</rdf:first>
#                             </rdf:Description>
#                           </rdf:rest>
#                         </rdf:Description>
#                       </swrl:arguments>
#                     </swrl:BuiltinAtom>
#                   </rdf:first>
#                   <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                 </rdf:Description>
#               </rdf:rest>
#             </rdf:Description>
#           </rdf:rest>
#         </rdf:Description>
#       </rdf:rest>
#     </rdf:Description>
#   </swrl:body>
#   <swrl:head>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:DatavaluedPropertyAtom>
#           <swrl:propertyPredicate rdf:resource="#hocLuc"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#           <swrl:argument2 rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Trung bình</swrl:argument2>
#         </swrl:DatavaluedPropertyAtom>
#       </rdf:first>
#       <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#     </rdf:Description>
#   </swrl:head>
# </swrl:Imp>
#
# <swrl:Imp>
#   <swrl:body>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:ClassAtom>
#           <swrl:classPredicate rdf:resource="#HocSinh"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#         </swrl:ClassAtom>
#       </rdf:first>
#       <rdf:rest>
#         <rdf:Description>
#           <rdf:first>
#             <swrl:DatavaluedPropertyAtom>
#               <swrl:propertyPredicate rdf:resource="#diemTB"/>
#               <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#               <swrl:argument2 rdf:resource="urn:swrl#dtb"/>
#             </swrl:DatavaluedPropertyAtom>
#           </rdf:first>
#           <rdf:rest>
#             <rdf:Description>
#               <rdf:first>
#                 <swrl:BuiltinAtom>
#                   <swrl:builtin rdf:resource="http://www.w3.org/2003/11/swrlb#greaterThanOrEqual"/>
#                   <swrl:arguments>
#                     <rdf:Description>
#                       <rdf:first rdf:resource="urn:swrl#dtb"/>
#                       <rdf:rest>
#                         <rdf:Description>
#                           <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                           <rdf:first rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">6.5</rdf:first>
#                         </rdf:Description>
#                       </rdf:rest>
#                     </rdf:Description>
#                   </swrl:arguments>
#                 </swrl:BuiltinAtom>
#               </rdf:first>
#               <rdf:rest>
#                 <rdf:Description>
#                   <rdf:first>
#                     <swrl:BuiltinAtom>
#                       <swrl:builtin rdf:resource="http://www.w3.org/2003/11/swrlb#lessThan"/>
#                       <swrl:arguments>
#                         <rdf:Description>
#                           <rdf:first rdf:resource="urn:swrl#dtb"/>
#                           <rdf:rest>
#                             <rdf:Description>
#                               <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                               <rdf:first rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">8.0</rdf:first>
#                             </rdf:Description>
#                           </rdf:rest>
#                         </rdf:Description>
#                       </swrl:arguments>
#                     </swrl:BuiltinAtom>
#                   </rdf:first>
#                   <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                 </rdf:Description>
#               </rdf:rest>
#             </rdf:Description>
#           </rdf:rest>
#         </rdf:Description>
#       </rdf:rest>
#     </rdf:Description>
#   </swrl:body>
#   <swrl:head>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:DatavaluedPropertyAtom>
#           <swrl:propertyPredicate rdf:resource="#hocLuc"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#           <swrl:argument2 rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khá</swrl:argument2>
#         </swrl:DatavaluedPropertyAtom>
#       </rdf:first>
#       <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#     </rdf:Description>
#   </swrl:head>
# </swrl:Imp>
#
# <swrl:Imp>
#   <swrl:body>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:ClassAtom>
#           <swrl:classPredicate rdf:resource="#HocSinh"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#         </swrl:ClassAtom>
#       </rdf:first>
#       <rdf:rest>
#         <rdf:Description>
#           <rdf:first>
#             <swrl:DatavaluedPropertyAtom>
#               <swrl:propertyPredicate rdf:resource="#diemTB"/>
#               <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#               <swrl:argument2 rdf:resource="urn:swrl#dtb"/>
#             </swrl:DatavaluedPropertyAtom>
#           </rdf:first>
#           <rdf:rest>
#             <rdf:Description>
#               <rdf:first>
#                 <swrl:BuiltinAtom>
#                   <swrl:builtin rdf:resource="http://www.w3.org/2003/11/swrlb#greaterThanOrEqual"/>
#                   <swrl:arguments>
#                     <rdf:Description>
#                       <rdf:first rdf:resource="urn:swrl#dtb"/>
#                       <rdf:rest>
#                         <rdf:Description>
#                           <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                           <rdf:first rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">8.0</rdf:first>
#                         </rdf:Description>
#                       </rdf:rest>
#                     </rdf:Description>
#                   </swrl:arguments>
#                 </swrl:BuiltinAtom>
#               </rdf:first>
#               <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#             </rdf:Description>
#           </rdf:rest>
#         </rdf:Description>
#       </rdf:rest>
#     </rdf:Description>
#   </swrl:body>
#   <swrl:head>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:DatavaluedPropertyAtom>
#           <swrl:propertyPredicate rdf:resource="#hocLuc"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#           <swrl:argument2 rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Giỏi</swrl:argument2>
#         </swrl:DatavaluedPropertyAtom>
#       </rdf:first>
#       <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#     </rdf:Description>
#   </swrl:head>
# </swrl:Imp>
#
# <swrl:Imp>
#   <swrl:body>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:ClassAtom>
#           <swrl:classPredicate rdf:resource="#HocSinh"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#         </swrl:ClassAtom>
#       </rdf:first>
#       <rdf:rest>
#         <rdf:Description>
#           <rdf:first>
#             <swrl:IndividualPropertyAtom>
#               <swrl:propertyPredicate rdf:resource="#cha"/>
#               <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#               <swrl:argument2 rdf:resource="urn:swrl#ph1"/>
#             </swrl:IndividualPropertyAtom>
#           </rdf:first>
#           <rdf:rest>
#             <rdf:Description>
#               <rdf:first>
#                 <swrl:IndividualPropertyAtom>
#                   <swrl:propertyPredicate rdf:resource="#me"/>
#                   <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#                   <swrl:argument2 rdf:resource="urn:swrl#ph2"/>
#                 </swrl:IndividualPropertyAtom>
#               </rdf:first>
#               <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#             </rdf:Description>
#           </rdf:rest>
#         </rdf:Description>
#       </rdf:rest>
#     </rdf:Description>
#   </swrl:body>
#   <swrl:head>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:IndividualPropertyAtom>
#           <swrl:propertyPredicate rdf:resource="#vo"/>
#           <swrl:argument1 rdf:resource="urn:swrl#ph1"/>
#           <swrl:argument2 rdf:resource="urn:swrl#ph2"/>
#         </swrl:IndividualPropertyAtom>
#       </rdf:first>
#       <rdf:rest>
#         <rdf:Description>
#           <rdf:first>
#             <swrl:IndividualPropertyAtom>
#               <swrl:propertyPredicate rdf:resource="#chong"/>
#               <swrl:argument1 rdf:resource="urn:swrl#ph2"/>
#               <swrl:argument2 rdf:resource="urn:swrl#ph1"/>
#             </swrl:IndividualPropertyAtom>
#           </rdf:first>
#           <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#         </rdf:Description>
#       </rdf:rest>
#     </rdf:Description>
#   </swrl:head>
# </swrl:Imp>
#
# <swrl:Imp>
#   <swrl:body>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:ClassAtom>
#           <swrl:classPredicate rdf:resource="#HocSinh"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#         </swrl:ClassAtom>
#       </rdf:first>
#       <rdf:rest>
#         <rdf:Description>
#           <rdf:first>
#             <swrl:IndividualPropertyAtom>
#               <swrl:propertyPredicate rdf:resource="#cha"/>
#               <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#               <swrl:argument2 rdf:resource="urn:swrl#c"/>
#             </swrl:IndividualPropertyAtom>
#           </rdf:first>
#           <rdf:rest>
#             <rdf:Description>
#               <rdf:first>
#                 <swrl:IndividualPropertyAtom>
#                   <swrl:propertyPredicate rdf:resource="#me"/>
#                   <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#                   <swrl:argument2 rdf:resource="urn:swrl#m"/>
#                 </swrl:IndividualPropertyAtom>
#               </rdf:first>
#               <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#             </rdf:Description>
#           </rdf:rest>
#         </rdf:Description>
#       </rdf:rest>
#     </rdf:Description>
#   </swrl:body>
#   <swrl:head>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:IndividualPropertyAtom>
#           <swrl:propertyPredicate rdf:resource="#phuHuynh"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#           <swrl:argument2 rdf:resource="urn:swrl#c"/>
#         </swrl:IndividualPropertyAtom>
#       </rdf:first>
#       <rdf:rest>
#         <rdf:Description>
#           <rdf:first>
#             <swrl:IndividualPropertyAtom>
#               <swrl:propertyPredicate rdf:resource="#phuHuynh"/>
#               <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#               <swrl:argument2 rdf:resource="urn:swrl#m"/>
#             </swrl:IndividualPropertyAtom>
#           </rdf:first>
#           <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#         </rdf:Description>
#       </rdf:rest>
#     </rdf:Description>
#   </swrl:head>
# </swrl:Imp>
#
#
# </rdf:RDF>

# %% [markdown]
# ### Thêm dữ liệu

# %%
# # Đọc CSDL từ file
# onto = get_ontology("../app/data/education.owl").load()

# %%
# %run ../app/models/data.py
create_Data(soLopMoiKhoi = 3, soHSMoiLop = 5, soHSCoAnhEm = 20, soGVMoiMon = 3, soGVDay2Mon = 5)
# Lưu CSDL ra file
onto.save(file="../app/data/education.owl", format='rdfxml') # 'ntriples' / "rdfxml"
with open("../app/data/education.owl", "r") as f:
    print(f.read())
# Out:
# <?xml version="1.0"?>
# <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#"
#          xmlns:xsd="http://www.w3.org/2001/XMLSchema#"
#          xmlns:rdfs="http://www.w3.org/2000/01/rdf-schema#"
#          xmlns:owl="http://www.w3.org/2002/07/owl#"
#          xml:base="http://hc.com/school"
#          xmlns="http://hc.com/school#"
#          xmlns:swrl="http://www.w3.org/2003/11/swrl#">
#
# <owl:Ontology rdf:about="http://hc.com/school"/>
#
# <owl:ObjectProperty rdf:about="#thanhVien">
#   <rdfs:domain rdf:resource="#ToChuc"/>
#   <rdfs:range rdf:resource="#Nguoi"/>
#   <owl:inverseOf rdf:resource="#toChuc"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#phong">
#   <rdfs:domain rdf:resource="#ToChuc"/>
#   <rdfs:range rdf:resource="#Phong"/>
#   <owl:inverseOf rdf:resource="#suDungBoi"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#toChuc">
#   <rdfs:domain rdf:resource="#Nguoi"/>
#   <rdfs:range rdf:resource="#ToChuc"/>
#   <owl:inverseOf rdf:resource="#thanhVien"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#chucVu">
#   <rdfs:domain rdf:resource="#NhanVien"/>
#   <rdfs:range rdf:resource="#ChucVu"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#con">
#   <rdfs:domain rdf:resource="#PhuHuynh"/>
#   <rdfs:range rdf:resource="#HocSinh"/>
#   <owl:inverseOf rdf:resource="#phuHuynh"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#giaoVienChuNhiem">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#LopHoc"/>
#   <rdfs:range rdf:resource="#GiaoVien"/>
#   <owl:inverseOf rdf:resource="#lopChuNhiem"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#dsHocSinh">
#   <rdfs:domain rdf:resource="#LopHoc"/>
#   <rdfs:range rdf:resource="#HocSinh"/>
#   <owl:inverseOf rdf:resource="#hocLop"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#hocLop">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#LopHoc"/>
#   <owl:inverseOf rdf:resource="#dsHocSinh"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#phuHuynh">
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#PhuHuynh"/>
#   <owl:inverseOf rdf:resource="#con"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#me">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:subPropertyOf rdf:resource="#phuHuynh"/>
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#Me"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#cha">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:subPropertyOf rdf:resource="#phuHuynh"/>
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#Cha"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#diemSo">
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#DiemSo"/>
#   <owl:inverseOf rdf:resource="#hocSinh"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#dayMon">
#   <rdfs:domain rdf:resource="#GiaoVien"/>
#   <rdfs:range rdf:resource="#MonHoc"/>
#   <owl:inverseOf rdf:resource="#giaoVienDay"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#giangDay">
#   <rdfs:domain rdf:resource="#GiaoVien"/>
#   <rdfs:range rdf:resource="#GiangDay"/>
#   <owl:inverseOf rdf:resource="#giaoVien"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#lopChuNhiem">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#GiaoVien"/>
#   <rdfs:range rdf:resource="#LopHoc"/>
#   <owl:inverseOf rdf:resource="#giaoVienChuNhiem"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#giaoVienDay">
#   <rdfs:domain rdf:resource="#MonHoc"/>
#   <rdfs:range rdf:resource="#GiaoVien"/>
#   <owl:inverseOf rdf:resource="#dayMon"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#hocSinh">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="#HocSinh"/>
#   <owl:inverseOf rdf:resource="#diemSo"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#monHoc">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="#MonHoc"/>
#   <rdfs:domain rdf:resource="#GiangDay"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#giaoVien">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#GiangDay"/>
#   <rdfs:range rdf:resource="#GiaoVien"/>
#   <owl:inverseOf rdf:resource="#giangDay"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#lopHoc">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#GiangDay"/>
#   <rdfs:range rdf:resource="#LopHoc"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#suDungBoi">
#   <rdfs:domain rdf:resource="#Phong"/>
#   <rdfs:range rdf:resource="#ToChuc"/>
#   <owl:inverseOf rdf:resource="#phong"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#quanLy">
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:range rdf:resource="#Nguoi"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#thamGia">
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:range rdf:resource="#Nguoi"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#nguoi">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemDanh"/>
#   <rdfs:range rdf:resource="#Nguoi"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#hoatDong">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemDanh"/>
#   <rdfs:range rdf:resource="#HoatDong"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#anhChiEm">
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#HocSinh"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#anh">
#   <rdfs:subPropertyOf rdf:resource="#anhChiEm"/>
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#Anh"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#chi">
#   <rdfs:subPropertyOf rdf:resource="#anhChiEm"/>
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#Chi"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#em">
#   <rdfs:subPropertyOf rdf:resource="#anhChiEm"/>
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#Em"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#vo">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Cha"/>
#   <rdfs:range rdf:resource="#Me"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#chong">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Me"/>
#   <rdfs:range rdf:resource="#Cha"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#phongLamViec">
#   <rdfs:domain rdf:resource="#NhanVien"/>
#   <rdfs:range rdf:resource="#Phong"/>
# </owl:ObjectProperty>
#
# <owl:DatatypeProperty rdf:about="#ten">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#ChucVu"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
#   <rdfs:domain rdf:resource="#ToChuc"/>
#   <rdfs:domain rdf:resource="#MonHoc"/>
#   <rdfs:domain rdf:resource="#Phong"/>
#   <rdfs:domain rdf:resource="#HoatDong"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#phuCap">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#ChucVu"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#hoTen">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Nguoi"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngaySinh">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Nguoi"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#gioiTinh">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Nguoi"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#heSoLuong">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#NhanVien"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngheNghiep">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#PhuHuynh"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#diemTB">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
#   <rdfs:domain rdf:resource="#DiemSo"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#hanhKiem">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#trinhDo">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#GiaoVien"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#soTiet">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#MonHoc"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#integer"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#heSo1">
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#heSo2">
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#heSo3">
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayBatDau">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayKetThuc">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayGio">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemDanh"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#dateTime"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#trangThai">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemDanh"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#hocLuc">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#danhHieu">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:Class rdf:about="#ChucVu">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#ToChuc">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#Nguoi">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#NhanVien">
#   <rdfs:subClassOf rdf:resource="#Nguoi"/>
# </owl:Class>
#
# <owl:Class rdf:about="#PhuHuynh">
#   <rdfs:subClassOf rdf:resource="#Nguoi"/>
# </owl:Class>
#
# <owl:Class rdf:about="#Cha">
#   <rdfs:subClassOf rdf:resource="#PhuHuynh"/>
# </owl:Class>
#
# <owl:Class rdf:about="#Me">
#   <rdfs:subClassOf rdf:resource="#PhuHuynh"/>
# </owl:Class>
#
# <owl:Class rdf:about="#LopHoc">
#   <rdfs:subClassOf rdf:resource="#ToChuc"/>
# </owl:Class>
#
# <owl:Class rdf:about="#HocSinh">
#   <rdfs:subClassOf rdf:resource="#Nguoi"/>
# </owl:Class>
#
# <owl:Class rdf:about="#Anh">
#   <rdfs:subClassOf rdf:resource="#HocSinh"/>
# </owl:Class>
#
# <owl:Class rdf:about="#Chi">
#   <rdfs:subClassOf rdf:resource="#HocSinh"/>
# </owl:Class>
#
# <owl:Class rdf:about="#Em">
#   <rdfs:subClassOf rdf:resource="#HocSinh"/>
# </owl:Class>
#
# <owl:Class rdf:about="#GiaoVien">
#   <rdfs:subClassOf rdf:resource="#NhanVien"/>
# </owl:Class>
#
# <owl:Class rdf:about="#MonHoc">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#DiemSo">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#GiangDay">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#Phong">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#HoatDong">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#DiemDanh">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <swrl:Variable rdf:about="urn:swrl#hs"/>
#
# <swrl:Variable rdf:about="urn:swrl#c"/>
#
# <swrl:Variable rdf:about="urn:swrl#m"/>
#
# <swrl:Variable rdf:about="urn:swrl#ph1"/>
#
# <swrl:Variable rdf:about="urn:swrl#ph2"/>
#
# <swrl:Variable rdf:about="urn:swrl#dtb"/>
#
# <swrl:Variable rdf:about="urn:swrl#hl"/>
#
# <swrl:Variable rdf:about="urn:swrl#hk"/>
#
# <Phong rdf:about="#Phong10C01">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <ten rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Phòng 10C01</ten>
# </Phong>
#
# <LopHoc rdf:about="#10C01">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <phong rdf:resource="#Phong10C01"/>
#   <ten rdf:datatype="http://www.w3.org/2001/XMLSchema#string">10C01</ten>
# </LopHoc>
#
# <HocSinh rdf:about="#hocsinh1">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#10C01"/>
#   <cha rdf:resource="#cha26"/>
#   <me rdf:resource="#me26"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Trần Mai Quỳnh</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-10-06</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <diemTB rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">7.95</diemTB>
#   <hanhKiem rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khá</hanhKiem>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh2">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#10C01"/>
#   <cha rdf:resource="#cha43"/>
#   <me rdf:resource="#me43"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tôn Quý Thiên</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-04-29</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <diemTB rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">7.71</diemTB>
#   <hanhKiem rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khá</hanhKiem>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh3">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#10C01"/>
#   <cha rdf:resource="#cha12"/>
#   <me rdf:resource="#me12"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Phạm Bảo Quỳnh</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-07-26</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <diemTB rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">7.12</diemTB>
#   <hanhKiem rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khá</hanhKiem>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh4">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#10C01"/>
#   <cha rdf:resource="#cha4"/>
#   <me rdf:resource="#me4"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đoàn Hồng Hải</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-12-12</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <diemTB rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">7.75</diemTB>
#   <hanhKiem rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khá</hanhKiem>
# </HocSinh>
#
# <Cha rdf:about="#cha4">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Trần Mai Vân</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1975-02-19</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nông dân</ngheNghiep>
# </Cha>
#
# <Me rdf:about="#me4">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Ngô Minh Quân</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1970-09-30</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Giáo viên</ngheNghiep>
# </Me>
#
# <HocSinh rdf:about="#hocsinh5">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#10C01"/>
#   <cha rdf:resource="#cha5"/>
#   <me rdf:resource="#me5"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đào Hữu Việt</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-09-14</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <diemTB rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">8.75</diemTB>
#   <hanhKiem rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khá</hanhKiem>
# </HocSinh>
#
# <Cha rdf:about="#cha5">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Quách Hoài Thuận</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1980-06-25</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Giáo viên</ngheNghiep>
# </Cha>
#
# <Me rdf:about="#me5">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đặng Hoài Xuân</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1972-05-31</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Giáo viên</ngheNghiep>
# </Me>
#
# <Phong rdf:about="#Phong10C02">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <ten rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Phòng 10C02</ten>
# </Phong>
#
# <LopHoc rdf:about="#10C02">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <phong rdf:resource="#Phong10C02"/>
#   <ten rdf:datatype="http://www.w3.org/2001/XMLSchema#string">10C02</ten>
# </LopHoc>
#
# <HocSinh rdf:about="#hocsinh6">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#10C02"/>
#   <cha rdf:resource="#cha6"/>
#   <me rdf:resource="#me6"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Bành Thị Nhật</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-12-18</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <diemTB rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">5.47</diemTB>
#   <hanhKiem rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khá</hanhKiem>
# </HocSinh>
#
# <Cha rdf:about="#cha6">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tô Hồng Vinh</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1980-05-29</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nông dân</ngheNghiep>
# </Cha>
#
# <Me rdf:about="#me6">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nguyễn Ngọc Hiền</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1975-10-06</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Giáo viên</ngheNghiep>
# </Me>
#
# <HocSinh rdf:about="#hocsinh7">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#10C02"/>
#   <cha rdf:resource="#cha5"/>
#   <me rdf:resource="#me5"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tăng Thu Hải</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-08-23</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <diemTB rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">3.74</diemTB>
#   <hanhKiem rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Yếu</hanhKiem>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh8">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#10C02"/>
#   <cha rdf:resource="#cha22"/>
#   <me rdf:resource="#me22"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Quách Hữu Quỳnh</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-07-06</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <diemTB rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">6.97</diemTB>
#   <hanhKiem rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tốt</hanhKiem>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh9">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#10C02"/>
#   <cha rdf:resource="#cha9"/>
#   <me rdf:resource="#me9"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Lương Hữu Hùng</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-08-17</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <diemTB rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">6.86</diemTB>
#   <hanhKiem rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khá</hanhKiem>
# </HocSinh>
#
# <Cha rdf:about="#cha9">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Lương Minh Hiền</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1979-05-17</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Chủ doanh nghiệp</ngheNghiep>
# </Cha>
#
# <Me rdf:about="#me9">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Phan Văn Long</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1973-12-06</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Bác sĩ</ngheNghiep>
# </Me>
#
# <HocSinh rdf:about="#hocsinh10">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#10C02"/>
#   <cha rdf:resource="#cha10"/>
#   <me rdf:resource="#me10"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Hoàng Quốc Tú</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-09-24</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <diemTB rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">6.85</diemTB>
#   <hanhKiem rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tốt</hanhKiem>
# </HocSinh>
#
# <Cha rdf:about="#cha10">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Phạm Ngọc Nhật</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1974-01-11</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Công nhân</ngheNghiep>
# </Cha>
#
# <Me rdf:about="#me10">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Quách Thu Tùng</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1977-09-01</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Giáo viên</ngheNghiep>
# </Me>
#
# <Phong rdf:about="#Phong10C03">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <ten rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Phòng 10C03</ten>
# </Phong>
#
# <LopHoc rdf:about="#10C03">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <phong rdf:resource="#Phong10C03"/>
#   <ten rdf:datatype="http://www.w3.org/2001/XMLSchema#string">10C03</ten>
# </LopHoc>
#
# <HocSinh rdf:about="#hocsinh11">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#10C03"/>
#   <cha rdf:resource="#cha40"/>
#   <me rdf:resource="#me40"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đặng Thanh Việt</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-05-15</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <diemTB rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">8.33</diemTB>
#   <hanhKiem rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khá</hanhKiem>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh12">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#10C03"/>
#   <cha rdf:resource="#cha12"/>
#   <me rdf:resource="#me12"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Trần Minh Sơn</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-02-01</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <diemTB rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">4.65</diemTB>
#   <hanhKiem rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Yếu</hanhKiem>
# </HocSinh>
#
# <Cha rdf:about="#cha12">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đặng Anh Dũng</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1975-12-19</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nông dân</ngheNghiep>
# </Cha>
#
# <Me rdf:about="#me12">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đoàn Văn Dũng</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1975-05-21</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nông dân</ngheNghiep>
# </Me>
#
# <HocSinh rdf:about="#hocsinh13">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#10C03"/>
#   <cha rdf:resource="#cha4"/>
#   <me rdf:resource="#me4"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Lương Văn Thiên</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-10-22</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <diemTB rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">4.22</diemTB>
#   <hanhKiem rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Trung bình</hanhKiem>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh14">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#10C03"/>
#   <cha rdf:resource="#cha33"/>
#   <me rdf:resource="#me33"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Ngô Minh Ngọc</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-03-21</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <diemTB rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">7.37</diemTB>
#   <hanhKiem rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khá</hanhKiem>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh15">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#10C03"/>
#   <cha rdf:resource="#cha15"/>
#   <me rdf:resource="#me15"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Trần Thanh Thảo</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-09-17</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <diemTB rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">5.26</diemTB>
#   <hanhKiem rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khá</hanhKiem>
# </HocSinh>
#
# <Cha rdf:about="#cha15">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Mai Minh Hiền</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1971-04-10</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Chủ doanh nghiệp</ngheNghiep>
# </Cha>
#
# <Me rdf:about="#me15">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Bùi Thu Hiền</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1978-04-08</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Bác sĩ</ngheNghiep>
# </Me>
#
# <Phong rdf:about="#Phong11B01">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <ten rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Phòng 11B01</ten>
# </Phong>
#
# <LopHoc rdf:about="#11B01">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <phong rdf:resource="#Phong11B01"/>
#   <ten rdf:datatype="http://www.w3.org/2001/XMLSchema#string">11B01</ten>
# </LopHoc>
#
# <HocSinh rdf:about="#hocsinh16">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#11B01"/>
#   <cha rdf:resource="#cha16"/>
#   <me rdf:resource="#me16"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Mai Thu Minh</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-08-01</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <diemTB rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">7.57</diemTB>
#   <hanhKiem rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tốt</hanhKiem>
# </HocSinh>
#
# <Cha rdf:about="#cha16">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đoàn Thị Ngọc</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1972-11-21</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Bác sĩ</ngheNghiep>
# </Cha>
#
# <Me rdf:about="#me16">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tô Ngọc Xuân</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1979-02-19</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Kỹ sư</ngheNghiep>
# </Me>
#
# <HocSinh rdf:about="#hocsinh17">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#11B01"/>
#   <cha rdf:resource="#cha17"/>
#   <me rdf:resource="#me17"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Thái Đình Quân</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-09-10</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <diemTB rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">8.04</diemTB>
#   <hanhKiem rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khá</hanhKiem>
# </HocSinh>
#
# <Cha rdf:about="#cha17">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Hoàng Kim Thuận</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1974-05-24</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Giáo viên</ngheNghiep>
# </Cha>
#
# <Me rdf:about="#me17">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Hồ Đình Xuân</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1973-11-12</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Kỹ sư</ngheNghiep>
# </Me>
#
# <HocSinh rdf:about="#hocsinh18">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#11B01"/>
#   <cha rdf:resource="#cha18"/>
#   <me rdf:resource="#me18"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Thái Hữu Vinh</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-07-17</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <diemTB rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">5.19</diemTB>
#   <hanhKiem rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Trung bình</hanhKiem>
# </HocSinh>
#
# <Cha rdf:about="#cha18">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tô Thanh Hoàng</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1977-03-17</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Kỹ sư</ngheNghiep>
# </Cha>
#
# <Me rdf:about="#me18">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Lương Thu Thiên</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1977-05-13</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Công nhân</ngheNghiep>
# </Me>
#
# <HocSinh rdf:about="#hocsinh19">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#11B01"/>
#   <cha rdf:resource="#cha19"/>
#   <me rdf:resource="#me19"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Bùi Thanh Tú</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-04-07</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <diemTB rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">8.93</diemTB>
#   <hanhKiem rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tốt</hanhKiem>
# </HocSinh>
#
# <Cha rdf:about="#cha19">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Bùi Ngọc Việt</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1970-09-02</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Công nhân</ngheNghiep>
# </Cha>
#
# <Me rdf:about="#me19">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Võ Anh Hùng</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1972-05-09</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Công nhân</ngheNghiep>
# </Me>
#
# <HocSinh rdf:about="#hocsinh20">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#11B01"/>
#   <cha rdf:resource="#cha20"/>
#   <me rdf:resource="#me20"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tô Hữu Tùng</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-06-20</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <diemTB rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">8.95</diemTB>
#   <hanhKiem rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tốt</hanhKiem>
# </HocSinh>
#
# <Cha rdf:about="#cha20">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Hoàng Mai Thiện</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1977-07-13</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Giáo viên</ngheNghiep>
# </Cha>
#
# <Me rdf:about="#me20">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tôn Quý Thiên</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1976-12-06</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Giáo viên</ngheNghiep>
# </Me>
#
# <Phong rdf:about="#Phong11B02">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <ten rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Phòng 11B02</ten>
# </Phong>
#
# <LopHoc rdf:about="#11B02">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <phong rdf:resource="#Phong11B02"/>
#   <ten rdf:datatype="http://www.w3.org/2001/XMLSchema#string">11B02</ten>
# </LopHoc>
#
# <HocSinh rdf:about="#hocsinh21">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#11B02"/>
#   <cha rdf:resource="#cha27"/>
#   <me rdf:resource="#me27"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tạ Hoài Minh</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-10-17</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <diemTB rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">6.92</diemTB>
#   <hanhKiem rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khá</hanhKiem>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh22">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#11B02"/>
#   <cha rdf:resource="#cha22"/>
#   <me rdf:resource="#me22"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đỗ Anh Hải</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-07-01</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <diemTB rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">6.36</diemTB>
#   <hanhKiem rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Trung bình</hanhKiem>
# </HocSinh>
#
# <Cha rdf:about="#cha22">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Lý Thu Bình</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1977-09-09</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Bác sĩ</ngheNghiep>
# </Cha>
#
# <Me rdf:about="#me22">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Võ Đình Khánh</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1978-02-16</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nông dân</ngheNghiep>
# </Me>
#
# <HocSinh rdf:about="#hocsinh23">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#11B02"/>
#   <cha rdf:resource="#cha45"/>
#   <me rdf:resource="#me45"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Trương Ngọc Vinh</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-12-06</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <diemTB rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">4.46</diemTB>
#   <hanhKiem rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Trung bình</hanhKiem>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh24">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#11B02"/>
#   <cha rdf:resource="#cha30"/>
#   <me rdf:resource="#me30"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đào Hồng Quang</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-03-26</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <diemTB rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">8.82</diemTB>
#   <hanhKiem rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khá</hanhKiem>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh25">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#11B02"/>
#   <cha rdf:resource="#cha17"/>
#   <me rdf:resource="#me17"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Phùng Văn Quang</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-05-10</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <diemTB rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">3.83</diemTB>
#   <hanhKiem rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Trung bình</hanhKiem>
# </HocSinh>
#
# <Phong rdf:about="#Phong11B03">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <ten rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Phòng 11B03</ten>
# </Phong>
#
# <LopHoc rdf:about="#11B03">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <phong rdf:resource="#Phong11B03"/>
#   <ten rdf:datatype="http://www.w3.org/2001/XMLSchema#string">11B03</ten>
# </LopHoc>
#
# <HocSinh rdf:about="#hocsinh26">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#11B03"/>
#   <cha rdf:resource="#cha26"/>
#   <me rdf:resource="#me26"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Lê Hoài Nhật</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-10-05</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <diemTB rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">6.9</diemTB>
#   <hanhKiem rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tốt</hanhKiem>
# </HocSinh>
#
# <Cha rdf:about="#cha26">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Phùng Văn Hùng</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1980-01-02</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Chủ doanh nghiệp</ngheNghiep>
# </Cha>
#
# <Me rdf:about="#me26">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tô Đình Hoàng</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1971-04-29</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Chủ doanh nghiệp</ngheNghiep>
# </Me>
#
# <HocSinh rdf:about="#hocsinh27">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#11B03"/>
#   <cha rdf:resource="#cha27"/>
#   <me rdf:resource="#me27"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Vũ Kim Linh</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-04-28</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <diemTB rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">9.39</diemTB>
#   <hanhKiem rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tốt</hanhKiem>
# </HocSinh>
#
# <Cha rdf:about="#cha27">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Dương Thanh An</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1976-04-28</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Bác sĩ</ngheNghiep>
# </Cha>
#
# <Me rdf:about="#me27">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Bành Thu Hiền</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1971-07-20</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Kỹ sư</ngheNghiep>
# </Me>
#
# <HocSinh rdf:about="#hocsinh28">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#11B03"/>
#   <cha rdf:resource="#cha20"/>
#   <me rdf:resource="#me20"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đặng Kim Linh</hoTen>
# ...
#                                 </rdf:Description>
#                               </rdf:rest>
#                             </rdf:Description>
#                           </swrl:arguments>
#                         </swrl:BuiltinAtom>
#                       </rdf:first>
#                       <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                     </rdf:Description>
#                   </rdf:rest>
#                 </rdf:Description>
#               </rdf:rest>
#             </rdf:Description>
#           </rdf:rest>
#         </rdf:Description>
#       </rdf:rest>
#     </rdf:Description>
#   </swrl:body>
#   <swrl:head>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:DatavaluedPropertyAtom>
#           <swrl:propertyPredicate rdf:resource="#danhHieu"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#           <swrl:argument2 rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Học sinh giỏi</swrl:argument2>
#         </swrl:DatavaluedPropertyAtom>
#       </rdf:first>
#       <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#     </rdf:Description>
#   </swrl:head>
# </swrl:Imp>
#
# <swrl:Imp>
#   <swrl:body>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:ClassAtom>
#           <swrl:classPredicate rdf:resource="#HocSinh"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#         </swrl:ClassAtom>
#       </rdf:first>
#       <rdf:rest>
#         <rdf:Description>
#           <rdf:first>
#             <swrl:DatavaluedPropertyAtom>
#               <swrl:propertyPredicate rdf:resource="#diemTB"/>
#               <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#               <swrl:argument2 rdf:resource="urn:swrl#dtb"/>
#             </swrl:DatavaluedPropertyAtom>
#           </rdf:first>
#           <rdf:rest>
#             <rdf:Description>
#               <rdf:first>
#                 <swrl:BuiltinAtom>
#                   <swrl:builtin rdf:resource="http://www.w3.org/2003/11/swrlb#lessThan"/>
#                   <swrl:arguments>
#                     <rdf:Description>
#                       <rdf:first rdf:resource="urn:swrl#dtb"/>
#                       <rdf:rest>
#                         <rdf:Description>
#                           <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                           <rdf:first rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">5.0</rdf:first>
#                         </rdf:Description>
#                       </rdf:rest>
#                     </rdf:Description>
#                   </swrl:arguments>
#                 </swrl:BuiltinAtom>
#               </rdf:first>
#               <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#             </rdf:Description>
#           </rdf:rest>
#         </rdf:Description>
#       </rdf:rest>
#     </rdf:Description>
#   </swrl:body>
#   <swrl:head>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:DatavaluedPropertyAtom>
#           <swrl:propertyPredicate rdf:resource="#hocLuc"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#           <swrl:argument2 rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Yếu</swrl:argument2>
#         </swrl:DatavaluedPropertyAtom>
#       </rdf:first>
#       <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#     </rdf:Description>
#   </swrl:head>
# </swrl:Imp>
#
# <swrl:Imp>
#   <swrl:body>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:ClassAtom>
#           <swrl:classPredicate rdf:resource="#HocSinh"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#         </swrl:ClassAtom>
#       </rdf:first>
#       <rdf:rest>
#         <rdf:Description>
#           <rdf:first>
#             <swrl:DatavaluedPropertyAtom>
#               <swrl:propertyPredicate rdf:resource="#diemTB"/>
#               <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#               <swrl:argument2 rdf:resource="urn:swrl#dtb"/>
#             </swrl:DatavaluedPropertyAtom>
#           </rdf:first>
#           <rdf:rest>
#             <rdf:Description>
#               <rdf:first>
#                 <swrl:BuiltinAtom>
#                   <swrl:builtin rdf:resource="http://www.w3.org/2003/11/swrlb#greaterThanOrEqual"/>
#                   <swrl:arguments>
#                     <rdf:Description>
#                       <rdf:first rdf:resource="urn:swrl#dtb"/>
#                       <rdf:rest>
#                         <rdf:Description>
#                           <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                           <rdf:first rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">5.0</rdf:first>
#                         </rdf:Description>
#                       </rdf:rest>
#                     </rdf:Description>
#                   </swrl:arguments>
#                 </swrl:BuiltinAtom>
#               </rdf:first>
#               <rdf:rest>
#                 <rdf:Description>
#                   <rdf:first>
#                     <swrl:BuiltinAtom>
#                       <swrl:builtin rdf:resource="http://www.w3.org/2003/11/swrlb#lessThan"/>
#                       <swrl:arguments>
#                         <rdf:Description>
#                           <rdf:first rdf:resource="urn:swrl#dtb"/>
#                           <rdf:rest>
#                             <rdf:Description>
#                               <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                               <rdf:first rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">6.5</rdf:first>
#                             </rdf:Description>
#                           </rdf:rest>
#                         </rdf:Description>
#                       </swrl:arguments>
#                     </swrl:BuiltinAtom>
#                   </rdf:first>
#                   <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                 </rdf:Description>
#               </rdf:rest>
#             </rdf:Description>
#           </rdf:rest>
#         </rdf:Description>
#       </rdf:rest>
#     </rdf:Description>
#   </swrl:body>
#   <swrl:head>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:DatavaluedPropertyAtom>
#           <swrl:propertyPredicate rdf:resource="#hocLuc"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#           <swrl:argument2 rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Trung bình</swrl:argument2>
#         </swrl:DatavaluedPropertyAtom>
#       </rdf:first>
#       <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#     </rdf:Description>
#   </swrl:head>
# </swrl:Imp>
#
# <swrl:Imp>
#   <swrl:body>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:ClassAtom>
#           <swrl:classPredicate rdf:resource="#HocSinh"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#         </swrl:ClassAtom>
#       </rdf:first>
#       <rdf:rest>
#         <rdf:Description>
#           <rdf:first>
#             <swrl:DatavaluedPropertyAtom>
#               <swrl:propertyPredicate rdf:resource="#diemTB"/>
#               <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#               <swrl:argument2 rdf:resource="urn:swrl#dtb"/>
#             </swrl:DatavaluedPropertyAtom>
#           </rdf:first>
#           <rdf:rest>
#             <rdf:Description>
#               <rdf:first>
#                 <swrl:BuiltinAtom>
#                   <swrl:builtin rdf:resource="http://www.w3.org/2003/11/swrlb#greaterThanOrEqual"/>
#                   <swrl:arguments>
#                     <rdf:Description>
#                       <rdf:first rdf:resource="urn:swrl#dtb"/>
#                       <rdf:rest>
#                         <rdf:Description>
#                           <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                           <rdf:first rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">6.5</rdf:first>
#                         </rdf:Description>
#                       </rdf:rest>
#                     </rdf:Description>
#                   </swrl:arguments>
#                 </swrl:BuiltinAtom>
#               </rdf:first>
#               <rdf:rest>
#                 <rdf:Description>
#                   <rdf:first>
#                     <swrl:BuiltinAtom>
#                       <swrl:builtin rdf:resource="http://www.w3.org/2003/11/swrlb#lessThan"/>
#                       <swrl:arguments>
#                         <rdf:Description>
#                           <rdf:first rdf:resource="urn:swrl#dtb"/>
#                           <rdf:rest>
#                             <rdf:Description>
#                               <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                               <rdf:first rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">8.0</rdf:first>
#                             </rdf:Description>
#                           </rdf:rest>
#                         </rdf:Description>
#                       </swrl:arguments>
#                     </swrl:BuiltinAtom>
#                   </rdf:first>
#                   <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                 </rdf:Description>
#               </rdf:rest>
#             </rdf:Description>
#           </rdf:rest>
#         </rdf:Description>
#       </rdf:rest>
#     </rdf:Description>
#   </swrl:body>
#   <swrl:head>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:DatavaluedPropertyAtom>
#           <swrl:propertyPredicate rdf:resource="#hocLuc"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#           <swrl:argument2 rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Khá</swrl:argument2>
#         </swrl:DatavaluedPropertyAtom>
#       </rdf:first>
#       <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#     </rdf:Description>
#   </swrl:head>
# </swrl:Imp>
#
# <swrl:Imp>
#   <swrl:body>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:ClassAtom>
#           <swrl:classPredicate rdf:resource="#HocSinh"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#         </swrl:ClassAtom>
#       </rdf:first>
#       <rdf:rest>
#         <rdf:Description>
#           <rdf:first>
#             <swrl:DatavaluedPropertyAtom>
#               <swrl:propertyPredicate rdf:resource="#diemTB"/>
#               <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#               <swrl:argument2 rdf:resource="urn:swrl#dtb"/>
#             </swrl:DatavaluedPropertyAtom>
#           </rdf:first>
#           <rdf:rest>
#             <rdf:Description>
#               <rdf:first>
#                 <swrl:BuiltinAtom>
#                   <swrl:builtin rdf:resource="http://www.w3.org/2003/11/swrlb#greaterThanOrEqual"/>
#                   <swrl:arguments>
#                     <rdf:Description>
#                       <rdf:first rdf:resource="urn:swrl#dtb"/>
#                       <rdf:rest>
#                         <rdf:Description>
#                           <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#                           <rdf:first rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">8.0</rdf:first>
#                         </rdf:Description>
#                       </rdf:rest>
#                     </rdf:Description>
#                   </swrl:arguments>
#                 </swrl:BuiltinAtom>
#               </rdf:first>
#               <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#             </rdf:Description>
#           </rdf:rest>
#         </rdf:Description>
#       </rdf:rest>
#     </rdf:Description>
#   </swrl:body>
#   <swrl:head>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:DatavaluedPropertyAtom>
#           <swrl:propertyPredicate rdf:resource="#hocLuc"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#           <swrl:argument2 rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Giỏi</swrl:argument2>
#         </swrl:DatavaluedPropertyAtom>
#       </rdf:first>
#       <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#     </rdf:Description>
#   </swrl:head>
# </swrl:Imp>
#
# <swrl:Imp>
#   <swrl:body>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:ClassAtom>
#           <swrl:classPredicate rdf:resource="#HocSinh"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#         </swrl:ClassAtom>
#       </rdf:first>
#       <rdf:rest>
#         <rdf:Description>
#           <rdf:first>
#             <swrl:IndividualPropertyAtom>
#               <swrl:propertyPredicate rdf:resource="#cha"/>
#               <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#               <swrl:argument2 rdf:resource="urn:swrl#ph1"/>
#             </swrl:IndividualPropertyAtom>
#           </rdf:first>
#           <rdf:rest>
#             <rdf:Description>
#               <rdf:first>
#                 <swrl:IndividualPropertyAtom>
#                   <swrl:propertyPredicate rdf:resource="#me"/>
#                   <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#                   <swrl:argument2 rdf:resource="urn:swrl#ph2"/>
#                 </swrl:IndividualPropertyAtom>
#               </rdf:first>
#               <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#             </rdf:Description>
#           </rdf:rest>
#         </rdf:Description>
#       </rdf:rest>
#     </rdf:Description>
#   </swrl:body>
#   <swrl:head>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:IndividualPropertyAtom>
#           <swrl:propertyPredicate rdf:resource="#vo"/>
#           <swrl:argument1 rdf:resource="urn:swrl#ph1"/>
#           <swrl:argument2 rdf:resource="urn:swrl#ph2"/>
#         </swrl:IndividualPropertyAtom>
#       </rdf:first>
#       <rdf:rest>
#         <rdf:Description>
#           <rdf:first>
#             <swrl:IndividualPropertyAtom>
#               <swrl:propertyPredicate rdf:resource="#chong"/>
#               <swrl:argument1 rdf:resource="urn:swrl#ph2"/>
#               <swrl:argument2 rdf:resource="urn:swrl#ph1"/>
#             </swrl:IndividualPropertyAtom>
#           </rdf:first>
#           <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#         </rdf:Description>
#       </rdf:rest>
#     </rdf:Description>
#   </swrl:head>
# </swrl:Imp>
#
# <swrl:Imp>
#   <swrl:body>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:ClassAtom>
#           <swrl:classPredicate rdf:resource="#HocSinh"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#         </swrl:ClassAtom>
#       </rdf:first>
#       <rdf:rest>
#         <rdf:Description>
#           <rdf:first>
#             <swrl:IndividualPropertyAtom>
#               <swrl:propertyPredicate rdf:resource="#cha"/>
#               <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#               <swrl:argument2 rdf:resource="urn:swrl#c"/>
#             </swrl:IndividualPropertyAtom>
#           </rdf:first>
#           <rdf:rest>
#             <rdf:Description>
#               <rdf:first>
#                 <swrl:IndividualPropertyAtom>
#                   <swrl:propertyPredicate rdf:resource="#me"/>
#                   <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#                   <swrl:argument2 rdf:resource="urn:swrl#m"/>
#                 </swrl:IndividualPropertyAtom>
#               </rdf:first>
#               <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#             </rdf:Description>
#           </rdf:rest>
#         </rdf:Description>
#       </rdf:rest>
#     </rdf:Description>
#   </swrl:body>
#   <swrl:head>
#     <rdf:Description>
#       <rdf:first>
#         <swrl:IndividualPropertyAtom>
#           <swrl:propertyPredicate rdf:resource="#phuHuynh"/>
#           <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#           <swrl:argument2 rdf:resource="urn:swrl#c"/>
#         </swrl:IndividualPropertyAtom>
#       </rdf:first>
#       <rdf:rest>
#         <rdf:Description>
#           <rdf:first>
#             <swrl:IndividualPropertyAtom>
#               <swrl:propertyPredicate rdf:resource="#phuHuynh"/>
#               <swrl:argument1 rdf:resource="urn:swrl#hs"/>
#               <swrl:argument2 rdf:resource="urn:swrl#m"/>
#             </swrl:IndividualPropertyAtom>
#           </rdf:first>
#           <rdf:rest rdf:resource="http://www.w3.org/1999/02/22-rdf-syntax-ns#nil"/>
#         </rdf:Description>
#       </rdf:rest>
#     </rdf:Description>
#   </swrl:head>
# </swrl:Imp>
#
#
# </rdf:RDF>

# %%
# Đọc CSDL từ file
onto = get_ontology("../app/data/education.owl").load()

# In DS học sinh ra màn hình
print("Danh sách học sinh:")
stt = 1
for hs in onto.HocSinh.instances():
    print(stt, hs.hoTen)
    stt += 1
# Out:
# Danh sách học sinh:
# 1 Trần Mai Quỳnh
# 2 Tôn Quý Thiên
# 3 Phạm Bảo Quỳnh
# 4 Đoàn Hồng Hải
# 5 Đào Hữu Việt
# 6 Bành Thị Nhật
# 7 Tăng Thu Hải
# 8 Quách Hữu Quỳnh
# 9 Lương Hữu Hùng
# 10 Hoàng Quốc Tú
# 11 Đặng Thanh Việt
# 12 Trần Minh Sơn
# 13 Lương Văn Thiên
# 14 Ngô Minh Ngọc
# 15 Trần Thanh Thảo
# 16 Mai Thu Minh
# 17 Thái Đình Quân
# 18 Thái Hữu Vinh
# 19 Bùi Thanh Tú
# 20 Tô Hữu Tùng
# 21 Tạ Hoài Minh
# 22 Đỗ Anh Hải
# 23 Trương Ngọc Vinh
# 24 Đào Hồng Quang
# 25 Phùng Văn Quang
# 26 Lê Hoài Nhật
# 27 Vũ Kim Linh
# 28 Đặng Kim Linh
# 29 Tôn Thị Vân
# 30 Đoàn Kim Minh
# 31 Bành Hoài Linh
# 32 Trương Quốc Minh
# 33 Đỗ Hữu Sơn
# 34 Phan Quốc Thuận
# 35 Phan Hồng Minh
# 36 Ngô Quý Hiền
# 37 Quách Thị Nhật
# 38 Đoàn Mai Việt
# 39 Dương Quý Vân
# 40 Nguyễn Bảo Thuận
# 41 Trương Thị Cường
# 42 Hồ Hữu Bình
# 43 Lương Hữu Quỳnh
# 44 Quách Văn Dũng
# 45 Hoàng Quý Thiên

# %%
# In DS giáo viên
print("Danh sách giáo viên:")
for gv in onto.GiaoVien.instances():
    print(gv.hoTen, gv.ngaySinh, gv.gioiTinh, gv.trinhDo, getattr(gv.lopChuNhiem,'ten',''), *[mon.ten for mon in gv.dayMon])
# Out:
# Danh sách giáo viên:
# Phùng Mai Thảo 1989-06-05 Nữ Đại học  Toán học
# Tạ Thu Tú 1975-10-20 Nữ Thạc sĩ  Toán học
# Đoàn Minh Khánh 1985-08-16 Nam Thạc sĩ 11B01 Toán học
# Tạ Mai Khánh 1974-02-18 Nữ Thạc sĩ  Ngữ văn
# Thái Quốc Phương 1982-06-05 Nam Thạc sĩ 10C02 Ngữ văn
# Bùi Đình Thiện 1973-01-08 Nam Thạc sĩ 10C03 Ngữ văn
# Đào Bảo Thúy 1983-01-14 Nam Thạc sĩ  Hóa học
# Trương Văn Nam 1979-09-13 Nam Thạc sĩ 12A01 Hóa học
# Thái Đình Xuân 1977-05-07 Nam Thạc sĩ  Hóa học
# Nguyễn Hữu Khánh 1971-02-10 Nam Đại học  Lịch sử
# Võ Minh Xuân 1982-11-14 Nam Thạc sĩ  Lịch sử
# Lê Hữu Hoàng 1977-11-26 Nam Thạc sĩ  Lịch sử Công nghệ
# Đoàn Thu Long 1984-09-25 Nữ Thạc sĩ  Địa lý
# Quách Hồng Quân 1971-02-19 Nữ Đại học  Địa lý
# Lý Anh Thiện 1983-12-31 Nam Thạc sĩ  Địa lý Lịch sử
# Đặng Quý Thuận 1973-01-24 Nam Đại học  Sinh học
# Thái Thu Thúy 1976-11-17 Nữ Thạc sĩ 10C01 Sinh học
# Đặng Đình An 1982-02-01 Nam Đại học  Sinh học Hóa học
# Lâm Anh Minh 1970-05-25 Nam Đại học  Tiếng Anh
# Quách Đình Thúy 1990-10-21 Nam Đại học  Tiếng Anh
# Quách Hoài Dũng 1982-12-13 Nữ Đại học  Tiếng Anh Hóa học
# Mai Anh Nhật 1970-11-28 Nam Đại học 11B03 GDCD
# Hoàng Kim Thảo 1984-07-30 Nữ Thạc sĩ  GDCD
# Tạ Hoài Hải 1981-06-14 Nữ Thạc sĩ  GDCD
# Mai Quốc An 1989-01-16 Nam Thạc sĩ 12A02 Công nghệ
# Hoàng Hoài Thuận 1979-03-04 Nữ Đại học 12A03 Công nghệ
# Huỳnh Mai Bình 1977-01-30 Nữ Đại học 11B02 Công nghệ
# Bành Anh Bình 1973-10-04 Nam Đại học  Thể dục
# Đinh Thị Thúy 1985-04-27 Nữ Thạc sĩ  Thể dục
# Bùi Mai Hùng 1975-05-20 Nữ Đại học  Thể dục Lịch sử

# %%
# In DS HS trong lớp 10C01
print("Danh sách học sinh lớp 10C01:")
for hs in onto.HocSinh.instances():
    if hs.hocLop.ten == "10C01":
        print(hs.hoTen, hs.ngaySinh, hs.gioiTinh, hs.hocLop.ten)
# Out:
# Danh sách học sinh lớp 10C01:
# Trần Mai Quỳnh 2000-10-06 Nữ 10C01
# Tôn Quý Thiên 2000-04-29 Nam 10C01
# Phạm Bảo Quỳnh 2000-07-26 Nam 10C01
# Đoàn Hồng Hải 2000-12-12 Nữ 10C01
# Đào Hữu Việt 2000-09-14 Nam 10C01

# %%
# in ds GV chủ nhiệm của từng lớp
print("Danh sách giáo viên chủ nhiệm:")
for lop in onto.LopHoc.instances():
    gv = lop.giaoVienChuNhiem
    if gv:
        print(gv.hoTen, gv.ngaySinh, gv.gioiTinh, gv.trinhDo, getattr(gv.lopChuNhiem,'ten',''))
# Out:
# Danh sách giáo viên chủ nhiệm:
# Thái Thu Thúy 1976-11-17 Nữ Thạc sĩ 10C01
# Thái Quốc Phương 1982-06-05 Nam Thạc sĩ 10C02
# Bùi Đình Thiện 1973-01-08 Nam Thạc sĩ 10C03
# Đoàn Minh Khánh 1985-08-16 Nam Thạc sĩ 11B01
# Huỳnh Mai Bình 1977-01-30 Nữ Đại học 11B02
# Mai Anh Nhật 1970-11-28 Nam Đại học 11B03
# Trương Văn Nam 1979-09-13 Nam Thạc sĩ 12A01
# Mai Quốc An 1989-01-16 Nam Thạc sĩ 12A02
# Hoàng Hoài Thuận 1979-03-04 Nữ Đại học 12A03

# %%
# Sửa tên của giáo viên chủ nhiệm Nguyễn Văn X thành Nguyễn Văn Tèo
print("Sửa tên của giáo viên chủ nhiệm Nguyễn Văn X thành Nguyễn Văn Tèo")
for gv in onto.GiaoVien.instances():
    if gv.hoTen == "Nguyễn Văn X":
        gv.hoTen = "Nguyễn Văn Tèo"
        print(gv.hoTen, gv.ngaySinh, gv.gioiTinh, gv.trinhDo, getattr(gv.lopChuNhiem,'ten',''))
# Out:
# Sửa tên của giáo viên chủ nhiệm Nguyễn Văn X thành Nguyễn Văn Tèo

# %%
# Tạo mới một học sinh và thêm vào lớp 10A01
print("Tạo mới một học sinh và thêm vào lớp 10C01")
lop = onto.search_one(ten = "10C01", type = onto.LopHoc)
hs1 = HocSinh(hoTen = "Nguyễn Văn XXX", ngaySinh = "01/01/2011", gioiTinh = "Nam", hocLop = lop)
# In DS HS trong lớp 10A01
print("Danh sách học sinh lớp 10A01:")
print('\n'.join(str(hs.hoTen) for hs in lop.dsHocSinh))
# Out:
# Tạo mới một học sinh và thêm vào lớp 10C01
# Danh sách học sinh lớp 10A01:
# Trần Mai Quỳnh
# Tôn Quý Thiên
# Phạm Bảo Quỳnh
# Đoàn Hồng Hải
# Đào Hữu Việt
# Nguyễn Văn XXX

# %%
# Xoá học sinh có ngày sinh là 01/01/2011
print("Xoá học sinh có ngày sinh là 01/01/2011")
hs_ind = onto.search_one(ngaySinh="01/01/2011", type=onto.HocSinh)
# Nếu individual được tìm thấy, xoá individual đó
if hs_ind is not None:
    destroy_entity(hs_ind)
# Out:
# Xoá học sinh có ngày sinh là 01/01/2011

# %%
# In tất cả điểm số của một học sinh
print("In tất cả điểm số của một học sinh")
hs_ind = onto.search_one(type=onto.HocSinh)
if hs_ind is not None:
    for diem in hs_ind.diemSo:
        print(diem.monHoc.ten, *diem.heSo1, *diem.heSo2, *diem.heSo3)
# Out:
# In tất cả điểm số của một học sinh
# Toán học 7.3 8.8 9.5 7.3 8.8 9.5 6.5 6.5 7.8 7.8
# Ngữ văn 8.3 9.5 5.8 8.3 9.5 5.8 10 10 8.3 8.3
# Hóa học 6.3 8.3 6.3 8.3 10 10 6.8 6.8
# Lịch sử 6.8 7.5 9.3 6.8 7.5 9.3 5.5 5.5 4.5 4.5
# Địa lý 10 9.8 10.0 10 9.8 10.0 9.3 9.3 10.0 10.0
# Sinh học 5.8 8.3 9.8 5.8 8.3 9.8 9.8 9.8 4.8 4.8
# Tiếng Anh 8.5 9.3 10.0 8.5 9.3 10.0 9.8 9.8 10.0 10.0
# GDCD 4.5 7.3 6.3 4.5 7.3 6.3 8.5 8.5 5.5 5.5
# Công nghệ 7.5 5.8 7.5 5.8 7.8 7.8 10 10
# Thể dục 10.0 7.3 4.3 10.0 7.3 4.3 10 10 7.5 7.5

# %%
print(hoTen.iri)
print(HocSinh.iri)
# Out:
# http://hc.com/school#hoTen
# http://hc.com/school#HocSinh

# %%
print('In ra các lớp mà GV dạy')
gv = onto.search_one(type = onto.GiaoVien)
for gd in gv.giangDay:
    print(gd.lopHoc.ten, gd.monHoc.ten)
# Out:
# In ra các lớp mà GV dạy
# 10C01 Toán học
# 10C02 Toán học
# 10C03 Toán học

# %%
print('In các GV dạy lớp 10C03')
lop = onto.search_one(type = onto.LopHoc, ten = '10C03')
gd = onto.search(type = onto.GiangDay, lopHoc = lop)
for g in gd:
    print(g.giaoVien.hoTen, g.monHoc.ten, g.lopHoc.ten)
# Out:
# In các GV dạy lớp 10C03
# Phùng Mai Thảo Toán học 10C03
# Tạ Mai Khánh Ngữ văn 10C03
# Thái Đình Xuân Hóa học 10C03
# Lê Hữu Hoàng Lịch sử 10C03
# Đoàn Thu Long Địa lý 10C03
# Đặng Quý Thuận Sinh học 10C03
# Lâm Anh Minh Tiếng Anh 10C03
# Mai Anh Nhật GDCD 10C03
# Mai Quốc An Công nghệ 10C03
# Bành Anh Bình Thể dục 10C03

# %%
print('- Liệt kê ban giám hiệu')
BGH = onto.search_one(type = onto.ToChuc, ten = 'Ban giám hiệu')
for nv in BGH.thanhVien:
    print(nv.hoTen, nv.chucVu[0].ten, nv.chucVu[0].phuCap)
print('- Liệt kê tổ Văn phòng')
VP = onto.search_one(type = onto.ToChuc, ten = 'Văn phòng')
for nv in VP.thanhVien:
    print(nv.hoTen, nv.chucVu[0].ten, nv.chucVu[0].phuCap)
# Out:
# - Liệt kê ban giám hiệu
# Trần Thị Ngọc Hiệu trưởng 0.7
# Nguyễn Thanh Hải Phó hiệu Trưởng 0.5
# Dương Thị Quân Phó hiệu Trưởng 0.5
# - Liệt kê tổ Văn phòng
# Mai Thu Sơn Bảo vệ 0
# Phùng Bảo Thiện Bảo vệ 0
# Quách Minh Dũng Bảo vệ 0
# Thái Hữu Bình Phục vụ 0
# Tôn Bảo Hiền Phục vụ 0
# Tôn Hoài Hùng Văn thư 0.3
# Vũ Hồng Hải Thủ quỹ 0.3
# Vũ Văn Việt Kế toán 0.5
# Đào Quý Thiện Thư viện 0
# Võ Quý Hiền Thiết bị 0.25
# Lương Thị Bình Thiết bị 0.25

# %%
print('Liệt kê các tổ trưởng và tổ phó của các tổ chuyên môn')
toChuyenMon = [x for x in onto.search(type = onto.ToChuc) if x.name.startswith('To')]
for tc in toChuyenMon:
    print(tc.ten)
    for nv in tc.thanhVien:
        print('   -', nv.hoTen, nv.chucVu[0].ten, nv.chucVu[0].phuCap, nv.dayMon)
# Out:
# Liệt kê các tổ trưởng và tổ phó của các tổ chuyên môn
# Tổ Toán học
#    - Phùng Mai Thảo Tổ trưởng 0.2 [school.Toan]
#    - Tạ Thu Tú Tổ phó 0.15 [school.Toan]
#    - Đoàn Minh Khánh Giáo viên 0 [school.Toan]
# Tổ Ngữ văn
#    - Tạ Mai Khánh Tổ trưởng 0.2 [school.NguVan]
#    - Thái Quốc Phương Tổ phó 0.15 [school.NguVan]
#    - Bùi Đình Thiện Giáo viên 0 [school.NguVan]
# Tổ Hóa học
#    - Đào Bảo Thúy Tổ trưởng 0.2 [school.HoaHoc]
#    - Trương Văn Nam Tổ phó 0.15 [school.HoaHoc]
#    - Thái Đình Xuân Giáo viên 0 [school.HoaHoc]
#    - Đặng Đình An Giáo viên 0 [school.SinhHoc, school.HoaHoc]
#    - Quách Hoài Dũng Giáo viên 0 [school.TiengAnh, school.HoaHoc]
# Tổ Lịch sử
#    - Nguyễn Hữu Khánh Tổ trưởng 0.2 [school.LichSu]
#    - Võ Minh Xuân Tổ phó 0.15 [school.LichSu]
#    - Lê Hữu Hoàng Giáo viên 0 [school.LichSu, school.CongNghe]
#    - Lý Anh Thiện Giáo viên 0 [school.DiaLy, school.LichSu]
#    - Bùi Mai Hùng Giáo viên 0 [school.TheDuc, school.LichSu]
# Tổ Địa lý
#    - Đoàn Thu Long Tổ trưởng 0.2 [school.DiaLy]
#    - Quách Hồng Quân Tổ phó 0.15 [school.DiaLy]
#    - Lý Anh Thiện Giáo viên 0 [school.DiaLy, school.LichSu]
# Tổ Sinh học
#    - Đặng Quý Thuận Tổ trưởng 0.2 [school.SinhHoc]
#    - Thái Thu Thúy Tổ phó 0.15 [school.SinhHoc]
#    - Đặng Đình An Giáo viên 0 [school.SinhHoc, school.HoaHoc]
# Tổ Tiếng Anh
#    - Lâm Anh Minh Tổ trưởng 0.2 [school.TiengAnh]
#    - Quách Đình Thúy Tổ phó 0.15 [school.TiengAnh]
#    - Quách Hoài Dũng Giáo viên 0 [school.TiengAnh, school.HoaHoc]
# Tổ GDCD
#    - Mai Anh Nhật Tổ trưởng 0.2 [school.GDCD]
#    - Hoàng Kim Thảo Tổ phó 0.15 [school.GDCD]
#    - Tạ Hoài Hải Giáo viên 0 [school.GDCD]
# Tổ Công nghệ
#    - Lê Hữu Hoàng Giáo viên 0 [school.LichSu, school.CongNghe]
#    - Mai Quốc An Tổ trưởng 0.2 [school.CongNghe]
#    - Hoàng Hoài Thuận Tổ phó 0.15 [school.CongNghe]
#    - Huỳnh Mai Bình Giáo viên 0 [school.CongNghe]
# Tổ Thể dục
#    - Bành Anh Bình Tổ trưởng 0.2 [school.TheDuc]
#    - Đinh Thị Thúy Tổ phó 0.15 [school.TheDuc]
#    - Bùi Mai Hùng Giáo viên 0 [school.TheDuc, school.LichSu]

# %%
print('Liệt kê các phòng kèm tổ chức sử dụng')
for p in onto.Phong.instances():
    print(p.ten, end = ' ')
    for tc in p.suDungBoi:
        print('-', tc.ten, end = ' ')
    print()
# Out:
# Liệt kê các phòng kèm tổ chức sử dụng
# Phòng 10C01 - 10C01
# Phòng 10C02 - 10C02
# Phòng 10C03 - 10C03
# Phòng 11B01 - 11B01
# Phòng 11B02 - 11B02
# Phòng 11B03 - 11B03
# Phòng 12A01 - 12A01
# Phòng 12A02 - 12A02
# Phòng 12A03 - 12A03
# Phòng Toán học - Tổ Toán học
# Phòng Ngữ văn - Tổ Ngữ văn
# Phòng Hóa học - Tổ Hóa học
# Phòng Lịch sử - Tổ Lịch sử
# Phòng Địa lý - Tổ Địa lý
# Phòng Sinh học - Tổ Sinh học
# Phòng Tiếng Anh - Tổ Tiếng Anh
# Phòng GDCD - Tổ GDCD
# Phòng Công nghệ - Tổ Công nghệ
# Phòng Thể dục - Tổ Thể dục
# Phòng Hiệu trưởng - Ban giám hiệu
# Phòng Phó hiệu Trưởng 1 - Ban giám hiệu
# Phòng Phó hiệu Trưởng 2 - Ban giám hiệu
# Phòng Bảo vệ 1 - Văn phòng
# Phòng Bảo vệ 2 - Văn phòng
# Phòng Bảo vệ 3 - Văn phòng
# Phòng Phục vụ 1 - Văn phòng
# Phòng Phục vụ 2 - Văn phòng
# Phòng Văn thư - Văn phòng
# Phòng Thủ quỹ - Văn phòng
# Phòng Kế toán - Văn phòng
# Phòng Thư viện - Văn phòng
# Phòng Thiết bị 1 - Văn phòng
# Phòng Thiết bị 2 - Văn phòng

# %%
print('Liệt kê các hoạt động')
for hd in onto.HoatDong.instances():
    print(hd.ten, hd.ngayBatDau, hd.ngayKetThuc,[gv.hoTen for gv in hd.quanLy], [ng.hoTen for ng in hd.thamGia])
# Out:
# Liệt kê các hoạt động
# Học tập 2021-11-30 2022-05-06 ['Nguyễn Hữu Khánh', 'Phùng Mai Thảo', 'Nguyễn Hữu Khánh', 'Phùng Mai Thảo'] ['Đỗ Hữu Sơn', 'Tôn Thị Vân', 'Phan Hồng Minh', 'Tôn Quý Thiên', 'Bùi Thanh Tú']
# Thể thao 2021-10-24 2022-05-14 ['Tạ Thu Tú', 'Trương Văn Nam', 'Tạ Thu Tú', 'Trương Văn Nam'] ['Đặng Kim Linh', 'Trần Minh Sơn', 'Phan Hồng Minh', 'Phan Quốc Thuận', 'Lương Văn Thiên', 'Đào Hồng Quang', 'Bành Hoài Linh', 'Vũ Kim Linh', 'Tăng Thu Hải', 'Bành Thị Nhật']
# Văn hóa 2021-12-27 2022-02-07 ['Thái Thu Thúy', 'Thái Thu Thúy'] ['Phạm Bảo Quỳnh', 'Bành Thị Nhật', 'Đoàn Mai Việt']
# Nghệ thuật 2021-11-08 2022-01-20 ['Hoàng Kim Thảo', 'Tạ Mai Khánh', 'Quách Hồng Quân', 'Hoàng Kim Thảo', 'Tạ Mai Khánh', 'Quách Hồng Quân'] ['Tôn Quý Thiên', 'Đoàn Hồng Hải', 'Đặng Thanh Việt', 'Hồ Hữu Bình']
# Tình nguyện 2021-09-23 2022-04-21 ['Bùi Mai Hùng', 'Đinh Thị Thúy', 'Hoàng Hoài Thuận', 'Bùi Mai Hùng', 'Đinh Thị Thúy', 'Hoàng Hoài Thuận'] ['Quách Thị Nhật', 'Tăng Thu Hải']
# Khoa học 2021-09-14 2022-03-09 ['Quách Hoài Dũng', 'Quách Hồng Quân', 'Lê Hữu Hoàng', 'Quách Hoài Dũng', 'Quách Hồng Quân', 'Lê Hữu Hoàng'] ['Trương Thị Cường', 'Bùi Thanh Tú', 'Thái Hữu Vinh', 'Phan Quốc Thuận', 'Đoàn Hồng Hải', 'Trần Minh Sơn']
# Kỹ năng sống 2021-11-04 2022-01-09 ['Lê Hữu Hoàng', 'Lê Hữu Hoàng'] ['Lương Hữu Hùng', 'Nguyễn Bảo Thuận', 'Đoàn Kim Minh', 'Quách Hữu Quỳnh', 'Dương Quý Vân', 'Quách Văn Dũng', 'Ngô Minh Ngọc', 'Thái Hữu Vinh']
# Ngoại khóa 2021-11-25 2022-03-22 ['Hoàng Hoài Thuận', 'Hoàng Hoài Thuận'] ['Đoàn Mai Việt', 'Trương Thị Cường', 'Trương Quốc Minh', 'Đặng Kim Linh']

# %%
print('Liệt kê các HS điểm danh ở 1 hoạt động')
hd = onto.search(type = onto.HoatDong)[4]
dd = onto.search(type = onto.DiemDanh, hoatDong = hd)
for d in dd:
    print(d.nguoi.hoTen, d.ngayGio, d.trangThai)
# Out:
# Liệt kê các HS điểm danh ở 1 hoạt động
# Quách Thị Nhật 2021-09-23 09:00:00 Có mặt
# Tăng Thu Hải 2021-09-23 09:00:00 Vắng

# %%
print('Liệt kê các đối tượng chưa có dữ liệu trong CSDL')
for x in onto.classes():
    if len(x.instances()) == 0:
        print(x.name)
# Out:
# Liệt kê các đối tượng chưa có dữ liệu trong CSDL
# Anh
# Chi
# Em
