# %% [markdown]
# ### Cài đặt thư viện:
#
# Cài đặt các thư viện vào môi trường anaconda:
#
# ```bash
# conda install -c conda-forge owlready2
# ```

# %% [markdown]
# ### Tạo ontology

# %%
# %run ../app/models/model.py
# Out:
# * Owlready2 * Warning: optimized Cython parser module 'owlready2_optimized' is not available, defaulting to slower Python implementation

# %%
# Lưu CSDL ra file
onto.save(file="../app/data/education.owl")
with open("../app/data/education.owl", "r") as f:
    print(f.read())
# Out:
# <?xml version="1.0"?>
# <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#"
#          xmlns:xsd="http://www.w3.org/2001/XMLSchema#"
#          xmlns:rdfs="http://www.w3.org/2000/01/rdf-schema#"
#          xmlns:owl="http://www.w3.org/2002/07/owl#"
#          xml:base="http://hc.com/school"
#          xmlns="http://hc.com/school#">
#
# <owl:Ontology rdf:about="http://hc.com/school"/>
#
# <owl:ObjectProperty rdf:about="#thanhVien">
#   <rdfs:domain rdf:resource="#ToChuc"/>
#   <rdfs:range rdf:resource="#Nguoi"/>
#   <owl:inverseOf rdf:resource="#toChuc"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#phong">
#   <rdfs:domain rdf:resource="#ToChuc"/>
#   <rdfs:range rdf:resource="#Phong"/>
#   <rdfs:domain rdf:resource="#LopHoc"/>
#   <owl:inverseOf rdf:resource="#suDungBoi"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#toChuc">
#   <rdfs:domain rdf:resource="#Nguoi"/>
#   <rdfs:range rdf:resource="#ToChuc"/>
#   <owl:inverseOf rdf:resource="#thanhVien"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#chucVu">
#   <rdfs:domain rdf:resource="#NhanVien"/>
#   <rdfs:range rdf:resource="#ChucVu"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#con">
#   <rdfs:domain rdf:resource="#PhuHuynh"/>
#   <rdfs:range rdf:resource="#HocSinh"/>
#   <owl:inverseOf rdf:resource="#phuHuynh"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#giaoVienChuNhiem">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#LopHoc"/>
#   <rdfs:range rdf:resource="#GiaoVien"/>
#   <owl:inverseOf rdf:resource="#lopChuNhiem"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#dsHocSinh">
#   <rdfs:domain rdf:resource="#LopHoc"/>
#   <rdfs:range rdf:resource="#HocSinh"/>
#   <owl:inverseOf rdf:resource="#hocLop"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#hocLop">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#LopHoc"/>
#   <owl:inverseOf rdf:resource="#dsHocSinh"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#phuHuynh">
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#PhuHuynh"/>
#   <owl:inverseOf rdf:resource="#con"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#diemSo">
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#DiemSo"/>
#   <owl:inverseOf rdf:resource="#hocSinh"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#dayMon">
#   <rdfs:domain rdf:resource="#GiaoVien"/>
#   <rdfs:range rdf:resource="#MonHoc"/>
#   <owl:inverseOf rdf:resource="#giaoVienDay"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#giangDay">
#   <rdfs:domain rdf:resource="#GiaoVien"/>
#   <rdfs:range rdf:resource="#GiangDay"/>
#   <owl:inverseOf rdf:resource="#giaoVien"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#lopChuNhiem">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#GiaoVien"/>
#   <rdfs:range rdf:resource="#LopHoc"/>
#   <owl:inverseOf rdf:resource="#giaoVienChuNhiem"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#giaoVienDay">
#   <rdfs:domain rdf:resource="#MonHoc"/>
#   <rdfs:range rdf:resource="#GiaoVien"/>
#   <owl:inverseOf rdf:resource="#dayMon"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#hocSinh">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="#HocSinh"/>
#   <owl:inverseOf rdf:resource="#diemSo"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#monHoc">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="#MonHoc"/>
#   <rdfs:domain rdf:resource="#GiangDay"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#giaoVien">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#GiangDay"/>
#   <rdfs:range rdf:resource="#GiaoVien"/>
#   <owl:inverseOf rdf:resource="#giangDay"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#lopHoc">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#GiangDay"/>
#   <rdfs:range rdf:resource="#LopHoc"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#docGia">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DocGia"/>
#   <rdfs:range rdf:resource="#Nguoi"/>
#   <rdfs:domain rdf:resource="#PhieuMuon"/>
#   <rdfs:range rdf:resource="#DocGia"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#sachDaDoc">
#   <rdfs:domain rdf:resource="#DocGia"/>
#   <rdfs:range rdf:resource="#Sach"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#dsSach">
#   <rdfs:domain rdf:resource="#TacGia"/>
#   <rdfs:range rdf:resource="#Sach"/>
#   <rdfs:domain rdf:resource="#NhaXuatBan"/>
#   <rdfs:domain rdf:resource="#TheLoai"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#tacGia">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Sach"/>
#   <rdfs:range rdf:resource="#TacGia"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#nhaXuatBan">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Sach"/>
#   <rdfs:range rdf:resource="#NhaXuatBan"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#theLoai">
#   <rdfs:domain rdf:resource="#Sach"/>
#   <rdfs:range rdf:resource="#TheLoai"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#sachMuon">
#   <rdfs:domain rdf:resource="#PhieuMuon"/>
#   <rdfs:range rdf:resource="#Sach"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#suDungBoi">
#   <rdfs:domain rdf:resource="#Phong"/>
#   <rdfs:range rdf:resource="#ToChuc"/>
#   <owl:inverseOf rdf:resource="#phong"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#quanLy">
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:range rdf:resource="#Nguoi"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#thamGia">
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:range rdf:resource="#Nguoi"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#nguoi">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemDanh"/>
#   <rdfs:range rdf:resource="#Nguoi"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#hoatDong">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemDanh"/>
#   <rdfs:range rdf:resource="#HoatDong"/>
# </owl:ObjectProperty>
#
# <owl:DatatypeProperty rdf:about="#ten">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#ChucVu"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
#   <rdfs:domain rdf:resource="#ToChuc"/>
#   <rdfs:domain rdf:resource="#MonHoc"/>
#   <rdfs:domain rdf:resource="#TacGia"/>
#   <rdfs:domain rdf:resource="#NhaXuatBan"/>
#   <rdfs:domain rdf:resource="#Sach"/>
#   <rdfs:domain rdf:resource="#TheLoai"/>
#   <rdfs:domain rdf:resource="#Phong"/>
#   <rdfs:domain rdf:resource="#HoatDong"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#phuCap">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#ChucVu"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#hoTen">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Nguoi"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngaySinh">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Nguoi"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#gioiTinh">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Nguoi"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#heSoLuong">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#NhanVien"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngheNghiep">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#PhuHuynh"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#trinhDo">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#GiaoVien"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#soTiet">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#MonHoc"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#integer"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#heSo1">
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#heSo2">
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#heSo3">
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayCap">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DocGia"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayHetHan">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DocGia"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#giaTien">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Sach"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#integer"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#soLuong">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Sach"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#integer"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayMuon">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#PhieuMuon"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayTra">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#PhieuMuon"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayBatDau">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayKetThuc">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayGio">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemDanh"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#dateTime"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#trangThai">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemDanh"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:Class rdf:about="#ChucVu">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#ToChuc">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#Nguoi">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#NhanVien">
#   <rdfs:subClassOf rdf:resource="#Nguoi"/>
# </owl:Class>
#
# <owl:Class rdf:about="#PhuHuynh">
#   <rdfs:subClassOf rdf:resource="#Nguoi"/>
# </owl:Class>
#
# <owl:Class rdf:about="#LopHoc">
#   <rdfs:subClassOf rdf:resource="#ToChuc"/>
# </owl:Class>
#
# <owl:Class rdf:about="#HocSinh">
#   <rdfs:subClassOf rdf:resource="#Nguoi"/>
# </owl:Class>
#
# <owl:Class rdf:about="#GiaoVien">
#   <rdfs:subClassOf rdf:resource="#NhanVien"/>
# </owl:Class>
#
# <owl:Class rdf:about="#MonHoc">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#DiemSo">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#GiangDay">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#DocGia">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#TacGia">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#NhaXuatBan">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#Sach">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#TheLoai">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#PhieuMuon">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#Phong">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#HoatDong">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#DiemDanh">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
#
# </rdf:RDF>

# %%
lsPro = list(onto.properties())
def get_properties(obj):
    return [p for p in lsPro if obj.is_a[0] in p.domain] + [p for p in lsPro if obj in p.domain]
print('Liệt kê toàn bộ các đối tượng trong ontology')
lsClass= list(onto.classes())
for i, class_ in zip(range(len(lsClass)), lsClass):
    # print(class_.name, '[', ', '.join([x.name for x in get_properties(class_)]), ']')
    print(str(i+1)+'.', class_.name, 'kế thừa từ', class_.is_a)
    for x in get_properties(class_) :
        print('-', x.name, ':', x.range)
# Out:
# Liệt kê toàn bộ các đối tượng trong ontology
# 1. ChucVu kế thừa từ [owl.Thing]
# - ten : [<class 'str'>, <class 'str'>]
# - phuCap : [<class 'float'>]
# 2. ToChuc kế thừa từ [owl.Thing]
# - ten : [<class 'str'>, <class 'str'>]
# - thanhVien : [school.Nguoi]
# - phong : [school.Phong, school.Phong]
# 3. Nguoi kế thừa từ [owl.Thing]
# - hoTen : [<class 'str'>]
# - ngaySinh : [<class 'datetime.date'>]
# - gioiTinh : [<class 'str'>]
# - toChuc : [school.ToChuc]
# 4. NhanVien kế thừa từ [school.Nguoi]
# - hoTen : [<class 'str'>]
# - ngaySinh : [<class 'datetime.date'>]
# - gioiTinh : [<class 'str'>]
# - toChuc : [school.ToChuc]
# - heSoLuong : [<class 'float'>]
# - chucVu : [school.ChucVu]
# 5. PhuHuynh kế thừa từ [school.Nguoi]
# - hoTen : [<class 'str'>]
# - ngaySinh : [<class 'datetime.date'>]
# - gioiTinh : [<class 'str'>]
# - toChuc : [school.ToChuc]
# - ngheNghiep : [<class 'str'>]
# - con : [school.HocSinh]
# 6. LopHoc kế thừa từ [school.ToChuc]
# - ten : [<class 'str'>, <class 'str'>]
# - thanhVien : [school.Nguoi]
# - phong : [school.Phong, school.Phong]
# - phong : [school.Phong, school.Phong]
# - giaoVienChuNhiem : [school.GiaoVien]
# - dsHocSinh : [school.HocSinh]
# 7. HocSinh kế thừa từ [school.Nguoi]
# - hoTen : [<class 'str'>]
# - ngaySinh : [<class 'datetime.date'>]
# - gioiTinh : [<class 'str'>]
# - toChuc : [school.ToChuc]
# - hocLop : [school.LopHoc]
# - phuHuynh : [school.PhuHuynh]
# - diemSo : [school.DiemSo]
# 8. GiaoVien kế thừa từ [school.NhanVien]
# - heSoLuong : [<class 'float'>]
# - chucVu : [school.ChucVu]
# - trinhDo : [<class 'str'>]
# - dayMon : [school.MonHoc]
# - giangDay : [school.GiangDay]
# - lopChuNhiem : [school.LopHoc]
# 9. MonHoc kế thừa từ [owl.Thing]
# - ten : [<class 'str'>, <class 'str'>]
# - soTiet : [<class 'int'>]
# - giaoVienDay : [school.GiaoVien]
# 10. DiemSo kế thừa từ [owl.Thing]
# - heSo1 : [<class 'float'>]
# - heSo2 : [<class 'float'>]
# - heSo3 : [<class 'float'>]
# - hocSinh : [school.HocSinh]
# - monHoc : [school.MonHoc, school.MonHoc]
# 11. GiangDay kế thừa từ [owl.Thing]
# - monHoc : [school.MonHoc, school.MonHoc]
# - giaoVien : [school.GiaoVien]
# - lopHoc : [school.LopHoc]
# 12. DocGia kế thừa từ [owl.Thing]
# - ngayCap : [<class 'datetime.date'>]
# - ngayHetHan : [<class 'datetime.date'>]
# - docGia : [school.Nguoi, school.DocGia]
# - sachDaDoc : [school.Sach]
# 13. TacGia kế thừa từ [owl.Thing]
# - ten : [<class 'str'>, <class 'str'>]
# - dsSach : [school.Sach, school.Sach]
# 14. NhaXuatBan kế thừa từ [owl.Thing]
# - ten : [<class 'str'>, <class 'str'>]
# - dsSach : [school.Sach, school.Sach]
# 15. Sach kế thừa từ [owl.Thing]
# - ten : [<class 'str'>, <class 'str'>]
# - giaTien : [<class 'int'>]
# - soLuong : [<class 'int'>]
# - tacGia : [school.TacGia]
# - nhaXuatBan : [school.NhaXuatBan]
# - theLoai : [school.TheLoai]
# 16. TheLoai kế thừa từ [owl.Thing]
# - ten : [<class 'str'>, <class 'str'>]
# - dsSach : [school.Sach, school.Sach]
# 17. PhieuMuon kế thừa từ [owl.Thing]
# - ngayMuon : [<class 'datetime.date'>]
# - ngayTra : [<class 'datetime.date'>]
# - docGia : [school.Nguoi, school.DocGia]
# - sachMuon : [school.Sach]
# 18. Phong kế thừa từ [owl.Thing]
# - ten : [<class 'str'>, <class 'str'>]
# - suDungBoi : [school.ToChuc]
# 19. HoatDong kế thừa từ [owl.Thing]
# - ten : [<class 'str'>, <class 'str'>]
# - ngayBatDau : [<class 'datetime.date'>]
# - ngayKetThuc : [<class 'datetime.date'>]
# - quanLy : [school.Nguoi]
# - thamGia : [school.Nguoi]
# 20. DiemDanh kế thừa từ [owl.Thing]
# - ngayGio : [<class 'datetime.datetime'>]
# - trangThai : [<class 'str'>]
# - nguoi : [school.Nguoi]
# - hoatDong : [school.HoatDong]

# %% [markdown]
# ### Thêm dữ liệu

# %%
# # Đọc CSDL từ file
# onto = get_ontology("../app/data/education.owl").load()

# %%
# %run ../app/models/data.py
create_Data(soLopMoiKhoi = 3, soHSMoiLop = 5, soHSCoAnhEm = 20, soGVMoiMon = 3, soGVDay2Mon = 5, soDocGia = 10, soSach = 15, soTacGia = 5, soNXB = 3)
# Lưu CSDL ra file
onto.save(file="../app/data/education.owl", format='rdfxml') # 'ntriples' / "rdfxml"
with open("../app/data/education.owl", "r") as f:
    print(f.read())
# Out:
# <?xml version="1.0"?>
# <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#"
#          xmlns:xsd="http://www.w3.org/2001/XMLSchema#"
#          xmlns:rdfs="http://www.w3.org/2000/01/rdf-schema#"
#          xmlns:owl="http://www.w3.org/2002/07/owl#"
#          xml:base="http://hc.com/school"
#          xmlns="http://hc.com/school#">
#
# <owl:Ontology rdf:about="http://hc.com/school"/>
#
# <owl:ObjectProperty rdf:about="#thanhVien">
#   <rdfs:domain rdf:resource="#ToChuc"/>
#   <rdfs:range rdf:resource="#Nguoi"/>
#   <owl:inverseOf rdf:resource="#toChuc"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#phong">
#   <rdfs:domain rdf:resource="#ToChuc"/>
#   <rdfs:range rdf:resource="#Phong"/>
#   <rdfs:domain rdf:resource="#LopHoc"/>
#   <owl:inverseOf rdf:resource="#suDungBoi"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#toChuc">
#   <rdfs:domain rdf:resource="#Nguoi"/>
#   <rdfs:range rdf:resource="#ToChuc"/>
#   <owl:inverseOf rdf:resource="#thanhVien"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#chucVu">
#   <rdfs:domain rdf:resource="#NhanVien"/>
#   <rdfs:range rdf:resource="#ChucVu"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#con">
#   <rdfs:domain rdf:resource="#PhuHuynh"/>
#   <rdfs:range rdf:resource="#HocSinh"/>
#   <owl:inverseOf rdf:resource="#phuHuynh"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#giaoVienChuNhiem">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#LopHoc"/>
#   <rdfs:range rdf:resource="#GiaoVien"/>
#   <owl:inverseOf rdf:resource="#lopChuNhiem"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#dsHocSinh">
#   <rdfs:domain rdf:resource="#LopHoc"/>
#   <rdfs:range rdf:resource="#HocSinh"/>
#   <owl:inverseOf rdf:resource="#hocLop"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#hocLop">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#LopHoc"/>
#   <owl:inverseOf rdf:resource="#dsHocSinh"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#phuHuynh">
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#PhuHuynh"/>
#   <owl:inverseOf rdf:resource="#con"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#diemSo">
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#DiemSo"/>
#   <owl:inverseOf rdf:resource="#hocSinh"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#dayMon">
#   <rdfs:domain rdf:resource="#GiaoVien"/>
#   <rdfs:range rdf:resource="#MonHoc"/>
#   <owl:inverseOf rdf:resource="#giaoVienDay"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#giangDay">
#   <rdfs:domain rdf:resource="#GiaoVien"/>
#   <rdfs:range rdf:resource="#GiangDay"/>
#   <owl:inverseOf rdf:resource="#giaoVien"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#lopChuNhiem">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#GiaoVien"/>
#   <rdfs:range rdf:resource="#LopHoc"/>
#   <owl:inverseOf rdf:resource="#giaoVienChuNhiem"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#giaoVienDay">
#   <rdfs:domain rdf:resource="#MonHoc"/>
#   <rdfs:range rdf:resource="#GiaoVien"/>
#   <owl:inverseOf rdf:resource="#dayMon"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#hocSinh">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="#HocSinh"/>
#   <owl:inverseOf rdf:resource="#diemSo"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#monHoc">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="#MonHoc"/>
#   <rdfs:domain rdf:resource="#GiangDay"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#giaoVien">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#GiangDay"/>
#   <rdfs:range rdf:resource="#GiaoVien"/>
#   <owl:inverseOf rdf:resource="#giangDay"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#lopHoc">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#GiangDay"/>
#   <rdfs:range rdf:resource="#LopHoc"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#docGia">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DocGia"/>
#   <rdfs:range rdf:resource="#Nguoi"/>
#   <rdfs:domain rdf:resource="#PhieuMuon"/>
#   <rdfs:range rdf:resource="#DocGia"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#sachDaDoc">
#   <rdfs:domain rdf:resource="#DocGia"/>
#   <rdfs:range rdf:resource="#Sach"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#dsSach">
#   <rdfs:domain rdf:resource="#TacGia"/>
#   <rdfs:range rdf:resource="#Sach"/>
#   <rdfs:domain rdf:resource="#NhaXuatBan"/>
#   <rdfs:domain rdf:resource="#TheLoai"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#tacGia">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Sach"/>
#   <rdfs:range rdf:resource="#TacGia"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#nhaXuatBan">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Sach"/>
#   <rdfs:range rdf:resource="#NhaXuatBan"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#theLoai">
#   <rdfs:domain rdf:resource="#Sach"/>
#   <rdfs:range rdf:resource="#TheLoai"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#sachMuon">
#   <rdfs:domain rdf:resource="#PhieuMuon"/>
#   <rdfs:range rdf:resource="#Sach"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#suDungBoi">
#   <rdfs:domain rdf:resource="#Phong"/>
#   <rdfs:range rdf:resource="#ToChuc"/>
#   <owl:inverseOf rdf:resource="#phong"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#quanLy">
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:range rdf:resource="#Nguoi"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#thamGia">
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:range rdf:resource="#Nguoi"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#nguoi">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemDanh"/>
#   <rdfs:range rdf:resource="#Nguoi"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#hoatDong">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemDanh"/>
#   <rdfs:range rdf:resource="#HoatDong"/>
# </owl:ObjectProperty>
#
# <owl:DatatypeProperty rdf:about="#ten">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#ChucVu"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
#   <rdfs:domain rdf:resource="#ToChuc"/>
#   <rdfs:domain rdf:resource="#MonHoc"/>
#   <rdfs:domain rdf:resource="#TacGia"/>
#   <rdfs:domain rdf:resource="#NhaXuatBan"/>
#   <rdfs:domain rdf:resource="#Sach"/>
#   <rdfs:domain rdf:resource="#TheLoai"/>
#   <rdfs:domain rdf:resource="#Phong"/>
#   <rdfs:domain rdf:resource="#HoatDong"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#phuCap">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#ChucVu"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#hoTen">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Nguoi"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngaySinh">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Nguoi"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#gioiTinh">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Nguoi"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#heSoLuong">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#NhanVien"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngheNghiep">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#PhuHuynh"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#trinhDo">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#GiaoVien"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#soTiet">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#MonHoc"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#integer"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#heSo1">
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#heSo2">
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#heSo3">
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayCap">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DocGia"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayHetHan">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DocGia"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#giaTien">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Sach"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#integer"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#soLuong">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Sach"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#integer"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayMuon">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#PhieuMuon"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayTra">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#PhieuMuon"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayBatDau">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayKetThuc">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayGio">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemDanh"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#dateTime"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#trangThai">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemDanh"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:Class rdf:about="#ChucVu">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#ToChuc">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#Nguoi">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#NhanVien">
#   <rdfs:subClassOf rdf:resource="#Nguoi"/>
# </owl:Class>
#
# <owl:Class rdf:about="#PhuHuynh">
#   <rdfs:subClassOf rdf:resource="#Nguoi"/>
# </owl:Class>
#
# <owl:Class rdf:about="#LopHoc">
#   <rdfs:subClassOf rdf:resource="#ToChuc"/>
# </owl:Class>
#
# <owl:Class rdf:about="#HocSinh">
#   <rdfs:subClassOf rdf:resource="#Nguoi"/>
# </owl:Class>
#
# <owl:Class rdf:about="#GiaoVien">
#   <rdfs:subClassOf rdf:resource="#NhanVien"/>
# </owl:Class>
#
# <owl:Class rdf:about="#MonHoc">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#DiemSo">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#GiangDay">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#DocGia">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#TacGia">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#NhaXuatBan">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#Sach">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#TheLoai">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#PhieuMuon">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#Phong">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#HoatDong">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#DiemDanh">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <Phong rdf:about="#Phong10C01">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <ten rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Phòng 10C01</ten>
# </Phong>
#
# <LopHoc rdf:about="#10C01">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <phong rdf:resource="#Phong10C01"/>
#   <ten rdf:datatype="http://www.w3.org/2001/XMLSchema#string">10C01</ten>
# </LopHoc>
#
# <HocSinh rdf:about="#hocsinh1">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#10C01"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Ngô Kim Quỳnh</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-06-24</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
# </HocSinh>
#
# <PhuHuynh rdf:about="#phuhuynh1">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh1"/>
#   <con rdf:resource="#hocsinh45"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Vũ Kim An</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1977-03-16</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Công nhân</ngheNghiep>
# </PhuHuynh>
#
# <PhuHuynh rdf:about="#phuhuynh2">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh1"/>
#   <con rdf:resource="#hocsinh45"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tôn Anh Vinh</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1978-02-06</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Giáo viên</ngheNghiep>
# </PhuHuynh>
#
# <HocSinh rdf:about="#hocsinh2">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#10C01"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Huỳnh Thanh Phương</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-03-04</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
# </HocSinh>
#
# <PhuHuynh rdf:about="#phuhuynh3">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh2"/>
#   <con rdf:resource="#hocsinh29"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đoàn Bảo Bình</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1973-12-23</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Kỹ sư</ngheNghiep>
# </PhuHuynh>
#
# <PhuHuynh rdf:about="#phuhuynh4">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh2"/>
#   <con rdf:resource="#hocsinh29"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tạ Kim Hải</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1978-03-21</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Bác sĩ</ngheNghiep>
# </PhuHuynh>
#
# <HocSinh rdf:about="#hocsinh3">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#10C01"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Mai Hữu Tú</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-08-19</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
# </HocSinh>
#
# <PhuHuynh rdf:about="#phuhuynh5">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh3"/>
#   <con rdf:resource="#hocsinh40"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Hoàng Kim Ngọc</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1980-07-20</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Giáo viên</ngheNghiep>
# </PhuHuynh>
#
# <PhuHuynh rdf:about="#phuhuynh6">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh3"/>
#   <con rdf:resource="#hocsinh40"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Lương Anh Bình</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1970-08-10</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Chủ doanh nghiệp</ngheNghiep>
# </PhuHuynh>
#
# <HocSinh rdf:about="#hocsinh4">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#10C01"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Hoàng Mai Việt</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-09-23</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
# </HocSinh>
#
# <PhuHuynh rdf:about="#phuhuynh7">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh4"/>
#   <con rdf:resource="#hocsinh39"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Quách Anh An</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1979-02-21</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Bác sĩ</ngheNghiep>
# </PhuHuynh>
#
# <PhuHuynh rdf:about="#phuhuynh8">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh4"/>
#   <con rdf:resource="#hocsinh39"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tôn Anh Tùng</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1973-10-21</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nông dân</ngheNghiep>
# </PhuHuynh>
#
# <HocSinh rdf:about="#hocsinh5">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#10C01"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Ngô Văn Hải</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-12-30</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
# </HocSinh>
#
# <Phong rdf:about="#Phong10C02">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <ten rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Phòng 10C02</ten>
# </Phong>
#
# <LopHoc rdf:about="#10C02">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <phong rdf:resource="#Phong10C02"/>
#   <ten rdf:datatype="http://www.w3.org/2001/XMLSchema#string">10C02</ten>
# </LopHoc>
#
# <HocSinh rdf:about="#hocsinh6">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#10C02"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đào Bảo Thiện</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-09-24</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
# </HocSinh>
#
# <PhuHuynh rdf:about="#phuhuynh11">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh6"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Phan Đình Linh</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1973-03-03</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Giáo viên</ngheNghiep>
# </PhuHuynh>
#
# <PhuHuynh rdf:about="#phuhuynh12">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh6"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tạ Đình Vinh</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1977-06-06</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Công nhân</ngheNghiep>
# </PhuHuynh>
#
# <HocSinh rdf:about="#hocsinh7">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#10C02"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Quách Hoài Quang</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-05-08</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
# </HocSinh>
#
# <PhuHuynh rdf:about="#phuhuynh13">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh7"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tô Văn Ngọc</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1976-05-21</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nhân viên văn phòng</ngheNghiep>
# </PhuHuynh>
#
# <PhuHuynh rdf:about="#phuhuynh14">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh7"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Lâm Đình Hải</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1975-08-10</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Bác sĩ</ngheNghiep>
# </PhuHuynh>
#
# <HocSinh rdf:about="#hocsinh8">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#10C02"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đinh Thu Hiền</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-03-06</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh9">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#10C02"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đinh Mai Thuận</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-08-15</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
# </HocSinh>
#
# <PhuHuynh rdf:about="#phuhuynh17">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh9"/>
#   <con rdf:resource="#hocsinh18"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Mai Hoài Linh</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1976-10-17</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Công nhân</ngheNghiep>
# </PhuHuynh>
#
# <PhuHuynh rdf:about="#phuhuynh18">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh9"/>
#   <con rdf:resource="#hocsinh18"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Lâm Mai Thuận</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1976-08-06</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Giáo viên</ngheNghiep>
# </PhuHuynh>
#
# <HocSinh rdf:about="#hocsinh10">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#10C02"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Lương Hồng Cường</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-02-02</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
# </HocSinh>
#
# <Phong rdf:about="#Phong10C03">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <ten rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Phòng 10C03</ten>
# </Phong>
#
# <LopHoc rdf:about="#10C03">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <phong rdf:resource="#Phong10C03"/>
#   <ten rdf:datatype="http://www.w3.org/2001/XMLSchema#string">10C03</ten>
# </LopHoc>
#
# <HocSinh rdf:about="#hocsinh11">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#10C03"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đặng Hồng Quỳnh</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-08-20</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
# </HocSinh>
#
# <PhuHuynh rdf:about="#phuhuynh21">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh11"/>
#   <con rdf:resource="#hocsinh34"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tăng Thị Nam</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1973-09-06</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Kỹ sư</ngheNghiep>
# </PhuHuynh>
#
# <PhuHuynh rdf:about="#phuhuynh22">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh11"/>
#   <con rdf:resource="#hocsinh34"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Hồ Đình Long</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1971-10-29</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nông dân</ngheNghiep>
# </PhuHuynh>
#
# <HocSinh rdf:about="#hocsinh12">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#10C03"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Trương Thị Nam</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-10-14</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
# </HocSinh>
#
# <PhuHuynh rdf:about="#phuhuynh23">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh12"/>
#   <con rdf:resource="#hocsinh24"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đặng Bảo Hùng</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1976-07-19</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Bác sĩ</ngheNghiep>
# </PhuHuynh>
#
# <PhuHuynh rdf:about="#phuhuynh24">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh12"/>
#   <con rdf:resource="#hocsinh24"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đoàn Ngọc Quỳnh</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1972-10-03</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nhân viên văn phòng</ngheNghiep>
# </PhuHuynh>
#
# <HocSinh rdf:about="#hocsinh13">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#10C03"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Lương Đình Hùng</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-09-19</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
# </HocSinh>
#
# <PhuHuynh rdf:about="#phuhuynh25">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh13"/>
#   <con rdf:resource="#hocsinh15"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đặng Hoài Sơn</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1975-04-06</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Chủ doanh nghiệp</ngheNghiep>
# </PhuHuynh>
#
# <PhuHuynh rdf:about="#phuhuynh26">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh13"/>
#   <con rdf:resource="#hocsinh15"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Bùi Hoài Phương</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1980-12-18</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Bác sĩ</ngheNghiep>
# </PhuHuynh>
#
# <HocSinh rdf:about="#hocsinh14">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#10C03"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Quách Mai Phương</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-09-18</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh15">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#10C03"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đinh Thị Thuận</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-03-31</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
# </HocSinh>
#
# <Phong rdf:about="#Phong11B01">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <ten rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Phòng 11B01</ten>
# </Phong>
#
# <LopHoc rdf:about="#11B01">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <phong rdf:resource="#Phong11B01"/>
#   <ten rdf:datatype="http://www.w3.org/2001/XMLSchema#string">11B01</ten>
# </LopHoc>
#
# <HocSinh rdf:about="#hocsinh16">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#11B01"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đoàn Thị Dũng</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-07-23</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh17">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#11B01"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tô Anh Nhật</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-03-16</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
# </HocSinh>
#
# <PhuHuynh rdf:about="#phuhuynh33">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh17"/>
#   <con rdf:resource="#hocsinh8"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Võ Ngọc Việt</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1977-08-05</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Công nhân</ngheNghiep>
# </PhuHuynh>
#
# <PhuHuynh rdf:about="#phuhuynh34">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh17"/>
#   <con rdf:resource="#hocsinh8"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đinh Bảo Quang</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1972-11-16</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Bác sĩ</ngheNghiep>
# </PhuHuynh>
#
# <HocSinh rdf:about="#hocsinh18">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#11B01"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Võ Bảo Long</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-07-19</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh19">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#11B01"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đoàn Anh Hải</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-08-31</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh20">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#11B01"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tạ Mai Linh</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-06-10</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
# </HocSinh>
#
# <PhuHuynh rdf:about="#phuhuynh39">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh20"/>
#   <con rdf:resource="#hocsinh19"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Phan Đình An</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1980-04-20</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nhân viên văn phòng</ngheNghiep>
# </PhuHuynh>
#
# <PhuHuynh rdf:about="#phuhuynh40">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh20"/>
#   <con rdf:resource="#hocsinh19"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Vũ Kim Bình</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1973-12-17</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Kỹ sư</ngheNghiep>
# </PhuHuynh>
#
# <Phong rdf:about="#Phong11B02">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <ten rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Phòng 11B02</ten>
# </Phong>
#
# <LopHoc rdf:about="#11B02">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <phong rdf:resource="#Phong11B02"/>
#   <ten rdf:datatype="http://www.w3.org/2001/XMLSchema#string">11B02</ten>
# </LopHoc>
#
# <HocSinh rdf:about="#hocsinh21">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#11B02"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Bành Mai Thảo</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-03-16</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
# </HocSinh>
#
# <PhuHuynh rdf:about="#phuhuynh41">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh21"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Lê Đình Cường</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1978-01-13</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Bác sĩ</ngheNghiep>
# </PhuHuynh>
#
# <PhuHuynh rdf:about="#phuhuynh42">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh21"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đoàn Kim Hiền</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1979-07-04</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Bác sĩ</ngheNghiep>
# </PhuHuynh>
#
# <HocSinh rdf:about="#hocsinh22">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#11B02"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Vũ Hữu Quang</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-06-07</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
# </HocSinh>
#
# <PhuHuynh rdf:about="#phuhuynh43">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh22"/>
#   <con rdf:resource="#hocsinh38"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Thái Hữu Hải</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1978-11-05</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Kỹ sư</ngheNghiep>
# </PhuHuynh>
#
# <PhuHuynh rdf:about="#phuhuynh44">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh22"/>
#   <con rdf:resource="#hocsinh38"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Phan Ngọc Thiện</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1980-02-07</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Kỹ sư</ngheNghiep>
# </PhuHuynh>
#
# <HocSinh rdf:about="#hocsinh23">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#11B02"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nguyễn Hồng Ngọc</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-07-04</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
# </HocSinh>
#
# <PhuHuynh rdf:about="#phuhuynh45">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh23"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Tôn Minh Xuân</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1971-05-29</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Công nhân</ngheNghiep>
# </PhuHuynh>
#
# <PhuHuynh rdf:about="#phuhuynh46">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh23"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đỗ Minh Hiền</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1973-02-14</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Giáo viên</ngheNghiep>
# </PhuHuynh>
#
# <HocSinh rdf:about="#hocsinh24">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#11B02"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Lý Anh Bình</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-09-15</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
# </HocSinh>
#
# <HocSinh rdf:about="#hocsinh25">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#11B02"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Thái Kim Tùng</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-06-29</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
# </HocSinh>
#
# <Phong rdf:about="#Phong11B03">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <ten rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Phòng 11B03</ten>
# </Phong>
#
# <LopHoc rdf:about="#11B03">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <phong rdf:resource="#Phong11B03"/>
#   <ten rdf:datatype="http://www.w3.org/2001/XMLSchema#string">11B03</ten>
# </LopHoc>
#
# <HocSinh rdf:about="#hocsinh26">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#11B03"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đỗ Anh Vân</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-11-08</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
# </HocSinh>
#
# <PhuHuynh rdf:about="#phuhuynh51">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh26"/>
#   <con rdf:resource="#hocsinh42"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Hoàng Ngọc Khánh</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1978-07-03</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Chủ doanh nghiệp</ngheNghiep>
# </PhuHuynh>
#
# <PhuHuynh rdf:about="#phuhuynh52">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh26"/>
#   <con rdf:resource="#hocsinh42"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đinh Bảo Xuân</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1976-05-17</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nhân viên văn phòng</ngheNghiep>
# </PhuHuynh>
#
# <HocSinh rdf:about="#hocsinh27">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#11B03"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Vũ Hữu Linh</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-06-08</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
# </HocSinh>
#
# <PhuHuynh rdf:about="#phuhuynh53">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh27"/>
#   <con rdf:resource="#hocsinh44"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Quách Kim Tường</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1970-06-28</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nông dân</ngheNghiep>
# </PhuHuynh>
#
# <PhuHuynh rdf:about="#phuhuynh54">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh27"/>
#   <con rdf:resource="#hocsinh44"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Mai Văn Cường</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1975-05-31</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nông dân</ngheNghiep>
# </PhuHuynh>
#
# <HocSinh rdf:about="#hocsinh28">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#11B03"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Trần Đình Thiên</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2000-11-10</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
# </HocSinh>
#
# <PhuHuynh rdf:about="#phuhuynh55">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh28"/>
#   <con rdf:resource="#hocsinh14"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Lý Anh Bình</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1980-12-14</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nữ</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Công nhân</ngheNghiep>
# </PhuHuynh>
#
# <PhuHuynh rdf:about="#phuhuynh56">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <con rdf:resource="#hocsinh28"/>
#   <con rdf:resource="#hocsinh14"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Lương Anh Hải</hoTen>
#   <ngaySinh rdf:datatype="http://www.w3.org/2001/XMLSchema#date">1977-03-20</ngaySinh>
#   <gioiTinh rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nam</gioiTinh>
#   <ngheNghiep rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Nhân viên văn phòng</ngheNghiep>
# </PhuHuynh>
#
# <HocSinh rdf:about="#hocsinh29">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hocLop rdf:resource="#11B03"/>
#   <hoTen rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Hồ Thị Thảo</hoTen>
# ...
# </DiemDanh>
#
# <DiemDanh rdf:about="#diemdanh5">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoatDong rdf:resource="#hoatdong34"/>
#   <nguoi rdf:resource="#hocsinh181"/>
#   <ngayGio rdf:datatype="http://www.w3.org/2001/XMLSchema#dateTime">2021-12-26T08:00:00.000</ngayGio>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Vắng</trangThai>
# </DiemDanh>
#
# <DiemDanh rdf:about="#diemdanh6">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoatDong rdf:resource="#hoatdong35"/>
#   <nguoi rdf:resource="#hocsinh182"/>
#   <ngayGio rdf:datatype="http://www.w3.org/2001/XMLSchema#dateTime">2021-10-30T09:00:00.000</ngayGio>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đúng giờ</trangThai>
# </DiemDanh>
#
# <DiemDanh rdf:about="#diemdanh7">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoatDong rdf:resource="#hoatdong35"/>
#   <nguoi rdf:resource="#hocsinh218"/>
#   <ngayGio rdf:datatype="http://www.w3.org/2001/XMLSchema#dateTime">2021-10-30T07:00:00.000</ngayGio>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Trễ</trangThai>
# </DiemDanh>
#
# <DiemDanh rdf:about="#diemdanh8">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoatDong rdf:resource="#hoatdong35"/>
#   <nguoi rdf:resource="#hocsinh223"/>
#   <ngayGio rdf:datatype="http://www.w3.org/2001/XMLSchema#dateTime">2021-10-30T07:00:00.000</ngayGio>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Trễ</trangThai>
# </DiemDanh>
#
# <DiemDanh rdf:about="#diemdanh9">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoatDong rdf:resource="#hoatdong35"/>
#   <nguoi rdf:resource="#hocsinh205"/>
#   <ngayGio rdf:datatype="http://www.w3.org/2001/XMLSchema#dateTime">2021-10-30T07:00:00.000</ngayGio>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Vắng</trangThai>
# </DiemDanh>
#
# <DiemDanh rdf:about="#diemdanh10">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoatDong rdf:resource="#hoatdong35"/>
#   <nguoi rdf:resource="#hocsinh204"/>
#   <ngayGio rdf:datatype="http://www.w3.org/2001/XMLSchema#dateTime">2021-10-30T09:00:00.000</ngayGio>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Vắng</trangThai>
# </DiemDanh>
#
# <DiemDanh rdf:about="#diemdanh11">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoatDong rdf:resource="#hoatdong35"/>
#   <nguoi rdf:resource="#hocsinh191"/>
#   <ngayGio rdf:datatype="http://www.w3.org/2001/XMLSchema#dateTime">2021-10-30T09:00:00.000</ngayGio>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Vắng</trangThai>
# </DiemDanh>
#
# <DiemDanh rdf:about="#diemdanh12">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoatDong rdf:resource="#hoatdong35"/>
#   <nguoi rdf:resource="#hocsinh212"/>
#   <ngayGio rdf:datatype="http://www.w3.org/2001/XMLSchema#dateTime">2021-10-30T08:00:00.000</ngayGio>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Trễ</trangThai>
# </DiemDanh>
#
# <DiemDanh rdf:about="#diemdanh13">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoatDong rdf:resource="#hoatdong35"/>
#   <nguoi rdf:resource="#hocsinh219"/>
#   <ngayGio rdf:datatype="http://www.w3.org/2001/XMLSchema#dateTime">2021-10-30T08:00:00.000</ngayGio>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đúng giờ</trangThai>
# </DiemDanh>
#
# <DiemDanh rdf:about="#diemdanh14">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoatDong rdf:resource="#hoatdong35"/>
#   <nguoi rdf:resource="#hocsinh198"/>
#   <ngayGio rdf:datatype="http://www.w3.org/2001/XMLSchema#dateTime">2021-10-30T09:00:00.000</ngayGio>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Vắng</trangThai>
# </DiemDanh>
#
# <DiemDanh rdf:about="#diemdanh15">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoatDong rdf:resource="#hoatdong36"/>
#   <nguoi rdf:resource="#hocsinh218"/>
#   <ngayGio rdf:datatype="http://www.w3.org/2001/XMLSchema#dateTime">2021-11-03T07:00:00.000</ngayGio>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Vắng</trangThai>
# </DiemDanh>
#
# <DiemDanh rdf:about="#diemdanh16">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoatDong rdf:resource="#hoatdong36"/>
#   <nguoi rdf:resource="#hocsinh192"/>
#   <ngayGio rdf:datatype="http://www.w3.org/2001/XMLSchema#dateTime">2021-11-03T08:00:00.000</ngayGio>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đúng giờ</trangThai>
# </DiemDanh>
#
# <DiemDanh rdf:about="#diemdanh17">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoatDong rdf:resource="#hoatdong36"/>
#   <nguoi rdf:resource="#hocsinh203"/>
#   <ngayGio rdf:datatype="http://www.w3.org/2001/XMLSchema#dateTime">2021-11-03T09:00:00.000</ngayGio>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đúng giờ</trangThai>
# </DiemDanh>
#
# <DiemDanh rdf:about="#diemdanh18">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoatDong rdf:resource="#hoatdong36"/>
#   <nguoi rdf:resource="#hocsinh183"/>
#   <ngayGio rdf:datatype="http://www.w3.org/2001/XMLSchema#dateTime">2021-11-03T08:00:00.000</ngayGio>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Trễ</trangThai>
# </DiemDanh>
#
# <DiemDanh rdf:about="#diemdanh19">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoatDong rdf:resource="#hoatdong36"/>
#   <nguoi rdf:resource="#hocsinh216"/>
#   <ngayGio rdf:datatype="http://www.w3.org/2001/XMLSchema#dateTime">2021-11-03T09:00:00.000</ngayGio>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Trễ</trangThai>
# </DiemDanh>
#
# <DiemDanh rdf:about="#diemdanh20">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoatDong rdf:resource="#hoatdong36"/>
#   <nguoi rdf:resource="#hocsinh219"/>
#   <ngayGio rdf:datatype="http://www.w3.org/2001/XMLSchema#dateTime">2021-11-03T07:00:00.000</ngayGio>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Vắng</trangThai>
# </DiemDanh>
#
# <DiemDanh rdf:about="#diemdanh21">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoatDong rdf:resource="#hoatdong36"/>
#   <nguoi rdf:resource="#hocsinh201"/>
#   <ngayGio rdf:datatype="http://www.w3.org/2001/XMLSchema#dateTime">2021-11-03T08:00:00.000</ngayGio>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đúng giờ</trangThai>
# </DiemDanh>
#
# <DiemDanh rdf:about="#diemdanh22">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoatDong rdf:resource="#hoatdong36"/>
#   <nguoi rdf:resource="#hocsinh194"/>
#   <ngayGio rdf:datatype="http://www.w3.org/2001/XMLSchema#dateTime">2021-11-03T08:00:00.000</ngayGio>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Trễ</trangThai>
# </DiemDanh>
#
# <DiemDanh rdf:about="#diemdanh23">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoatDong rdf:resource="#hoatdong36"/>
#   <nguoi rdf:resource="#hocsinh188"/>
#   <ngayGio rdf:datatype="http://www.w3.org/2001/XMLSchema#dateTime">2021-11-03T07:00:00.000</ngayGio>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đúng giờ</trangThai>
# </DiemDanh>
#
# <DiemDanh rdf:about="#diemdanh24">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoatDong rdf:resource="#hoatdong36"/>
#   <nguoi rdf:resource="#hocsinh221"/>
#   <ngayGio rdf:datatype="http://www.w3.org/2001/XMLSchema#dateTime">2021-11-03T07:00:00.000</ngayGio>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Vắng</trangThai>
# </DiemDanh>
#
# <DiemDanh rdf:about="#diemdanh25">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoatDong rdf:resource="#hoatdong37"/>
#   <nguoi rdf:resource="#hocsinh224"/>
#   <ngayGio rdf:datatype="http://www.w3.org/2001/XMLSchema#dateTime">2021-12-22T07:00:00.000</ngayGio>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đúng giờ</trangThai>
# </DiemDanh>
#
# <DiemDanh rdf:about="#diemdanh26">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoatDong rdf:resource="#hoatdong37"/>
#   <nguoi rdf:resource="#hocsinh218"/>
#   <ngayGio rdf:datatype="http://www.w3.org/2001/XMLSchema#dateTime">2021-12-22T09:00:00.000</ngayGio>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Vắng</trangThai>
# </DiemDanh>
#
# <DiemDanh rdf:about="#diemdanh27">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoatDong rdf:resource="#hoatdong37"/>
#   <nguoi rdf:resource="#hocsinh194"/>
#   <ngayGio rdf:datatype="http://www.w3.org/2001/XMLSchema#dateTime">2021-12-22T07:00:00.000</ngayGio>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Trễ</trangThai>
# </DiemDanh>
#
# <DiemDanh rdf:about="#diemdanh28">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoatDong rdf:resource="#hoatdong37"/>
#   <nguoi rdf:resource="#hocsinh209"/>
#   <ngayGio rdf:datatype="http://www.w3.org/2001/XMLSchema#dateTime">2021-12-22T09:00:00.000</ngayGio>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Trễ</trangThai>
# </DiemDanh>
#
# <DiemDanh rdf:about="#diemdanh29">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoatDong rdf:resource="#hoatdong37"/>
#   <nguoi rdf:resource="#hocsinh188"/>
#   <ngayGio rdf:datatype="http://www.w3.org/2001/XMLSchema#dateTime">2021-12-22T07:00:00.000</ngayGio>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Vắng</trangThai>
# </DiemDanh>
#
# <DiemDanh rdf:about="#diemdanh30">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoatDong rdf:resource="#hoatdong38"/>
#   <nguoi rdf:resource="#hocsinh194"/>
#   <ngayGio rdf:datatype="http://www.w3.org/2001/XMLSchema#dateTime">2021-10-06T07:00:00.000</ngayGio>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Vắng</trangThai>
# </DiemDanh>
#
# <DiemDanh rdf:about="#diemdanh31">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoatDong rdf:resource="#hoatdong38"/>
#   <nguoi rdf:resource="#hocsinh188"/>
#   <ngayGio rdf:datatype="http://www.w3.org/2001/XMLSchema#dateTime">2021-10-06T09:00:00.000</ngayGio>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Trễ</trangThai>
# </DiemDanh>
#
# <DiemDanh rdf:about="#diemdanh32">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoatDong rdf:resource="#hoatdong38"/>
#   <nguoi rdf:resource="#hocsinh217"/>
#   <ngayGio rdf:datatype="http://www.w3.org/2001/XMLSchema#dateTime">2021-10-06T07:00:00.000</ngayGio>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Trễ</trangThai>
# </DiemDanh>
#
# <DiemDanh rdf:about="#diemdanh33">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoatDong rdf:resource="#hoatdong39"/>
#   <nguoi rdf:resource="#hocsinh203"/>
#   <ngayGio rdf:datatype="http://www.w3.org/2001/XMLSchema#dateTime">2021-10-06T07:00:00.000</ngayGio>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Trễ</trangThai>
# </DiemDanh>
#
# <DiemDanh rdf:about="#diemdanh34">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoatDong rdf:resource="#hoatdong39"/>
#   <nguoi rdf:resource="#hocsinh188"/>
#   <ngayGio rdf:datatype="http://www.w3.org/2001/XMLSchema#dateTime">2021-10-06T07:00:00.000</ngayGio>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Trễ</trangThai>
# </DiemDanh>
#
# <DiemDanh rdf:about="#diemdanh35">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoatDong rdf:resource="#hoatdong39"/>
#   <nguoi rdf:resource="#hocsinh194"/>
#   <ngayGio rdf:datatype="http://www.w3.org/2001/XMLSchema#dateTime">2021-10-06T09:00:00.000</ngayGio>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Vắng</trangThai>
# </DiemDanh>
#
# <DiemDanh rdf:about="#diemdanh36">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoatDong rdf:resource="#hoatdong39"/>
#   <nguoi rdf:resource="#hocsinh223"/>
#   <ngayGio rdf:datatype="http://www.w3.org/2001/XMLSchema#dateTime">2021-10-06T08:00:00.000</ngayGio>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đúng giờ</trangThai>
# </DiemDanh>
#
# <DiemDanh rdf:about="#diemdanh37">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoatDong rdf:resource="#hoatdong39"/>
#   <nguoi rdf:resource="#hocsinh184"/>
#   <ngayGio rdf:datatype="http://www.w3.org/2001/XMLSchema#dateTime">2021-10-06T09:00:00.000</ngayGio>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Trễ</trangThai>
# </DiemDanh>
#
# <DiemDanh rdf:about="#diemdanh38">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoatDong rdf:resource="#hoatdong39"/>
#   <nguoi rdf:resource="#hocsinh205"/>
#   <ngayGio rdf:datatype="http://www.w3.org/2001/XMLSchema#dateTime">2021-10-06T09:00:00.000</ngayGio>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đúng giờ</trangThai>
# </DiemDanh>
#
# <DiemDanh rdf:about="#diemdanh39">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoatDong rdf:resource="#hoatdong39"/>
#   <nguoi rdf:resource="#hocsinh190"/>
#   <ngayGio rdf:datatype="http://www.w3.org/2001/XMLSchema#dateTime">2021-10-06T08:00:00.000</ngayGio>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Trễ</trangThai>
# </DiemDanh>
#
# <DiemDanh rdf:about="#diemdanh40">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoatDong rdf:resource="#hoatdong40"/>
#   <nguoi rdf:resource="#hocsinh185"/>
#   <ngayGio rdf:datatype="http://www.w3.org/2001/XMLSchema#dateTime">2021-11-18T07:00:00.000</ngayGio>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Trễ</trangThai>
# </DiemDanh>
#
# <DiemDanh rdf:about="#diemdanh41">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoatDong rdf:resource="#hoatdong40"/>
#   <nguoi rdf:resource="#hocsinh208"/>
#   <ngayGio rdf:datatype="http://www.w3.org/2001/XMLSchema#dateTime">2021-11-18T09:00:00.000</ngayGio>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Trễ</trangThai>
# </DiemDanh>
#
# <DiemDanh rdf:about="#diemdanh42">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoatDong rdf:resource="#hoatdong40"/>
#   <nguoi rdf:resource="#hocsinh198"/>
#   <ngayGio rdf:datatype="http://www.w3.org/2001/XMLSchema#dateTime">2021-11-18T08:00:00.000</ngayGio>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đúng giờ</trangThai>
# </DiemDanh>
#
# <DiemDanh rdf:about="#diemdanh43">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoatDong rdf:resource="#hoatdong40"/>
#   <nguoi rdf:resource="#hocsinh192"/>
#   <ngayGio rdf:datatype="http://www.w3.org/2001/XMLSchema#dateTime">2021-11-18T08:00:00.000</ngayGio>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Trễ</trangThai>
# </DiemDanh>
#
# <DiemDanh rdf:about="#diemdanh44">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoatDong rdf:resource="#hoatdong40"/>
#   <nguoi rdf:resource="#hocsinh212"/>
#   <ngayGio rdf:datatype="http://www.w3.org/2001/XMLSchema#dateTime">2021-11-18T09:00:00.000</ngayGio>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Vắng</trangThai>
# </DiemDanh>
#
# <DiemDanh rdf:about="#diemdanh45">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#NamedIndividual"/>
#   <hoatDong rdf:resource="#hoatdong40"/>
#   <nguoi rdf:resource="#hocsinh207"/>
#   <ngayGio rdf:datatype="http://www.w3.org/2001/XMLSchema#dateTime">2021-11-18T07:00:00.000</ngayGio>
#   <trangThai rdf:datatype="http://www.w3.org/2001/XMLSchema#string">Đúng giờ</trangThai>
# </DiemDanh>
#
#
# </rdf:RDF>

# %%
# Đọc CSDL từ file
onto = get_ontology("../app/data/education.owl").load()

# In DS học sinh ra màn hình
print("Danh sách học sinh:")
stt = 1
for hs in onto.HocSinh.instances():
    print(stt, hs)
    stt += 1

# %%
# In DS giáo viên
print("Danh sách giáo viên:")
for gv in onto.GiaoVien.instances():
    print(gv.hoTen, gv.ngaySinh, gv.gioiTinh, gv.trinhDo, getattr(gv.lopChuNhiem,'ten',''), *[mon.ten for mon in gv.dayMon])

# %%
# In DS HS trong lớp 10A01
print("Danh sách học sinh lớp 10A01:")
for hs in onto.HocSinh.instances():
    if hs.hocLop.ten == "10A01":
        print(hs)

# %%
# in ds GV chủ nhiệm của từng lớp
print("Danh sách giáo viên chủ nhiệm:")
for lop in onto.LopHoc.instances():
    gv = lop.giaoVienChuNhiem
    if gv:
        print(gv.hoTen, gv.ngaySinh, gv.gioiTinh, gv.trinhDo, getattr(gv.lopChuNhiem,'ten',''))

# %%
# Sửa tên của giáo viên chủ nhiệm Nguyễn Văn X thành Nguyễn Văn Tèo
print("Sửa tên của giáo viên chủ nhiệm Nguyễn Văn X thành Nguyễn Văn Tèo")
for gv in onto.GiaoVien.instances():
    if gv.hoTen == "Nguyễn Văn X":
        gv.hoTen = "Nguyễn Văn Tèo"
        print(gv.hoTen, gv.ngaySinh, gv.gioiTinh, gv.trinhDo, getattr(gv.lopChuNhiem,'ten',''))

# %%
# Tạo mới một học sinh và thêm vào lớp 10A01
print("Tạo mới một học sinh và thêm vào lớp 10C01")
lop = onto.search_one(ten = "10C01", type = onto.LopHoc)
hs1 = HocSinh(hoTen = "Nguyễn Văn XXX", ngaySinh = "01/01/2011", gioiTinh = "Nam", hocLop = lop)
# In DS HS trong lớp 10A01
print("Danh sách học sinh lớp 10A01:")
print('\n'.join(str(hs) for hs in lop.dsHocSinh))

# %%
# Xoá học sinh có ngày sinh là 01/01/2011
print("Xoá học sinh có ngày sinh là 01/01/2011")
hs_ind = onto.search_one(ngaySinh="01/01/2011", type=onto.HocSinh)
# Nếu individual được tìm thấy, xoá individual đó
if hs_ind is not None:
    destroy_entity(hs_ind)

# %%
# In tất cả điểm số của một học sinh
print("In tất cả điểm số của một học sinh")
hs_ind = onto.search_one(type=onto.HocSinh)
if hs_ind is not None:
    for diem in hs_ind.diemSo:
        print(diem.monHoc.ten, *diem.heSo1, *diem.heSo2, *diem.heSo3)

# %%
print(hoTen.iri)
print(HocSinh.iri)

# %%
print('In ra các lớp mà GV dạy')
gv = onto.search_one(type = onto.GiaoVien)
for gd in gv.giangDay:
    print(gd.lopHoc.ten, gd.monHoc.ten)

# %%
print('In các GV dạy lớp 10C03')
lop = onto.search_one(type = onto.LopHoc, ten = '10C03')
gd = onto.search(type = onto.GiangDay, lopHoc = lop)
for g in gd:
    print(g.giaoVien.hoTen, g.monHoc.ten, g.lopHoc.ten)

# %%
print('- Liệt kê ban giám hiệu')
BGH = onto.search_one(type = onto.ToChuc, ten = 'Ban giám hiệu')
for nv in BGH.thanhVien:
    print(nv.hoTen, nv.chucVu[0].ten, nv.chucVu[0].phuCap)
print('- Liệt kê tổ Văn phòng')
VP = onto.search_one(type = onto.ToChuc, ten = 'Văn phòng')
for nv in VP.thanhVien:
    print(nv.hoTen, nv.chucVu[0].ten, nv.chucVu[0].phuCap)

# %%
print('Liệt kê các tổ trưởng và tổ phó của các tổ chuyên môn')
toChuyenMon = [x for x in onto.search(type = onto.ToChuc) if x.name.startswith('To')]
for tc in toChuyenMon:
    print(tc.ten)
    for nv in tc.thanhVien:
        print('   -', nv.hoTen, nv.chucVu[0].ten, nv.chucVu[0].phuCap, nv.dayMon)

# %%
print('Liệt kê các phòng kèm tổ chức sử dụng')
for p in onto.Phong.instances():
    print(p.ten, end = ' ')
    for tc in p.suDungBoi:
        print('-', tc.ten, end = ' ')
    print()

# %%
print('Liệt kê sách trong thư viện')
for sach in onto.Sach.instances():
    print(sach.ten, [tl.ten for tl in sach.theLoai], sach.tacGia.ten, sach.nhaXuatBan.ten, sach.giaTien)

# %%
print('Liệt kê các hoạt động')
for hd in onto.HoatDong.instances():
    print(hd.ten, hd.ngayBatDau, hd.ngayKetThuc,[gv.hoTen for gv in hd.quanLy], [ng.hoTen for ng in hd.thamGia])

# %%
print('Liệt kê các HS điểm danh ở 1 hoạt động')
hd = onto.search(type = onto.HoatDong)[4]
dd = onto.search(type = onto.DiemDanh, hoatDong = hd)
for d in dd:
    print(d.nguoi.hoTen, d.ngayGio, d.trangThai)

# %%
print('Liệt kê các đối tượng chưa có dữ liệu trong CSDL')
for x in onto.classes():
    if len(x.instances()) == 0:
        print(x.name)
