# %% [markdown]
# ### Cài đặt thư viện:
#
# Cài đặt các thư viện vào môi trường anaconda:
#
# ```bash
# conda install -c conda-forge owlready2
# ```

# %% [markdown]
# ### Tạo ontology

# %%
# %run ../app/models/model.py

# %%
# Lưu CSDL ra file
onto.save(file="../app/data/education.owl")
with open("../app/data/education.owl", "r") as f:
    print(f.read())
# Out:
# <?xml version="1.0"?>
# <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#"
#          xmlns:xsd="http://www.w3.org/2001/XMLSchema#"
#          xmlns:rdfs="http://www.w3.org/2000/01/rdf-schema#"
#          xmlns:owl="http://www.w3.org/2002/07/owl#"
#          xml:base="http://hc.com/school"
#          xmlns="http://hc.com/school#">
#
# <owl:Ontology rdf:about="http://hc.com/school"/>
#
# <owl:ObjectProperty rdf:about="#thanhVien">
#   <rdfs:domain rdf:resource="#ToChuc"/>
#   <rdfs:range rdf:resource="#Nguoi"/>
#   <owl:inverseOf rdf:resource="#toChuc"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#phong">
#   <rdfs:domain rdf:resource="#ToChuc"/>
#   <rdfs:range rdf:resource="#Phong"/>
#   <owl:inverseOf rdf:resource="#suDungBoi"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#toChuc">
#   <rdfs:domain rdf:resource="#Nguoi"/>
#   <rdfs:range rdf:resource="#ToChuc"/>
#   <owl:inverseOf rdf:resource="#thanhVien"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#chucVu">
#   <rdfs:domain rdf:resource="#NhanVien"/>
#   <rdfs:range rdf:resource="#ChucVu"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#con">
#   <rdfs:domain rdf:resource="#PhuHuynh"/>
#   <rdfs:range rdf:resource="#HocSinh"/>
#   <owl:inverseOf rdf:resource="#phuHuynh"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#giaoVienChuNhiem">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#LopHoc"/>
#   <rdfs:range rdf:resource="#GiaoVien"/>
#   <owl:inverseOf rdf:resource="#lopChuNhiem"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#phongHoc">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#LopHoc"/>
#   <rdfs:range rdf:resource="#Phong"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#dsHocSinh">
#   <rdfs:domain rdf:resource="#LopHoc"/>
#   <rdfs:range rdf:resource="#HocSinh"/>
#   <owl:inverseOf rdf:resource="#hocLop"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#hocLop">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#LopHoc"/>
#   <owl:inverseOf rdf:resource="#dsHocSinh"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#phuHuynh">
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#PhuHuynh"/>
#   <owl:inverseOf rdf:resource="#con"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#diemSo">
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#DiemSo"/>
#   <owl:inverseOf rdf:resource="#hocSinh"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#dayMon">
#   <rdfs:domain rdf:resource="#GiaoVien"/>
#   <rdfs:range rdf:resource="#MonHoc"/>
#   <owl:inverseOf rdf:resource="#giaoVienDay"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#giangDay">
#   <rdfs:domain rdf:resource="#GiaoVien"/>
#   <rdfs:range rdf:resource="#GiangDay"/>
#   <owl:inverseOf rdf:resource="#giaoVien"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#lopChuNhiem">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#GiaoVien"/>
#   <rdfs:range rdf:resource="#LopHoc"/>
#   <owl:inverseOf rdf:resource="#giaoVienChuNhiem"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#giaoVienDay">
#   <rdfs:domain rdf:resource="#MonHoc"/>
#   <rdfs:range rdf:resource="#GiaoVien"/>
#   <owl:inverseOf rdf:resource="#dayMon"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#hocSinh">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="#HocSinh"/>
#   <owl:inverseOf rdf:resource="#diemSo"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#monHoc">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="#MonHoc"/>
#   <rdfs:domain rdf:resource="#GiangDay"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#giaoVien">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#GiangDay"/>
#   <rdfs:range rdf:resource="#GiaoVien"/>
#   <owl:inverseOf rdf:resource="#giangDay"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#lopHoc">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#GiangDay"/>
#   <rdfs:range rdf:resource="#LopHoc"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#docGia">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DocGia"/>
#   <rdfs:range rdf:resource="#Nguoi"/>
#   <rdfs:domain rdf:resource="#PhieuMuon"/>
#   <rdfs:range rdf:resource="#DocGia"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#sachDaDoc">
#   <rdfs:domain rdf:resource="#DocGia"/>
#   <rdfs:range rdf:resource="#Sach"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#dsSach">
#   <rdfs:domain rdf:resource="#TacGia"/>
#   <rdfs:range rdf:resource="#Sach"/>
#   <rdfs:domain rdf:resource="#NhaXuatBan"/>
#   <rdfs:domain rdf:resource="#TheLoai"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#tacGia">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Sach"/>
#   <rdfs:range rdf:resource="#TacGia"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#nhaXuatBan">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Sach"/>
#   <rdfs:range rdf:resource="#NhaXuatBan"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#theLoai">
#   <rdfs:domain rdf:resource="#Sach"/>
#   <rdfs:range rdf:resource="#TheLoai"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#sachMuon">
#   <rdfs:domain rdf:resource="#PhieuMuon"/>
#   <rdfs:range rdf:resource="#Sach"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#suDungBoi">
#   <rdfs:domain rdf:resource="#Phong"/>
#   <rdfs:range rdf:resource="#ToChuc"/>
#   <owl:inverseOf rdf:resource="#phong"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#quanLy">
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:range rdf:resource="#Nguoi"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#thamGia">
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:range rdf:resource="#Nguoi"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#nguoi">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemDanh"/>
#   <rdfs:range rdf:resource="#Nguoi"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#hoatDong">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemDanh"/>
#   <rdfs:range rdf:resource="#HoatDong"/>
# </owl:ObjectProperty>
#
# <owl:DatatypeProperty rdf:about="#ten">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#ChucVu"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
#   <rdfs:domain rdf:resource="#ToChuc"/>
#   <rdfs:domain rdf:resource="#MonHoc"/>
#   <rdfs:domain rdf:resource="#TacGia"/>
#   <rdfs:domain rdf:resource="#NhaXuatBan"/>
#   <rdfs:domain rdf:resource="#Sach"/>
#   <rdfs:domain rdf:resource="#TheLoai"/>
#   <rdfs:domain rdf:resource="#Phong"/>
#   <rdfs:domain rdf:resource="#HoatDong"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#phuCap">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#ChucVu"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#hoTen">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Nguoi"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngaySinh">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Nguoi"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#gioiTinh">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Nguoi"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#heSoLuong">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#NhanVien"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngheNghiep">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#PhuHuynh"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#trinhDo">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#GiaoVien"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#soTiet">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#MonHoc"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#integer"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#heSo1">
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#heSo2">
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#heSo3">
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayCap">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DocGia"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayHetHan">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DocGia"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#giaTien">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Sach"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#integer"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#soLuong">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Sach"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#integer"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayMuon">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#PhieuMuon"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayTra">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#PhieuMuon"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayBatDau">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayKetThuc">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayGio">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemDanh"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#dateTime"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#trangThai">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemDanh"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:Class rdf:about="#ChucVu">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#ToChuc">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#Nguoi">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#NhanVien">
#   <rdfs:subClassOf rdf:resource="#Nguoi"/>
# </owl:Class>
#
# <owl:Class rdf:about="#PhuHuynh">
#   <rdfs:subClassOf rdf:resource="#Nguoi"/>
# </owl:Class>
#
# <owl:Class rdf:about="#LopHoc">
#   <rdfs:subClassOf rdf:resource="#ToChuc"/>
# </owl:Class>
#
# <owl:Class rdf:about="#HocSinh">
#   <rdfs:subClassOf rdf:resource="#Nguoi"/>
# </owl:Class>
#
# <owl:Class rdf:about="#GiaoVien">
#   <rdfs:subClassOf rdf:resource="#NhanVien"/>
# </owl:Class>
#
# <owl:Class rdf:about="#MonHoc">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#DiemSo">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#GiangDay">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#DocGia">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#TacGia">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#NhaXuatBan">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#Sach">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#TheLoai">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#PhieuMuon">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#Phong">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#HoatDong">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#DiemDanh">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
#
# </rdf:RDF>

# %%
lsPro = list(onto.properties())
def get_properties(obj):
    return [p for p in lsPro if obj.is_a[0] in p.domain] + [p for p in lsPro if obj in p.domain]
print('Liệt kê toàn bộ các đối tượng trong ontology')
lsClass= list(onto.classes())
for i, class_ in zip(range(len(lsClass)), lsClass):
    # print(class_.name, '[', ', '.join([x.name for x in get_properties(class_)]), ']')
    print(str(i+1)+'.', class_.name, 'kế thừa từ', class_.is_a)
    for x in get_properties(class_) :
        print('-', x.name, ':', x.range)
# Out:
# Liệt kê toàn bộ các đối tượng trong ontology
# 1. ChucVu kế thừa từ [owl.Thing]
# - ten : [<class 'str'>, <class 'str'>, <class 'str'>]
# - phuCap : [<class 'float'>, <class 'float'>, <class 'float'>]
# 2. ToChuc kế thừa từ [owl.Thing]
# - ten : [<class 'str'>, <class 'str'>, <class 'str'>]
# - thanhVien : [school.Nguoi, school.Nguoi, school.Nguoi]
# - phong : [school.Phong, school.Phong, school.Phong]
# 3. Nguoi kế thừa từ [owl.Thing]
# - hoTen : [<class 'str'>, <class 'str'>, <class 'str'>]
# - ngaySinh : [<class 'datetime.date'>, <class 'datetime.date'>, <class 'datetime.date'>]
# - gioiTinh : [<class 'str'>, <class 'str'>, <class 'str'>]
# - toChuc : [school.ToChuc, school.ToChuc, school.ToChuc]
# 4. NhanVien kế thừa từ [school.Nguoi]
# - hoTen : [<class 'str'>, <class 'str'>, <class 'str'>]
# - ngaySinh : [<class 'datetime.date'>, <class 'datetime.date'>, <class 'datetime.date'>]
# - gioiTinh : [<class 'str'>, <class 'str'>, <class 'str'>]
# - toChuc : [school.ToChuc, school.ToChuc, school.ToChuc]
# - heSoLuong : [<class 'float'>, <class 'float'>, <class 'float'>]
# - chucVu : [school.ChucVu, school.ChucVu, school.ChucVu]
# 5. PhuHuynh kế thừa từ [school.Nguoi]
# - hoTen : [<class 'str'>, <class 'str'>, <class 'str'>]
# - ngaySinh : [<class 'datetime.date'>, <class 'datetime.date'>, <class 'datetime.date'>]
# - gioiTinh : [<class 'str'>, <class 'str'>, <class 'str'>]
# - toChuc : [school.ToChuc, school.ToChuc, school.ToChuc]
# - ngheNghiep : [<class 'str'>, <class 'str'>, <class 'str'>]
# - con : [school.HocSinh, school.HocSinh, school.HocSinh]
# 6. LopHoc kế thừa từ [school.ToChuc]
# - ten : [<class 'str'>, <class 'str'>, <class 'str'>]
# - thanhVien : [school.Nguoi, school.Nguoi, school.Nguoi]
# - phong : [school.Phong, school.Phong, school.Phong]
# - giaoVienChuNhiem : [school.GiaoVien, school.GiaoVien, school.GiaoVien]
# - phongHoc : [school.Phong, school.Phong, school.Phong]
# - dsHocSinh : [school.HocSinh, school.HocSinh, school.HocSinh]
# 7. HocSinh kế thừa từ [school.Nguoi]
# - hoTen : [<class 'str'>, <class 'str'>, <class 'str'>]
# - ngaySinh : [<class 'datetime.date'>, <class 'datetime.date'>, <class 'datetime.date'>]
# - gioiTinh : [<class 'str'>, <class 'str'>, <class 'str'>]
# - toChuc : [school.ToChuc, school.ToChuc, school.ToChuc]
# - hocLop : [school.LopHoc, school.LopHoc, school.LopHoc]
# - phuHuynh : [school.PhuHuynh, school.PhuHuynh, school.PhuHuynh]
# - diemSo : [school.DiemSo, school.DiemSo, school.DiemSo]
# 8. GiaoVien kế thừa từ [school.NhanVien]
# - heSoLuong : [<class 'float'>, <class 'float'>, <class 'float'>]
# - chucVu : [school.ChucVu, school.ChucVu, school.ChucVu]
# - trinhDo : [<class 'str'>, <class 'str'>, <class 'str'>]
# - dayMon : [school.MonHoc, school.MonHoc, school.MonHoc]
# - giangDay : [school.GiangDay, school.GiangDay, school.GiangDay]
# - lopChuNhiem : [school.LopHoc, school.LopHoc, school.LopHoc]
# 9. MonHoc kế thừa từ [owl.Thing]
# - ten : [<class 'str'>, <class 'str'>, <class 'str'>]
# - soTiet : [<class 'int'>, <class 'int'>, <class 'int'>]
# - giaoVienDay : [school.GiaoVien, school.GiaoVien, school.GiaoVien]
# 10. DiemSo kế thừa từ [owl.Thing]
# - heSo1 : [<class 'float'>, <class 'float'>, <class 'float'>]
# - heSo2 : [<class 'float'>, <class 'float'>, <class 'float'>]
# - heSo3 : [<class 'float'>, <class 'float'>, <class 'float'>]
# - hocSinh : [school.HocSinh, school.HocSinh, school.HocSinh]
# - monHoc : [school.MonHoc, school.MonHoc, school.MonHoc]
# 11. GiangDay kế thừa từ [owl.Thing]
# - monHoc : [school.MonHoc, school.MonHoc, school.MonHoc]
# - giaoVien : [school.GiaoVien, school.GiaoVien, school.GiaoVien]
# - lopHoc : [school.LopHoc, school.LopHoc, school.LopHoc]
# 12. DocGia kế thừa từ [owl.Thing]
# - ngayCap : [<class 'datetime.date'>, <class 'datetime.date'>, <class 'datetime.date'>]
# - ngayHetHan : [<class 'datetime.date'>, <class 'datetime.date'>, <class 'datetime.date'>]
# - docGia : [school.Nguoi, school.DocGia, school.Nguoi, school.DocGia, school.DocGia]
# - sachDaDoc : [school.Sach, school.Sach, school.Sach]
# 13. TacGia kế thừa từ [owl.Thing]
# - ten : [<class 'str'>, <class 'str'>, <class 'str'>]
# - dsSach : [school.Sach, school.Sach, school.Sach]
# 14. NhaXuatBan kế thừa từ [owl.Thing]
# - ten : [<class 'str'>, <class 'str'>, <class 'str'>]
# - dsSach : [school.Sach, school.Sach, school.Sach]
# 15. Sach kế thừa từ [owl.Thing]
# - ten : [<class 'str'>, <class 'str'>, <class 'str'>]
# - giaTien : [<class 'int'>, <class 'int'>, <class 'int'>]
# - soLuong : [<class 'int'>, <class 'int'>, <class 'int'>]
# - tacGia : [school.TacGia, school.TacGia, school.TacGia]
# - nhaXuatBan : [school.NhaXuatBan, school.NhaXuatBan, school.NhaXuatBan]
# - theLoai : [school.TheLoai, school.TheLoai, school.TheLoai]
# 16. TheLoai kế thừa từ [owl.Thing]
# - ten : [<class 'str'>, <class 'str'>, <class 'str'>]
# - dsSach : [school.Sach, school.Sach, school.Sach]
# 17. PhieuMuon kế thừa từ [owl.Thing]
# - ngayMuon : [<class 'datetime.date'>, <class 'datetime.date'>, <class 'datetime.date'>]
# - ngayTra : [<class 'datetime.date'>, <class 'datetime.date'>, <class 'datetime.date'>]
# - docGia : [school.Nguoi, school.DocGia, school.Nguoi, school.DocGia, school.DocGia]
# - sachMuon : [school.Sach, school.Sach, school.Sach]
# 18. Phong kế thừa từ [owl.Thing]
# - ten : [<class 'str'>, <class 'str'>, <class 'str'>]
# - suDungBoi : [school.ToChuc, school.ToChuc, school.ToChuc]
# 19. HoatDong kế thừa từ [owl.Thing]
# - ten : [<class 'str'>, <class 'str'>, <class 'str'>]
# - ngayBatDau : [<class 'datetime.date'>, <class 'datetime.date'>, <class 'datetime.date'>]
# - ngayKetThuc : [<class 'datetime.date'>, <class 'datetime.date'>, <class 'datetime.date'>]
# - quanLy : [school.Nguoi, school.Nguoi, school.Nguoi]
# - thamGia : [school.Nguoi, school.Nguoi, school.Nguoi]
# 20. DiemDanh kế thừa từ [owl.Thing]
# - ngayGio : [<class 'datetime.datetime'>, <class 'datetime.datetime'>, <class 'datetime.datetime'>]
# - trangThai : [<class 'str'>, <class 'str'>, <class 'str'>]
# - nguoi : [school.Nguoi, school.Nguoi, school.Nguoi]
# - hoatDong : [school.HoatDong, school.HoatDong, school.HoatDong]

# %% [markdown]
# ### Thêm dữ liệu

# %%
# Đọc CSDL từ file
onto = get_ontology("../app/data/education.owl").load()

# %%
import random
from datetime import datetime, timedelta

def createRandomDate(start_year, end_year):
    return createRandomFromDate(f'01/01/{start_year}', f'31/12/{end_year}')
def createRandomFromDate(start, end): #01/01/2022
    start_date = datetime(year=int(start[6:]), month=int(start[3:5]), day=int(start[:2]))
    end_date = datetime(year=int(end[6:]), month=int(end[3:5]), day=int(end[:2]))
    days_in_range = (end_date - start_date).days + 1
    random_days = random.randint(0, days_in_range - 1)
    birth_date = start_date + timedelta(days=random_days)
    return birth_date.strftime('%d/%m/%Y')

def createRandomInfo():
    ho = random.choice(["Nguyễn", "Trần", "Lê", "Phạm", "Hoàng", "Huỳnh", "Phan", "Vũ", "Võ", "Đặng", "Bùi", "Đỗ", "Hồ", "Ngô", "Dương", "Lý", "Lương", "Mai", "Trương", "Tạ", "Đào", 
                            "Đoàn", "Đinh", "Lâm", "Phùng", "Đoàn", "Bành", "Quách", "Thái", "Tô", "Tôn", "Tăng"])
    lot = random.choice(['Văn', 'Thị', 'Hồng', 'Anh', 'Quý', 'Bảo', "Thanh", "Thu", "Hữu", "Mai", "Đình", "Hoài", "Ngọc", "Minh", "Kim"])
    ten = random.choice(["An", "Bình", "Cường", "Dũng", "Hải", "Hiền", "Hoàng", "Hùng", "Khánh", "Linh", "Long", "Minh", "Nam", "Ngọc", "Nhật", "Phương", "Quân", "Quang", "Quỳnh", 
                            "Sơn", "Thảo", "Thiên", "Thiện", "Thúy", "Thuận", "Tùng", "Tú", "Tường", "Việt", "Vân", "Vinh", "Xuân"])
    gioiTinh = random.choice(["Nam", "Nữ", "Khác"])
    return f"{ho} {lot} {ten}", gioiTinh
def randScore():
    score = random.randint(0, 10)
    if score != 10:
        score += random.choice([0.3, 0.5, 0.8])
    return score

def getClassName(soLopMoiKhoi, index):
    khoi = index // soLopMoiKhoi
    lop = index % soLopMoiKhoi + 1
    tenLop = f'{khoi+10}{"CBA"[khoi]}'
    if lop < 10:
        return f'{tenLop}0{lop}'
    else:
        return f'{tenLop}{lop}'

# %%
soLopMoiKhoi = 3
tongSoLop = soLopMoiKhoi * 3
soHSMoiLop = 5
soHSCoAnhEm = 20
dsLop, dsHS = [], []
for i in range(tongSoLop):
    lop = LopHoc(ten = getClassName(soLopMoiKhoi, i))
    dsLop.append(lop)
    # Tạo ngẫu nhiên HS cho mỗi lớp
    for j in range(soHSMoiLop):
        ten, gt = createRandomInfo()
        hs = HocSinh(hoTen = ten, ngaySinh = createRandomDate(2000, 2000), gioiTinh = gt, hocLop = lop)
        dsHS.append(hs)
        # Tạo ngẫu nhiên 2 PH cho mỗi HS
        for k in range(2):
            ten, gt = createRandomInfo()
            nghe = random.choice(["Nông dân", "Công nhân", "Giáo viên", "Bác sĩ", "Kỹ sư", "Nhân viên văn phòng", "Chủ doanh nghiệp"])
            ph = PhuHuynh(hoTen = ten, ngaySinh = createRandomDate(1970, 1980), gioiTinh = gt, con = [hs], ngheNghiep = nghe)
       

# Cho một số học sinh có chung phụ huynh
random_items = random.sample(dsHS, soHSCoAnhEm)
remaining_items = list(set(dsHS) - set(random_items))
new_random_items = random.sample(remaining_items, soHSCoAnhEm)
for hs, i in zip(random_items, range(soHSCoAnhEm)):
    for ph in hs.phuHuynh: destroy_entity(ph)
    hs.phuHuynh = []
    for ph in new_random_items[i].phuHuynh: 
        ph.con.append(hs)
        hs.phuHuynh.append(ph)

# %%
soGVMoiMon = 3
soGVDay2Mon = 5
dsGV, dsMonHoc, dsToChuc, dsChucVu, dsPhong  = [], [], [], [], []
# Tạo chức vụ tổ trưởng, tổ phó
toTruong = ChucVu('cvToTruong', ten = 'Tổ trưởng', phuCap = 0.2)
dsChucVu.append(toTruong)
toPho = ChucVu('cvToPho', ten = 'Tổ phó', phuCap = 0.15)
dsChucVu.append(toPho)
giaoVien = ChucVu('cvGiaoVien', ten = 'Giáo viên', phuCap = 0)
dsChucVu.append(giaoVien)
# Tạo môn học
dataMonHoc = [('Toan', 'Toán học', 5), ('NguVan', 'Ngữ văn', 3), ('HoaHoc', 'Hóa học', 3), ('LichSu', 'Lịch sử', 3), ('DiaLy', 'Địa lý', 5), 
                ('SinhHoc', 'Sinh học', 2), ('TiengAnh', 'Tiếng Anh', 2), ('GDCD', 'GDCD', 3), ('CongNghe', 'Công nghệ', 2), ('TheDuc', 'Thể dục', 2)]
for id, mon, st in dataMonHoc:
    mon_hoc = MonHoc(id, ten = mon, soTiet = st)
    dsMonHoc.append(mon_hoc)
    phong = Phong('Phong' + id, ten = 'Phòng ' + mon)
    dsPhong.append(phong)
    toChuyenMon = ToChuc('To' + id, ten = 'Tổ '+ mon, phong = [phong]) 
    dsToChuc.append(toChuyenMon)
    # Tạo ngẫu nhiên GV cho mỗi môn
    for j in range(soGVMoiMon):
        ten, gt = createRandomInfo()
        td = ['Đại học', 'Thạc sĩ'][random.randint(0,1)]
        gv = GiaoVien(hoTen = ten, ngaySinh = createRandomDate(1970, 1990), gioiTinh = gt, trinhDo = td, dayMon = [mon_hoc], toChuc = [toChuyenMon], heSoLuong = random.uniform(1, 9))
        if j == 0: gv.chucVu = [toTruong, giaoVien]
        elif j == 1: gv.chucVu = [toPho, giaoVien]   
        else: gv.chucVu = [giaoVien]         
        dsGV.append(gv)
    # Tạo điểm số cho từng HS
    for hs in dsHS:
        diem = DiemSo(hocSinh = hs, monHoc = mon_hoc, 
                        heSo1 = [randScore(),randScore(),randScore()], 
                        heSo2 = [randScore(),randScore()], 
                        heSo3 = [randScore()])
# Chọn ngẫu nhiên các giáo viên làm tổ trưởng, tổ phó
# Cho một số GV dạy 2 môn
gvKhongChucVu = [gv for gv in dsGV if len(gv.chucVu) == 1]
for gv in random.sample(gvKhongChucVu, soGVDay2Mon):
    monChuaDay = [mon for mon in dsMonHoc if mon not in gv.dayMon]
    mon = random.choice(monChuaDay)
    gv.dayMon.append(mon)
    to = [to for to in dsToChuc if mon.ten in to.ten][0]
    gv.toChuc.append(to)

# Gán GVCN cho từng lớp
dsGVCN = random.sample(dsGV, tongSoLop)
for i in range(tongSoLop):
    dsGVCN[i].lopChuNhiem = dsLop[i]

# Phân công giáo viên dạy môn học
for mon in dsMonHoc:
    dsGVDayMon = [gv for gv in dsGV if mon in gv.dayMon]
    soLopMoiGV = len(dsLop) // len(dsGVDayMon)
    index = 0
    for gv in dsGVDayMon:
        for i in range(soLopMoiGV):
            tenLop = getClassName(soLopMoiKhoi, index)
            lop = [l for l in dsLop if l.ten == tenLop][0]
            gd = GiangDay(giaoVien = gv, monHoc = mon, lopHoc = lop)
            index += 1
    # Phân công giáo viên dạy môn học cho lớp còn lại
    for i in range(index, tongSoLop):
        tenLop = getClassName(soLopMoiKhoi, i)
        lop = [l for l in dsLop if l.ten == tenLop][0]
        gv = random.choice(dsGVDayMon)
        gd = GiangDay(giaoVien = gv, monHoc = mon, lopHoc = lop)

# %%
dsNV = []
dataNhanVien = [('BGH', 'Ban giám hiệu', 'Hiệu trưởng', 0.7, 1), ('BGH', 'Ban giám hiệu', 'Phó hiệu Trưởng', 0.5, 2), 
                ('VP', 'Văn phòng', 'Bảo vệ', 0, 3), ('VP', 'Văn phòng', 'Phục vụ', 0, 2), ('VP', 'Văn phòng', 'Văn thư', 0.3, 1), ('VP', 'Văn phòng', 'Thủ quỹ', 0.3, 1), 
                ('VP', 'Văn phòng', 'Kế toán', 0.5, 1), ('VP', 'Văn phòng', 'Thư viện', 0, 1), ('VP', 'Văn phòng', 'Thiết bị', 0.25, 2)]
for id, toChuc, chucVu, phuCap, soNV in dataNhanVien:
    if id not in [tc.name for tc in dsToChuc]:
        tc = ToChuc(id, ten = toChuc)
        dsToChuc.append(tc)
    else:
        tc = [tc for tc in dsToChuc if tc.name == id][0]
    if chucVu not in [cv.ten for cv in dsChucVu]:
        cv = ChucVu(ten = chucVu, phuCap = phuCap)
        dsChucVu.append(cv)
    else:
        cv = [cv for cv in dsChucVu if cv.toChuc == tc and cv.ten == chucVu][0]
    for i in range(soNV):
        ten, gt = createRandomInfo()
        nv = NhanVien(hoTen = ten, ngaySinh = createRandomDate(1960, 1995), gioiTinh = gt, toChuc = [tc], chucVu = [cv], heSoLuong = random.uniform(1, 9))
        dsNV.append(nv)
# Cho kế toán làm tổ trưởng và văn thư làm tổ phó
nv = [nv for nv in dsNV if nv.chucVu[0].ten == 'Kế toán'][0]
nv.chucVu.append(toTruong)
nv = [nv for nv in dsNV if nv.chucVu[0].ten == 'Văn thư'][0]
nv.chucVu.append(toPho)

# %%
soDocGia = 10
soSach = 15
soTacGia = 5
soNXB = 3 
# Tạo ngẫu nhiên tác giả
dsTacGia = []
for i in range(soTacGia):
    tg = TacGia(ten = f'Tác giả {i+1}')
    dsTacGia.append(tg)

# Tạo ngẫu nhiên NXB
dsNXB = []
for i in range(soNXB):
    nxb = NhaXuatBan(ten = f'NXB {i+1}')
    dsNXB.append(nxb)
# Tạo ngẫu nhiên thể loại sách
dsTheLoai = []
dsTenTheLoai = ["SGK", "Sách bài tập", "Tài liệu tham khảo", "Truyện tranh"]
for theLoai in dsTenTheLoai:
    tl = TheLoai(ten = theLoai)
    dsTheLoai.append(tl)
# Tạo ngẫu nhiên sách
dsSach = []
dsTenMonHoc = [mon.ten for mon in dsMonHoc]
for i in range(soSach):
    ten = random.choice(dsTenTheLoai) + ' ' + random.choice(dsTenMonHoc)
    sach = Sach(ten = ten, tacGia = random.choice(dsTacGia), nhaXuatBan = random.choice(dsNXB), theLoai = random.choices(dsTheLoai,k=random.randint(1,2)), namXuatBan = random.randint(1920, 2021), giaTien = random.randint(1, 200)*1000)
    dsSach.append(sach)

# Tạo ngẫu nhiên đọc giả
dsDocGia = []
dsMuonSach=[]
nguoi = random.sample(dsGV+dsHS+dsNV, soDocGia)
for i in range(soDocGia):
    ten, gt = createRandomInfo()
    docGia = DocGia(docGia = nguoi[i], ngayCap = createRandomDate(2022, 2023), ngayHetHan = createRandomDate(2024, 2025))
    dsDocGia.append(docGia)
    # Tạo ngẫu nhiên mượn sách
    soSachMuon = random.randint(1, 5)
    for j in range(soSachMuon):
        sach = random.choice(dsSach)
        muon = PhieuMuon(docGia = docGia, sachMuon = random.choices(dsSach, k=random.randint(1,3)), ngayMuon = createRandomFromDate('05/09/2021', '31/12/2021'), ngayTra = createRandomFromDate('01/01/2022', '15/05/2022'))
        dsMuonSach.append(muon)

# %%
dsTenHoatDong = ['Học tập', 'Thể thao', 'Văn hóa', 'Nghệ thuật', 'Tình nguyện', 'Khoa học', 'Kỹ năng sống', 'Ngoại khóa']
dsHoatDong = []
for ten in dsTenHoatDong:
    hd = HoatDong(ten = ten, ngayBatDau = createRandomFromDate('05/09/2021', '31/12/2021'), ngayKetThuc = createRandomFromDate('01/01/2022', '15/05/2022'),
                  quanLy = random.choices(dsGV, k= random.randint(1, 3)),
                  thamGia = random.choices(dsHS, k= random.randint(2, 10)))
    dsHoatDong.append(hd)

# %%
dsDiemDanh = []
for hd in dsHoatDong:
    for hs in hd.thamGia:
        diemDanh = DiemDanh(hoatDong = hd, nguoi = hs, ngayDiemDanh = random.choice([hd.ngayBatDau, hd.ngayKetThuc]))
        dsDiemDanh.append(diemDanh)

# %%
# Lưu CSDL ra file
onto.save(file="../app/data/education.owl", format='rdfxml') # 'ntriples' / "rdfxml"
with open("../app/data/education.owl", "r") as f:
    print(f.read())
# Out:
# <?xml version="1.0"?>
# <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#"
#          xmlns:xsd="http://www.w3.org/2001/XMLSchema#"
#          xmlns:rdfs="http://www.w3.org/2000/01/rdf-schema#"
#          xmlns:owl="http://www.w3.org/2002/07/owl#"
#          xml:base="http://hc.com/school"
#          xmlns="http://hc.com/school#">
#
# <owl:Ontology rdf:about="http://hc.com/school"/>
#
# <owl:ObjectProperty rdf:about="#thanhVien">
#   <rdfs:domain rdf:resource="#ToChuc"/>
#   <rdfs:range rdf:resource="#Nguoi"/>
#   <owl:inverseOf rdf:resource="#toChuc"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#phong">
#   <rdfs:domain rdf:resource="#ToChuc"/>
#   <rdfs:range rdf:resource="#Phong"/>
#   <owl:inverseOf rdf:resource="#suDungBoi"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#toChuc">
#   <rdfs:domain rdf:resource="#Nguoi"/>
#   <rdfs:range rdf:resource="#ToChuc"/>
#   <owl:inverseOf rdf:resource="#thanhVien"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#chucVu">
#   <rdfs:domain rdf:resource="#NhanVien"/>
#   <rdfs:range rdf:resource="#ChucVu"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#con">
#   <rdfs:domain rdf:resource="#PhuHuynh"/>
#   <rdfs:range rdf:resource="#HocSinh"/>
#   <owl:inverseOf rdf:resource="#phuHuynh"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#giaoVienChuNhiem">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#LopHoc"/>
#   <rdfs:range rdf:resource="#GiaoVien"/>
#   <owl:inverseOf rdf:resource="#lopChuNhiem"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#phongHoc">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#LopHoc"/>
#   <rdfs:range rdf:resource="#Phong"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#dsHocSinh">
#   <rdfs:domain rdf:resource="#LopHoc"/>
#   <rdfs:range rdf:resource="#HocSinh"/>
#   <owl:inverseOf rdf:resource="#hocLop"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#hocLop">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#LopHoc"/>
#   <owl:inverseOf rdf:resource="#dsHocSinh"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#phuHuynh">
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#PhuHuynh"/>
#   <owl:inverseOf rdf:resource="#con"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#diemSo">
#   <rdfs:domain rdf:resource="#HocSinh"/>
#   <rdfs:range rdf:resource="#DiemSo"/>
#   <owl:inverseOf rdf:resource="#hocSinh"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#dayMon">
#   <rdfs:domain rdf:resource="#GiaoVien"/>
#   <rdfs:range rdf:resource="#MonHoc"/>
#   <owl:inverseOf rdf:resource="#giaoVienDay"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#giangDay">
#   <rdfs:domain rdf:resource="#GiaoVien"/>
#   <rdfs:range rdf:resource="#GiangDay"/>
#   <owl:inverseOf rdf:resource="#giaoVien"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#lopChuNhiem">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#GiaoVien"/>
#   <rdfs:range rdf:resource="#LopHoc"/>
#   <owl:inverseOf rdf:resource="#giaoVienChuNhiem"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#giaoVienDay">
#   <rdfs:domain rdf:resource="#MonHoc"/>
#   <rdfs:range rdf:resource="#GiaoVien"/>
#   <owl:inverseOf rdf:resource="#dayMon"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#hocSinh">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="#HocSinh"/>
#   <owl:inverseOf rdf:resource="#diemSo"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#monHoc">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="#MonHoc"/>
#   <rdfs:domain rdf:resource="#GiangDay"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#giaoVien">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#GiangDay"/>
#   <rdfs:range rdf:resource="#GiaoVien"/>
#   <owl:inverseOf rdf:resource="#giangDay"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#lopHoc">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#GiangDay"/>
#   <rdfs:range rdf:resource="#LopHoc"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#docGia">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DocGia"/>
#   <rdfs:range rdf:resource="#Nguoi"/>
#   <rdfs:domain rdf:resource="#PhieuMuon"/>
#   <rdfs:range rdf:resource="#DocGia"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#sachDaDoc">
#   <rdfs:domain rdf:resource="#DocGia"/>
#   <rdfs:range rdf:resource="#Sach"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#dsSach">
#   <rdfs:domain rdf:resource="#TacGia"/>
#   <rdfs:range rdf:resource="#Sach"/>
#   <rdfs:domain rdf:resource="#NhaXuatBan"/>
#   <rdfs:domain rdf:resource="#TheLoai"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#tacGia">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Sach"/>
#   <rdfs:range rdf:resource="#TacGia"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#nhaXuatBan">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Sach"/>
#   <rdfs:range rdf:resource="#NhaXuatBan"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#theLoai">
#   <rdfs:domain rdf:resource="#Sach"/>
#   <rdfs:range rdf:resource="#TheLoai"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#sachMuon">
#   <rdfs:domain rdf:resource="#PhieuMuon"/>
#   <rdfs:range rdf:resource="#Sach"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#suDungBoi">
#   <rdfs:domain rdf:resource="#Phong"/>
#   <rdfs:range rdf:resource="#ToChuc"/>
#   <owl:inverseOf rdf:resource="#phong"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#quanLy">
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:range rdf:resource="#Nguoi"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#thamGia">
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:range rdf:resource="#Nguoi"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#nguoi">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemDanh"/>
#   <rdfs:range rdf:resource="#Nguoi"/>
# </owl:ObjectProperty>
#
# <owl:ObjectProperty rdf:about="#hoatDong">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemDanh"/>
#   <rdfs:range rdf:resource="#HoatDong"/>
# </owl:ObjectProperty>
#
# <owl:DatatypeProperty rdf:about="#ten">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#ChucVu"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
#   <rdfs:domain rdf:resource="#ToChuc"/>
#   <rdfs:domain rdf:resource="#MonHoc"/>
#   <rdfs:domain rdf:resource="#TacGia"/>
#   <rdfs:domain rdf:resource="#NhaXuatBan"/>
#   <rdfs:domain rdf:resource="#Sach"/>
#   <rdfs:domain rdf:resource="#TheLoai"/>
#   <rdfs:domain rdf:resource="#Phong"/>
#   <rdfs:domain rdf:resource="#HoatDong"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#phuCap">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#ChucVu"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#hoTen">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Nguoi"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngaySinh">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Nguoi"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#gioiTinh">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Nguoi"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#heSoLuong">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#NhanVien"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngheNghiep">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#PhuHuynh"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#trinhDo">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#GiaoVien"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#soTiet">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#MonHoc"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#integer"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#heSo1">
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#heSo2">
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#heSo3">
#   <rdfs:domain rdf:resource="#DiemSo"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#decimal"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayCap">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DocGia"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayHetHan">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DocGia"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#giaTien">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Sach"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#integer"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#soLuong">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#Sach"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#integer"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayMuon">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#PhieuMuon"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayTra">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#PhieuMuon"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayBatDau">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayKetThuc">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#HoatDong"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#date"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#ngayGio">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemDanh"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#dateTime"/>
# </owl:DatatypeProperty>
#
# <owl:DatatypeProperty rdf:about="#trangThai">
#   <rdf:type rdf:resource="http://www.w3.org/2002/07/owl#FunctionalProperty"/>
#   <rdfs:domain rdf:resource="#DiemDanh"/>
#   <rdfs:range rdf:resource="http://www.w3.org/2001/XMLSchema#string"/>
# </owl:DatatypeProperty>
#
# <owl:Class rdf:about="#ChucVu">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#ToChuc">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#Nguoi">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#NhanVien">
#   <rdfs:subClassOf rdf:resource="#Nguoi"/>
# </owl:Class>
#
# <owl:Class rdf:about="#PhuHuynh">
#   <rdfs:subClassOf rdf:resource="#Nguoi"/>
# </owl:Class>
#
# <owl:Class rdf:about="#LopHoc">
#   <rdfs:subClassOf rdf:resource="#ToChuc"/>
# </owl:Class>
#
# <owl:Class rdf:about="#HocSinh">
#   <rdfs:subClassOf rdf:resource="#Nguoi"/>
# </owl:Class>
#
# <owl:Class rdf:about="#GiaoVien">
#   <rdfs:subClassOf rdf:resource="#NhanVien"/>
# </owl:Class>
#
# <owl:Class rdf:about="#MonHoc">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#DiemSo">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#GiangDay">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#DocGia">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#TacGia">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#NhaXuatBan">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#Sach">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#TheLoai">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#PhieuMuon">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#Phong">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#HoatDong">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
# <owl:Class rdf:about="#DiemDanh">
#   <rdfs:subClassOf rdf:resource="http://www.w3.org/2002/07/owl#Thing"/>
# </owl:Class>
#
#
# </rdf:RDF>

# %%
# Đọc CSDL từ file
onto = get_ontology("../app/data/education.owl").load()

# In DS học sinh ra màn hình
print("Danh sách học sinh:")
stt = 1
for hs in onto.HocSinh.instances():
    print(stt, hs)
    stt += 1
# Out:
# Danh sách học sinh:
# 1 Lâm Ngọc Thiện - 05/09/2000 - Khác - 10C01
# 2 Đỗ Hồng Nhật - 11/04/2000 - Khác - 10C01
# 3 Tăng Quý Cường - 27/10/2000 - Nam - 10C01
# 4 Hồ Hồng Quân - 17/04/2000 - Khác - 10C01
# 5 Hồ Thị An - 30/10/2000 - Nữ - 10C01
# 6 Phạm Thu Hùng - 02/04/2000 - Nữ - 10C02
# 7 Bùi Bảo Sơn - 05/05/2000 - Nam - 10C02
# 8 Phan Kim Tùng - 19/09/2000 - Khác - 10C02
# 9 Đinh Thị Phương - 31/01/2000 - Nam - 10C02
# 10 Lý Bảo An - 03/02/2000 - Nữ - 10C02
# 11 Lý Hồng Thảo - 08/07/2000 - Nữ - 10C03
# 12 Đỗ Thu Thuận - 28/03/2000 - Nữ - 10C03
# 13 Phan Thanh Hải - 11/09/2000 - Nam - 10C03
# 14 Tôn Đình Vinh - 07/03/2000 - Nam - 10C03
# 15 Đào Hoài Vân - 09/04/2000 - Khác - 10C03
# 16 Tăng Thị Linh - 20/12/2000 - Nam - 11B01
# 17 Ngô Ngọc Thiên - 17/09/2000 - Khác - 11B01
# 18 Đào Minh Xuân - 30/11/2000 - Nam - 11B01
# 19 Bành Văn Sơn - 26/05/2000 - Khác - 11B01
# 20 Quách Văn Linh - 02/08/2000 - Khác - 11B01
# 21 Vũ Quý Cường - 09/12/2000 - Nữ - 11B02
# In DS HS trong lớp 10A01
print("Danh sách học sinh lớp 10A01:")
for hs in onto.HocSinh.instances():
    if hs.hocLop.ten == "10A01":
        print(hs)
# Out:
# Danh sách học sinh lớp 10A01:

# %%
# in ds GV chủ nhiệm của từng lớp
print("Danh sách giáo viên chủ nhiệm:")
for lop in onto.LopHoc.instances():
    gv = lop.giaoVienChuNhiem
    if gv:
        print(gv.hoTen, gv.ngaySinh, gv.gioiTinh, gv.trinhDo, getattr(gv.lopChuNhiem,'ten',''))
# Out:
# Danh sách giáo viên chủ nhiệm:
# Hoàng Minh Thiên 28/11/1974 Khác Thạc sĩ 10C01
# Đỗ Minh Hoàng 15/10/1988 Nữ Đại học 10C02
# Bùi Thị Thiên 08/10/1985 Nam Thạc sĩ 10C03
# Quách Hoài Thúy 13/09/1972 Khác Thạc sĩ 11B01
# Đào Quý Thiên 27/04/1988 Nam Đại học 11B02
# Đỗ Quý Vân 24/01/1974 Khác Thạc sĩ 11B03
# Bùi Thanh Xuân 30/07/1988 Nam Thạc sĩ 12A01
# Dương Hồng Vinh 21/07/1981 Khác Đại học 12A02
# Đoàn Hồng Dũng 30/10/1973 Khác Đại học 12A03
# Huỳnh Thị Thiện 21/11/1980 Nữ Thạc sĩ 10C01
# Phạm Thu Thiên 18/05/1974 Nữ Đại học 10C02
# Tô Thị Tú 29/05/1970 Khác Đại học 10C03
# Phùng Quý Phương 10/02/1974 Khác Thạc sĩ 11B01
# Quách Ngọc Thuận 12/02/1981 Nam Đại học 11B02
# Lê Thị Quỳnh 06/12/1974 Nam Đại học 11B03
# Võ Ngọc Nam 17/12/1978 Nam Đại học 12A01
# Bành Quý An 18/02/1978 Khác Đại học 12A02
# Mai Thanh Nam 14/05/1971 Khác Thạc sĩ 12A03

# %%
# Sửa tên của giáo viên chủ nhiệm Nguyễn Văn X thành Nguyễn Văn Tèo
print("Sửa tên của giáo viên chủ nhiệm Nguyễn Văn X thành Nguyễn Văn Tèo")
for gv in onto.GiaoVien.instances():
    if gv.hoTen == "Nguyễn Văn X":
        gv.hoTen = "Nguyễn Văn Tèo"
        print(gv.hoTen, gv.ngaySinh, gv.gioiTinh, gv.trinhDo, getattr(gv.lopChuNhiem,'ten',''))
# Out:
# Sửa tên của giáo viên chủ nhiệm Nguyễn Văn X thành Nguyễn Văn Tèo

# %%
# Tạo mới một học sinh và thêm vào lớp 10A01
print("Tạo mới một học sinh và thêm vào lớp 10C01")
lop = onto.search_one(ten = "10C01", type = onto.LopHoc)
hs1 = HocSinh(hoTen = "Nguyễn Văn XXX", ngaySinh = "01/01/2011", gioiTinh = "Nam", hocLop = lop)
# In DS HS trong lớp 10A01
print("Danh sách học sinh lớp 10A01:")
print('\n'.join(str(hs) for hs in lop.dsHocSinh))
# Out:
# Tạo mới một học sinh và thêm vào lớp 10C01
# Danh sách học sinh lớp 10A01:
# Lâm Ngọc Thiện - 05/09/2000 - Khác - 10C01
# Đỗ Hồng Nhật - 11/04/2000 - Khác - 10C01
# Tăng Quý Cường - 27/10/2000 - Nam - 10C01
# Hồ Hồng Quân - 17/04/2000 - Khác - 10C01
# Hồ Thị An - 30/10/2000 - Nữ - 10C01
# Nguyễn Văn XXX - 01/01/2011 - Nam - 10C01

# %%
# Xoá học sinh có ngày sinh là 01/01/2011
print("Xoá học sinh có ngày sinh là 01/01/2011")
hs_ind = onto.search_one(ngaySinh="01/01/2011", type=onto.HocSinh)
# Nếu individual được tìm thấy, xoá individual đó
if hs_ind is not None:
    destroy_entity(hs_ind)
# Out:
# Xoá học sinh có ngày sinh là 01/01/2011

# %%
# In tất cả điểm số của một học sinh
print("In tất cả điểm số của một học sinh")
hs_ind = onto.search_one(type=onto.HocSinh)
if hs_ind is not None:
    for diem in hs_ind.diemSo:
        print(diem.monHoc.ten, *diem.heSo1, *diem.heSo2, *diem.heSo3)
# Out:
# In tất cả điểm số của một học sinh
# Toán học 4.3 1.5 9.5 8.8 5.8 1.5
# Ngữ văn 7.8 1.8 10 0.8 1.8 8.3
# Hóa học 1.3 3.5 10 5.3 7.3 0.8
# Lịch sử 1.3 7.8 4.5 8.5 5.5 2.3
# Địa lý 2.5 5.3 6.8 1.3 1.5 7.8
# Sinh học 10 5.3 4.3 0.5 3.5 10
# Tiếng Anh 10 3.3 9.3 10 3.8 10
# GDCD 0.3 5.8 4.5 2.8 7.3
# Công nghệ 2.3 9.3 4.3 8.3 6.5 0.3
# Thể dục 9.8 8.5 8.3 8.3 3.8 1.3

# %%
print(hoTen.iri)
print(HocSinh.iri)
# Out:
# http://hc.com/school#hoTen
# http://hc.com/school#HocSinh

# %%
print('In ra các lớp mà GV dạy')
gv = onto.search_one(type = onto.GiaoVien)
for gd in gv.giangDay:
    print(gd.lopHoc.ten, gd.monHoc.ten)
# Out:
# In ra các lớp mà GV dạy
# 10C01 Toán học

# %%
print('In các GV dạy lớp 10C03')
lop = onto.search_one(type = onto.LopHoc, ten = '10C03')
gd = onto.search(type = onto.GiangDay, lopHoc = lop)
for g in gd:
    print(g.giaoVien.hoTen, g.monHoc.ten, g.lopHoc.ten)
# Out:
# In các GV dạy lớp 10C03
# Đỗ Hữu Hùng Toán học 10C03
# Đào Quý Thiên Ngữ văn 10C03
# Bành Anh Quân Hóa học 10C03
# Bành Thu Nhật Lịch sử 10C03
# Đoàn Mai An Địa lý 10C03
# Đào Thu Cường Sinh học 10C03
# Bùi Thanh Xuân Tiếng Anh 10C03
# Hồ Anh Dũng GDCD 10C03
# Thái Hữu Hiền Công nghệ 10C03
# Đoàn Quý Hoàng Thể dục 10C03

# %%
print('- Liệt kê ban giám hiệu')
BGH = onto.search_one(type = onto.ToChuc, ten = 'Ban giám hiệu')
for nv in BGH.thanhVien:
    print(nv.hoTen, nv.chucVu[0].ten, nv.chucVu[0].phuCap)
print('- Liệt kê tổ Văn phòng')
VP = onto.search_one(type = onto.ToChuc, ten = 'Văn phòng')
for nv in VP.thanhVien:
    print(nv.hoTen, nv.chucVu[0].ten, nv.chucVu[0].phuCap)
# Out:
# - Liệt kê ban giám hiệu
# Đặng Mai Tú Hiệu trưởng 0.7
# Vũ Văn Bình Phó hiệu Trưởng 0.5
# Tôn Thu Bình Phó hiệu Trưởng 0.5
# Đoàn Đình Quang Hiệu trưởng 0.7
# Lê Hoài Ngọc Phó hiệu Trưởng 0.5
# Phan Đình Bình Phó hiệu Trưởng 0.5
# - Liệt kê tổ Văn phòng
# Đào Văn Minh Bảo vệ 0
# Đào Thị Thảo Bảo vệ 0
# Đào Hồng Xuân Bảo vệ 0
# Mai Hữu Tường Phục vụ 0
# Trần Ngọc Việt Phục vụ 0
# Đặng Thu Thảo Văn thư 0.3
# Đoàn Đình Hùng Thủ quỹ 0.3
# Phùng Quý Minh Kế toán 0.5
# Võ Đình Khánh Thư viện 0
# Đỗ Thanh Hùng Thiết bị 0.25
# Đinh Hoài Ngọc Thiết bị 0.25
# Ngô Hoài Nam Bảo vệ 0
# Phùng Văn Vân Bảo vệ 0
# Lê Hữu An Bảo vệ 0
# Tô Minh Tùng Phục vụ 0
# Đặng Ngọc Xuân Phục vụ 0
# Lâm Thị Việt Văn thư 0.3
# Lý Kim Linh Thủ quỹ 0.3
# Hoàng Thanh Sơn Kế toán 0.5
# Dương Anh Khánh Thư viện 0
# Lê Hữu Thuận Thiết bị 0.25
# Lương Đình Thuận Thiết bị 0.25

# %%
print('Liệt kê các tổ trưởng và tổ phó của các tổ chuyên môn')
toChuyenMon = [x for x in onto.search(type = onto.ToChuc) if x.name.startswith('To')]
for tc in toChuyenMon:
    print(tc.ten)
    for nv in tc.thanhVien:
        print('   -', nv.hoTen, nv.chucVu[0].ten, nv.chucVu[0].phuCap, nv.dayMon)
# Out:
# Liệt kê các tổ trưởng và tổ phó của các tổ chuyên môn
# Tổ Toán học
#    - Thái Thanh Phương Tổ trưởng 0.2 [school.Toan]
#    - Lý Thanh Sơn Tổ phó 0.15 [school.Toan]
#    - Đỗ Hữu Hùng Giáo viên 0 [school.Toan]
#    - Tạ Anh Long Giáo viên 0 [school.HoaHoc, school.Toan]
#    - Ngô Văn Cường Giáo viên 0 [school.SinhHoc, school.Toan]
#    - Huỳnh Thị Thiện Tổ trưởng 0.2 [school.Toan]
#    - Lâm Hữu Xuân Tổ phó 0.15 [school.Toan]
#    - Lê Thị Quỳnh Giáo viên 0 [school.Toan, school.SinhHoc]
#    - Trương Văn Ngọc Giáo viên 0 [school.NguVan, school.Toan]
# Tổ Ngữ văn
#    - Đào Quý Thiên Tổ trưởng 0.2 [school.NguVan]
#    - Lương Hoài Xuân Tổ phó 0.15 [school.NguVan]
#    - Quách Hoài Thúy Giáo viên 0 [school.NguVan]
#    - Bùi Hữu Minh Tổ trưởng 0.2 [school.NguVan]
#    - Lâm Văn Nhật Tổ phó 0.15 [school.NguVan]
#    - Trương Văn Ngọc Giáo viên 0 [school.NguVan, school.Toan]
# Tổ Hóa học
#    - Bành Anh Quân Tổ trưởng 0.2 [school.HoaHoc]
#    - Đỗ Quý Tường Tổ phó 0.15 [school.HoaHoc]
#    - Tạ Anh Long Giáo viên 0 [school.HoaHoc, school.Toan]
#    - Đinh Thanh Hoàng Tổ trưởng 0.2 [school.HoaHoc]
#    - Võ Hồng Quỳnh Tổ phó 0.15 [school.HoaHoc]
#    - Tô Thị Tú Giáo viên 0 [school.HoaHoc]
#    - Bành Hồng Quỳnh Giáo viên 0 [school.LichSu, school.HoaHoc]
# Tổ Lịch sử
#    - Bành Thu Nhật Tổ trưởng 0.2 [school.LichSu]
#    - Huỳnh Thu Hải Tổ phó 0.15 [school.LichSu]
#    - Phạm Thị Thiện Giáo viên 0 [school.LichSu]
#    - Võ Ngọc Nam Tổ trưởng 0.2 [school.LichSu]
#    - Bành Quý An Tổ phó 0.15 [school.LichSu]
#    - Bành Hồng Quỳnh Giáo viên 0 [school.LichSu, school.HoaHoc]
# Tổ Địa lý
#    - Đoàn Mai An Tổ trưởng 0.2 [school.DiaLy]
#    - Hoàng Minh Thiên Tổ phó 0.15 [school.DiaLy]
#    - Đoàn Hồng Dũng Giáo viên 0 [school.DiaLy]
#    - Hồ Kim Vân Tổ trưởng 0.2 [school.DiaLy]
#    - Tăng Minh Thảo Tổ phó 0.15 [school.DiaLy]
#    - Mai Thanh Nam Giáo viên 0 [school.DiaLy]
#    - Lê Thu Khánh Giáo viên 0 [school.TiengAnh, school.DiaLy]
# Tổ Sinh học
#    - Đoàn Thanh Xuân Tổ trưởng 0.2 [school.SinhHoc]
#    - Đào Thu Cường Tổ phó 0.15 [school.SinhHoc]
#    - Ngô Văn Cường Giáo viên 0 [school.SinhHoc, school.Toan]
#    - Ngô Anh Phương Giáo viên 0 [school.TheDuc, school.SinhHoc]
#    - Lê Thị Quỳnh Giáo viên 0 [school.Toan, school.SinhHoc]
#    - Vũ Thu Thiên Tổ trưởng 0.2 [school.SinhHoc]
#    - Phạm Quý Tú Tổ phó 0.15 [school.SinhHoc]
#    - Đinh Thanh Long Giáo viên 0 [school.SinhHoc]
# Tổ Tiếng Anh
#    - Dương Hồng Vinh Tổ trưởng 0.2 [school.TiengAnh]
#    - Bùi Thanh Xuân Tổ phó 0.15 [school.TiengAnh]
#    - Đỗ Quý Vân Giáo viên 0 [school.TiengAnh, school.TheDuc]
#    - Tạ Văn Phương Giáo viên 0 [school.CongNghe, school.TiengAnh]
#    - Tôn Thu Vân Tổ trưởng 0.2 [school.TiengAnh]
#    - Phạm Thu Thiên Tổ phó 0.15 [school.TiengAnh]
#    - Lê Thu Khánh Giáo viên 0 [school.TiengAnh, school.DiaLy]
# Tổ GDCD
#    - Hồ Anh Dũng Tổ trưởng 0.2 [school.GDCD]
#    - Đoàn Đình Hoàng Tổ phó 0.15 [school.GDCD]
#    - Vũ Thanh Tú Giáo viên 0 [school.GDCD]
#    - Phùng Quý Phương Tổ trưởng 0.2 [school.GDCD]
#    - Hoàng Quý Linh Tổ phó 0.15 [school.GDCD]
#    - Đào Kim Vân Giáo viên 0 [school.GDCD]
# Tổ Công nghệ
#    - Thái Hữu Hiền Tổ trưởng 0.2 [school.CongNghe]
#    - Bùi Thị Thiên Tổ phó 0.15 [school.CongNghe]
#    - Tạ Văn Phương Giáo viên 0 [school.CongNghe, school.TiengAnh]
#    - Ngô Mai Long Tổ trưởng 0.2 [school.CongNghe]
#    - Bùi Anh Tường Tổ phó 0.15 [school.CongNghe]
#    - Quách Thu Vân Giáo viên 0 [school.CongNghe, school.TheDuc]
# Tổ Thể dục
#    - Đỗ Quý Vân Giáo viên 0 [school.TiengAnh, school.TheDuc]
#    - Đoàn Quý Hoàng Tổ trưởng 0.2 [school.TheDuc]
#    - Đỗ Minh Hoàng Tổ phó 0.15 [school.TheDuc]
#    - Ngô Anh Phương Giáo viên 0 [school.TheDuc, school.SinhHoc]
#    - Quách Thu Vân Giáo viên 0 [school.CongNghe, school.TheDuc]
#    - Phạm Hồng Thúy Tổ trưởng 0.2 [school.TheDuc]
#    - Trương Ngọc Cường Tổ phó 0.15 [school.TheDuc]
#    - Quách Ngọc Thuận Giáo viên 0 [school.TheDuc]

# %%
print('Liệt kê sách trong thư viện')
for sach in onto.Sach.instances():
    print(sach.ten, [tl.ten for tl in sach.theLoai], sach.tacGia.ten, sach.nhaXuatBan.ten, sach.giaTien)
# Out:
# Liệt kê sách trong thư viện
# Sách bài tập Địa lý ['Tài liệu tham khảo', 'SGK'] Tác giả 4 NXB 3 154000
# SGK Hóa học ['Truyện tranh', 'Tài liệu tham khảo'] Tác giả 5 NXB 1 166000
# Truyện tranh GDCD ['Truyện tranh'] Tác giả 4 NXB 3 44000
# Tài liệu tham khảo Thể dục ['Truyện tranh'] Tác giả 3 NXB 1 43000
# Truyện tranh Địa lý ['Truyện tranh'] Tác giả 2 NXB 3 51000
# SGK Ngữ văn ['Truyện tranh'] Tác giả 2 NXB 1 75000
# SGK Thể dục ['Sách bài tập'] Tác giả 1 NXB 2 111000
# Truyện tranh Địa lý ['Truyện tranh', 'Tài liệu tham khảo'] Tác giả 4 NXB 2 198000
# SGK Ngữ văn ['Truyện tranh'] Tác giả 2 NXB 2 145000
# Sách bài tập Lịch sử ['Sách bài tập'] Tác giả 5 NXB 2 119000
# Truyện tranh Hóa học ['Tài liệu tham khảo'] Tác giả 4 NXB 1 89000
# SGK Sinh học ['SGK'] Tác giả 4 NXB 2 18000
# SGK Ngữ văn ['Tài liệu tham khảo'] Tác giả 4 NXB 2 192000
# SGK GDCD ['SGK', 'Sách bài tập'] Tác giả 3 NXB 3 160000
# SGK Tiếng Anh ['Sách bài tập'] Tác giả 5 NXB 3 89000
# Tài liệu tham khảo Địa lý ['Sách bài tập'] Tác giả 1 NXB 3 72000
# SGK Địa lý ['Tài liệu tham khảo'] Tác giả 1 NXB 3 1000
# Truyện tranh Sinh học ['Tài liệu tham khảo'] Tác giả 4 NXB 1 200000
# Sách bài tập Toán học ['Tài liệu tham khảo', 'Sách bài tập'] Tác giả 3 NXB 1 104000
# SGK Công nghệ ['Truyện tranh'] Tác giả 3 NXB 1 121000
# Tài liệu tham khảo Địa lý ['Truyện tranh', 'Tài liệu tham khảo'] Tác giả 4 NXB 2 135000
# Tài liệu tham khảo Địa lý ['Sách bài tập', 'Truyện tranh'] Tác giả 3 NXB 3 166000
# Sách bài tập Thể dục ['Sách bài tập', 'Tài liệu tham khảo'] Tác giả 3 NXB 3 78000
# Truyện tranh Thể dục ['Truyện tranh', 'Tài liệu tham khảo'] Tác giả 4 NXB 2 65000
# Sách bài tập GDCD ['Sách bài tập'] Tác giả 1 NXB 1 91000
# Sách bài tập Hóa học ['Tài liệu tham khảo', 'SGK'] Tác giả 5 NXB 2 163000
# Truyện tranh Toán học ['SGK'] Tác giả 1 NXB 2 89000
# Truyện tranh Hóa học ['Tài liệu tham khảo', 'Truyện tranh'] Tác giả 3 NXB 3 89000
# Sách bài tập Sinh học ['Sách bài tập'] Tác giả 1 NXB 1 134000
# SGK Địa lý ['Sách bài tập'] Tác giả 4 NXB 2 148000

# %%
print('Liệt kê các hoạt động')
for hd in onto.HoatDong.instances():
    print(hd.ten, hd.ngayBatDau, hd.ngayKetThuc,[gv.hoTen for gv in hd.quanLy], [ng.hoTen for ng in hd.thamGia])
# Out:
# Liệt kê các hoạt động
# Học tập 21/12/2021 24/03/2022 ['Thái Hữu Hiền'] ['Tăng Quý Cường', 'Phạm Văn Quân']
# Thể thao 29/10/2021 05/05/2022 ['Tạ Văn Phương', 'Bành Anh Quân'] ['Tôn Minh Dũng', 'Phan Thanh Hải', 'Thái Văn An']
# Văn hóa 14/09/2021 18/02/2022 ['Bùi Thị Thiên', 'Hồ Anh Dũng', 'Lý Thanh Sơn'] ['Ngô Minh Tường', 'Đoàn Hữu Tường']
# Nghệ thuật 23/09/2021 09/02/2022 ['Đoàn Thanh Xuân', 'Ngô Anh Phương', 'Hồ Anh Dũng'] ['Tăng Quý Cường', 'Đỗ Thu Thuận', 'Phan Quý Nhật']
# Tình nguyện 23/10/2021 08/01/2022 ['Bành Anh Quân'] ['Võ Mai Ngọc', 'Đào Minh Xuân']
# Khoa học 13/10/2021 08/03/2022 ['Thái Thanh Phương', 'Hồ Anh Dũng', 'Đỗ Quý Tường'] ['Tôn Đình Vinh', 'Phan Thanh Hải', 'Thái Văn An']
# Kỹ năng sống 24/11/2021 12/04/2022 ['Đào Quý Thiên', 'Đỗ Hữu Hùng'] ['Đào Minh Xuân', 'Bùi Hữu Phương', 'Hoàng Anh Quỳnh', 'Phạm Văn Quân', 'Võ Ngọc Minh', 'Bùi Mai Xuân']
# Ngoại khóa 15/11/2021 22/01/2022 ['Đỗ Quý Tường'] ['Phạm Văn Quân', 'Tôn Đình Vinh', 'Lý Bảo An']
# Học tập 06/09/2021 19/01/2022 ['Lê Thị Quỳnh', 'Tôn Thu Vân'] ['Phạm Bảo Hùng', 'Đinh Văn Quân', 'Thái Bảo Tú', 'Tạ Hữu Hùng']
# Thể thao 28/10/2021 16/03/2022 ['Mai Thanh Nam', 'Lê Thu Khánh'] ['Hồ Ngọc Xuân', 'Ngô Đình Long', 'Phan Hồng Thiện', 'Đoàn Hữu Phương', 'Tạ Mai Nhật', 'Đoàn Đình Hoàng', 'Lương Hồng Hải']
# Văn hóa 20/11/2021 27/04/2022 ['Bành Quý An', 'Phùng Quý Phương'] ['Hồ Ngọc Xuân', 'Phạm Thanh Minh', 'Đoàn Thanh Dũng', 'Dương Thanh Thúy', 'Tôn Anh Quang', 'Đỗ Thanh Hải']
# Nghệ thuật 23/10/2021 13/05/2022 ['Bùi Hữu Minh', 'Lâm Hữu Xuân', 'Tăng Minh Thảo'] ['Huỳnh Thanh Tú', 'Hồ Ngọc Xuân', 'Tạ Quý Linh', 'Đào Văn Xuân', 'Quách Quý Phương', 'Nguyễn Thị Xuân', 'Bùi Ngọc Thảo', 'Đoàn Đình Hoàng', 'Phạm Anh Thiện']
# Tình nguyện 08/12/2021 02/05/2022 ['Đinh Thanh Hoàng', 'Lâm Văn Nhật', 'Bành Quý An'] ['Đoàn Minh Vân', 'Phạm Bảo Hùng', 'Quách Thị Vinh']
# Khoa học 20/10/2021 05/05/2022 ['Trương Ngọc Cường', 'Ngô Mai Long'] ['Đoàn Ngọc Bình', 'Lý Quý Xuân', 'Thái Bảo Tú', 'Vũ Thu Vinh', 'Tôn Hữu Thúy', 'Đỗ Thanh Hải', 'Hồ Ngọc Xuân']
# Kỹ năng sống 01/11/2021 01/01/2022 ['Bành Hồng Quỳnh', 'Bùi Anh Tường'] ['Vũ Thu Vinh', 'Phan Hồng Thiện', 'Phạm Bảo Hùng', 'Quách Thị Vinh', 'Lý Hoài Khánh']
# Ngoại khóa 30/10/2021 02/02/2022 ['Phạm Hồng Thúy', 'Huỳnh Thị Thiện'] ['Đoàn Ngọc Bình', 'Lương Đình Vân', 'Hồ Kim Linh']

# %%
Liệt kê các

# %%
print('Liệt kê các đối tượng chưa có dữ liệu trong CSDL')
for x in onto.classes():
    if len(x.instances()) == 0:
        print(x.name)
# Out:
# Liệt kê các đối tượng chưa có dữ liệu trong CSDL
